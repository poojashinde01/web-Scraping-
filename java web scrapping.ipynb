# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="https://www.oracle.com/technetwork/java/javase/overview/index.html">
# <span class="css-truncate css-truncate-target" title="www.oracle.com/technetwork/java/javase/overview/index.html">
#           www.oracle.com/technetwork/java/javase/overview/index.html
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/Java_(software_platform)">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/Java_(software_platform)">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'CS-Notes'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'CyC2018'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text
stars
# Out:
# '154k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/CyC2018/CS-Notes'

# %%
base_url='https://github.com/topics/java'

# %%
base_url
# Out:
# 'https://github.com/topics/java'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
Repository_page
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":36260787,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="a2b059518605faece612dfc85daf93e0ee3a1d29ae0b6050b7d82b03298892c4" data-turbo="false" data-view-component="true" href="/CyC2018">
#              CyC2018
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":121395510,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="12308931086804a0fba8bb0d295aa3228368537ad872c610a227c0bb1dfcf678" data-turbo="false" data-view-component="true" href="/CyC2018/CS-Notes">
#              CS-Notes
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":121395510,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="d83c617a7ab88a6d3f405f65ae0222df8e756f83a380e759c31e29ac581a2b38" data-view-component="true" href="/login?return_to=%2FCyC2018%2FCS-Notes" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="153795 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="153,795">154k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":121395510,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="299b13ed9b377da679dcacb97af73a70fdb3fdefea4fb01f94bdabe3808d7256" data-turbo="false" data-view-component="true" href="/CyC2018/CS-Notes" id="code-tab-121395510">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":121395510,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="9c91989d69866f480565aa4449a6c3d3928a136bec0dafd5efffca41596a538d" data-turbo="false" data-view-component="true" href="/CyC2018/CS-Notes/issues" id="issues-tab-121395510">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":121395510,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="e3a06c467f3b7a081bfdb3d88238c006f5c633d5d33f52f5e415424bb965cb55" data-turbo="false" data-view-component="true" href="/CyC2018/CS-Notes/pulls" id="pull-requests-tab-121395510">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>
#  <g-emoji alias="books" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4da.png">📚</g-emoji> 技术面试必备基础知识、Leetcode、计算机操作系统、计算机网络、系统设计</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":84,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="4a809ff5765c8c7f3ce8df46a0b93d09a0f9560123259cb4f5e434f1e723fcba" data-view-component="true" href="/topics/python" title="Topic: python">
#                python
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":160,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="05a735c1b0636caa9f06675199798f76136066cb052a91f72b3648797b7dac97" data-view-component="true" href="/topics/java" title="Topic: java">
#                java
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":369,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="b4558a54d0acc577b79a6e4fa55e545295fd0276b997315803378f4e08fc12d3" data-view-component="true" href="/topics/computer-science" title="Topic: computer-science">
#                computer-science
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":7501,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="1a1ab30ac944cf6789158164579ce88eceb7a1b785a8562933940a8444b7fd2a" data-view-component="true" href="/topics/algorithm" title="Topic: algorithm">
#                algorithm
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9758,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="efd38368a0b6143f02bf2caa6096399182e801d912174dabcdcfa14f23c6b21c" data-view-component="true" href="/topics/leetcode" title="Topic: leetcode">
#                leetcode
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9802,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="ffb7647afc6d8b5811675bd4c88fc8f2f0fa74b637562f45ff4fc5e9c51f86ed" data-view-component="true" href="/topics/cpp" title="Topic: cpp">
#                cpp
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22469,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac

#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>快速、简洁、解决大文件内存溢出的java处理Excel工具</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":160,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="05a735c1b0636caa9f06675199798f76136066cb052a91f72b3648797b7dac97" data-view-component="true" href="/topics/java" title="Topic: java">
#                java
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":13269,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="159057bb2766fa8659fd67387dd9431533ca77665da7424bb73f48c78670ef8c" data-view-component="true" href="/topics/excel" title="Topic: excel">
#                excel
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17743,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="d1eefff169e27ce8691606f185e16dda177d770b85fce064338cee571f367d7e" data-view-component="true" href="/topics/xlsx" title="Topic: xlsx">
#                xlsx
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17753,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="bd977b774ce2fcf630415a92dd8bc8506e89ef86592f49a21d06d73b5006a6d7" data-view-component="true" href="/topics/xls" title="Topic: xls">
#                xls
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":45494,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="76c81e0e4353dd300805c1afa12d69d2acebd104ee1145ab0e535cbac9c482f5" data-view-component="true" href="/topics/poi" title="Topic: poi">
#                poi
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":353992,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="ffc203b3a3d651cf3259c6b49cb433f7a5f9dee0de2f45613ad0056ddc2eebbc" data-view-component="true" href="/topics/oom" title="Topic: oom">
#                oom
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":446369,"originating_url":"https://github.com/topics/java","user_id":null}}' data-hydro-click-hmac="ec5881c0c0c0c9fd7387bdb33434b7b4896edfb6bbd137834a950b8c6d76a16c" data-view-component="true" href="/topics/jxl" title="Topic: jxl">
#                jxl
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-06-30T06:26:51Z">Jun 30, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #b07219"></span>
#  <span itemprop="programmingLanguage">Java</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
base_url='https://github.com/topics/java'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
Repository_1_lst
# Out:
# [{'Repository Name': 'CS-Notes',
#   'User Name': 'CyC2018',
#   'stars': '154k',
#   'Repository URL': 'https://github.com/topics/javaCyC2018/CS-Notes'},
#  {'Repository Name': 'JavaGuide',
#   'User Name': 'Snailclimb',
#   'stars': '124k',
#   'Repository URL': 'https://github.com/topics/javaSnailclimb/JavaGuide'},
#  {'Repository Name': 'java-design-patterns',
#   'User Name': 'iluwatar',
#   'stars': '75.7k',
#   'Repository URL': 'https://github.com/topics/javailuwatar/java-design-patterns'},
#  {'Repository Name': 'advanced-java',
#   'User Name': 'doocs',
#   'stars': '64.2k',
#   'Repository URL': 'https://github.com/topics/javadoocs/advanced-java'},
#  {'Repository Name': 'spring-boot',
#   'User Name': 'spring-projects',
#   'stars': '62k',
#   'Repository URL': 'https://github.com/topics/javaspring-projects/spring-boot'},
#  {'Repository Name': 'elasticsearch',
#   'User Name': 'elastic',
#   'stars': '60.3k',
#   'Repository URL': 'https://github.com/topics/javaelastic/elasticsearch'},
#  {'Repository Name': 'mall',
#   'User Name': 'macrozheng',
#   'stars': '59.5k',
#   'Repository URL': 'https://github.com/topics/javamacrozheng/mall'},
#  {'Repository Name': 'interviews',
#   'User Name': 'kdn251',
#   'stars': '57.6k',
#   'Repository URL': 'https://github.com/topics/javakdn251/interviews'},
#  {'Repository Name': 'leetcode',
#   'User Name': 'azl397985856',
#   'stars': '48.6k',
#   'Repository URL': 'https://github.com/topics/javaazl397985856/leetcode'},
#  {'Repository Name': 'Java',
#   'User Name': 'TheAlgorithms',
#   'stars': '46.7k',
#   'Repository URL': 'https://github.com/topics/javaTheAlgorithms/Java'},
#  {'Repository Name': 'RxJava',
#   'User Name': 'ReactiveX',
#   'stars': '46.2k',
#   'Repository URL': 'https://github.com/topics/javaReactiveX/RxJava'},
#  {'Repository Name': 'guava',
#   'User Name': 'google',
#   'stars': '45k',
#   'Repository URL': 'https://github.com/topics/javagoogle/guava'},
#  {'Repository Name': 'okhttp',
#   'User Name': 'square',
#   'stars': '42.4k',
#   'Repository URL': 'https://github.com/topics/javasquare/okhttp'},
#  {'Repository Name': 'retrofit',
#   'User Name': 'square',
#   'stars': '40.2k',
#   'Repository URL': 'https://github.com/topics/javasquare/retrofit'},
#  {'Repository Name': 'MPAndroidChart',
#   'User Name': 'PhilJay',
#   'stars': '35.3k',
#   'Repository URL': 'https://github.com/topics/javaPhilJay/MPAndroidChart'},
#  {'Repository Name': 'spark',
#   'User Name': 'apache',
#   'stars': '33.3k',
#   'Repository URL': 'https://github.com/topics/javaapache/spark'},
#  {'Repository Name': 'JavaFamily',
#   'User Name': 'AobingJava',
#   'stars': '31.1k',
#   'Repository URL': 'https://github.com/topics/javaAobingJava/JavaFamily'},
#  {'Repository Name': 'jadx',
#   'User Name': 'skylot',
#   'stars': '30.8k',
#   'Repository URL': 'https://github.com/topics/javaskylot/jadx'},
#  {'Repository Name': 'jeecg-boot',
#   'User Name': 'jeecgboot',
#   'stars': '30k',
#   'Repository URL': 'https://github.com/topics/javajeecgboot/jeecg-boot'},
#  {'Repository Name': 'zxing',
#   'User Name': 'zxing',
#   'stars': '29.8k',
#   'Repository URL': 'https://github.com/topics/javazxing/zxing'},
#  {'Repository Name': 'arthas',
#   'User Name': 'alibaba',
#   'stars': '29.5k',
#   'Repository URL': 'https://github.com/topics/javaalibaba/arthas'},
#  {'Repository Name': 'leetcode-master',
#   'User Name': 'youngyangyang04',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/topics/javayoungyangyang04/leetcode-master'},
#  {'Repository Name': 'spring-boot-examples',
#   'User Name': 'ityouknow',
#   'stars': '27.7k',
#   'Repository URL': 'https://github.com/topics/javaityouknow/spring-boot-examples'},
#  {'Repository Name': 'leakcanary',
#   'User Name': 'square',
#   'stars': '27.7k',
#   'Repository URL': 'https://github.com/topics/javasquare/leakcanary'},
#  {'Repository Name': 'dbeaver',
#   'User Name': 'dbeaver',
#   'stars': '27.2k',
#   'Repository URL': 'https://github.com/topics/javadbeaver/dbeaver'},
#  {'Repository Name': 'JCSprout',
#   'User Name': 'crossoverJie',
#   'stars': '26.7k',
#   'Repository URL': 'https://github.com/topics/javacrossoverJie/JCSprout'},
#  {'Repository Name': 'spring-boot-demo',
#   'User Name': 'xkcoding',
#   'stars': '26k',
#   'Repository URL': 'https://github.com/topics/javaxkcoding/spring-boot-demo'},
#  {'Repository Name': 'WxJava',
#   'User Name': 'Wechat-Group',
#   'stars': '25.7k',
#   'Repository URL': 'https://github.com/topics/javaWechat-Group/WxJava'},
#  {'Repository Name': 'fastjson',
#   'User Name': 'alibaba',
#   'stars': '24.8k',
#   'Repository URL': 'https://github.com/topics/javaalibaba/fastjson'},
#  {'Repository Name': 'easyexcel',
#   'User Name': 'alibaba',
#   'stars': '24.1k',
#   'Repository URL': 'https://github.com/topics/javaalibaba/easyexcel'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#          Repository Name        User Name  stars  \
# 0               CS-Notes          CyC2018   154k
# 1              JavaGuide       Snailclimb   124k
# 2   java-design-patterns         iluwatar  75.7k
# 3          advanced-java            doocs  64.2k
# 4            spring-boot  spring-projects    62k
# 5          elasticsearch          elastic  60.3k
# 6                   mall       macrozheng  59.5k
# 7             interviews           kdn251  57.6k
# 8               leetcode     azl397985856  48.6k
# 9                   Java    TheAlgorithms  46.7k
# 10                RxJava        ReactiveX  46.2k
# 11                 guava           google    45k
# 12                okhttp           square  42.4k
# 13              retrofit           square  40.2k
# 14        MPAndroidChart          PhilJay  35.3k
# 15                 spark           apache  33.3k
# 16            JavaFamily       AobingJava  31.1k
# 17                  jadx           skylot  30.8k
# 18            jeecg-boot        jeecgboot    30k
# 19                 zxing            zxing  29.8k
# 20                arthas          alibaba  29.5k
# 21       leetcode-master  youngyangyang04  29.1k
# 22  spring-boot-examples        ityouknow  27.7k
# 23            leakcanary           square  27.7k
# 24               dbeaver          dbeaver  27.2k
# 25              JCSprout     crossoverJie  26.7k
# 26      spring-boot-demo         xkcoding    26k
# 27                WxJava     Wechat-Group  25.7k
# 28              fastjson          alibaba  24.8k
# 29             easyexcel          alibaba  24.1k
#
#                                        Repository URL
# 0      https://github.com/topics/javaCyC2018/CS-Notes
# 1   https://github.com/topics/javaSnailclimb/JavaG...
# 2   https://github.com/topics/javailuwatar/java-de...
# 3   https://github.com/topics/javadoocs/advanced-java
# 4   https://github.com/topics/javaspring-projects/...
# 5   https://github.com/topics/javaelastic/elastics...
# 6       https://github.com/topics/javamacrozheng/mall
# 7     https://github.com/topics/javakdn251/interviews
# 8   https://github.com/topics/javaazl397985856/lee...
# 9    https://github.com/topics/javaTheAlgorithms/Java
# 10     https://github.com/topics/javaReactiveX/RxJava
# 11         https://github.com/topics/javagoogle/guava
# 12        https://github.com/topics/javasquare/okhttp
# 13      https://github.com/topics/javasquare/retrofit
# 14  https://github.com/topics/javaPhilJay/MPAndroi...
# 15         https://github.com/topics/javaapache/spark
# 16  https://github.com/topics/javaAobingJava/JavaF...
# 17          https://github.com/topics/javaskylot/jadx
# 18  https://github.com/topics/javajeecgboot/jeecg-...
# 19          https://github.com/topics/javazxing/zxing
# 20       https://github.com/topics/javaalibaba/arthas
# 21  https://github.com/topics/javayoungyangyang04/...
# 22  https://github.com/topics/javaityouknow/spring...
# 23    https://github.com/topics/javasquare/leakcanary
# 24      https://github.com/topics/javadbeaver/dbeaver
# 25  https://github.com/topics/javacrossoverJie/JCS...
# 26  https://github.com/topics/javaxkcoding/spring-...
# 27  https://github.com/topics/javaWechat-Group/WxJava
# 28     https://github.com/topics/javaalibaba/fastjson
# 29    https://github.com/topics/javaalibaba/easyexcel

# %%
df.to_excel('java.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/java?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/java?page=1',
#  'https://github.com/topics/java?page=2',
#  'https://github.com/topics/java?page=3',
#  'https://github.com/topics/java?page=4',
#  'https://github.com/topics/java?page=5',
#  'https://github.com/topics/java?page=6',
#  'https://github.com/topics/java?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/java?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'CS-Notes',
#   'User Name': 'CyC2018',
#   'stars': '154k',
#   'Repository URL': 'https://github.com/CyC2018/CS-Notes'},
#  {'Sr No': 2,
#   'Repository Name': 'JavaGuide',
#   'User Name': 'Snailclimb',
#   'stars': '124k',
#   'Repository URL': 'https://github.com/Snailclimb/JavaGuide'},
#  {'Sr No': 3,
#   'Repository Name': 'java-design-patterns',
#   'User Name': 'iluwatar',
#   'stars': '75.7k',
#   'Repository URL': 'https://github.com/iluwatar/java-design-patterns'},
#  {'Sr No': 4,
#   'Repository Name': 'advanced-java',
#   'User Name': 'doocs',
#   'stars': '64.2k',
#   'Repository URL': 'https://github.com/doocs/advanced-java'},
#  {'Sr No': 5,
#   'Repository Name': 'spring-boot',
#   'User Name': 'spring-projects',
#   'stars': '62k',
#   'Repository URL': 'https://github.com/spring-projects/spring-boot'},
#  {'Sr No': 6,
#   'Repository Name': 'elasticsearch',
#   'User Name': 'elastic',
#   'stars': '60.3k',
#   'Repository URL': 'https://github.com/elastic/elasticsearch'},
#  {'Sr No': 7,
#   'Repository Name': 'mall',
#   'User Name': 'macrozheng',
#   'stars': '59.5k',
#   'Repository URL': 'https://github.com/macrozheng/mall'},
#  {'Sr No': 8,
#   'Repository Name': 'interviews',
#   'User Name': 'kdn251',
#   'stars': '57.6k',
#   'Repository URL': 'https://github.com/kdn251/interviews'},
#  {'Sr No': 9,
#   'Repository Name': 'leetcode',
#   'User Name': 'azl397985856',
#   'stars': '48.6k',
#   'Repository URL': 'https://github.com/azl397985856/leetcode'},
#  {'Sr No': 10,
#   'Repository Name': 'Java',
#   'User Name': 'TheAlgorithms',
#   'stars': '46.7k',
#   'Repository URL': 'https://github.com/TheAlgorithms/Java'},
#  {'Sr No': 11,
#   'Repository Name': 'RxJava',
#   'User Name': 'ReactiveX',
#   'stars': '46.2k',
#   'Repository URL': 'https://github.com/ReactiveX/RxJava'},
#  {'Sr No': 12,
#   'Repository Name': 'guava',
#   'User Name': 'google',
#   'stars': '45k',
#   'Repository URL': 'https://github.com/google/guava'},
#  {'Sr No': 13,
#   'Repository Name': 'okhttp',
#   'User Name': 'square',
#   'stars': '42.4k',
#   'Repository URL': 'https://github.com/square/okhttp'},
#  {'Sr No': 14,
#   'Repository Name': 'retrofit',
#   'User Name': 'square',
#   'stars': '40.2k',
#   'Repository URL': 'https://github.com/square/retrofit'},
#  {'Sr No': 15,
#   'Repository Name': 'MPAndroidChart',
#   'User Name': 'PhilJay',
#   'stars': '35.3k',
#   'Repository URL': 'https://github.com/PhilJay/MPAndroidChart'},
#  {'Sr No': 16,
#   'Repository Name': 'spark',
#   'User Name': 'apache',
#   'stars': '33.3k',
#   'Repository URL': 'https://github.com/apache/spark'},
#  {'Sr No': 17,
#   'Repository Name': 'JavaFamily',
#   'User Name': 'AobingJava',
#   'stars': '31.1k',
#   'Repository URL': 'https://github.com/AobingJava/JavaFamily'},
#  {'Sr No': 18,
#   'Repository Name': 'jadx',
#   'User Name': 'skylot',
#   'stars': '30.8k',
#   'Repository URL': 'https://github.com/skylot/jadx'},
#  {'Sr No': 19,
#   'Repository Name': 'jeecg-boot',
#   'User Name': 'jeecgboot',
#   'stars': '30k',
#   'Repository URL': 'https://github.com/jeecgboot/jeecg-boot'},
#  {'Sr No': 20,
#   'Repository Name': 'zxing',
#   'User Name': 'zxing',
#   'stars': '29.8k',
#   'Repository URL': 'https://github.com/zxing/zxing'},
#  {'Sr No': 21,
#   'Repository Name': 'arthas',
#   'User Name': 'alibaba',
#   'stars': '29.5k',
#   'Repository URL': 'https://github.com/alibaba/arthas'},
#  {'Sr No': 22,
#   'Repository Name': 'leetcode-master',
#   'User Name': 'youngyangyang04',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/youngyangyang04/leetcode-master'},
#  {'Sr No': 23,
#   'Repository Name': 'spring-boot-examples',
#   'User Name': 'ityouknow',
#   'stars': '27.7k',
#   'Repository URL': 'https://github.com/ityouknow/spring-boot-examples'},
#  {'Sr No': 24,
#   'Repository Name': 'leakcanary',
#   'User Name': 'square',
#   'stars': '27.7k',
#   'Repository URL': 'https://github.com/square/leakcanary'},
#  {'Sr No': 25,
#   'Repository Name': 'dbeaver',
#   'User Name': 'dbeaver',
#   'stars': '27.2k',
#   'Repository URL': 'https://github.com/dbeaver/dbeaver'},
#  {'Sr No': 26,
#   'Repository Name': 'JCSprout',
#   'User Name': 'crossoverJie',
#   'stars': '26.7k',
#   'Repository URL': 'https://github.com/crossoverJie/JCSprout'},
#  {'Sr No': 27,
#   'Repository Name': 'spring-boot-demo',
#   'User Name': 'xkcoding',
#   'stars': '26k',
#   'Repository URL': 'https://github.com/xkcoding/spring-boot-demo'},
#  {'Sr No': 28,
#   'Repository Name': 'WxJava',
#   'User Name': 'Wechat-Group',
#   'stars': '25.7k',
#   'Repository URL': 'https://github.com/Wechat-Group/WxJava'},
#  {'Sr No': 29,
#   'Repository Name': 'fastjson',
#   'User Name': 'alibaba',
#   'stars': '24.8k',
#   'Repository URL': 'https://github.com/alibaba/fastjson'},
#  {'Sr No': 30,
#   'Repository Name': 'easyexcel',
#   'User Name': 'alibaba',
#   'stars': '24.1k',
#   'Repository URL': 'https://github.com/alibaba/easyexcel'},
#  {'Sr No': 31,
#   'Repository Name': 'selenium',
#   'User Name': 'SeleniumHQ',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/SeleniumHQ/selenium'},
#  {'Sr No': 32,
#   'Repository Name': 'toBeTopJavaer',
#   'User Name': 'hollischuang',
#   'stars': '23.4k',
#   'Repository URL': 'https://github.com/hollischuang/toBeTopJavaer'},
#  {'Sr No': 33,
#   'Repository Name': 'hutool',
#   'User Name': 'dromara',
#   'stars': '23.2k',
#   'Repository URL': 'https://github.com/dromara/hutool'},
#  {'Sr No': 34,
#   'Repository Name': 'spring-cloud-alibaba',
#   'User Name': 'alibaba',
#   'stars': '22.9k',
#   'Repository URL': 'https://github.com/alibaba/spring-cloud-alibaba'},
#  {'Sr No': 35,
#   'Repository Name': 'xxl-job',
#   'User Name': 'xuxueli',
#   'stars': '21.9k',
#   'Repository URL': 'https://github.com/xuxueli/xxl-job'},
#  {'Sr No': 36,
#   'Repository Name': 'NativeScript',
#   'User Name': 'NativeScript',
#   'stars': '21.4k',
#   'Repository URL': 'https://github.com/NativeScript/NativeScript'},
#  {'Sr No': 37,
#   'Repository Name': 'ray',
#   'User Name': 'ray-project',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/ray-project/ray'},
#  {'Sr No': 38,
#   'Repository Name': 'libgdx',
#   'User Name': 'libgdx',
#   'stars': '20.2k',
#   'Repository URL': 'https://github.com/libgdx/libgdx'},
#  {'Sr No': 39,
#   'Repository Name': 'IntelliJ-IDEA-Tutorial',
#   'User Name': 'judasn',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/judasn/IntelliJ-IDEA-Tutorial'},
#  {'Sr No': 40,
#   'Repository Name': 'generator-jhipster',
#   'User Name': 'jhipster',
#   'stars': '19.7k',
#   'Repository URL': 'https://github.com/jhipster/generator-jhipster'},
#  {'Sr No': 41,
#   'Repository Name': 'ExoPlayer',
#   'User Name': 'google',
#   'stars': '19.5k',
#   'Repository URL': 'https://github.com/google/ExoPlayer'},
#  {'Sr No': 42,
#   'Repository Name': 'appsmith',
#   'User Name': 'appsmithorg',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/appsmithorg/appsmith'},
#  {'Sr No': 43,
#   'Repository Name': 'Sentinel',
#   'User Name': 'alibaba',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/alibaba/Sentinel'},
#  {'Sr No': 44,
#   'Repository Name': 'redisson',
#   'User Name': 'redisson',
#   'stars': '19.3k',
#   'Repository URL': 'https://github.com/redisson/redisson'},
#  {'Sr No': 45,
#   'Repository Name': 'flink',
#   'User Name': 'apache',
#   'stars': '19.3k',
#   'Repository URL': 'https://github.com/apache/flink'},
#  {'Sr No': 46,
#   'Repository Name': 'jenkins',
#   'User Name': 'jenkinsci',
#   'stars': '19.1k',
#   'Repository URL': 'https://github.com/jenkinsci/jenkins'},
#  {'Sr No': 47,
#   'Repository Name': 'flatbuffers',
#   'User Name': 'google',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/google/flatbuffers'},
#  {'Sr No': 48,
#   'Repository Name': 'mybatis-3',
#   'User Name': 'mybatis',
#   'stars': '17.4k',
#   'Repository URL': 'https://github.com/mybatis/mybatis-3'},
#  {'Sr No': 49,
#   'Repository Name': 'graal',
#   'User Name': 'oracle',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/oracle/graal'},
#  {'Sr No': 50,
#   'Repository Name': 'CNTK',
#   'User Name': 'microsoft',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/microsoft/CNTK'},
#  {'Sr No': 51,
#   'Repository Name': 'HikariCP',
#   'User Name': 'brettwooldridge',
#   'stars': '16.9k',
#   'Repository URL': 'https://github.com/brettwooldridge/HikariCP'},
#  {'Sr No': 52,
#   'Repository Name': 'cat',
#   'User Name': 'dianping',
#   'stars': '16.9k',
#   'Repository URL': 'https://github.com/dianping/cat'},
#  {'Sr No': 53,
#   'Repository Name': 'java8-tutorial',
#   'User Name': 'winterbe',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/winterbe/java8-tutorial'},
#  {'Sr No': 54,
#   'Repository Name': 'GitHubDaily',
#   'User Name': 'GitHubDaily',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/GitHubDaily/GitHubDaily'},
#  {'Sr No': 55,
#   'Repository Name': 'Android-CleanArchitecture',
#   'User Name': 'android10',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/android10/Android-CleanArchitecture'},
#  {'Sr No': 56,
#   'Repository Name': 'Mindustry',
#   'User Name': 'Anuken',
#   'stars': '15k',
#   'Repository URL': 'https://github.com/Anuken/Mindustry'},
#  {'Sr No': 57,
#   'Repository Name': 'disruptor',
#   'User Name': 'LMAX-Exchange',
#   'stars': '15k',
#   'Repository URL': 'https://github.com/LMAX-Exchange/disruptor'},
#  {'Sr No': 58,
#   'Repository Name': 'leetcode',
#   'User Name': 'doocs',
#   'stars': '14.6k',
#   'Repository URL': 'https://github.com/doocs/leetcode'},
#  {'Sr No': 59,
#   'Repository Name': 'elasticsearch-analysis-ik',
#   'User Name': 'medcl',
#   'stars': '14k',
#   'Repository URL': 'https://github.com/medcl/elasticsearch-analysis-ik'},
#  {'Sr No': 60,
#   'Repository Name': 'presto',
#   'User Name': 'prestodb',
#   'stars': '13.6k',
#   'Repository URL': 'https://github.com/prestodb/presto'},
#  {'Sr No': 61,
#   'Repository Name': 'jdk',
#   'User Name': 'openjdk',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/openjdk/jdk'},
#  {'Sr No': 62,
#   'Repository Name': 'awesome-cs-books',
#   'User Name': 'imarvinle',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/imarvinle/awesome-cs-books'},
#  {'Sr No': 63,
#   'Repository Name': 'infer',
#   'User Name': 'facebook',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/facebook/infer'},
#  {'Sr No': 64,
#   'Repository Name': 'logger',
#   'User Name': 'orhanobut',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/orhanobut/logger'},
#  {'Sr No': 65,
#   'Repository Name': 'mockito',
#   'User Name': 'mockito',
#   'stars': '13.1k',
#   'Repository URL': 'https://github.com/mockito/mockito'},
#  {'Sr No': 66,
#   'Repository Name': 'bytecode-viewer',
#   'User Name': 'Konloch',
#   'stars': '13.1k',
#   'Repository URL': 'https://github.com/Konloch/bytecode-viewer'},
#  {'Sr No': 67,
#   'Repository Name': 'vert.x',
#   'User Name': 'eclipse-vertx',
#   'stars': '13k',
#   'Repository URL': 'https://github.com/eclipse-vertx/vert.x'},
#  {'Sr No': 68,
#   'Repository Name': 'logstash',
#   'User Name': 'elastic',
#   'stars': '12.9k',
#   'Repository URL': 'https://github.com/elastic/logstash'},
#  {'Sr No': 69,
#   'Repository Name': 'LearningNotes',
#   'User Name': 'francistao',
#   'stars': '12.8k',
#   'Repository URL': 'https://github.com/francistao/LearningNotes'},
#  {'Sr No': 70,
#   'Repository Name': 'Sourcetrail',
#   'User Name': 'CoatiSoftware',
#   'stars': '12.8k',
#   'Repository URL': 'https://github.com/CoatiSoftware/Sourcetrail'},
#  {'Sr No': 71,
#   'Repository Name': 'deeplearning4j',
#   'User Name': 'eclipse',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/eclipse/deeplearning4j'},
#  {'Sr No': 72,
#   'Repository Name': 'antlr4',
#   'User Name': 'antlr',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/antlr/antlr4'},
#  {'Sr No': 73,
#   'Repository Name': 'technology-talk',
#   'User Name': 'aalansehaiyang',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/aalansehaiyang/technology-talk'},
#  {'Sr No': 74,
#   'Repository Name': 'Android',
#   'User Name': 'open-android',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/open-android/Android'},
#  {'Sr No': 75,
#   'Repository Name': 'tink',
#   'User Name': 'google',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/google/tink'},
#  {'Sr No': 76,
#   'Repository Name': 'playframework',
#   'User Name': 'playframework',
#   'stars': '12.2k',
#   'Repository URL': 'https://github.com/playframework/playframework'},
#  {'Sr No': 77,
#   'Repository Name': 'jib',
#   'User Name': 'GoogleContainerTools',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/GoogleContainerTools/jib'},
#  {'Sr No': 78,
#   'Repository Name': 'thingsboard',
#   'User Name': 'thingsboard',
#   'stars': '12k',
#   'Repository URL': 'https://github.com/thingsboard/thingsboard'},
#  {'Sr No': 79,
#   'Repository Name': 'RxTool',
#   'User Name': 'Tamsiree',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/Tamsiree/RxTool'},
#  {'Sr No': 80,
#   'Repository Name': 'MaterialDrawer',
#   'User Name': 'mikepenz',
#   'stars': '11.5k',
#   'Repository URL': 'https://github.com/mikepenz/MaterialDrawer'},
#  {'Sr No': 81,
#   'Repository Name': 'realm-java',
#   'User Name': 'realm',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/realm/realm-java'},
#  {'Sr No': 82,
#   'Repository Name': 'uCrop',
#   'User Name': 'Yalantis',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/Yalantis/uCrop'},
#  {'Sr No': 83,
#   'Repository Name': 'androidannotations',
#   'User Name': 'androidannotations',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/androidannotations/androidannotations'},
#  {'Sr No': 84,
#   'Repository Name': 'recyclerview-animators',
#   'User Name': 'wasabeef',
#   'stars': '11.1k',
#   'Repository URL': 'https://github.com/wasabeef/recyclerview-animators'},
#  {'Sr No': 85,
#   'Repository Name': 'PermissionsDispatcher',
#   'User Name': 'permissions-dispatcher',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/permissions-dispatcher/PermissionsDispatcher'},
#  {'Sr No': 86,
#   'Repository Name': 'spring-boot-admin',
#   'User Name': 'codecentric',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/codecentric/spring-boot-admin'},
#  {'Sr No': 87,
#   'Repository Name': 'labs',
#   'User Name': 'docker',
#   'stars': '10.8k',
#   'Repository URL': 'https://github.com/docker/labs'},
#  {'Sr No': 88,
#   'Repository Name': 'android-async-http',
#   'User Name': 'android-async-http',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/android-async-http/android-async-http'},
#  {'Sr No': 89,
#   'Repository Name': 'zookeeper',
#   'User Name': 'apache',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/apache/zookeeper'},
#  {'Sr No': 90,
#   'Repository Name': 'fullstack-tutorial',
#   'User Name': 'frank-lam',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/frank-lam/fullstack-tutorial'},
#  {'Sr No': 91,
#   'Repository Name': 'ip2region',
#   'User Name': 'lionsoul2014',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/lionsoul2014/ip2region'},
#  {'Sr No': 92,
#   'Repository Name': 'jedis',
#   'User Name': 'redis',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/redis/jedis'},
#  {'Sr No': 93,
#   'Repository Name': 'webmagic',
#   'User Name': 'code4craft',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/code4craft/webmagic'},
#  {'Sr No': 94,
#   'Repository Name': 'quarkus',
#   'User Name': 'quarkusio',
#   'stars': '10.3k',
#   'Repository URL': 'https://github.com/quarkusio/quarkus'},
#  {'Sr No': 95,
#   'Repository Name': 'algorithm-base',
#   'User Name': 'chefyuan',
#   'stars': '10k',
#   'Repository URL': 'https://github.com/chefyuan/algorithm-base'},
#  {'Sr No': 96,
#   'Repository Name': 'CtCI-6th-Edition',
#   'User Name': 'careercup',
#   'stars': '10k',
#   'Repository URL': 'https://github.com/careercup/CtCI-6th-Edition'},
#  {'Sr No': 97,
#   'Repository Name': 'CS-Book',
#   'User Name': 'iamshuaidi',
#   'stars': '9.9k',
#   'Repository URL': 'https://github.com/iamshuaidi/CS-Book'},
#  {'Sr No': 98,
#   'Repository Name': 'glide-transformations',
#   'User Name': 'wasabeef',
#   'stars': '9.7k',
#   'Repository URL': 'https://github.com/wasabeef/glide-transformations'},
#  {'Sr No': 99,
#   'Repository Name': 'mirai',
#   'User Name': 'mamoe',
#   'stars': '9.7k',
#   'Repository URL': 'https://github.com/mamoe/mirai'},
#  {'Sr No': 100,
#   'Repository Name': 'cas',
#   'User Name': 'apereo',
#   'stars': '9.6k',
#   'Repository URL': 'https://github.com/apereo/cas'},
#  {'Sr No': 101,
#   'Repository Name': 'jsoup',
#   'User Name': 'jhy',
#   'stars': '9.5k',
#   'Repository URL': 'https://github.com/jhy/jsoup'},
#  {'Sr No': 102,
#   'Repository Name': 'Sa-Token',
#   'User Name': 'dromara',
#   'stars': '9.5k',
#   'Repository URL': 'https://github.com/dromara/Sa-Token'},
#  {'Sr No': 103,
#   'Repository Name': 'TabNine',
#   'User Name': 'codota',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/codota/TabNine'},
#  {'Sr No': 104,
#   'Repository Name': 'spring-boot-api-project-seed',
#   'User Name': 'lihengming',
#   'stars': '9.1k',
#   'Repository URL': 'https://github.com/lihengming/spring-boot-api-project-seed'},
#  {'Sr No': 105,
#   'Repository Name': 'newbee-mall',
#   'User Name': 'newbee-ltd',
#   'stars': '9k',
#   'Repository URL': 'https://github.com/newbee-ltd/newbee-mall'},
#  {'Sr No': 106,
#   'Repository Name': 'Grasscutter',
#   'User Name': 'Grasscutters',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/Grasscutters/Grasscutter'},
#  {'Sr No': 107,
#   'Repository Name': 'graphql-code-generator',
#   'User Name': 'dotansimha',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/dotansimha/graphql-code-generator'},
#  {'Sr No': 108,
#   'Repository Name': 'OpenRefine',
#   'User Name': 'OpenRefine',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/OpenRefine/OpenRefine'},
#  {'Sr No': 109,
#   'Repository Name': 'tiled',
#   'User Name': 'mapeditor',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/mapeditor/tiled'},
#  {'Sr No': 110,
#   'Repository Name': 'questdb',
#   'User Name': 'questdb',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/questdb/questdb'},
#  {'Sr No': 111,
#   'Repository Name': 'mal',
#   'User Name': 'kanaka',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/kanaka/mal'},
#  {'Sr No': 112,
#   'Repository Name': 'mall-swarm',
#   'User Name': 'macrozheng',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/macrozheng/mall-swarm'},
#  {'Sr No': 113,
#   'Repository Name': 'Activiti',
#   'User Name': 'Activiti',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/Activiti/Activiti'},
#  {'Sr No': 114,
#   'Repository Name': 'jvm',
#   'User Name': 'doocs',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/doocs/jvm'},
#  {'Sr No': 115,
#   'Repository Name': 'BottomBar',
#   'User Name': 'roughike',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/roughike/BottomBar'},
#  {'Sr No': 116,
#   'Repository Name': 'android-gpuimage',
#   'User Name': 'cats-oss',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/cats-oss/android-gpuimage'},
#  {'Sr No': 117,
#   'Repository Name': 'jjwt',
#   'User Name': 'jwtk',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/jwtk/jjwt'},
#  {'Sr No': 118,
#   'Repository Name': 'buck',
#   'User Name': 'facebook',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/facebook/buck'},
#  {'Sr No': 119,
#   'Repository Name': 'finagle',
#   'User Name': 'twitter',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/twitter/finagle'},
#  {'Sr No': 120,
#   'Repository Name': 'dropwizard',
#   'User Name': 'dropwizard',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/dropwizard/dropwizard'},
#  {'Sr No': 121,
#   'Repository Name': 'quicktype',
#   'User Name': 'quicktype',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/quicktype/quicktype'},
#  {'Sr No': 122,
#   'Repository Name': 'MaterialViewPager',
#   'User Name': 'florent37',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/florent37/MaterialViewPager'},
#  {'Sr No': 123,
#   'Repository Name': 'feign',
#   'User Name': 'OpenFeign',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/OpenFeign/feign'},
#  {'Sr No': 124,
#   'Repository Name': 'CodeGuide',
#   'User Name': 'fuzhengwei',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/fuzhengwei/CodeGuide'},
#  {'Sr No': 125,
#   'Repository Name': 'The-Complete-FAANG-Preparation',
#   'User Name': 'AkashSingh3031',
#   'stars': '7.9k',
#   'Repository URL': 'https://github.com/AkashSingh3031/The-Complete-FAANG-Preparation'},
#  {'Sr No': 126,
#   'Repository Name': 'hsweb-framework',
#   'User Name': 'hs-web',
#   'stars': '7.9k',
#   'Repository URL': 'https://github.com/hs-web/hsweb-framework'},
#  {'Sr No': 127,
#   'Repository Name': 'DSA-Bootcamp-Java',
#   'User Name': 'kunal-kushwaha',
#   'stars': '7.7k',
#   'Repository URL': 'https://github.com/kunal-kushwaha/DSA-Bootcamp-Java'},
#  {'Sr No': 128,
#   'Repository Name': 'capacitor',
#   'User Name': 'ionic-team',
#   'stars': '7.7k',
#   'Repository URL': 'https://github.com/ionic-team/capacitor'},
#  {'Sr No': 129,
#   'Repository Name': 'metrics',
#   'User Name': 'dropwizard',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/dropwizard/metrics'},
#  {'Sr No': 130,
#   'Repository Name': 'cryptomator',
#   'User Name': 'cryptomator',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/cryptomator/cryptomator'},
#  {'Sr No': 131,
#   'Repository Name': 'RxJava-Android-Samples',
#   'User Name': 'kaushikgopal',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/kaushikgopal/RxJava-Android-Samples'},
#  {'Sr No': 132,
#   'Repository Name': 'cassandra',
#   'User Name': 'apache',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/apache/cassandra'},
#  {'Sr No': 133,
#   'Repository Name': 'guiadevbrasil',
#   'User Name': 'arthurspk',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/arthurspk/guiadevbrasil'},
#  {'Sr No': 134,
#   'Repository Name': 'vjtools',
#   'User Name': 'vipshop',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/vipshop/vjtools'},
#  {'Sr No': 135,
#   'Repository Name': 'Android-Bootstrap',
#   'User Name': 'Bearded-Hen',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/Bearded-Hen/Android-Bootstrap'},
#  {'Sr No': 136,
#   'Repository Name': 'UltimateRecyclerView',
#   'User Name': 'cymcsg',
#   'stars': '7.2k',
#   'Repository URL': 'https://github.com/cymcsg/UltimateRecyclerView'},
#  {'Sr No': 137,
#   'Repository Name': 'CS-Books',
#   'User Name': 'forthespada',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/forthespada/CS-Books'},
#  {'Sr No': 138,
#   'Repository Name': 'checkstyle',
#   'User Name': 'checkstyle',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/checkstyle/checkstyle'},
#  {'Sr No': 139,
#   'Repository Name': 'android-classyshark',
#   'User Name': 'google',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/google/android-classyshark'},
#  {'Sr No': 140,
#   'Repository Name': 'swagger-core',
#   'User Name': 'swagger-api',
#   'stars': '7k',
#   'Repository URL': 'https://github.com/swagger-api/swagger-core'},
#  {'Sr No': 141,
#   'Repository Name': 'spring-security',
#   'User Name': 'spring-projects',
#   'stars': '6.9k',
#   'Repository URL': 'https://github.com/spring-projects/spring-security'},
#  {'Sr No': 142,
#   'Repository Name': 'botframework-sdk',
#   'User Name': 'microsoft',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/microsoft/botframework-sdk'},
#  {'Sr No': 143,
#   'Repository Name': 'cachecloud',
#   'User Name': 'sohutv',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/sohutv/cachecloud'},
#  {'Sr No': 144,
#   'Repository Name': 'semgrep',
#   'User Name': 'returntocorp',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/returntocorp/semgrep'},
#  {'Sr No': 145,
#   'Repository Name': 'dtm',
#   'User Name': 'dtm-labs',
#   'stars': '6.7k',
#   'Repository URL': 'https://github.com/dtm-labs/dtm'},
#  {'Sr No': 146,
#   'Repository Name': 'flyway',
#   'User Name': 'flyway',
#   'stars': '6.6k',
#   'Repository URL': 'https://github.com/flyway/flyway'},
#  {'Sr No': 147,
#   'Repository Name': 'supertokens-core',
#   'User Name': 'supertokens',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/supertokens/supertokens-core'},
#  {'Sr No': 148,
#   'Repository Name': 'leetcode-patterns',
#   'User Name': 'seanprashad',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/seanprashad/leetcode-patterns'},
#  {'Sr No': 149,
#   'Repository Name': 'Paper',
#   'User Name': 'PaperMC',
#   'stars': '6.4k',
#   'Repository URL': 'https://github.com/PaperMC/Paper'},
#  {'Sr No': 150,
#   'Repository Name': 'storm',
#   'User Name': 'apache',
#   'stars': '6.4k',
#   'Repository URL': 'https://github.com/apache/storm'},
#  {'Sr No': 151,
#   'Repository Name': 'processing',
#   'User Name': 'processing',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/processing/processing'},
#  {'Sr No': 152,
#   'Repository Name': 'jmeter',
#   'User Name': 'apache',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/apache/jmeter'},
#  {'Sr No': 153,
#   'Repository Name': 'useful-scripts',
#   'User Name': 'oldratlee',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/oldratlee/useful-scripts'},
#  {'Sr No': 154,
#   'Repository Name': 'ansj_seg',
#   'User Name': 'NLPchina',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/NLPchina/ansj_seg'},
#  {'Sr No': 155,
#   'Repository Name': 'tomcat',
#   'User Name': 'apache',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/apache/tomcat'},
#  {'Sr No': 156,
#   'Repository Name': 'cadence',
#   'User Name': 'uber',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/uber/cadence'},
#  {'Sr No': 157,
#   'Repository Name': 'SmartTubeNext',
#   'User Name': 'yuliskov',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/yuliskov/SmartTubeNext'},
#  {'Sr No': 158,
#   'Repository Name': 'testcontainers-java',
#   'User Name': 'testcontainers',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/testcontainers/testcontainers-java'},
#  {'Sr No': 159,
#   'Repository Name': 'flutter-examples',
#   'User Name': 'nisrulz',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/nisrulz/flutter-examples'},
#  {'Sr No': 160,
#   'Repository Name': 'aeron',
#   'User Name': 'real-logic',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/real-logic/aeron'},
#  {'Sr No': 161,
#   'Repository Name': 'material',
#   'User Name': 'rey5137',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/rey5137/material'},
#  {'Sr No': 162,
#   'Repository Name': 'javacv',
#   'User Name': 'bytedeco',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/bytedeco/javacv'},
#  {'Sr No': 163,
#   'Repository Name': 'error-prone',
#   'User Name': 'google',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/google/error-prone'},
#  {'Sr No': 164,
#   'Repository Name': 'async-http-client',
#   'User Name': 'AsyncHttpClient',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/AsyncHttpClient/async-http-client'},
#  {'Sr No': 165,
#   'Repository Name': 'rest-assured',
#   'User Name': 'rest-assured',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/rest-assured/rest-assured'},
#  {'Sr No': 166,
#   'Repository Name': 'JFoenix',
#   'User Name': 'sshahine',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/sshahine/JFoenix'},
#  {'Sr No': 167,
#   'Repository Name': 'h2o-3',
#   'User Name': 'h2oai',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/h2oai/h2o-3'},
#  {'Sr No': 168,
#   'Repository Name': 'netty-socketio',
#   'User Name': 'mrniko',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/mrniko/netty-socketio'},
#  {'Sr No': 169,
#   'Repository Name': 'material-calendarview',
#   'User Name': 'prolificinteractive',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/prolificinteractive/material-calendarview'},
#  {'Sr No': 170,
#   'Repository Name': 'jsonschema2pojo',
#   'User Name': 'joelittlejohn',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/joelittlejohn/jsonschema2pojo'},
#  {'Sr No': 171,
#   'Repository Name': 'better-java',
#   'User Name': 'cxxr',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/cxxr/better-java'},
#  {'Sr No': 172,
#   'Repository Name': 'zeppelin',
#   'User Name': 'apache',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/apache/zeppelin'},
#  {'Sr No': 173,
#   'Repository Name': 'FEBS-Shiro',
#   'User Name': 'febsteam',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/febsteam/FEBS-Shiro'},
#  {'Sr No': 174,
#   'Repository Name': 'from-java-to-kotlin',
#   'User Name': 'MindorksOpenSource',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/MindorksOpenSource/from-java-to-kotlin'},
#  {'Sr No': 175,
#   'Repository Name': 'trino',
#   'User Name': 'trinodb',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/trinodb/trino'},
#  {'Sr No': 176,
#   'Repository Name': 'beam',
#   'User Name': 'apache',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/apache/beam'},
#  {'Sr No': 177,
#   'Repository Name': 'curlconverter',
#   'User Name': 'curlconverter',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/curlconverter/curlconverter'},
#  {'Sr No': 178,
#   'Repository Name': 'ssm',
#   'User Name': 'liyifeng1994',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/liyifeng1994/ssm'},
#  {'Sr No': 179,
#   'Repository Name': 'javalin',
#   'User Name': 'javalin',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/javalin/javalin'},
#  {'Sr No': 180,
#   'Repository Name': 'springfox',
#   'User Name': 'springfox',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/springfox/springfox'},
#  {'Sr No': 181,
#   'Repository Name': 'aws-doc-sdk-examples',
#   'User Name': 'awsdocs',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/awsdocs/aws-doc-sdk-examples'},
#  {'Sr No': 182,
#   'Repository Name': 'MinecraftForge',
#   'User Name': 'MinecraftForge',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/MinecraftForge/MinecraftForge'},
#  {'Sr No': 183,
#   'Repository Name': 'graphql-java',
#   'User Name': 'graphql-java',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/graphql-java/graphql-java'},
#  {'Sr No': 184,
#   'Repository Name': 'mosby',
#   'User Name': 'sockeqwe',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/sockeqwe/mosby'},
#  {'Sr No': 185,
#   'Repository Name': 'robolectric',
#   'User Name': 'robolectric',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/robolectric/robolectric'},
#  {'Sr No': 186,
#   'Repository Name': 'kryo',
#   'User Name': 'EsotericSoftware',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/EsotericSoftware/kryo'},
#  {'Sr No': 187,
#   'Repository Name': 'ysoserial',
#   'User Name': 'frohoff',
#   'stars': '5.4k',
#   'Repository URL': 'https://github.com/frohoff/ysoserial'},
#  {'Sr No': 188,
#   'Repository Name': 'transmittable-thread-local',
#   'User Name': 'alibaba',
#   'stars': '5.4k',
#   'Repository URL': 'https://github.com/alibaba/transmittable-thread-local'},
#  {'Sr No': 189,
#   'Repository Name': 'micronaut-core',
#   'User Name': 'micronaut-projects',
#   'stars': '5.4k',
#   'Repository URL': 'https://github.com/micronaut-projects/micronaut-core'},
#  {'Sr No': 190,
#   'Repository Name': 'mapstruct',
#   'User Name': 'mapstruct',
#   'stars': '5.4k',
#   'Repository URL': 'https://github.com/mapstruct/mapstruct'},
#  {'Sr No': 191,
#   'Repository Name': 'OpenSearch',
#   'User Name': 'opensearch-project',
#   'stars': '5.3k',
#   'Repository URL': 'https://github.com/opensearch-project/OpenSearch'},
#  {'Sr No': 192,
#   'Repository Name': 'Alerter',
#   'User Name': 'Tapadoo',
#   'stars': '5.3k',
#   'Repository URL': 'https://github.com/Tapadoo/Alerter'},
#  {'Sr No': 193,
#   'Repository Name': 'junit5',
#   'User Name': 'junit-team',
#   'stars': '5.3k',
#   'Repository URL': 'https://github.com/junit-team/junit5'},
#  {'Sr No': 194,
#   'Repository Name': 'scribejava',
#   'User Name': 'scribejava',
#   'stars': '5.3k',
#   'Repository URL': 'https://github.com/scribejava/scribejava'},
#  {'Sr No': 195,
#   'Repository Name': 'Anki-Android',
#   'User Name': 'ankidroid',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/ankidroid/Anki-Android'},
#  {'Sr No': 196,
#   'Repository Name': 'craftinginterpreters',
#   'User Name': 'munificent',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/munificent/craftinginterpreters'},
#  {'Sr No': 197,
#   'Repository Name': 'Blurry',
#   'User Name': 'wasabeef',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/wasabeef/Blurry'},
#  {'Sr No': 198,
#   'Repository Name': 'Side-Menu.Android',
#   'User Name': 'Yalantis',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/Yalantis/Side-Menu.Android'},
#  {'Sr No': 199,
#   'Repository Name': 'camerakit-android',
#   'User Name': 'CameraKit',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/CameraKit/camerakit-android'},
#  {'Sr No': 200,
#   'Repository Name': 'awesome-test-automation',
#   'User Name': 'atinfo',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/atinfo/awesome-test-automation'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No          Repository Name        User Name  stars  \
# 0        1                 CS-Notes          CyC2018   154k
# 1        2                JavaGuide       Snailclimb   124k
# 2        3     java-design-patterns         iluwatar  75.7k
# 3        4            advanced-java            doocs  64.2k
# 4        5              spring-boot  spring-projects    62k
# ..     ...                      ...              ...    ...
# 195    196     craftinginterpreters       munificent   5.2k
# 196    197                   Blurry         wasabeef   5.2k
# 197    198        Side-Menu.Android         Yalantis   5.2k
# 198    199        camerakit-android        CameraKit   5.2k
# 199    200  awesome-test-automation           atinfo   5.1k
#
#                                         Repository URL
# 0                  https://github.com/CyC2018/CS-Notes
# 1              https://github.com/Snailclimb/JavaGuide
# 2     https://github.com/iluwatar/java-design-patterns
# 3               https://github.com/doocs/advanced-java
# 4       https://github.com/spring-projects/spring-boot
# ..                                                 ...
# 195  https://github.com/munificent/craftinginterpre...
# 196                 https://github.com/wasabeef/Blurry
# 197      https://github.com/Yalantis/Side-Menu.Android
# 198     https://github.com/CameraKit/camerakit-android
# 199  https://github.com/atinfo/awesome-test-automation
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_java.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
