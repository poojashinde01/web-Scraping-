# %%
#data visualization web scraping

# %%
import requests

# %%
url=requests.get('https://github.com/topics/data-visualization').text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogK
# ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
print(first_rep1)
# Out:
# <article class="border rounded color-shadow-small color-bg-subtle my-4">
# <div class="px-3">
# <div class="d-flex flex-justify-between my-3">
# <div class="d-flex flex-auto">
# <span style="margin-top:2px">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# </span>
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# ...

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'd3'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'd3'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text

# %%
stars
# Out:
# '102k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/d3/d3'

# %%
base_url='https://github.com/topics/data-visualization'

# %%
base_url
# Out:
# 'https://github.com/topics/data-visualization'

# %%
Repository_url=base_url+url_link

# %%
Repository_url
# Out:
# 'https://github.com/topics/data-visualization/d3/d3'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
base_url='https://github.com/'
page_1_dict={}
Repository_1_lst=[]

for item in Repository_page:
   
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
             'Repository Name': Repository_name,
             'User Name': User_Name ,
             'stars': stars,
             'Repository URL':URL,
    }
        
    Repository_1_lst.append(Repository_1_dict)

# %%
print(Repository_1_lst)
# Out:
# [{'Repository Name': 'd3', 'User Name': 'd3', 'stars': '102k', 'Repository URL': 'https://github.com/d3/d3'}, {'Repository Name': 'echarts', 'User Name': 'apache', 'stars': '51.6k', 'Repository URL': 'https://github.com/apache/echarts'}, {'Repository Name': 'grafana', 'User Name': 'grafana', 'stars': '49.8k', 'Repository URL': 'https://github.com/grafana/grafana'}, {'Repository Name': 'superset', 'User Name': 'apache', 'stars': '46.9k', 'Repository URL': 'https://github.com/apache/superset'}, {'Repository Name': 'pixijs', 'User Name': 'pixijs', 'stars': '36.8k', 'Repository URL': 'https://github.com/pixijs/pixijs'}, {'Repository Name': 'metabase', 'User Name': 'metabase', 'stars': '29k', 'Repository URL': 'https://github.com/metabase/metabase'}, {'Repository Name': 'streamlit', 'User Name': 'streamlit', 'stars': '19.8k', 'Repository URL': 'https://github.com/streamlit/streamlit'}, {'Repository Name': 'awesome-datascience', 'User Name': 'academic', 'stars': '19k', 'Repository URL': 'h
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                Repository Name       User Name  stars  \
# 0                           d3              d3   102k
# 1                      echarts          apache  51.6k
# 2                      grafana         grafana  49.8k
# 3                     superset          apache  46.9k
# 4                       pixijs          pixijs  36.8k
# 5                     metabase        metabase    29k
# 6                    streamlit       streamlit  19.8k
# 7          awesome-datascience        academic    19k
# 8                         dash          plotly  16.8k
# 9                     directus        directus  16.7k
# 10                  matplotlib      matplotlib  15.7k
# 11                        visx          airbnb  15.4k
# 12  Data-Science-For-Beginners       microsoft  15.3k
# 13                   plotly.js          plotly  14.8k
# 14               apexcharts.js      apexcharts  11.6k
# 15                          G2          antvis  11.3k
# ...

# %%
df.to_excel('datavisualization.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/data-visualization?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/data-visualization?page=1',
#  'https://github.com/topics/data-visualization?page=2',
#  'https://github.com/topics/data-visualization?page=3',
#  'https://github.com/topics/data-visualization?page=4',
#  'https://github.com/topics/data-visualization?page=5',
#  'https://github.com/topics/data-visualization?page=6',
#  'https://github.com/topics/data-visualization?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/data-visualization?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'd3',
#   'User Name': 'd3',
#   'stars': '102k',
#   'Repository URL': 'https://github.com/d3/d3'},
#  {'Sr No': 2,
#   'Repository Name': 'echarts',
#   'User Name': 'apache',
#   'stars': '51.6k',
#   'Repository URL': 'https://github.com/apache/echarts'},
#  {'Sr No': 3,
#   'Repository Name': 'grafana',
#   'User Name': 'grafana',
#   'stars': '49.8k',
#   'Repository URL': 'https://github.com/grafana/grafana'},
#  {'Sr No': 4,
#   'Repository Name': 'superset',
#   'User Name': 'apache',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/apache/superset'},
#  {'Sr No': 5,
#   'Repository Name': 'pixijs',
#   'User Name': 'pixijs',
#   'stars': '36.8k',
#   'Repository URL': 'https://github.com/pixijs/pixijs'},
#  {'Sr No': 6,
#   'Repository Name': 'metabase',
#   'User Name': 'metabase',
#   'stars': '29k',
#   'Repository URL': 'https://github.com/metabase/metabase'},
#  {'Sr No': 7,
#   'Repository Name': 'streamlit',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No   Repository Name      User Name  stars  \
# 0        1                d3             d3   102k
# 1        2           echarts         apache  51.6k
# 2        3           grafana        grafana  49.8k
# 3        4          superset         apache  46.9k
# 4        5            pixijs         pixijs  36.8k
# ..     ...               ...            ...    ...
# 195    196             py_d3  ResidentMario    442
# 196    197  plotly-resampler  predict-idlab    447
# 197    198   report-designer        xinglie    444
# 198    199          ipyvizzu        vizzuhq    437
# 199    200       cubesviewer      jjmontesl    430
#
#                                         Repository URL
# 0                             https://github.com/d3/d3
# 1                    https://github.com/apache/echarts
# 2                   https://github.com/grafana/grafana
# 3                   https://github.com/apache/superset
# 4                     https://github.com/pixijs/pixijs
# ...

# %%
df.to_excel('200_data_visu.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
