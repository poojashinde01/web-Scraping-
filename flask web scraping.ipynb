# %%
import requests

# %%
url=requests.get('https://github.com/topics/flask').text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-10084108b209.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" rel="stylesheet" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" rel="stylesheet" href="https://github.githubassets.com/assets/github-f815d05d371a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYw ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-92c7d381038e.css" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-10084108b209.css" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f815d05d371a.css" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-d31ea144555c.css" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYwk1Z+BnSLOwYorhPLm6jrWoV3c7Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-44mCWWd9he+TZlQdLzIEo+cbYo6tgMXkx8954MY/9DknkwxQmYGmKJrGKCgbWmcMYmBgxLX6uOEgcRoDL/5eCA==" src="https://github.githubassets.com/assets/runtime-e3898259677d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZXV4TpPmxfyBQ9eFqJaVR/Z8Rrt+f/In8yBbbMmt6pqCRMVcnlTWS7/Xy5aedmiIj1tNZXmsvW3cf/vRas/mvQ==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-74aed8-6575784e93e6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-km+JVvSjuMukaGXFPj5OuzW1lNCVhWt0dB2EAkW4NpEj6x301u0l22+XLYaKm9+hvluGH0OlM6BE4hoTjxtFoQ==" src="https://github.githubassets.com/assets/environment-926f8956f4a3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-57NPhP0wWFMwvRygugK3iI3z+Sv0WTNy8MGBcwfMPYE7SoHKEoH1B89v+ANBqnW9GGvUYzf4gLT6UrP/VmhY2g==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-e7b34f84fd30.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Es25N4GyPa8Yfp5wpahoe5b2fyPtkRMyR6mKIXyCJC0ocqQazeWvxhGZhx3StRxOfqDfHDR5SS35u/R3Wux6Cg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-12cdb93781b2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-lmiecOIgf+hakg5oKMNM7grVhEDyPoIrT39Px448JJH5PSAaK21PH0Twgyz5O5oi8+dnlLr3Jt8bBCtAcpNdRw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-c7e9ed-96689e70e220.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-FhIi1nHjAzm1txsZ2LPPUfqIASARJ44qRQ09VSY4p/NVvWz/1reBy21+3an4fDIi6QhfrHNUI4ldKz3NW5by/Q==" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_time-elements_dist_index_js-161222d671e3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-DE9GK/TS3Hf/dJfP1GMiyjvsGRnpR4A1eGH64s0Ot7Vy7Tj7/aD1d5EOMWHFWQXlXy/ZSwu5MHInG6RZN31bMA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-52e104-0c4f462bf4d2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-fcVStVRolV54DldAqKbEzSE1OB6Rd/jIIpSj/dcCRRaSc8EgN68GT9sT/Ya0gtpNTq0aAPzs9OLlhWY7l0s4eA==" src="https://github.githubassets.com/assets/github-elements-7dc552b55468.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-n0EqohMRhyf2gYDkWAvqYJsBzb8qCciNwqGUpwOEjVfSLESviOFqm7IrHsihpfLAm+ZhteYJkQ+PPwqjJTUTrQ==" src="https://github.githubassets.com/assets/element-registry-9f412aa21311.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ULHDrjH3Nz+5xGQnGJ+51ZBv5qENKe3TikjwAxKli4TyT+8KZ5mnWUJxUdXaFwRVMGRJD+8CjfCVhj7913OiOA==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-50b1c3ae31f7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-XubU6uMX6y2ka6JR/QVSIS8aAdXBH9Jhm1lLCNFS5Dy3xbDEdS6W4ENFx71XaEAwW3d8xzgiS4cS0J/zsnYm6w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_github_catalyst_lib_index_-bd1f73-5ee6d4eae317.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-0r1nf/rfPz54kyePp4f63bcPxkFo7wyaUZJD/SwIVDK3q0WzurAK9ydOm88tzKtPJm8xWI0Vo25NyCfecwxJ9g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-d2bd677ffadf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-b6LnssJjHkph4nI0CxyYnXJ/d7eWTCd6fDCQZkhXUwNTMcB55fwq4nPNUDdsFG3h/KS3VEsMjhkqC8jBcQVazA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-f71f15-6fa2e7b2c263.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-aD+lpuc5jHemEy0Cf2KYz46MdwOIlj3+2cZ59XIi+mentNdewI1LzaDqroNLJzONIiL4IeUUZ7hJzhPYV4DQVA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_pjax_ts-683fa5a6e739.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-i6G+/7pwOhMb9q+i08xUSvHWO8fWX9lkXtuIJQGpHGn299Mb74hWyc5ikFQAuqgd2i/cV9c5Jw6O9Z10jDfAwg==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_be-af52ef-8ba1beffba70.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sGIJsMNVLhivulsWgcWql7t/JEs3gUQQt/9GHRjArviQLj6smy1Cei4X6Bg51OC/rZMDXeTNSL733VSNtdlynA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-019af8-b06209b0c355.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-1CN8HrSEXNbvvtNrIvzOMA1IkGwLyUOaFBl/N2UE91/8EvcqBFxy3M83mJVi/n50Kdq4oIRIeZG5D5oTpFTBDg==" src="https://github.githubassets.com/assets/behaviors-d4237c1eb484.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5nWr6hoxY6oc8ngCIfUbQS8h+5n8/1XZVb9KFgP0ak4NzsfM7ERe6b5639AYjyAbYZGs6I/7hC3eieSbWkHx9w==" src="https://github.githubassets.com/assets/notifications-global-e675abea1a31.js" type="application/javascript"></script>
# <title>flask · GitHub Topics · GitHub</title>
# <meta content="EDE0:785E:232B48:28BCBB:62C429DF" data-pjax-transient="true" name="request-id"/><meta content="c83a052849b2cd133d8bb57edff291cd849e99d7b26504b1a0c4a8e07040e08c" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFREUwOjc4NUU6MjMyQjQ4OjI4QkNCQjo2MkM0MjlERiIsInZpc2l0b3JfaWQiOiIyNjMyMjEyODU3NTUzMDAzMTkiLCJyZWdpb25fZWRnZSI6ImFwLXNvdXRoLTEiLCJyZWdpb25fcmVuZGVyIjoiYXAtc291dGgtMSJ9" data-pjax-transient="true" name="visitor-payload"/><meta content="7352b4588908e234296a27d4a30775f6fe402de05a47d473895e4203ea966652" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/flask"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="4fb0ce033c03e2368cb87da68cef7260f0ccd2409e89b597612503688cb0c12c" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fflask&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/flask;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/flask;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/flask;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/flask;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/flask;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/flask;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/flask;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/flask;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/flask;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/flask;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/flask;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/flask;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/flask;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/flask;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/flask;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/flask;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/flask;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/flask;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/flask;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/flask;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/flask;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/flask;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/flask;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/flask;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/flask;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/flask;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/flask;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/flask;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/flask;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/flask;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/flask;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/flask" aria-label="Site" class="js-site-search-form" data-scope-id="615" data-scope-type="Topic" data-scoped-search-url="/topics/flask" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="W0RK92vFK0q3rZReY+cwKTcL5KONMu/ohj48CbxDuqTblQPYTsOt7AXkREExPbkyRF9sZZFX37+76JGzdbdMrg=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </label>
# </form> </div>
# </div>
# </div>
# ...
# </svg> Pull requests
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <div class="px-3 pt-3">
# <p class="color-fg-muted mb-0"></p><div>Easy HTML form without PHP or JavaScript</div>
# </div>
# <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
# <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":615,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8e86e661e84eb1415f30d43720e281e4d7268feb64a926b3f03601c10624fdab" data-view-component="true" href="/topics/flask" title="Topic: flask">
#               flask
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":12554,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="13fef4d3625f2a144f597f7423b1e6cbea72b98a1646eb198e92a2f74594d94a" data-view-component="true" href="/topics/forms" title="Topic: forms">
#               forms
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17184,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="5fc67285bcca6014c7f4ad3addf0988b8aa2044b0173c948d8e08608f966d9d5" data-view-component="true" href="/topics/postgresql" title="Topic: postgresql">
#               postgresql
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":59935,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="cca13bf79b407e2817d72169b72a3896e1e0837b74e985b22f2b40a0a962b175" data-view-component="true" href="/topics/sendgrid" title="Topic: sendgrid">
#               sendgrid
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":109982,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="b6945469fc15440d95eb5fd55cdd777e4e0133d8662f5bc4ad5a68b302978c14" data-view-component="true" href="/topics/formspree" title="Topic: formspree">
#               formspree
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":133000,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8dd5ab264c9ce7dc66d2b63086e0f46854f2e3482407b5a9f091ab2fb805fe3d" data-view-component="true" href="/topics/jamstack" title="Topic: jamstack">
#               jamstack
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2019-11-13T17:27:05Z">Nov 13, 2019</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #3572A5"></span>
# <span itemprop="programmingLanguage">Python</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/flask" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Armin Ronacher
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> April 1, 2010
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Latest release</span>
# <a alt="Latest release" href="https://github.com/pallets/flask/releases/latest">
#         2 months ago
#       </a>
# </p>
# <dl class="my-4">
# <dt class="d-none">
#         Repository
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to pallets/flask, location:topic page" href="https://github.com/pallets/flask">
# <span class="css-truncate css-truncate-target" title="pallets/flask">
#           pallets/flask
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="http://flask.pocoo.org/">
# <span class="css-truncate css-truncate-target" title="flask.pocoo.org">
#           flask.pocoo.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/Flask_(web_framework)">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/Flask_(web_framework)">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'flask'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'pallets'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text
stars
# Out:
# '59.7k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/pallets/flask'

# %%
base_url='https://github.com/topics/flask'

# %%
base_url
# Out:
# 'https://github.com/topics/flask'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
Repository_page
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":16748505,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="4b18232241afbf1529f3eae12c0b2d80624740f04745bf430bae183a42764476" data-turbo="false" data-view-component="true" href="/pallets">
#              pallets
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":596892,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="905cc4058ee038753d8982e259b7d51304f9f7b67dfdf82d0741fa37c180203b" data-turbo="false" data-view-component="true" href="/pallets/flask">
#              flask
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":596892,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="a9052b03a5d25f3206dcee131c60f8b431d7c36675071ed288c7191b7c6a7d76" data-view-component="true" href="/login?return_to=%2Fpallets%2Fflask" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="59727 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="59,727">59.7k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":596892,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="33216129333c4f1b47731301973bf0165fe49094d6804f684adef8c86f005009" data-turbo="false" data-view-component="true" href="/pallets/flask" id="code-tab-596892">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":596892,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="cd43607f93183338d35174f28c8be48557699bf0fffdf7b02383d611b55d9840" data-turbo="false" data-view-component="true" href="/pallets/flask/issues" id="issues-tab-596892">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":596892,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="5e883c48090f6b78220a701519a9512cf650ddd92d0e353674e7570027365820" data-turbo="false" data-view-component="true" href="/pallets/flask/pulls" id="pull-requests-tab-596892">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":596892,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="6e528b15d2678517e8183bfeee3940dea510f75b0b05bc7a92ec0502609d40e2" data-turbo="false" data-view-component="true" href="/pallets/flask/discussions" id="discussions-tab-596892">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>The Python micro framework for building web applications.</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":84,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="d324ec3dbb0c33f062513a65b478d59492b555157d6c1de6d7692ec97160001c" data-view-component="true" href="/topics/python" title="Topic: python">
#                python
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":615,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8e86e661e84eb1415f30d43720e281e4d7268feb64a926b3f03601c10624fdab" data-view-component="true" href="/topics/flask" title="Topic: flask">
#                flask
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":21486,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="4a4a3a2d431801f46e10cd3e6a264d27b5f15745fa6186d210181d0cff9f7b48" data-view-component="true" href="/topics/web-framework" title="Topic: web-framework">
#                web-framework
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":45573,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="54cc8bab3324ef16e43c4b2e7875db3f129431709aac178891a661ec8866847f" data-view-component="true" href="/topics/wsgi" title="Topic: wsgi">
#                wsgi
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":288916,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="cbb983ca7a750a1993e6b4ae4bba582a5ea184288c1d17dc79448ee28d9ecf5c" data-view-component="true" href="/topics/jinja" title="Topic: jinja">
#                jinja
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":327785,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="9954a2d9e437a3e3fa9a358a7be75defe50db3b644ab90642e7b3aa31437faa0" data-view-component="true" href="/topics/werkzeug" title="Topic: werkzeug">
#                werkzeug
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":1107163,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="73af5df4e1375357243489bf0c1469803434ef4253308320d4e90b469be25838" data-view-component="true" href="/topics/pallets" title="Topic: pallets">
#                pallets
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-05T00:03:12Z">Jul 5, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3572A5"></span>
#  <span itemprop="programmingLanguage">Python</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="2ed0b571e2c472e659e204f085e51f2145d0738f817c6d2d5bb6481a446759ec" data-turbo="false" data-view-component="true" href="/apache/superset" style="max-height:275px">
#  <img alt="superset" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/39464018/58649580-eca4-11ea-844d-c2ddca24b226"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":47359,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="df415d8971ad500dd3cfba5d05683a23f43b80bf996479ac22857af82ef47778" data-turbo="false" data-view-component="true" href="/apache">
#              apache
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="b4ecf88449e67cdc474455313b6f266c41883698a8341356f54208f1802af611" data-turbo="false" data-view-component="true" href="/apache/superset">
#              superset
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":39464018,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="959ab00c1ad121e388f42bf0f415295b95d988a23eb2431d8999acb63fee3560" data-view-component="true" href="/login?return_to=%2Fapache%2Fsuperset" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="46871 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="46,871">46.9k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="07c3338c47d05dba912535015e69d38f469e97aad38cd41b38a90eb896df2d9d" data-turbo="false" data-view-component="true" href="/apache/superset" id="code-tab-39464018">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="67e4a585fe55829352a6f00c777b85e3c9759d2966976533f44b93d1e40e6edc" data-turbo="false" data-view-component="true" href="/apache/superset/issues" id="issues-tab-39464018">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="cda9f8bdd704b8422659f87f4fb225243f261d4dd7b4cc490ca9290461f3a89c" data-turbo="false" data-view-component="true" href="/apache/superset/pulls" id="pull-requests-tab-39464018">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="5c990fc5830ae960bb3d6f15429144544663eedb93b38b0bb7f5f062869e2fa9" data-turbo="false" data-view-component="true" href="/apache/superset/discussions" id="discussions-tab-39464018">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1119608035,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="a87a2f9ae7d046a0a2a6db99b744292f8e7f38591fd31fab12dbf25042823c55" data-turbo="false" data-view-component="true" href="https://github.com/apache/superset/issues/18235">
#                  [mixed time-series] Secondary y-axis title is disguised/misplaced
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                4
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="rumbin" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/1220356?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    rumbin
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-01-31T15:52:37Z">Jan 31, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p>The Mixed Time-Series chart type allows for configuring the title of the primary and the secondary y-axis.<br/>
#  However, while only the title of the primary axis is shown next to the axis, the title of the secondary one is placed at the upper end of the axis where it gets hidden by bar values and zoom controls.</p>
#  <h4>How to reproduce the bug</h4>
#  <ol>
#  <li>Create a <em>mixed time-series</em> chart</li>
#  <li>Configure axi</li>
#  </ol>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1119608035,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="17f294489d8bdd984436a858e6ec75b11e19939d7ced1abc312b904498bd0615" href="https://github.com/apache/superset/issues/18235">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":2116802574,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="ec947f9cfbf29317f6efe4a1a22b761d83f7ac95fdefb07369993536f58e5668" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-ca5554" style="--label-r:197;--label-g:222;--label-b:245;--label-h:208;--label-s:70;--label-l:86;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-ca5554" hidden="hidden">Good first issues for new contributors</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":2635447975,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="f1f64b0b60b8dd68e1738c4f8af640d11ceb1d7923bd5118d247db179f9f6c1e" data-name="#bug" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%23bug" id="label-12e197" style="--label-r:237;--label-g:237;--label-b:237;--label-h:0;--label-s:0;--label-l:92;">
#                      #bug
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-12e197" hidden="hidden">Bug report</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":3787809934,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="f09e5c3ab334cec3a0771a14d08c75e53b6b26420f84e77a2f0fb17c7cc667f5" data-name="validation:validated" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Avalidation%3Avalidated" id="label-dfa4ec" style="--label-r:79;--label-g:144;--label-b:49;--label-h:101;--label-s:49;--label-l:37;">
#                      validation:validated
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-dfa4ec" hidden="hidden">A committer has validated / submitted the issue or it was reported by multiple users</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":3787822439,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="ac729025633ed1147d59d4f3865f1fbf02f4e5390c8b7bb200d2a564506168e0" data-name="preset:cares" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Apreset%3Acares" id="label-326626" style="--label-r:46;--label-g:192;--label-b:150;--label-h:162;--label-s:61;--label-l:46;">
#                      preset:cares
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-326626" hidden="hidden">Preset cares about this issue</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1119587485,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="86814b917b6f4fdcc85fd2e763aef01dc11470e9937ee4f4d15b836b01b258d7" data-turbo="false" data-view-component="true" href="https://github.com/apache/superset/issues/18234">
#                      [mixed time-series; time-series bar chart v2] D3 format of saved metric is ignored; bar values ignore D3 format of the chart
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    2
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1118117196,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="f24ac08ab55a45be67e0896892b4e423d3b1ae679dfd26f45073116ee5b2e967" data-turbo="false" data-view-component="true" href="https://github.com/apache/superset/issues/18225">
#                      Attach new report to the dashboard again, but there are no error messages on the page
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    2
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":39464018,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="ccfc99ac96e2689fcd86defe03cd38d24e67725645181381c59dbf0a357090e1" data-turbo="false" data-view-component="true" href="/apache/superset/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":33702544,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="c52e0b66a0147510b81bd339a6cb3542019554aa1565a1ee09c1f016d5dbddc7" data-turbo="false" data-view-component="true" href="/plotly/dash" style="max-height:275px">
#  <img alt="dash" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/33702544/b4400c80-718b-11e9-9f3a-306c07a5f3de"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":5997976,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="47b2d44b234000cea4d4109540aca2eeeb56c8630ad9a6295ddfc46c734715d6" data-turbo="false" data-view-component="true" href="/plotly">
#              plotly
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":33702544,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="a20a706ef0e8d6dda6176a6765ed233d939b352dbb226ae4bd54f4b4000f85d0" data-turbo="false" data-view-component="true" href="/plotly/dash">
#              dash
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @plotly" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"plotly","originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="3bae6b751aca3bb73a57a75068b728e2836fd51f58420286344cefb78e4ca5cf" data-view-component="true" href="/sponsors/plotly">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":33702544,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="e86fc534deeffb673f1ed8f7db1c152ff16bc9bdd1f173ee2cbf9e4d1ff65ceb" data-view-component="true" href="/login?return_to=%2Fplotly%2Fdash" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="16769 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="16,769">16.8k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":33702544,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="b3c336cec1d68585064d50593f8fc333bdbe75c1374da7c55206f2bbc77cbeb9" data-turbo="false" data-view-component="true" href="/plotly/dash" id="code-tab-33702544">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":33702544,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="03703989ae18f6dd3309cd1ad2793edf5dae74cd006c09be9807bf08c654f08b" data-turbo="false" data-view-component="true" href="/plotly/dash/issues" id="issues-tab-33702544">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":33702544,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="4eb590b5d51dc852adc5cfff564882f6a1b7898d602f5d0ac163b9e7e19bd1e7" data-turbo="false" data-view-component="true" href="/plotly/dash/pulls" id="pull-requests-tab-33702544">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1071095020,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="b3df27e0487df878c13600ca79c3f871acd50688078b45eaf6c60584eb43cb2e" data-turbo="false" data-view-component="true" href="https://github.com/plotly/dash/issues/1854">
#                  [BUG] DataTable javascript error with row_selectable and filter_action
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# ...
#                python
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":615,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8e86e661e84eb1415f30d43720e281e4d7268feb64a926b3f03601c10624fdab" data-view-component="true" href="/topics/flask" title="Topic: flask">
#                flask
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":653,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8a7ed74631c06d570031c71fb0aab662d7d1b8d60fe487c7970ce49d62a075d5" data-view-component="true" href="/topics/elasticsearch" title="Topic: elasticsearch">
#                elasticsearch
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2133,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="bdce928836087b11a82d05eac78edae3c1f42dc523b84e2946f2ea2eed2447c4" data-view-component="true" href="/topics/torrent" title="Topic: torrent">
#                torrent
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9590,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="36a8d98fe4cb7a6b8eb4e86a98eecd3bb3e9d15d9b6df449b7f1cdd9e8000cbd" data-view-component="true" href="/topics/bittorrent" title="Topic: bittorrent">
#                bittorrent
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9815,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="5fce10ed4368f6371e99f91ef5d9190b3d402cbe970ab542752f3dc7c78d213e" data-view-component="true" href="/topics/anime" title="Topic: anime">
#                anime
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":407847,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="7566de8ba2e6bb2dfbfbc892896e0da0c7b2a70b94c8bc49f17e1463b6070801" data-view-component="true" href="/topics/nyaa" title="Topic: nyaa">
#                nyaa
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-06-04T02:11:22Z">Jun 4, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3572A5"></span>
#  <span itemprop="programmingLanguage">Python</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":14319378,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="ecdfbfbd9bc42a7e00bfcb84d89098eb904bfb05fa8ac8fd59b8521bd3ccb547" data-turbo="false" data-view-component="true" href="/formspree">
#              formspree
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":27942236,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="6b5388cab1bb1b7334a01a2d47051c0b625ab78ccf6de630031e7200298c3a32" data-turbo="false" data-view-component="true" href="/formspree/formspree">
#              formspree
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":27942236,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="4b6f0ef08ea3a290d13d4e0ba7bc239d8e4652073e5611f0c6d0534a35a8fbcf" data-view-component="true" href="/login?return_to=%2Fformspree%2Fformspree" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="2769 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="2,769">2.8k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":27942236,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="2fe4a69b82100c0f22e8aa54f19a02d04ca53f3e50a608917c0ec77f16d599df" data-turbo="false" data-view-component="true" href="/formspree/formspree" id="code-tab-27942236">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":27942236,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="245ba35e8ec66b4540f96dbf518194cc8e12c4b626b4fdf843486049a7580c50" data-turbo="false" data-view-component="true" href="/formspree/formspree/issues" id="issues-tab-27942236">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":27942236,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="269ecb05d789f30e3fd14da4f38a0edbb73d6a8f227983b0700f36c9a676dfa4" data-turbo="false" data-view-component="true" href="/formspree/formspree/pulls" id="pull-requests-tab-27942236">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>Easy HTML form without PHP or JavaScript</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":615,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8e86e661e84eb1415f30d43720e281e4d7268feb64a926b3f03601c10624fdab" data-view-component="true" href="/topics/flask" title="Topic: flask">
#                flask
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":12554,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="13fef4d3625f2a144f597f7423b1e6cbea72b98a1646eb198e92a2f74594d94a" data-view-component="true" href="/topics/forms" title="Topic: forms">
#                forms
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17184,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="5fc67285bcca6014c7f4ad3addf0988b8aa2044b0173c948d8e08608f966d9d5" data-view-component="true" href="/topics/postgresql" title="Topic: postgresql">
#                postgresql
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":59935,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="cca13bf79b407e2817d72169b72a3896e1e0837b74e985b22f2b40a0a962b175" data-view-component="true" href="/topics/sendgrid" title="Topic: sendgrid">
#                sendgrid
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":109982,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="b6945469fc15440d95eb5fd55cdd777e4e0133d8662f5bc4ad5a68b302978c14" data-view-component="true" href="/topics/formspree" title="Topic: formspree">
#                formspree
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":133000,"originating_url":"https://github.com/topics/flask","user_id":null}}' data-hydro-click-hmac="8dd5ab264c9ce7dc66d2b63086e0f46854f2e3482407b5a9f091ab2fb805fe3d" data-view-component="true" href="/topics/jamstack" title="Topic: jamstack">
#                jamstack
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2019-11-13T17:27:05Z">Nov 13, 2019</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3572A5"></span>
#  <span itemprop="programmingLanguage">Python</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
base_url='https://github.com/topics/flask'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
 Repository_1_lst
# Out:
# [{'Repository Name': 'flask',
#   'User Name': 'pallets',
#   'stars': '59.7k',
#   'Repository URL': 'https://github.com/topics/flaskpallets/flask'},
#  {'Repository Name': 'superset',
#   'User Name': 'apache',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/topics/flaskapache/superset'},
#  {'Repository Name': 'dash',
#   'User Name': 'plotly',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/topics/flaskplotly/dash'},
#  {'Repository Name': 'proxy_pool',
#   'User Name': 'jhao104',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/topics/flaskjhao104/proxy_pool'},
#  {'Repository Name': 'Zappa',
#   'User Name': 'Miserlou',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/topics/flaskMiserlou/Zappa'},
#  {'Repository Name': 'awesome-flask',
#   'User Name': 'humiaozuzu',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/topics/flaskhumiaozuzu/awesome-flask'},
#  {'Repository Name': 'flasky',
#   'User Name': 'miguelgrinberg',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/topics/flaskmiguelgrinberg/flasky'},
#  {'Repository Name': 'trape',
#   'User Name': 'jofpin',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/topics/flaskjofpin/trape'},
#  {'Repository Name': 'blockchain',
#   'User Name': 'dvf',
#   'stars': '7k',
#   'Repository URL': 'https://github.com/topics/flaskdvf/blockchain'},
#  {'Repository Name': 'eve',
#   'User Name': 'pyeve',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/topics/flaskpyeve/eve'},
#  {'Repository Name': 'whoogle-search',
#   'User Name': 'benbusby',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/topics/flaskbenbusby/whoogle-search'},
#  {'Repository Name': 'grip',
#   'User Name': 'joeyespo',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/topics/flaskjoeyespo/grip'},
#  {'Repository Name': 'Flask-SocketIO',
#   'User Name': 'miguelgrinberg',
#   'stars': '4.7k',
#   'Repository URL': 'https://github.com/topics/flaskmiguelgrinberg/Flask-SocketIO'},
#  {'Repository Name': 'nginx-ui',
#   'User Name': 'schenkd',
#   'stars': '4.2k',
#   'Repository URL': 'https://github.com/topics/flaskschenkd/nginx-ui'},
#  {'Repository Name': 'cookiecutter-flask',
#   'User Name': 'cookiecutter-flask',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/topics/flaskcookiecutter-flask/cookiecutter-flask'},
#  {'Repository Name': 'CTFd',
#   'User Name': 'CTFd',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/topics/flaskCTFd/CTFd'},
#  {'Repository Name': 'microblog',
#   'User Name': 'miguelgrinberg',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/topics/flaskmiguelgrinberg/microblog'},
#  {'Repository Name': 'Flask-AppBuilder',
#   'User Name': 'dpgaspar',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/topics/flaskdpgaspar/Flask-AppBuilder'},
#  {'Repository Name': 'flask-sqlalchemy',
#   'User Name': 'pallets-eco',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/topics/flaskpallets-eco/flask-sqlalchemy'},
#  {'Repository Name': 'ProxyPool',
#   'User Name': 'Python3WebSpider',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/topics/flaskPython3WebSpider/ProxyPool'},
#  {'Repository Name': 'responder',
#   'User Name': 'taoufik07',
#   'stars': '3.6k',
#   'Repository URL': 'https://github.com/topics/flasktaoufik07/responder'},
#  {'Repository Name': 'dtale',
#   'User Name': 'man-group',
#   'stars': '3.5k',
#   'Repository URL': 'https://github.com/topics/flaskman-group/dtale'},
#  {'Repository Name': 'Deep-Learning-in-Production',
#   'User Name': 'ahkarami',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/topics/flaskahkarami/Deep-Learning-in-Production'},
#  {'Repository Name': 'toapi',
#   'User Name': 'gaojiuli',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/topics/flaskgaojiuli/toapi'},
#  {'Repository Name': 'flask_jsondash',
#   'User Name': 'christabor',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/topics/flaskchristabor/flask_jsondash'},
#  {'Repository Name': 'authlib',
#   'User Name': 'lepture',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/topics/flasklepture/authlib'},
#  {'Repository Name': 'ShadowSocksShare',
#   'User Name': 'the0demiurge',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/topics/flaskthe0demiurge/ShadowSocksShare'},
#  {'Repository Name': 'flasgger',
#   'User Name': 'flasgger',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/topics/flaskflasgger/flasgger'},
#  {'Repository Name': 'nyaa',
#   'User Name': 'nyaadevs',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/topics/flasknyaadevs/nyaa'},
#  {'Repository Name': 'formspree',
#   'User Name': 'formspree',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/topics/flaskformspree/formspree'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                 Repository Name           User Name  stars  \
# 0                         flask             pallets  59.7k
# 1                      superset              apache  46.9k
# 2                          dash              plotly  16.8k
# 3                    proxy_pool             jhao104  15.6k
# 4                         Zappa            Miserlou  11.9k
# 5                 awesome-flask          humiaozuzu  10.7k
# 6                        flasky      miguelgrinberg   7.8k
# 7                         trape              jofpin   7.1k
# 8                    blockchain                 dvf     7k
# 9                           eve               pyeve   6.5k
# 10               whoogle-search            benbusby   5.9k
# 11                         grip            joeyespo   5.7k
# 12               Flask-SocketIO      miguelgrinberg   4.7k
# 13                     nginx-ui             schenkd   4.2k
# 14           cookiecutter-flask  cookiecutter-flask   4.1k
# 15                         CTFd                CTFd   4.1k
# 16                    microblog      miguelgrinberg     4k
# 17             Flask-AppBuilder            dpgaspar   3.8k
# 18             flask-sqlalchemy         pallets-eco   3.8k
# 19                    ProxyPool    Python3WebSpider   3.7k
# 20                    responder           taoufik07   3.6k
# 21                        dtale           man-group   3.5k
# 22  Deep-Learning-in-Production            ahkarami   3.3k
# 23                        toapi            gaojiuli   3.3k
# 24               flask_jsondash          christabor   3.2k
# 25                      authlib             lepture   3.2k
# 26             ShadowSocksShare        the0demiurge   3.1k
# 27                     flasgger            flasgger     3k
# 28                         nyaa            nyaadevs     3k
# 29                    formspree           formspree   2.8k
#
#                                        Repository URL
# 0        https://github.com/topics/flaskpallets/flask
# 1      https://github.com/topics/flaskapache/superset
# 2          https://github.com/topics/flaskplotly/dash
# 3   https://github.com/topics/flaskjhao104/proxy_pool
# 4       https://github.com/topics/flaskMiserlou/Zappa
# 5   https://github.com/topics/flaskhumiaozuzu/awes...
# 6   https://github.com/topics/flaskmiguelgrinberg/...
# 7         https://github.com/topics/flaskjofpin/trape
# 8       https://github.com/topics/flaskdvf/blockchain
# 9            https://github.com/topics/flaskpyeve/eve
# 10  https://github.com/topics/flaskbenbusby/whoogl...
# 11       https://github.com/topics/flaskjoeyespo/grip
# 12  https://github.com/topics/flaskmiguelgrinberg/...
# 13    https://github.com/topics/flaskschenkd/nginx-ui
# 14  https://github.com/topics/flaskcookiecutter-fl...
# 15           https://github.com/topics/flaskCTFd/CTFd
# 16  https://github.com/topics/flaskmiguelgrinberg/...
# 17  https://github.com/topics/flaskdpgaspar/Flask-...
# 18  https://github.com/topics/flaskpallets-eco/fla...
# 19  https://github.com/topics/flaskPython3WebSpide...
# 20  https://github.com/topics/flasktaoufik07/respo...
# 21     https://github.com/topics/flaskman-group/dtale
# 22  https://github.com/topics/flaskahkarami/Deep-L...
# 23      https://github.com/topics/flaskgaojiuli/toapi
# 24  https://github.com/topics/flaskchristabor/flas...
# 25     https://github.com/topics/flasklepture/authlib
# 26  https://github.com/topics/flaskthe0demiurge/Sh...
# 27   https://github.com/topics/flaskflasgger/flasgger
# 28       https://github.com/topics/flasknyaadevs/nyaa
# 29  https://github.com/topics/flaskformspree/forms...

# %%
df.to_excel('flask.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/flask?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/flask?page=1',
#  'https://github.com/topics/flask?page=2',
#  'https://github.com/topics/flask?page=3',
#  'https://github.com/topics/flask?page=4',
#  'https://github.com/topics/flask?page=5',
#  'https://github.com/topics/flask?page=6',
#  'https://github.com/topics/flask?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/flask?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'flask',
#   'User Name': 'pallets',
#   'stars': '59.7k',
#   'Repository URL': 'https://github.com/pallets/flask'},
#  {'Sr No': 2,
#   'Repository Name': 'superset',
#   'User Name': 'apache',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/apache/superset'},
#  {'Sr No': 3,
#   'Repository Name': 'dash',
#   'User Name': 'plotly',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/plotly/dash'},
#  {'Sr No': 4,
#   'Repository Name': 'proxy_pool',
#   'User Name': 'jhao104',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/jhao104/proxy_pool'},
#  {'Sr No': 5,
#   'Repository Name': 'Zappa',
#   'User Name': 'Miserlou',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/Miserlou/Zappa'},
#  {'Sr No': 6,
#   'Repository Name': 'awesome-flask',
#   'User Name': 'humiaozuzu',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/humiaozuzu/awesome-flask'},
#  {'Sr No': 7,
#   'Repository Name': 'flasky',
#   'User Name': 'miguelgrinberg',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/miguelgrinberg/flasky'},
#  {'Sr No': 8,
#   'Repository Name': 'trape',
#   'User Name': 'jofpin',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/jofpin/trape'},
#  {'Sr No': 9,
#   'Repository Name': 'blockchain',
#   'User Name': 'dvf',
#   'stars': '7k',
#   'Repository URL': 'https://github.com/dvf/blockchain'},
#  {'Sr No': 10,
#   'Repository Name': 'eve',
#   'User Name': 'pyeve',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/pyeve/eve'},
#  {'Sr No': 11,
#   'Repository Name': 'whoogle-search',
#   'User Name': 'benbusby',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/benbusby/whoogle-search'},
#  {'Sr No': 12,
#   'Repository Name': 'grip',
#   'User Name': 'joeyespo',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/joeyespo/grip'},
#  {'Sr No': 13,
#   'Repository Name': 'Flask-SocketIO',
#   'User Name': 'miguelgrinberg',
#   'stars': '4.7k',
#   'Repository URL': 'https://github.com/miguelgrinberg/Flask-SocketIO'},
#  {'Sr No': 14,
#   'Repository Name': 'nginx-ui',
#   'User Name': 'schenkd',
#   'stars': '4.2k',
#   'Repository URL': 'https://github.com/schenkd/nginx-ui'},
#  {'Sr No': 15,
#   'Repository Name': 'cookiecutter-flask',
#   'User Name': 'cookiecutter-flask',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/cookiecutter-flask/cookiecutter-flask'},
#  {'Sr No': 16,
#   'Repository Name': 'CTFd',
#   'User Name': 'CTFd',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/CTFd/CTFd'},
#  {'Sr No': 17,
#   'Repository Name': 'microblog',
#   'User Name': 'miguelgrinberg',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/miguelgrinberg/microblog'},
#  {'Sr No': 18,
#   'Repository Name': 'Flask-AppBuilder',
#   'User Name': 'dpgaspar',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/dpgaspar/Flask-AppBuilder'},
#  {'Sr No': 19,
#   'Repository Name': 'flask-sqlalchemy',
#   'User Name': 'pallets-eco',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/pallets-eco/flask-sqlalchemy'},
#  {'Sr No': 20,
#   'Repository Name': 'ProxyPool',
#   'User Name': 'Python3WebSpider',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/Python3WebSpider/ProxyPool'},
#  {'Sr No': 21,
#   'Repository Name': 'responder',
#   'User Name': 'taoufik07',
#   'stars': '3.6k',
#   'Repository URL': 'https://github.com/taoufik07/responder'},
#  {'Sr No': 22,
#   'Repository Name': 'dtale',
#   'User Name': 'man-group',
#   'stars': '3.5k',
#   'Repository URL': 'https://github.com/man-group/dtale'},
#  {'Sr No': 23,
#   'Repository Name': 'Deep-Learning-in-Production',
#   'User Name': 'ahkarami',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/ahkarami/Deep-Learning-in-Production'},
#  {'Sr No': 24,
#   'Repository Name': 'toapi',
#   'User Name': 'gaojiuli',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/gaojiuli/toapi'},
#  {'Sr No': 25,
#   'Repository Name': 'flask_jsondash',
#   'User Name': 'christabor',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/christabor/flask_jsondash'},
#  {'Sr No': 26,
#   'Repository Name': 'authlib',
#   'User Name': 'lepture',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/lepture/authlib'},
#  {'Sr No': 27,
#   'Repository Name': 'ShadowSocksShare',
#   'User Name': 'the0demiurge',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/the0demiurge/ShadowSocksShare'},
#  {'Sr No': 28,
#   'Repository Name': 'flasgger',
#   'User Name': 'flasgger',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/flasgger/flasgger'},
#  {'Sr No': 29,
#   'Repository Name': 'nyaa',
#   'User Name': 'nyaadevs',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/nyaadevs/nyaa'},
#  {'Sr No': 30,
#   'Repository Name': 'formspree',
#   'User Name': 'formspree',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/formspree/formspree'},
#  {'Sr No': 31,
#   'Repository Name': 'flask-base',
#   'User Name': 'hack4impact',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/hack4impact/flask-base'},
#  {'Sr No': 32,
#   'Repository Name': 'uwsgi-nginx-flask-docker',
#   'User Name': 'tiangolo',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/tiangolo/uwsgi-nginx-flask-docker'},
#  {'Sr No': 33,
#   'Repository Name': 'flask-restplus',
#   'User Name': 'noirbizarre',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/noirbizarre/flask-restplus'},
#  {'Sr No': 34,
#   'Repository Name': 'SMSBoom',
#   'User Name': 'WhaleFell',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/WhaleFell/SMSBoom'},
#  {'Sr No': 35,
#   'Repository Name': 'app',
#   'User Name': 'simple-login',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/simple-login/app'},
#  {'Sr No': 36,
#   'Repository Name': 'dynaconf',
#   'User Name': 'rochacbruno',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/rochacbruno/dynaconf'},
#  {'Sr No': 37,
#   'Repository Name': 'Machine-Learning-with-Python',
#   'User Name': 'tirthajyoti',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/tirthajyoti/Machine-Learning-with-Python'},
#  {'Sr No': 38,
#   'Repository Name': 'flaskbb',
#   'User Name': 'flaskbb',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/flaskbb/flaskbb'},
#  {'Sr No': 39,
#   'Repository Name': 'quokka',
#   'User Name': 'quokkaproject',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/quokkaproject/quokka'},
#  {'Sr No': 40,
#   'Repository Name': 'python-dependency-injector',
#   'User Name': 'ets-labs',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/ets-labs/python-dependency-injector'},
#  {'Sr No': 41,
#   'Repository Name': 'flaskr-tdd',
#   'User Name': 'mjhea0',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/mjhea0/flaskr-tdd'},
#  {'Sr No': 42,
#   'Repository Name': 'pyt',
#   'User Name': 'python-security',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/python-security/pyt'},
#  {'Sr No': 43,
#   'Repository Name': 'Flask-Migrate',
#   'User Name': 'miguelgrinberg',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/miguelgrinberg/Flask-Migrate'},
#  {'Sr No': 44,
#   'Repository Name': 'flask-ask',
#   'User Name': 'johnwheeler',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/johnwheeler/flask-ask'},
#  {'Sr No': 45,
#   'Repository Name': '30-Days-of-Python',
#   'User Name': 'codingforentrepreneurs',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/codingforentrepreneurs/30-Days-of-Python'},
#  {'Sr No': 46,
#   'Repository Name': 'Yacht',
#   'User Name': 'SelfhostedPro',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/SelfhostedPro/Yacht'},
#  {'Sr No': 47,
#   'Repository Name': 'wechat-admin',
#   'User Name': 'dongweiming',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/dongweiming/wechat-admin'},
#  {'Sr No': 48,
#   'Repository Name': 'explore-flask',
#   'User Name': 'rpicard',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/rpicard/explore-flask'},
#  {'Sr No': 49,
#   'Repository Name': 'best-of-web-python',
#   'User Name': 'ml-tooling',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/ml-tooling/best-of-web-python'},
#  {'Sr No': 50,
#   'Repository Name': 'flask-restx',
#   'User Name': 'python-restx',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/python-restx/flask-restx'},
#  {'Sr No': 51,
#   'Repository Name': 'Zappa',
#   'User Name': 'zappa',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/zappa/Zappa'},
#  {'Sr No': 52,
#   'Repository Name': 'sqlite-web',
#   'User Name': 'coleifer',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/coleifer/sqlite-web'},
#  {'Sr No': 53,
#   'Repository Name': 'PyOne',
#   'User Name': 'abbeyokgo',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/abbeyokgo/PyOne'},
#  {'Sr No': 54,
#   'Repository Name': 'React-Redux-Flask',
#   'User Name': 'dternyak',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/dternyak/React-Redux-Flask'},
#  {'Sr No': 55,
#   'Repository Name': 'flask-oauthlib',
#   'User Name': 'lepture',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/lepture/flask-oauthlib'},
#  {'Sr No': 56,
#   'Repository Name': 'helloflask',
#   'User Name': 'greyli',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/greyli/helloflask'},
#  {'Sr No': 57,
#   'Repository Name': 'indico',
#   'User Name': 'indico',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/indico/indico'},
#  {'Sr No': 58,
#   'Repository Name': 'gxgk-wechat-server',
#   'User Name': 'paicha',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/paicha/gxgk-wechat-server'},
#  {'Sr No': 59,
#   'Repository Name': 'flask-jwt-extended',
#   'User Name': 'vimalloc',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/vimalloc/flask-jwt-extended'},
#  {'Sr No': 60,
#   'Repository Name': 'weixin-python',
#   'User Name': 'zwczou',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/zwczou/weixin-python'},
#  {'Sr No': 61,
#   'Repository Name': 'flask-restplus-server-example',
#   'User Name': 'frol',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/frol/flask-restplus-server-example'},
#  {'Sr No': 62,
#   'Repository Name': 'flask-wtf',
#   'User Name': 'wtforms',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/wtforms/flask-wtf'},
#  {'Sr No': 63,
#   'Repository Name': 'flask-graphql',
#   'User Name': 'graphql-python',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/graphql-python/flask-graphql'},
#  {'Sr No': 64,
#   'Repository Name': 'webargs',
#   'User Name': 'marshmallow-code',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/marshmallow-code/webargs'},
#  {'Sr No': 65,
#   'Repository Name': 'reloadium',
#   'User Name': 'reloadware',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/reloadware/reloadium'},
#  {'Sr No': 66,
#   'Repository Name': 'flask-vuejs-template',
#   'User Name': 'gtalarico',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/gtalarico/flask-vuejs-template'},
#  {'Sr No': 67,
#   'Repository Name': 'flask-website',
#   'User Name': 'pallets',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/pallets/flask-website'},
#  {'Sr No': 68,
#   'Repository Name': 'querybook',
#   'User Name': 'pinterest',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/pinterest/querybook'},
#  {'Sr No': 69,
#   'Repository Name': 'web_develop',
#   'User Name': 'dongweiming',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/dongweiming/web_develop'},
#  {'Sr No': 70,
#   'Repository Name': 'tensorflow-101',
#   'User Name': 'burness',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/burness/tensorflow-101'},
#  {'Sr No': 71,
#   'Repository Name': 'Flask-HTTPAuth',
#   'User Name': 'miguelgrinberg',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/miguelgrinberg/Flask-HTTPAuth'},
#  {'Sr No': 72,
#   'Repository Name': 'invoice',
#   'User Name': 'guanshuicheng',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/guanshuicheng/invoice'},
#  {'Sr No': 73,
#   'Repository Name': 'OpenClubhouse',
#   'User Name': 'ai-eks',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/ai-eks/OpenClubhouse'},
#  {'Sr No': 74,
#   'Repository Name': 'keras-flask-deploy-webapp',
#   'User Name': 'imfing',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/imfing/keras-flask-deploy-webapp'},
#  {'Sr No': 75,
#   'Repository Name': 'apispec',
#   'User Name': 'marshmallow-code',
#   'stars': '965',
#   'Repository URL': 'https://github.com/marshmallow-code/apispec'},
#  {'Sr No': 76,
#   'Repository Name': 'V2RayCloudSpider',
#   'User Name': 'QIN2DIM',
#   'stars': '971',
#   'Repository URL': 'https://github.com/QIN2DIM/V2RayCloudSpider'},
#  {'Sr No': 77,
#   'Repository Name': 'heroku-buildpack-python',
#   'User Name': 'heroku',
#   'stars': '928',
#   'Repository URL': 'https://github.com/heroku/heroku-buildpack-python'},
#  {'Sr No': 78,
#   'Repository Name': 'flask-bones',
#   'User Name': 'cburmeister',
#   'stars': '938',
#   'Repository URL': 'https://github.com/cburmeister/flask-bones'},
#  {'Sr No': 79,
#   'Repository Name': 'awesome-flask',
#   'User Name': 'mjhea0',
#   'stars': '936',
#   'Repository URL': 'https://github.com/mjhea0/awesome-flask'},
#  {'Sr No': 80,
#   'Repository Name': 'pytorch_classification',
#   'User Name': 'lxztju',
#   'stars': '924',
#   'Repository URL': 'https://github.com/lxztju/pytorch_classification'},
#  {'Sr No': 81,
#   'Repository Name': 'chinese-dos-games-web',
#   'User Name': 'rwv',
#   'stars': '946',
#   'Repository URL': 'https://github.com/rwv/chinese-dos-games-web'},
#  {'Sr No': 82,
#   'Repository Name': 'bibi',
#   'User Name': 'seasonstar',
#   'stars': '911',
#   'Repository URL': 'https://github.com/seasonstar/bibi'},
#  {'Sr No': 83,
#   'Repository Name': 'flask-apscheduler',
#   'User Name': 'viniciuschiele',
#   'stars': '917',
#   'Repository URL': 'https://github.com/viniciuschiele/flask-apscheduler'},
#  {'Sr No': 84,
#   'Repository Name': 'rest-apis-flask-python',
#   'User Name': 'tecladocode',
#   'stars': '917',
#   'Repository URL': 'https://github.com/tecladocode/rest-apis-flask-python'},
#  {'Sr No': 85,
#   'Repository Name': 'Flask-Scaffold',
#   'User Name': 'Leo-G',
#   'stars': '879',
#   'Repository URL': 'https://github.com/Leo-G/Flask-Scaffold'},
#  {'Sr No': 86,
#   'Repository Name': 'Never-Blink',
#   'User Name': 'ByronHsu',
#   'stars': '852',
#   'Repository URL': 'https://github.com/ByronHsu/Never-Blink'},
#  {'Sr No': 87,
#   'Repository Name': 'Python24',
#   'User Name': 'HaoZhang95',
#   'stars': '901',
#   'Repository URL': 'https://github.com/HaoZhang95/Python24'},
#  {'Sr No': 88,
#   'Repository Name': 'TableExport',
#   'User Name': 'clarketm',
#   'stars': '836',
#   'Repository URL': 'https://github.com/clarketm/TableExport'},
#  {'Sr No': 89,
#   'Repository Name': 'restless',
#   'User Name': 'toastdriven',
#   'stars': '824',
#   'Repository URL': 'https://github.com/toastdriven/restless'},
#  {'Sr No': 90,
#   'Repository Name': 'mixer',
#   'User Name': 'klen',
#   'stars': '836',
#   'Repository URL': 'https://github.com/klen/mixer'},
#  {'Sr No': 91,
#   'Repository Name': 'build-a-saas-app-with-flask',
#   'User Name': 'nickjj',
#   'stars': '821',
#   'Repository URL': 'https://github.com/nickjj/build-a-saas-app-with-flask'},
#  {'Sr No': 92,
#   'Repository Name': 'flask-mongoengine',
#   'User Name': 'MongoEngine',
#   'stars': '802',
#   'Repository URL': 'https://github.com/MongoEngine/flask-mongoengine'},
#  {'Sr No': 93,
#   'Repository Name': 'sparrow',
#   'User Name': 'wylok',
#   'stars': '807',
#   'Repository URL': 'https://github.com/wylok/sparrow'},
#  {'Sr No': 94,
#   'Repository Name': 'spark-movie-lens',
#   'User Name': 'jadianes',
#   'stars': '788',
#   'Repository URL': 'https://github.com/jadianes/spark-movie-lens'},
#  {'Sr No': 95,
#   'Repository Name': 'flask-peewee',
#   'User Name': 'coleifer',
#   'stars': '752',
#   'Repository URL': 'https://github.com/coleifer/flask-peewee'},
#  {'Sr No': 96,
#   'Repository Name': 'flask-marshmallow',
#   'User Name': 'marshmallow-code',
#   'stars': '747',
#   'Repository URL': 'https://github.com/marshmallow-code/flask-marshmallow'},
#  {'Sr No': 97,
#   'Repository Name': 'kamiFaka',
#   'User Name': 'Baiyuetribe',
#   'stars': '752',
#   'Repository URL': 'https://github.com/Baiyuetribe/kamiFaka'},
#  {'Sr No': 98,
#   'Repository Name': 'bowtie',
#   'User Name': 'jwkvam',
#   'stars': '749',
#   'Repository URL': 'https://github.com/jwkvam/bowtie'},
#  {'Sr No': 99,
#   'Repository Name': 'ihatemoney',
#   'User Name': 'spiral-project',
#   'stars': '746',
#   'Repository URL': 'https://github.com/spiral-project/ihatemoney'},
#  {'Sr No': 100,
#   'Repository Name': 'flaskex',
#   'User Name': 'anfederico',
#   'stars': '737',
#   'Repository URL': 'https://github.com/anfederico/flaskex'},
#  {'Sr No': 101,
#   'Repository Name': 'hellogithub.com',
#   'User Name': '521xueweihan',
#   'stars': '725',
#   'Repository URL': 'https://github.com/521xueweihan/hellogithub.com'},
#  {'Sr No': 102,
#   'Repository Name': 'lin-cms-flask',
#   'User Name': 'TaleLin',
#   'stars': '724',
#   'Repository URL': 'https://github.com/TaleLin/lin-cms-flask'},
#  {'Sr No': 103,
#   'Repository Name': 'flask-caching',
#   'User Name': 'pallets-eco',
#   'stars': '726',
#   'Repository URL': 'https://github.com/pallets-eco/flask-caching'},
#  {'Sr No': 104,
#   'Repository Name': 'Frozen-Flask',
#   'User Name': 'Frozen-Flask',
#   'stars': '719',
#   'Repository URL': 'https://github.com/Frozen-Flask/Frozen-Flask'},
#  {'Sr No': 105,
#   'Repository Name': 'bootstrap-flask',
#   'User Name': 'helloflask',
#   'stars': '711',
#   'Repository URL': 'https://github.com/helloflask/bootstrap-flask'},
#  {'Sr No': 106,
#   'Repository Name': 'chartkick.py',
#   'User Name': 'mher',
#   'stars': '693',
#   'Repository URL': 'https://github.com/mher/chartkick.py'},
#  {'Sr No': 107,
#   'Repository Name': 'zenodo',
#   'User Name': 'zenodo',
#   'stars': '693',
#   'Repository URL': 'https://github.com/zenodo/zenodo'},
#  {'Sr No': 108,
#   'Repository Name': 'gae-boilerplate',
#   'User Name': 'coto',
#   'stars': '689',
#   'Repository URL': 'https://github.com/coto/gae-boilerplate'},
#  {'Sr No': 109,
#   'Repository Name': 'cookiecutter-flask-restful',
#   'User Name': 'karec',
#   'stars': '697',
#   'Repository URL': 'https://github.com/karec/cookiecutter-flask-restful'},
#  {'Sr No': 110,
#   'Repository Name': 'flask-profiler',
#   'User Name': 'muatik',
#   'stars': '695',
#   'Repository URL': 'https://github.com/muatik/flask-profiler'},
#  {'Sr No': 111,
#   'Repository Name': 'flask-vuejs-madblog',
#   'User Name': 'wangy8961',
#   'stars': '688',
#   'Repository URL': 'https://github.com/wangy8961/flask-vuejs-madblog'},
#  {'Sr No': 112,
#   'Repository Name': 'Multi-Camera-Live-Object-Tracking',
#   'User Name': 'LeonLok',
#   'stars': '669',
#   'Repository URL': 'https://github.com/LeonLok/Multi-Camera-Live-Object-Tracking'},
#  {'Sr No': 113,
#   'Repository Name': 'open-source-saas-boilerpate',
#   'User Name': 'saasforge',
#   'stars': '666',
#   'Repository URL': 'https://github.com/saasforge/open-source-saas-boilerpate'},
#  {'Sr No': 114,
#   'Repository Name': 'FXTest',
#   'User Name': 'liwanlei',
#   'stars': '664',
#   'Repository URL': 'https://github.com/liwanlei/FXTest'},
#  {'Sr No': 115,
#   'Repository Name': 'flask-restful-swagger',
#   'User Name': 'rantav',
#   'stars': '653',
#   'Repository URL': 'https://github.com/rantav/flask-restful-swagger'},
#  {'Sr No': 116,
#   'Repository Name': 'mlh-hackathon-flask-starter',
#   'User Name': 'MLH',
#   'stars': '651',
#   'Repository URL': 'https://github.com/MLH/mlh-hackathon-flask-starter'},
#  {'Sr No': 117,
#   'Repository Name': 'Flask-Blogging',
#   'User Name': 'gouthambs',
#   'stars': '647',
#   'Repository URL': 'https://github.com/gouthambs/Flask-Blogging'},
#  {'Sr No': 118,
#   'Repository Name': 'flask-empty',
#   'User Name': 'italomaia',
#   'stars': '624',
#   'Repository URL': 'https://github.com/italomaia/flask-empty'},
#  {'Sr No': 119,
#   'Repository Name': 'Flask-MonitoringDashboard',
#   'User Name': 'flask-dashboard',
#   'stars': '631',
#   'Repository URL': 'https://github.com/flask-dashboard/Flask-MonitoringDashboard'},
#  {'Sr No': 120,
#   'Repository Name': 'flask-restful-example',
#   'User Name': 'qzq1111',
#   'stars': '639',
#   'Repository URL': 'https://github.com/qzq1111/flask-restful-example'},
#  {'Sr No': 121,
#   'Repository Name': 'secure',
#   'User Name': 'cak',
#   'stars': '622',
#   'Repository URL': 'https://github.com/cak/secure'},
#  {'Sr No': 122,
#   'Repository Name': 'apiflask',
#   'User Name': 'apiflask',
#   'stars': '600',
#   'Repository URL': 'https://github.com/apiflask/apiflask'},
#  {'Sr No': 123,
#   'Repository Name': 'flask-rest-jsonapi',
#   'User Name': 'miLibris',
#   'stars': '597',
#   'Repository URL': 'https://github.com/miLibris/flask-rest-jsonapi'},
#  {'Sr No': 124,
#   'Repository Name': 'PyMessager',
#   'User Name': 'enginebai',
#   'stars': '592',
#   'Repository URL': 'https://github.com/enginebai/PyMessager'},
#  {'Sr No': 125,
#   'Repository Name': 'Flask-GoogleMaps',
#   'User Name': 'flask-extensions',
#   'stars': '597',
#   'Repository URL': 'https://github.com/flask-extensions/Flask-GoogleMaps'},
#  {'Sr No': 126,
#   'Repository Name': 'flask-vue-crud',
#   'User Name': 'testdrivenio',
#   'stars': '614',
#   'Repository URL': 'https://github.com/testdrivenio/flask-vue-crud'},
#  {'Sr No': 127,
#   'Repository Name': 'pygmy',
#   'User Name': 'amitt001',
#   'stars': '585',
#   'Repository URL': 'https://github.com/amitt001/pygmy'},
#  {'Sr No': 128,
#   'Repository Name': 'flask-restplus-boilerplate',
#   'User Name': 'cosmic-byte',
#   'stars': '592',
#   'Repository URL': 'https://github.com/cosmic-byte/flask-restplus-boilerplate'},
#  {'Sr No': 129,
#   'Repository Name': 'bolt-python',
#   'User Name': 'slackapi',
#   'stars': '571',
#   'Repository URL': 'https://github.com/slackapi/bolt-python'},
#  {'Sr No': 130,
#   'Repository Name': 'python-flask-microservice',
#   'User Name': 'ssola',
#   'stars': '569',
#   'Repository URL': 'https://github.com/ssola/python-flask-microservice'},
#  {'Sr No': 131,
#   'Repository Name': 'python-engineer-roadmap',
#   'User Name': 'DjangoEx',
#   'stars': '567',
#   'Repository URL': 'https://github.com/DjangoEx/python-engineer-roadmap'},
#  {'Sr No': 132,
#   'Repository Name': 'LXC-Web-Panel',
#   'User Name': 'lxc-webpanel',
#   'stars': '563',
#   'Repository URL': 'https://github.com/lxc-webpanel/LXC-Web-Panel'},
#  {'Sr No': 133,
#   'Repository Name': 'osroom',
#   'User Name': 'osroom',
#   'stars': '562',
#   'Repository URL': 'https://github.com/osroom/osroom'},
#  {'Sr No': 134,
#   'Repository Name': 'sis',
#   'User Name': 'matsui528',
#   'stars': '596',
#   'Repository URL': 'https://github.com/matsui528/sis'},
#  {'Sr No': 135,
#   'Repository Name': 'pepy',
#   'User Name': 'psincraian',
#   'stars': '593',
#   'Repository URL': 'https://github.com/psincraian/pepy'},
#  {'Sr No': 136,
#   'Repository Name': 'swagger-py-codegen',
#   'User Name': 'guokr',
#   'stars': '546',
#   'Repository URL': 'https://github.com/guokr/swagger-py-codegen'},
#  {'Sr No': 137,
#   'Repository Name': 'python-project-template',
#   'User Name': 'rochacbruno',
#   'stars': '550',
#   'Repository URL': 'https://github.com/rochacbruno/python-project-template'},
#  {'Sr No': 138,
#   'Repository Name': 'flask-gentelella',
#   'User Name': 'afourmy',
#   'stars': '551',
#   'Repository URL': 'https://github.com/afourmy/flask-gentelella'},
#  {'Sr No': 139,
#   'Repository Name': 'gae-init',
#   'User Name': 'gae-init',
#   'stars': '534',
#   'Repository URL': 'https://github.com/gae-init/gae-init'},
#  {'Sr No': 140,
#   'Repository Name': 'mini-shop-server',
#   'User Name': 'Allen7D',
#   'stars': '543',
#   'Repository URL': 'https://github.com/Allen7D/mini-shop-server'},
#  {'Sr No': 141,
#   'Repository Name': 'invenio',
#   'User Name': 'inveniosoftware',
#   'stars': '535',
#   'Repository URL': 'https://github.com/inveniosoftware/invenio'},
#  {'Sr No': 142,
#   'Repository Name': 'flask-tutorial',
#   'User Name': 'helloflask',
#   'stars': '543',
#   'Repository URL': 'https://github.com/helloflask/flask-tutorial'},
#  {'Sr No': 143,
#   'Repository Name': 'cesi',
#   'User Name': 'gamegos',
#   'stars': '531',
#   'Repository URL': 'https://github.com/gamegos/cesi'},
#  {'Sr No': 144,
#   'Repository Name': 'autotest_platform',
#   'User Name': 'jerrylizilong',
#   'stars': '521',
#   'Repository URL': 'https://github.com/jerrylizilong/autotest_platform'},
#  {'Sr No': 145,
#   'Repository Name': 'minimal-django',
#   'User Name': 'rnevius',
#   'stars': '519',
#   'Repository URL': 'https://github.com/rnevius/minimal-django'},
#  {'Sr No': 146,
#   'Repository Name': 'flask_reddit',
#   'User Name': 'codelucas',
#   'stars': '509',
#   'Repository URL': 'https://github.com/codelucas/flask_reddit'},
#  {'Sr No': 147,
#   'Repository Name': 'opendata.cern.ch',
#   'User Name': 'cernopendata',
#   'stars': '509',
#   'Repository URL': 'https://github.com/cernopendata/opendata.cern.ch'},
#  {'Sr No': 148,
#   'Repository Name': 'pb',
#   'User Name': 'ptpb',
#   'stars': '501',
#   'Repository URL': 'https://github.com/ptpb/pb'},
#  {'Sr No': 149,
#   'Repository Name': 'DailyNotes',
#   'User Name': 'm0ngr31',
#   'stars': '504',
#   'Repository URL': 'https://github.com/m0ngr31/DailyNotes'},
#  {'Sr No': 150,
#   'Repository Name': 'arxiv-sanity-lite',
#   'User Name': 'karpathy',
#   'stars': '562',
#   'Repository URL': 'https://github.com/karpathy/arxiv-sanity-lite'},
#  {'Sr No': 151,
#   'Repository Name': 'beibq',
#   'User Name': 'chaijunit',
#   'stars': '503',
#   'Repository URL': 'https://github.com/chaijunit/beibq'},
#  {'Sr No': 152,
#   'Repository Name': 'QQZoneMood',
#   'User Name': 'Maicius',
#   'stars': '496',
#   'Repository URL': 'https://github.com/Maicius/QQZoneMood'},
#  {'Sr No': 153,
#   'Repository Name': 'full-stack',
#   'User Name': 'tiangolo',
#   'stars': '501',
#   'Repository URL': 'https://github.com/tiangolo/full-stack'},
#  {'Sr No': 154,
#   'Repository Name': 'annotated-py-projects',
#   'User Name': 'hhstore',
#   'stars': '515',
#   'Repository URL': 'https://github.com/hhstore/annotated-py-projects'},
#  {'Sr No': 155,
#   'Repository Name': 'flaskSaaS',
#   'User Name': 'alectrocute',
#   'stars': '508',
#   'Repository URL': 'https://github.com/alectrocute/flaskSaaS'},
#  {'Sr No': 156,
#   'Repository Name': 'flack',
#   'User Name': 'miguelgrinberg',
#   'stars': '491',
#   'Repository URL': 'https://github.com/miguelgrinberg/flack'},
#  {'Sr No': 157,
#   'Repository Name': 'potion',
#   'User Name': 'biosustain',
#   'stars': '487',
#   'Repository URL': 'https://github.com/biosustain/potion'},
#  {'Sr No': 158,
#   'Repository Name': 'data-driven-web-apps-with-flask',
#   'User Name': 'talkpython',
#   'stars': '482',
#   'Repository URL': 'https://github.com/talkpython/data-driven-web-apps-with-flask'},
#  {'Sr No': 159,
#   'Repository Name': 'TradingView-Webhook-Bot',
#   'User Name': 'fabston',
#   'stars': '565',
#   'Repository URL': 'https://github.com/fabston/TradingView-Webhook-Bot'},
#  {'Sr No': 160,
#   'Repository Name': 'Yotter',
#   'User Name': 'ytorg',
#   'stars': '472',
#   'Repository URL': 'https://github.com/ytorg/Yotter'},
#  {'Sr No': 161,
#   'Repository Name': 'prometheus_flask_exporter',
#   'User Name': 'rycus86',
#   'stars': '485',
#   'Repository URL': 'https://github.com/rycus86/prometheus_flask_exporter'},
#  {'Sr No': 162,
#   'Repository Name': 'flask-smorest',
#   'User Name': 'marshmallow-code',
#   'stars': '465',
#   'Repository URL': 'https://github.com/marshmallow-code/flask-smorest'},
#  {'Sr No': 163,
#   'Repository Name': 'cmdb',
#   'User Name': 'pycook',
#   'stars': '445',
#   'Repository URL': 'https://github.com/pycook/cmdb'},
#  {'Sr No': 164,
#   'Repository Name': 'maple-bbs',
#   'User Name': 'honmaple',
#   'stars': '445',
#   'Repository URL': 'https://github.com/honmaple/maple-bbs'},
#  {'Sr No': 165,
#   'Repository Name': 'serverless-wsgi',
#   'User Name': 'logandk',
#   'stars': '433',
#   'Repository URL': 'https://github.com/logandk/serverless-wsgi'},
#  {'Sr No': 166,
#   'Repository Name': 'OctBlog',
#   'User Name': 'flyhigher139',
#   'stars': '430',
#   'Repository URL': 'https://github.com/flyhigher139/OctBlog'},
#  {'Sr No': 167,
#   'Repository Name': 'Douyin_TikTok_Download_API',
#   'User Name': 'Evil0ctal',
#   'stars': '441',
#   'Repository URL': 'https://github.com/Evil0ctal/Douyin_TikTok_Download_API'},
#  {'Sr No': 168,
#   'Repository Name': 'pytest-flask',
#   'User Name': 'pytest-dev',
#   'stars': '423',
#   'Repository URL': 'https://github.com/pytest-dev/pytest-flask'},
#  {'Sr No': 169,
#   'Repository Name': 'flask-security',
#   'User Name': 'Flask-Middleware',
#   'stars': '423',
#   'Repository URL': 'https://github.com/Flask-Middleware/flask-security'},
#  {'Sr No': 170,
#   'Repository Name': 'PyFladesk',
#   'User Name': 'smoqadam',
#   'stars': '424',
#   'Repository URL': 'https://github.com/smoqadam/PyFladesk'},
#  {'Sr No': 171,
#   'Repository Name': 'meinheld-gunicorn-flask-docker',
#   'User Name': 'tiangolo',
#   'stars': '428',
#   'Repository URL': 'https://github.com/tiangolo/meinheld-gunicorn-flask-docker'},
#  {'Sr No': 172,
#   'Repository Name': 'cnn_handwritten_chinese_recognition',
#   'User Name': 'taosir',
#   'stars': '422',
#   'Repository URL': 'https://github.com/taosir/cnn_handwritten_chinese_recognition'},
#  {'Sr No': 173,
#   'Repository Name': 'enferno',
#   'User Name': 'level09',
#   'stars': '406',
#   'Repository URL': 'https://github.com/level09/enferno'},
#  {'Sr No': 174,
#   'Repository Name': 'flask-redis',
#   'User Name': 'underyx',
#   'stars': '407',
#   'Repository URL': 'https://github.com/underyx/flask-redis'},
#  {'Sr No': 175,
#   'Repository Name': 'plotlydash-flask-tutorial',
#   'User Name': 'toddbirchard',
#   'stars': '406',
#   'Repository URL': 'https://github.com/toddbirchard/plotlydash-flask-tutorial'},
#  {'Sr No': 176,
#   'Repository Name': 'ojbk_jiexi',
#   'User Name': 'abbeyokgo',
#   'stars': '395',
#   'Repository URL': 'https://github.com/abbeyokgo/ojbk_jiexi'},
#  {'Sr No': 177,
#   'Repository Name': 'tasking-manager',
#   'User Name': 'hotosm',
#   'stars': '395',
#   'Repository URL': 'https://github.com/hotosm/tasking-manager'},
#  {'Sr No': 178,
#   'Repository Name': 'flask-session',
#   'User Name': 'fengsp',
#   'stars': '395',
#   'Repository URL': 'https://github.com/fengsp/flask-session'},
#  {'Sr No': 179,
#   'Repository Name': 'flask-vuejs',
#   'User Name': 'yymm',
#   'stars': '390',
#   'Repository URL': 'https://github.com/yymm/flask-vuejs'},
#  {'Sr No': 180,
#   'Repository Name': 'explore-flask-zh',
#   'User Name': 'spacewander',
#   'stars': '388',
#   'Repository URL': 'https://github.com/spacewander/explore-flask-zh'},
#  {'Sr No': 181,
#   'Repository Name': 'Topaz',
#   'User Name': 'Naresh1318',
#   'stars': '383',
#   'Repository URL': 'https://github.com/Naresh1318/Topaz'},
#  {'Sr No': 182,
#   'Repository Name': 'turkce-python-kaynaklari',
#   'User Name': 'ibrahimirdem',
#   'stars': '382',
#   'Repository URL': 'https://github.com/ibrahimirdem/turkce-python-kaynaklari'},
#  {'Sr No': 183,
#   'Repository Name': 'flask-session-cookie-manager',
#   'User Name': 'noraj',
#   'stars': '373',
#   'Repository URL': 'https://github.com/noraj/flask-session-cookie-manager'},
#  {'Sr No': 184,
#   'Repository Name': 'flask-api-starter-kit',
#   'User Name': 'antkahn',
#   'stars': '378',
#   'Repository URL': 'https://github.com/antkahn/flask-api-starter-kit'},
#  {'Sr No': 185,
#   'Repository Name': 'apm-agent-python',
#   'User Name': 'elastic',
#   'stars': '356',
#   'Repository URL': 'https://github.com/elastic/apm-agent-python'},
#  {'Sr No': 186,
#   'Repository Name': 'safrs',
#   'User Name': 'thomaxxl',
#   'stars': '346',
#   'Repository URL': 'https://github.com/thomaxxl/safrs'},
#  {'Sr No': 187,
#   'Repository Name': 'freki',
#   'User Name': 'cristianzsh',
#   'stars': '344',
#   'Repository URL': 'https://github.com/cristianzsh/freki'},
#  {'Sr No': 188,
#   'Repository Name': 'baymax',
#   'User Name': 'no13bus',
#   'stars': '341',
#   'Repository URL': 'https://github.com/no13bus/baymax'},
#  {'Sr No': 189,
#   'Repository Name': 'SSDBAdmin',
#   'User Name': 'jhao104',
#   'stars': '341',
#   'Repository URL': 'https://github.com/jhao104/SSDBAdmin'},
#  {'Sr No': 190,
#   'Repository Name': 'flask-chatterbot',
#   'User Name': 'chamkank',
#   'stars': '348',
#   'Repository URL': 'https://github.com/chamkank/flask-chatterbot'},
#  {'Sr No': 191,
#   'Repository Name': 'wikipedia-map',
#   'User Name': 'controversial',
#   'stars': '350',
#   'Repository URL': 'https://github.com/controversial/wikipedia-map'},
#  {'Sr No': 192,
#   'Repository Name': 'flask-blueprint-tutorial',
#   'User Name': 'hackersandslackers',
#   'stars': '355',
#   'Repository URL': 'https://github.com/hackersandslackers/flask-blueprint-tutorial'},
#  {'Sr No': 193,
#   'Repository Name': 'flask-bookshelf',
#   'User Name': 'damyanbogoev',
#   'stars': '336',
#   'Repository URL': 'https://github.com/damyanbogoev/flask-bookshelf'},
#  {'Sr No': 194,
#   'Repository Name': 'news-search-engine',
#   'User Name': '01joy',
#   'stars': '357',
#   'Repository URL': 'https://github.com/01joy/news-search-engine'},
#  {'Sr No': 195,
#   'Repository Name': 'fastwsgi',
#   'User Name': 'jamesroberts',
#   'stars': '333',
#   'Repository URL': 'https://github.com/jamesroberts/fastwsgi'},
#  {'Sr No': 196,
#   'Repository Name': 'admin-dashboards',
#   'User Name': 'app-generator',
#   'stars': '334',
#   'Repository URL': 'https://github.com/app-generator/admin-dashboards'},
#  {'Sr No': 197,
#   'Repository Name': 'renrenBackup',
#   'User Name': 'whusnoopy',
#   'stars': '335',
#   'Repository URL': 'https://github.com/whusnoopy/renrenBackup'},
#  {'Sr No': 198,
#   'Repository Name': 'redis-monitor',
#   'User Name': 'NetEaseGame',
#   'stars': '329',
#   'Repository URL': 'https://github.com/NetEaseGame/redis-monitor'},
#  {'Sr No': 199,
#   'Repository Name': 'overpass',
#   'User Name': 'GOATS2K',
#   'stars': '326',
#   'Repository URL': 'https://github.com/GOATS2K/overpass'},
#  {'Sr No': 200,
#   'Repository Name': 'flask-sqlalchemy-tutorial',
#   'User Name': 'hackersandslackers',
#   'stars': '319',
#   'Repository URL': 'https://github.com/hackersandslackers/flask-sqlalchemy-tutorial'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No            Repository Name           User Name  stars  \
# 0        1                      flask             pallets  59.7k
# 1        2                   superset              apache  46.9k
# 2        3                       dash              plotly  16.8k
# 3        4                 proxy_pool             jhao104  15.6k
# 4        5                      Zappa            Miserlou  11.9k
# ..     ...                        ...                 ...    ...
# 195    196           admin-dashboards       app-generator    334
# 196    197               renrenBackup           whusnoopy    335
# 197    198              redis-monitor         NetEaseGame    329
# 198    199                   overpass             GOATS2K    326
# 199    200  flask-sqlalchemy-tutorial  hackersandslackers    319
#
#                                         Repository URL
# 0                     https://github.com/pallets/flask
# 1                   https://github.com/apache/superset
# 2                       https://github.com/plotly/dash
# 3                https://github.com/jhao104/proxy_pool
# 4                    https://github.com/Miserlou/Zappa
# ..                                                 ...
# 195  https://github.com/app-generator/admin-dashboards
# 196          https://github.com/whusnoopy/renrenBackup
# 197       https://github.com/NetEaseGame/redis-monitor
# 198                https://github.com/GOATS2K/overpass
# 199  https://github.com/hackersandslackers/flask-sq...
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_flask.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
