# %%
import requests

# %%
url=requests.get('https://github.com/topics/javascript').text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-10084108b209.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" rel="stylesheet" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" rel="stylesheet" href="https://github.githubassets.com/assets/github-f815d05d371a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYw ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-92c7d381038e.css" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-10084108b209.css" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f815d05d371a.css" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-d31ea144555c.css" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYwk1Z+BnSLOwYorhPLm6jrWoV3c7Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-44mCWWd9he+TZlQdLzIEo+cbYo6tgMXkx8954MY/9DknkwxQmYGmKJrGKCgbWmcMYmBgxLX6uOEgcRoDL/5eCA==" src="https://github.githubassets.com/assets/runtime-e3898259677d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZXV4TpPmxfyBQ9eFqJaVR/Z8Rrt+f/In8yBbbMmt6pqCRMVcnlTWS7/Xy5aedmiIj1tNZXmsvW3cf/vRas/mvQ==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-74aed8-6575784e93e6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-km+JVvSjuMukaGXFPj5OuzW1lNCVhWt0dB2EAkW4NpEj6x301u0l22+XLYaKm9+hvluGH0OlM6BE4hoTjxtFoQ==" src="https://github.githubassets.com/assets/environment-926f8956f4a3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-57NPhP0wWFMwvRygugK3iI3z+Sv0WTNy8MGBcwfMPYE7SoHKEoH1B89v+ANBqnW9GGvUYzf4gLT6UrP/VmhY2g==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-e7b34f84fd30.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Es25N4GyPa8Yfp5wpahoe5b2fyPtkRMyR6mKIXyCJC0ocqQazeWvxhGZhx3StRxOfqDfHDR5SS35u/R3Wux6Cg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-12cdb93781b2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-lmiecOIgf+hakg5oKMNM7grVhEDyPoIrT39Px448JJH5PSAaK21PH0Twgyz5O5oi8+dnlLr3Jt8bBCtAcpNdRw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-c7e9ed-96689e70e220.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-FhIi1nHjAzm1txsZ2LPPUfqIASARJ44qRQ09VSY4p/NVvWz/1reBy21+3an4fDIi6QhfrHNUI4ldKz3NW5by/Q==" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_time-elements_dist_index_js-161222d671e3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-DE9GK/TS3Hf/dJfP1GMiyjvsGRnpR4A1eGH64s0Ot7Vy7Tj7/aD1d5EOMWHFWQXlXy/ZSwu5MHInG6RZN31bMA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-52e104-0c4f462bf4d2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-fcVStVRolV54DldAqKbEzSE1OB6Rd/jIIpSj/dcCRRaSc8EgN68GT9sT/Ya0gtpNTq0aAPzs9OLlhWY7l0s4eA==" src="https://github.githubassets.com/assets/github-elements-7dc552b55468.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-n0EqohMRhyf2gYDkWAvqYJsBzb8qCciNwqGUpwOEjVfSLESviOFqm7IrHsihpfLAm+ZhteYJkQ+PPwqjJTUTrQ==" src="https://github.githubassets.com/assets/element-registry-9f412aa21311.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ULHDrjH3Nz+5xGQnGJ+51ZBv5qENKe3TikjwAxKli4TyT+8KZ5mnWUJxUdXaFwRVMGRJD+8CjfCVhj7913OiOA==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-50b1c3ae31f7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-XubU6uMX6y2ka6JR/QVSIS8aAdXBH9Jhm1lLCNFS5Dy3xbDEdS6W4ENFx71XaEAwW3d8xzgiS4cS0J/zsnYm6w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_github_catalyst_lib_index_-bd1f73-5ee6d4eae317.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-0r1nf/rfPz54kyePp4f63bcPxkFo7wyaUZJD/SwIVDK3q0WzurAK9ydOm88tzKtPJm8xWI0Vo25NyCfecwxJ9g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-d2bd677ffadf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-b6LnssJjHkph4nI0CxyYnXJ/d7eWTCd6fDCQZkhXUwNTMcB55fwq4nPNUDdsFG3h/KS3VEsMjhkqC8jBcQVazA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-f71f15-6fa2e7b2c263.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-aD+lpuc5jHemEy0Cf2KYz46MdwOIlj3+2cZ59XIi+mentNdewI1LzaDqroNLJzONIiL4IeUUZ7hJzhPYV4DQVA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_pjax_ts-683fa5a6e739.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-i6G+/7pwOhMb9q+i08xUSvHWO8fWX9lkXtuIJQGpHGn299Mb74hWyc5ikFQAuqgd2i/cV9c5Jw6O9Z10jDfAwg==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_be-af52ef-8ba1beffba70.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sGIJsMNVLhivulsWgcWql7t/JEs3gUQQt/9GHRjArviQLj6smy1Cei4X6Bg51OC/rZMDXeTNSL733VSNtdlynA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-019af8-b06209b0c355.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-1CN8HrSEXNbvvtNrIvzOMA1IkGwLyUOaFBl/N2UE91/8EvcqBFxy3M83mJVi/n50Kdq4oIRIeZG5D5oTpFTBDg==" src="https://github.githubassets.com/assets/behaviors-d4237c1eb484.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5nWr6hoxY6oc8ngCIfUbQS8h+5n8/1XZVb9KFgP0ak4NzsfM7ERe6b5639AYjyAbYZGs6I/7hC3eieSbWkHx9w==" src="https://github.githubassets.com/assets/notifications-global-e675abea1a31.js" type="application/javascript"></script>
# <title>javascript · GitHub Topics · GitHub</title>
# <meta content="E795:6565:40F0B5:469A46:62C42668" data-pjax-transient="true" name="request-id"/><meta content="69a6b68d009b04605c506fd2c8ea94fa6649a9ec5de24fc78a8f0af74080bd4e" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFNzk1OjY1NjU6NDBGMEI1OjQ2OUE0Njo2MkM0MjY2OCIsInZpc2l0b3JfaWQiOiIxNzg2MDk1MDY4MzI3OTc4NjAwIiwicmVnaW9uX2VkZ2UiOiJhcC1zb3V0aC0xIiwicmVnaW9uX3JlbmRlciI6ImFwLXNvdXRoLTEifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="1b558b5e39e789f1a168cd11ef7e2f5a75fcc47e063bcc96f20c49424a27b0e3" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/javascript"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c8394509e7702c079f9193a636024ae1ea844060331b3388a6de060162d6885c" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fjavascript&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/javascript;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/javascript;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/javascript;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/javascript;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/javascript;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/javascript;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/javascript;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/javascript;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/javascript;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/javascript;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/javascript;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/javascript;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/javascript;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/javascript;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/javascript;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/javascript;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/javascript;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/javascript;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/javascript;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/javascript;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/javascript;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/javascript;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/javascript;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/javascript;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/javascript;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/javascript;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/javascript;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/javascript;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/javascript;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/javascript;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/javascript;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/javascript" aria-label="Site" class="js-site-search-form" data-scope-id="40" data-scope-type="Topic" data-scoped-search-url="/topics/javascript" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="OY/TMLj8XEKOkQNodDVbY9JSfatb54gH8Fl1qtpJmmPPtBbupXwG430jtQ1/1zIuao2/44Qoo6DOUpmBzcCthg=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# ...
# </svg> Pull requests
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <div class="px-3 pt-3">
# <p class="color-fg-muted mb-0"></p><div>A Vue.js 2.0 UI Toolkit for Web</div>
# </div>
# <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
# <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":40,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="ee1f2629a79fe8c2333c766ce309883415f81e081aba846c27d4c2fee94ba180" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#               javascript
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":569,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c6d2f8a928e5f244d3065107bc83f88b9e458c83c763e7e18a262ff4be763ed2" data-view-component="true" href="/topics/components" title="Topic: components">
#               components
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2367,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="4472e7b34b28aadd18663c1fce3c3a31ed72f7605e19609b397cbc1c383e7850" data-view-component="true" href="/topics/vuejs" title="Topic: vuejs">
#               vuejs
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9275,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="671cecd29723eaa3a48a7c6c512cd53a4adf9923c3db52fa9dcb83baf59c530d" data-view-component="true" href="/topics/vue" title="Topic: vue">
#               vue
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":21489,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="a64194123e49418eeb8c497448da10f70de3ff997065335fa432f54ea20a64c7" data-view-component="true" href="/topics/vue-components" title="Topic: vue-components">
#               vue-components
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":72835,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c4eb6218e6d681573aa64421879b1f3b884cc11db53fb3b089ea9158a440bba3" data-view-component="true" href="/topics/ui-kit" title="Topic: ui-kit">
#               ui-kit
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":238123,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="4846473d9f12c5131f8a1cac09fbfd912b7cba449fd1ba653e5baf9812188365" data-view-component="true" href="/topics/element-ui" title="Topic: element-ui">
#               element-ui
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-07-05T05:47:36Z">Jul 5, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #41b883"></span>
# <span itemprop="programmingLanguage">Vue</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/javascript" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Brendan Eich
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> December 4, 1995
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="https://developer.mozilla.org/en-US/docs/Web/JavaScript">
# <span class="css-truncate css-truncate-target" title="developer.mozilla.org/en-US/docs/Web/JavaScript">
#           developer.mozilla.org/en-US/docs/Web/JavaScript
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/JavaScript">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/JavaScript">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# <h2 class="h4 mb-2">
#     Related Topics
#   </h2>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:nodejs" data-view-component="true" href="/topics/nodejs" title="Topic: nodejs">
#   nodejs
# </a>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'freeCodeCamp'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'freeCodeCamp'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text

# %%
stars
# Out:
# '348k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/freeCodeCamp/freeCodeCamp'

# %%
base_url='https://github.com/topics/javascript'

# %%
base_url
# Out:
# 'https://github.com/topics/javascript'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
Repository_page
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":9892522,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="2d4fbb895e5cd4fcef4df447c38142115f13bb162e6131a87db8b6a45a7445cc" data-turbo="false" data-view-component="true" href="/freeCodeCamp">
#              freeCodeCamp
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":28457823,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="5a630e468d4194bc0af48cfdf64adc5eb185f04db96e23e6befb12fb9b755728" data-turbo="false" data-view-component="true" href="/freeCodeCamp/freeCodeCamp">
#              freeCodeCamp
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @freeCodeCamp" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"freeCodeCamp","originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="aeefd2cdafeb99d0511acf260a7076507a2353a8bdc08cefe29579e90c17f1c9" data-view-component="true" href="/sponsors/freeCodeCamp">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":28457823,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="ffd4d18da2f954ed045a2480de47025ad625125ae81bcb640c1f2672cd23e140" data-view-component="true" href="/login?return_to=%2FfreeCodeCamp%2FfreeCodeCamp" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="348491 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="348,491">348k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":28457823,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="71cad712d847fe61449d5bc62d5979b82c81a0b9d63cbadb665702b6381fb52b" data-turbo="false" data-view-component="true" href="/freeCodeCamp/freeCodeCamp" id="code-tab-28457823">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":28457823,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c80e63426c501e9098c5dabc6ef8df78b82220e6f7b32b1b83e05f12b2100239" data-turbo="false" data-view-component="true" href="/freeCodeCamp/freeCodeCamp/issues" id="issues-tab-28457823">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":28457823,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="64ba8af0b6470b199c28e06468570dd10dba1c24b88618ff5424472b853b02d7" data-turbo="false" data-view-component="true" href="/freeCodeCamp/freeCodeCamp/pulls" id="pull-requests-tab-28457823">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free.</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":12,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="228e4a79a252b5ab39b775ef9102391f84e237c2f2cebea8f189b449548edb3a" data-view-component="true" href="/topics/react" title="Topic: react">
#                react
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":39,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c9418821015f460ec7b22e4dba2c892715891a840d737450537e247023b0246d" data-view-component="true" href="/topics/nodejs" title="Topic: nodejs">
#                nodejs
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":40,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="ee1f2629a79fe8c2333c766ce309883415f81e081aba846c27d4c2fee94ba180" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#                javascript
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":58,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="5d2cbb7bb0385cff5e1e980e9f83bb195cbc551c724e3be2c3fb6e8377d03b54" data-view-component="true" href="/topics/d3" title="Topic: d3">
#                d3
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":248,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="b6b43524af968fddfbce3fa47b182d6a52c3c9027ee626476d1098eefce14d8a" data-view-component="true" href="/topics/teachers" title="Topic: teachers">
#                teachers
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":453,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="66eb9331464c1006a610cb7751379bfe43ad9ed7d48c1727fed6afdffc70b820" data-view-component="true" href="/topics/community" title="Topic: community">
#                community
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":486,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="1ec4349a127a9bf7e4953a47526a00a4834a95b05b66a7d9853eb4fd836065ae" data-view-component="true" href="/topics/education" title="Topic: education">
#                education
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":8898,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="dc633c7a88cc80d0ad02c66976c78af6da5d0658bc22a465d4a2bc629154036e" data-view-component="true" href="/topics/programming" title="Topic: programming">
#                programming
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9404,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="225d3c10ad02617b41a52b6b9915b386d0ca447fd52f5ab60b21b35104a01c2c" data-view-component="true" href="/topics/curriculum" title="Topic: curriculum">
#                curriculum
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9670,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="bb2f867ae8cbc1ee051a28cedd9e03b85ff57a468e96c877b0db812f03438f31" data-view-component="true" href="/topics/math" title="Topic: math">
#                math
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":21908,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="6018d19ab536e32863b1993e935e521bd4a406ff9a9c3550fb0bbdc96179ee42" data-view-component="true" href="/topics/freecodecamp" title="Topic: freecodecamp">
#                freecodecamp
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":27672,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="48e943bd3c2ceb7318ce4711cf917158de03841aaa1d7c2087fcf4796987df4a" data-view-component="true" href="/topics/learn-to-code" title="Topic: learn-to-code">
#                learn-to-code
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":27689,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="1499ce01177f271950c8133a91c8e16bce6180470c2fc7aa80f8df30ff0bbea1" data-view-component="true" href="/topics/nonprofits" title="Topic: nonprofits">
#                nonprofits
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":43407,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="3d96f5ae706e1986adb502f1baa7ac385e3a2d12a47286b0b73976b7dcd47e3c" data-view-component="true" href="/topics/careers" title="Topic: careers">
#                careers
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":119360,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="d58d41d5f623e10516d3a869432b7094671ce48f9959a57402e7b2c338fc34f5" data-view-component="true" href="/topics/certification" title="Topic: certification">
#                certification
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":196454,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="3f0baa153cb0c58f427a5db8a701d5661549d9dda1d8e62a1b2a7311b2677c42" data-view-component="true" href="/topics/hacktoberfest" title="Topic: hacktoberfest">
#                hacktoberfest
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-05T10:56:26Z">Jul 5, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3178c6"></span>
#  <span itemprop="programmingLanguage">TypeScript</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":6128107,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="cc3b3a658b46657ad6ffe552641b184fcf711467cf5fbf6b3bc29cf7a9d2e4d8" data-turbo="false" data-view-component="true" href="/vuejs">
#              vuejs
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":11730342,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="4209920feccc8a0a23afaf8004adcf73cfc088ac91f227becd3017adae0ef0ef" data-turbo="false" data-view-component="true" href="/vuejs/vue">
#              vue
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":11730342,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="1ea3bdbd353c0c637220450411ed9fefd95dc4f62760ee233c94e8443fa6e0ba" data-view-component="true" href="/login?return_to=%2Fvuejs%2Fvue" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="197455 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="197,455">197k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":11730342,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="158ff43965d7ee6097b570303487c5b2236ca29f973cef10943b38285becd0ed" data-turbo="false" data-view-component="true" href="/vuejs/vue" id="code-tab-11730342">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":11730342,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="99c51db5fcaf5a97ddc4a2c561c28a6de0aab55f9604a59e7a92d1e7dd44b6d5" data-turbo="false" data-view-component="true" href="/vuejs/vue/issues" id="issues-tab-11730342">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":11730342,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="68ee67d351ae55dc0f3472c8f6bcc577806051ba00bede06a76e86d9476e378d" data-turbo="false" data-view-component="true" href="/vuejs/vue/pulls" id="pull-requests-tab-11730342">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":466057344,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="7ddd4913b7bd0edeb8e53c5cebfa9c9cc4ba22af7cbcc58feb5368dd794a99b6" data-turbo="false" data-view-component="true" href="https://github.com/vuejs/vue/issues/10252">
#                  Wrong definition of the type AsyncComponentFactory
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                16
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="Maorey" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/18207829?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    Maorey
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2019-07-10T01:55:05Z">Jul 10, 2019</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h3>Version</h3>
#  <p>2.6.10</p>
#  <h3>Reproduction link</h3>
#  <p><a href="https://github.com/vuejs/vue">https://github.com/vuejs/vue</a></p>
#  <h3>Steps to reproduce</h3>
#  <ol>
#  <li>compare the <a href="https://github.com/vuejs/vue/blob/dev/types/options.d.ts">AsyncComponentFactory</a> definition with the <a href="https://vuejs.org/v2/guide/components-dynamic-async.html#Handling-Loading-State" rel="nofollow">document</a></li>
#  </ol>
#  <h3>What is expected?</h3>
#  <p>attribute 'componen</p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":466057344,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="f24ae308d3bb89ac54832ba7c1f978f29cc854a5b43288e7fbc34009010d1a0f" href="https://github.com/vuejs/vue/issues/10252">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":601343890,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="6e1b05fcaeb51f63a166e27e60714dd6d91b8de1614d8054172c37d52814d001" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-ca30a1" style="--label-r:111;--label-g:79;--label-b:255;--label-h:250;--label-s:100;--label-l:65;">
#                      good first issue
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":724459354,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="2827809f8803dc8acb710c7f1fe1f9303635ff7262a833e693679c6fd4384914" data-name="typescript" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Atypescript" id="label-b8f1de" style="--label-r:0;--label-g:82;--label-b:204;--label-h:215;--label-s:100;--label-l:40;">
#                      typescript
#  </a>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":863458406,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="d31e609f41db819bf18ecbfa24eebf41e6037b05c90b45d5b162cb193c5de769" data-name="has PR" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22has+PR%22" id="label-8f77b0" style="--label-r:83;--label-g:25;--label-b:231;--label-h:256;--label-s:81;--label-l:50;">
#                      has PR
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":460335705,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c20179182ff358bb6dd9d19f76663382b7b14d48bea9ef743b2572410b55cbdc" data-turbo="false" data-view-component="true" href="https://github.com/vuejs/vue/issues/10191">
#                      Warn if colon shorthand is used on v-if/v-html/etc.
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    9
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":378235731,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="4790fe203a3f39d737addeb08cab85854b900175677cf74c3f0993970b42fb3b" data-turbo="false" data-view-component="true" href="https://github.com/vuejs/vue/issues/9038">
#                      Throw error when using interpolation instead of JS expression for slot names
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    4
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":11730342,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="640dd024ef611653f84d7412cd913aed86b188d8f687c8b30e43685be7ebcf72" data-turbo="false" data-view-component="true" href="/vuejs/vue/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":69631,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="02510dccab30a77702351a7ec518a751d34a32647c4552f0a79e08cd264e4754" data-turbo="false" data-view-component="true" href="/facebook">
#              facebook
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":10270250,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="35ba12202fa2b7d964de37f211a87e1d1fb575489e65902c1f81a05f093e8ed4" data-turbo="false" data-view-component="true" href="/facebook/react">
#              react
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":10270250,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="6072a51774d540ec7015f5088cd8e3b50ac8e77f9c2e3b9db13e462e26afe1fa" data-view-component="true" href="/login?return_to=%2Ffacebook%2Freact" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="190855 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="190,855">191k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":10270250,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="74de67e2cc8d1c9cb0918c93db0dbfdd954b7cb2f74aba1c07f264cba61886a5" data-turbo="false" data-view-component="true" href="/facebook/react" id="code-tab-10270250">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":10270250,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="f37d100de3038840d75dc5518458ab221017b9fc64666d034bd63d0fe8bc8969" data-turbo="false" data-view-component="true" href="/facebook/react/issues" id="issues-tab-10270250">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":10270250,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="8057c3f8ba4226a2396bcdbc8b6b4dbae453855be82e3204bfa48c355005031e" data-turbo="false" data-view-component="true" href="/facebook/react/pulls" id="pull-requests-tab-10270250">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1229643466,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="9387f744609641cc932023f557248f51e91a1a6d4aeea93b12e4b541873a6a88" data-turbo="false" data-view-component="true" href="https://github.com/facebook/react/issues/24522">
#                  [DevTools] Manifest version 2 is deprecated
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                31
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="Bartel-C8" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/76486925?v=4" width="32"/>
#  </div>
# ...
#                css
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":203,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="f1309c418d9df05c9282e4b78312dc70946887a4833e849d99908eaa31db7cb7" data-view-component="true" href="/topics/html" title="Topic: html">
#                html
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9045,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="6e828ae1650ae4cc19660d9106205b05d2a59494b1b93dd0f3d5d4b13289c6ba" data-view-component="true" href="/topics/html5" title="Topic: html5">
#                html5
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":13214,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="ebd81789f19c873052ebb396c7fb4b7706b65a11e4a3fd36287375b171125afa" data-view-component="true" href="/topics/best-practices" title="Topic: best-practices">
#                best-practices
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":60473,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="91593fe08c7f5faf680d040440dcaa1a2a2aa26ea75c23a542e800093373ba00" data-view-component="true" href="/topics/robust" title="Topic: robust">
#                robust
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":119303,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="ff688abfc2eae26c5ffb9f21e43cddd3fd0d195824f7f92300303f1e73ee7321" data-view-component="true" href="/topics/html5-boilerplate" title="Topic: html5-boilerplate">
#                html5-boilerplate
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-03T18:00:58Z">Jul 3, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #f1e05a"></span>
#  <span itemprop="programmingLanguage">JavaScript</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":12810740,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="bd664395a2eee391598a0c49721e70fe74685b0f4193bef64a7b86f60f2e69f2" data-turbo="false" data-view-component="true" href="/ElemeFE">
#              ElemeFE
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":67274736,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="a76033b1e743ee8b351c0c2a1a46666d60e159ed0907507de8917f7a09d53106" data-turbo="false" data-view-component="true" href="/ElemeFE/element">
#              element
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":67274736,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="30bc0d19d9436c5fb9dacab44bfb5bbd577628c60401288155dfb5da8a61df17" data-view-component="true" href="/login?return_to=%2FElemeFE%2Felement" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="52309 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="52,309">52.3k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":67274736,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="971f95b930c0433e6b5f94df83a57948441f08908f3535e43c1972e18a209664" data-turbo="false" data-view-component="true" href="/ElemeFE/element" id="code-tab-67274736">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":67274736,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="f141a34ee78f57b484270fa956f281923e30fcd70bc7ed99b8a198fcdb154950" data-turbo="false" data-view-component="true" href="/ElemeFE/element/issues" id="issues-tab-67274736">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":67274736,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="a630790433e6af8b295a2cbf702cf0323f2bee7e882abd6c82b3389dcda38eb3" data-turbo="false" data-view-component="true" href="/ElemeFE/element/pulls" id="pull-requests-tab-67274736">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>A Vue.js 2.0 UI Toolkit for Web</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":40,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="ee1f2629a79fe8c2333c766ce309883415f81e081aba846c27d4c2fee94ba180" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#                javascript
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":569,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c6d2f8a928e5f244d3065107bc83f88b9e458c83c763e7e18a262ff4be763ed2" data-view-component="true" href="/topics/components" title="Topic: components">
#                components
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2367,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="4472e7b34b28aadd18663c1fce3c3a31ed72f7605e19609b397cbc1c383e7850" data-view-component="true" href="/topics/vuejs" title="Topic: vuejs">
#                vuejs
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9275,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="671cecd29723eaa3a48a7c6c512cd53a4adf9923c3db52fa9dcb83baf59c530d" data-view-component="true" href="/topics/vue" title="Topic: vue">
#                vue
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":21489,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="a64194123e49418eeb8c497448da10f70de3ff997065335fa432f54ea20a64c7" data-view-component="true" href="/topics/vue-components" title="Topic: vue-components">
#                vue-components
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":72835,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="c4eb6218e6d681573aa64421879b1f3b884cc11db53fb3b089ea9158a440bba3" data-view-component="true" href="/topics/ui-kit" title="Topic: ui-kit">
#                ui-kit
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":238123,"originating_url":"https://github.com/topics/javascript","user_id":null}}' data-hydro-click-hmac="4846473d9f12c5131f8a1cac09fbfd912b7cba449fd1ba653e5baf9812188365" data-view-component="true" href="/topics/element-ui" title="Topic: element-ui">
#                element-ui
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-05T05:47:36Z">Jul 5, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #41b883"></span>
#  <span itemprop="programmingLanguage">Vue</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
base_url='https://github.com/topics/javascript'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
Repository_1_lst
# Out:
# [{'Repository Name': 'freeCodeCamp',
#   'User Name': 'freeCodeCamp',
#   'stars': '348k',
#   'Repository URL': 'https://github.com/topics/javascriptfreeCodeCamp/freeCodeCamp'},
#  {'Repository Name': 'vue',
#   'User Name': 'vuejs',
#   'stars': '197k',
#   'Repository URL': 'https://github.com/topics/javascriptvuejs/vue'},
#  {'Repository Name': 'react',
#   'User Name': 'facebook',
#   'stars': '191k',
#   'Repository URL': 'https://github.com/topics/javascriptfacebook/react'},
#  {'Repository Name': 'bootstrap',
#   'User Name': 'twbs',
#   'stars': '158k',
#   'Repository URL': 'https://github.com/topics/javascripttwbs/bootstrap'},
#  {'Repository Name': 'You-Dont-Know-JS',
#   'User Name': 'getify',
#   'stars': '156k',
#   'Repository URL': 'https://github.com/topics/javascriptgetify/You-Dont-Know-JS'},
#  {'Repository Name': 'javascript-algorithms',
#   'User Name': 'trekhleb',
#   'stars': '145k',
#   'Repository URL': 'https://github.com/topics/javascripttrekhleb/javascript-algorithms'},
#  {'Repository Name': 'javascript',
#   'User Name': 'airbnb',
#   'stars': '124k',
#   'Repository URL': 'https://github.com/topics/javascriptairbnb/javascript'},
#  {'Repository Name': 'electron',
#   'User Name': 'electron',
#   'stars': '102k',
#   'Repository URL': 'https://github.com/topics/javascriptelectron/electron'},
#  {'Repository Name': '30-seconds-of-code',
#   'User Name': '30-seconds',
#   'stars': '98.3k',
#   'Repository URL': 'https://github.com/topics/javascript30-seconds/30-seconds-of-code'},
#  {'Repository Name': 'axios',
#   'User Name': 'axios',
#   'stars': '94.4k',
#   'Repository URL': 'https://github.com/topics/javascriptaxios/axios'},
#  {'Repository Name': 'free-programming-books-zh_CN',
#   'User Name': 'justjavac',
#   'stars': '94.1k',
#   'Repository URL': 'https://github.com/topics/javascriptjustjavac/free-programming-books-zh_CN'},
#  {'Repository Name': 'node',
#   'User Name': 'nodejs',
#   'stars': '88.6k',
#   'Repository URL': 'https://github.com/topics/javascriptnodejs/node'},
#  {'Repository Name': 'deno',
#   'User Name': 'denoland',
#   'stars': '83.7k',
#   'Repository URL': 'https://github.com/topics/javascriptdenoland/deno'},
#  {'Repository Name': 'three.js',
#   'User Name': 'mrdoob',
#   'stars': '83.3k',
#   'Repository URL': 'https://github.com/topics/javascriptmrdoob/three.js'},
#  {'Repository Name': 'angular',
#   'User Name': 'angular',
#   'stars': '82.5k',
#   'Repository URL': 'https://github.com/topics/javascriptangular/angular'},
#  {'Repository Name': 'TypeScript',
#   'User Name': 'microsoft',
#   'stars': '82k',
#   'Repository URL': 'https://github.com/topics/javascriptmicrosoft/TypeScript'},
#  {'Repository Name': 'material-ui',
#   'User Name': 'mui',
#   'stars': '79.5k',
#   'Repository URL': 'https://github.com/topics/javascriptmui/material-ui'},
#  {'Repository Name': 'nodebestpractices',
#   'User Name': 'goldbergyoni',
#   'stars': '79k',
#   'Repository URL': 'https://github.com/topics/javascriptgoldbergyoni/nodebestpractices'},
#  {'Repository Name': 'storybook',
#   'User Name': 'storybookjs',
#   'stars': '72.5k',
#   'Repository URL': 'https://github.com/topics/javascriptstorybookjs/storybook'},
#  {'Repository Name': 'project-based-learning',
#   'User Name': 'practical-tutorials',
#   'stars': '71.2k',
#   'Repository URL': 'https://github.com/topics/javascriptpractical-tutorials/project-based-learning'},
#  {'Repository Name': 'clean-code-javascript',
#   'User Name': 'ryanmcdermott',
#   'stars': '69.3k',
#   'Repository URL': 'https://github.com/topics/javascriptryanmcdermott/clean-code-javascript'},
#  {'Repository Name': 'webpack',
#   'User Name': 'webpack',
#   'stars': '61.3k',
#   'Repository URL': 'https://github.com/topics/javascriptwebpack/webpack'},
#  {'Repository Name': 'Front-End-Checklist',
#   'User Name': 'thedaviddias',
#   'stars': '60.5k',
#   'Repository URL': 'https://github.com/topics/javascriptthedaviddias/Front-End-Checklist'},
#  {'Repository Name': 'atom',
#   'User Name': 'atom',
#   'stars': '58.2k',
#   'Repository URL': 'https://github.com/topics/javascriptatom/atom'},
#  {'Repository Name': 'express',
#   'User Name': 'expressjs',
#   'stars': '57.5k',
#   'Repository URL': 'https://github.com/topics/javascriptexpressjs/express'},
#  {'Repository Name': 'Chart.js',
#   'User Name': 'chartjs',
#   'stars': '57.4k',
#   'Repository URL': 'https://github.com/topics/javascriptchartjs/Chart.js'},
#  {'Repository Name': 'Web-Dev-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '53.7k',
#   'Repository URL': 'https://github.com/topics/javascriptmicrosoft/Web-Dev-For-Beginners'},
#  {'Repository Name': 'lodash',
#   'User Name': 'lodash',
#   'stars': '53.6k',
#   'Repository URL': 'https://github.com/topics/javascriptlodash/lodash'},
#  {'Repository Name': 'html5-boilerplate',
#   'User Name': 'h5bp',
#   'stars': '53.1k',
#   'Repository URL': 'https://github.com/topics/javascripth5bp/html5-boilerplate'},
#  {'Repository Name': 'element',
#   'User Name': 'ElemeFE',
#   'stars': '52.3k',
#   'Repository URL': 'https://github.com/topics/javascriptElemeFE/element'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                  Repository Name            User Name  stars  \
# 0                   freeCodeCamp         freeCodeCamp   348k
# 1                            vue                vuejs   197k
# 2                          react             facebook   191k
# 3                      bootstrap                 twbs   158k
# 4               You-Dont-Know-JS               getify   156k
# 5          javascript-algorithms             trekhleb   145k
# 6                     javascript               airbnb   124k
# 7                       electron             electron   102k
# 8             30-seconds-of-code           30-seconds  98.3k
# 9                          axios                axios  94.4k
# 10  free-programming-books-zh_CN            justjavac  94.1k
# 11                          node               nodejs  88.6k
# 12                          deno             denoland  83.7k
# 13                      three.js               mrdoob  83.3k
# 14                       angular              angular  82.5k
# 15                    TypeScript            microsoft    82k
# 16                   material-ui                  mui  79.5k
# 17             nodebestpractices         goldbergyoni    79k
# 18                     storybook          storybookjs  72.5k
# 19        project-based-learning  practical-tutorials  71.2k
# 20         clean-code-javascript        ryanmcdermott  69.3k
# 21                       webpack              webpack  61.3k
# 22           Front-End-Checklist         thedaviddias  60.5k
# 23                          atom                 atom  58.2k
# 24                       express            expressjs  57.5k
# 25                      Chart.js              chartjs  57.4k
# 26         Web-Dev-For-Beginners            microsoft  53.7k
# 27                        lodash               lodash  53.6k
# 28             html5-boilerplate                 h5bp  53.1k
# 29                       element              ElemeFE  52.3k
#
#                                        Repository URL
# 0   https://github.com/topics/javascriptfreeCodeCa...
# 1       https://github.com/topics/javascriptvuejs/vue
# 2   https://github.com/topics/javascriptfacebook/r...
# 3   https://github.com/topics/javascripttwbs/boots...
# 4   https://github.com/topics/javascriptgetify/You...
# 5   https://github.com/topics/javascripttrekhleb/j...
# 6   https://github.com/topics/javascriptairbnb/jav...
# 7   https://github.com/topics/javascriptelectron/e...
# 8   https://github.com/topics/javascript30-seconds...
# 9     https://github.com/topics/javascriptaxios/axios
# 10  https://github.com/topics/javascriptjustjavac/...
# 11    https://github.com/topics/javascriptnodejs/node
# 12  https://github.com/topics/javascriptdenoland/deno
# 13  https://github.com/topics/javascriptmrdoob/thr...
# 14  https://github.com/topics/javascriptangular/an...
# 15  https://github.com/topics/javascriptmicrosoft/...
# 16  https://github.com/topics/javascriptmui/materi...
# 17  https://github.com/topics/javascriptgoldbergyo...
# 18  https://github.com/topics/javascriptstorybookj...
# 19  https://github.com/topics/javascriptpractical-...
# 20  https://github.com/topics/javascriptryanmcderm...
# 21  https://github.com/topics/javascriptwebpack/we...
# 22  https://github.com/topics/javascriptthedaviddi...
# 23      https://github.com/topics/javascriptatom/atom
# 24  https://github.com/topics/javascriptexpressjs/...
# 25  https://github.com/topics/javascriptchartjs/Ch...
# 26  https://github.com/topics/javascriptmicrosoft/...
# 27  https://github.com/topics/javascriptlodash/lodash
# 28  https://github.com/topics/javascripth5bp/html5...
# 29  https://github.com/topics/javascriptElemeFE/el...

# %%
df.to_excel('javascript.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/javascript?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/javascript?page=1',
#  'https://github.com/topics/javascript?page=2',
#  'https://github.com/topics/javascript?page=3',
#  'https://github.com/topics/javascript?page=4',
#  'https://github.com/topics/javascript?page=5',
#  'https://github.com/topics/javascript?page=6',
#  'https://github.com/topics/javascript?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/javascript?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'freeCodeCamp',
#   'User Name': 'freeCodeCamp',
#   'stars': '348k',
#   'Repository URL': 'https://github.com/freeCodeCamp/freeCodeCamp'},
#  {'Sr No': 2,
#   'Repository Name': 'vue',
#   'User Name': 'vuejs',
#   'stars': '197k',
#   'Repository URL': 'https://github.com/vuejs/vue'},
#  {'Sr No': 3,
#   'Repository Name': 'react',
#   'User Name': 'facebook',
#   'stars': '191k',
#   'Repository URL': 'https://github.com/facebook/react'},
#  {'Sr No': 4,
#   'Repository Name': 'bootstrap',
#   'User Name': 'twbs',
#   'stars': '158k',
#   'Repository URL': 'https://github.com/twbs/bootstrap'},
#  {'Sr No': 5,
#   'Repository Name': 'You-Dont-Know-JS',
#   'User Name': 'getify',
#   'stars': '156k',
#   'Repository URL': 'https://github.com/getify/You-Dont-Know-JS'},
#  {'Sr No': 6,
#   'Repository Name': 'javascript-algorithms',
#   'User Name': 'trekhleb',
#   'stars': '145k',
#   'Repository URL': 'https://github.com/trekhleb/javascript-algorithms'},
#  {'Sr No': 7,
#   'Repository Name': 'javascript',
#   'User Name': 'airbnb',
#   'stars': '124k',
#   'Repository URL': 'https://github.com/airbnb/javascript'},
#  {'Sr No': 8,
#   'Repository Name': 'electron',
#   'User Name': 'electron',
#   'stars': '102k',
#   'Repository URL': 'https://github.com/electron/electron'},
#  {'Sr No': 9,
#   'Repository Name': '30-seconds-of-code',
#   'User Name': '30-seconds',
#   'stars': '98.3k',
#   'Repository URL': 'https://github.com/30-seconds/30-seconds-of-code'},
#  {'Sr No': 10,
#   'Repository Name': 'axios',
#   'User Name': 'axios',
#   'stars': '94.4k',
#   'Repository URL': 'https://github.com/axios/axios'},
#  {'Sr No': 11,
#   'Repository Name': 'free-programming-books-zh_CN',
#   'User Name': 'justjavac',
#   'stars': '94.1k',
#   'Repository URL': 'https://github.com/justjavac/free-programming-books-zh_CN'},
#  {'Sr No': 12,
#   'Repository Name': 'node',
#   'User Name': 'nodejs',
#   'stars': '88.6k',
#   'Repository URL': 'https://github.com/nodejs/node'},
#  {'Sr No': 13,
#   'Repository Name': 'deno',
#   'User Name': 'denoland',
#   'stars': '83.7k',
#   'Repository URL': 'https://github.com/denoland/deno'},
#  {'Sr No': 14,
#   'Repository Name': 'three.js',
#   'User Name': 'mrdoob',
#   'stars': '83.3k',
#   'Repository URL': 'https://github.com/mrdoob/three.js'},
#  {'Sr No': 15,
#   'Repository Name': 'angular',
#   'User Name': 'angular',
#   'stars': '82.5k',
#   'Repository URL': 'https://github.com/angular/angular'},
#  {'Sr No': 16,
#   'Repository Name': 'TypeScript',
#   'User Name': 'microsoft',
#   'stars': '82k',
#   'Repository URL': 'https://github.com/microsoft/TypeScript'},
#  {'Sr No': 17,
#   'Repository Name': 'material-ui',
#   'User Name': 'mui',
#   'stars': '79.5k',
#   'Repository URL': 'https://github.com/mui/material-ui'},
#  {'Sr No': 18,
#   'Repository Name': 'nodebestpractices',
#   'User Name': 'goldbergyoni',
#   'stars': '79k',
#   'Repository URL': 'https://github.com/goldbergyoni/nodebestpractices'},
#  {'Sr No': 19,
#   'Repository Name': 'storybook',
#   'User Name': 'storybookjs',
#   'stars': '72.5k',
#   'Repository URL': 'https://github.com/storybookjs/storybook'},
#  {'Sr No': 20,
#   'Repository Name': 'project-based-learning',
#   'User Name': 'practical-tutorials',
#   'stars': '71.2k',
#   'Repository URL': 'https://github.com/practical-tutorials/project-based-learning'},
#  {'Sr No': 21,
#   'Repository Name': 'clean-code-javascript',
#   'User Name': 'ryanmcdermott',
#   'stars': '69.3k',
#   'Repository URL': 'https://github.com/ryanmcdermott/clean-code-javascript'},
#  {'Sr No': 22,
#   'Repository Name': 'webpack',
#   'User Name': 'webpack',
#   'stars': '61.3k',
#   'Repository URL': 'https://github.com/webpack/webpack'},
#  {'Sr No': 23,
#   'Repository Name': 'Front-End-Checklist',
#   'User Name': 'thedaviddias',
#   'stars': '60.5k',
#   'Repository URL': 'https://github.com/thedaviddias/Front-End-Checklist'},
#  {'Sr No': 24,
#   'Repository Name': 'atom',
#   'User Name': 'atom',
#   'stars': '58.2k',
#   'Repository URL': 'https://github.com/atom/atom'},
#  {'Sr No': 25,
#   'Repository Name': 'express',
#   'User Name': 'expressjs',
#   'stars': '57.5k',
#   'Repository URL': 'https://github.com/expressjs/express'},
#  {'Sr No': 26,
#   'Repository Name': 'Chart.js',
#   'User Name': 'chartjs',
#   'stars': '57.4k',
#   'Repository URL': 'https://github.com/chartjs/Chart.js'},
#  {'Sr No': 27,
#   'Repository Name': 'Web-Dev-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '53.7k',
#   'Repository URL': 'https://github.com/microsoft/Web-Dev-For-Beginners'},
#  {'Sr No': 28,
#   'Repository Name': 'lodash',
#   'User Name': 'lodash',
#   'stars': '53.6k',
#   'Repository URL': 'https://github.com/lodash/lodash'},
#  {'Sr No': 29,
#   'Repository Name': 'html5-boilerplate',
#   'User Name': 'h5bp',
#   'stars': '53.1k',
#   'Repository URL': 'https://github.com/h5bp/html5-boilerplate'},
#  {'Sr No': 30,
#   'Repository Name': 'element',
#   'User Name': 'ElemeFE',
#   'stars': '52.3k',
#   'Repository URL': 'https://github.com/ElemeFE/element'},
#  {'Sr No': 31,
#   'Repository Name': '33-js-concepts',
#   'User Name': 'leonardomso',
#   'stars': '49.7k',
#   'Repository URL': 'https://github.com/leonardomso/33-js-concepts'},
#  {'Sr No': 32,
#   'Repository Name': 'leetcode',
#   'User Name': 'azl397985856',
#   'stars': '48.6k',
#   'Repository URL': 'https://github.com/azl397985856/leetcode'},
#  {'Sr No': 33,
#   'Repository Name': 'nest',
#   'User Name': 'nestjs',
#   'stars': '48.3k',
#   'Repository URL': 'https://github.com/nestjs/nest'},
#  {'Sr No': 34,
#   'Repository Name': 'ionic-framework',
#   'User Name': 'ionic-team',
#   'stars': '47.6k',
#   'Repository URL': 'https://github.com/ionic-team/ionic-framework'},
#  {'Sr No': 35,
#   'Repository Name': 'awesome-interview-questions',
#   'User Name': 'DopplerHQ',
#   'stars': '47.4k',
#   'Repository URL': 'https://github.com/DopplerHQ/awesome-interview-questions'},
#  {'Sr No': 36,
#   'Repository Name': 'strapi',
#   'User Name': 'strapi',
#   'stars': '46.1k',
#   'Repository URL': 'https://github.com/strapi/strapi'},
#  {'Sr No': 37,
#   'Repository Name': 'awesome-nodejs',
#   'User Name': 'sindresorhus',
#   'stars': '45.3k',
#   'Repository URL': 'https://github.com/sindresorhus/awesome-nodejs'},
#  {'Sr No': 38,
#   'Repository Name': 'prettier',
#   'User Name': 'prettier',
#   'stars': '43.3k',
#   'Repository URL': 'https://github.com/prettier/prettier'},
#  {'Sr No': 39,
#   'Repository Name': 'meteor',
#   'User Name': 'meteor',
#   'stars': '42.9k',
#   'Repository URL': 'https://github.com/meteor/meteor'},
#  {'Sr No': 40,
#   'Repository Name': 'anime',
#   'User Name': 'juliangarnier',
#   'stars': '42.6k',
#   'Repository URL': 'https://github.com/juliangarnier/anime'},
#  {'Sr No': 41,
#   'Repository Name': 'babel',
#   'User Name': 'babel',
#   'stars': '41.1k',
#   'Repository URL': 'https://github.com/babel/babel'},
#  {'Sr No': 42,
#   'Repository Name': 'parcel',
#   'User Name': 'parcel-bundler',
#   'stars': '41k',
#   'Repository URL': 'https://github.com/parcel-bundler/parcel'},
#  {'Sr No': 43,
#   'Repository Name': 'yarn',
#   'User Name': 'yarnpkg',
#   'stars': '40.7k',
#   'Repository URL': 'https://github.com/yarnpkg/yarn'},
#  {'Sr No': 44,
#   'Repository Name': 'Ghost',
#   'User Name': 'TryGhost',
#   'stars': '40.6k',
#   'Repository URL': 'https://github.com/TryGhost/Ghost'},
#  {'Sr No': 45,
#   'Repository Name': 'playwright',
#   'User Name': 'microsoft',
#   'stars': '39.8k',
#   'Repository URL': 'https://github.com/microsoft/playwright'},
#  {'Sr No': 46,
#   'Repository Name': 'jest',
#   'User Name': 'facebook',
#   'stars': '39.5k',
#   'Repository URL': 'https://github.com/facebook/jest'},
#  {'Sr No': 47,
#   'Repository Name': 'nw.js',
#   'User Name': 'nwjs',
#   'stars': '39k',
#   'Repository URL': 'https://github.com/nwjs/nw.js'},
#  {'Sr No': 48,
#   'Repository Name': 'hyper',
#   'User Name': 'vercel',
#   'stars': '38.8k',
#   'Repository URL': 'https://github.com/vercel/hyper'},
#  {'Sr No': 49,
#   'Repository Name': 'materialize',
#   'User Name': 'Dogfalo',
#   'stars': '38.7k',
#   'Repository URL': 'https://github.com/Dogfalo/materialize'},
#  {'Sr No': 50,
#   'Repository Name': 'pixijs',
#   'User Name': 'pixijs',
#   'stars': '36.8k',
#   'Repository URL': 'https://github.com/pixijs/pixijs'},
#  {'Sr No': 51,
#   'Repository Name': 'uni-app',
#   'User Name': 'dcloudio',
#   'stars': '36.8k',
#   'Repository URL': 'https://github.com/dcloudio/uni-app'},
#  {'Sr No': 52,
#   'Repository Name': 'freecodecamp.cn',
#   'User Name': 'FreeCodeCampChina',
#   'stars': '36.5k',
#   'Repository URL': 'https://github.com/FreeCodeCampChina/freecodecamp.cn'},
#  {'Sr No': 53,
#   'Repository Name': 'discourse',
#   'User Name': 'discourse',
#   'stars': '36k',
#   'Repository URL': 'https://github.com/discourse/discourse'},
#  {'Sr No': 54,
#   'Repository Name': 'hexo',
#   'User Name': 'hexojs',
#   'stars': '35k',
#   'Repository URL': 'https://github.com/hexojs/hexo'},
#  {'Sr No': 55,
#   'Repository Name': 'Leaflet',
#   'User Name': 'Leaflet',
#   'stars': '34.9k',
#   'Repository URL': 'https://github.com/Leaflet/Leaflet'},
#  {'Sr No': 56,
#   'Repository Name': 'vuetify',
#   'User Name': 'vuetifyjs',
#   'stars': '34.6k',
#   'Repository URL': 'https://github.com/vuetifyjs/vuetify'},
#  {'Sr No': 57,
#   'Repository Name': 'docusaurus',
#   'User Name': 'facebook',
#   'stars': '34.6k',
#   'Repository URL': 'https://github.com/facebook/docusaurus'},
#  {'Sr No': 58,
#   'Repository Name': 'front-end-interview-handbook',
#   'User Name': 'yangshun',
#   'stars': '34.5k',
#   'Repository URL': 'https://github.com/yangshun/front-end-interview-handbook'},
#  {'Sr No': 59,
#   'Repository Name': 'fullPage.js',
#   'User Name': 'alvarotrigo',
#   'stars': '33.8k',
#   'Repository URL': 'https://github.com/alvarotrigo/fullPage.js'},
#  {'Sr No': 60,
#   'Repository Name': 'video.js',
#   'User Name': 'videojs',
#   'stars': '33.6k',
#   'Repository URL': 'https://github.com/videojs/video.js'},
#  {'Sr No': 61,
#   'Repository Name': 'zx',
#   'User Name': 'google',
#   'stars': '32.8k',
#   'Repository URL': 'https://github.com/google/zx'},
#  {'Sr No': 62,
#   'Repository Name': 'Rocket.Chat',
#   'User Name': 'RocketChat',
#   'stars': '32.6k',
#   'Repository URL': 'https://github.com/RocketChat/Rocket.Chat'},
#  {'Sr No': 63,
#   'Repository Name': 'esbuild',
#   'User Name': 'evanw',
#   'stars': '32.3k',
#   'Repository URL': 'https://github.com/evanw/esbuild'},
#  {'Sr No': 64,
#   'Repository Name': 'clipboard.js',
#   'User Name': 'zenorocha',
#   'stars': '32.3k',
#   'Repository URL': 'https://github.com/zenorocha/clipboard.js'},
#  {'Sr No': 65,
#   'Repository Name': 'phaser',
#   'User Name': 'photonstorm',
#   'stars': '32k',
#   'Repository URL': 'https://github.com/photonstorm/phaser'},
#  {'Sr No': 66,
#   'Repository Name': 'taro',
#   'User Name': 'NervJS',
#   'stars': '31.2k',
#   'Repository URL': 'https://github.com/NervJS/taro'},
#  {'Sr No': 67,
#   'Repository Name': 'uBlock',
#   'User Name': 'gorhill',
#   'stars': '31k',
#   'Repository URL': 'https://github.com/gorhill/uBlock'},
#  {'Sr No': 68,
#   'Repository Name': 'open-source-mac-os-apps',
#   'User Name': 'serhii-londar',
#   'stars': '31k',
#   'Repository URL': 'https://github.com/serhii-londar/open-source-mac-os-apps'},
#  {'Sr No': 69,
#   'Repository Name': 'gold-miner',
#   'User Name': 'xitu',
#   'stars': '30.9k',
#   'Repository URL': 'https://github.com/xitu/gold-miner'},
#  {'Sr No': 70,
#   'Repository Name': 'sheetjs',
#   'User Name': 'SheetJS',
#   'stars': '30.6k',
#   'Repository URL': 'https://github.com/SheetJS/sheetjs'},
#  {'Sr No': 71,
#   'Repository Name': 'carbon',
#   'User Name': 'carbon-app',
#   'stars': '30.6k',
#   'Repository URL': 'https://github.com/carbon-app/carbon'},
#  {'Sr No': 72,
#   'Repository Name': 'joplin',
#   'User Name': 'laurent22',
#   'stars': '30.5k',
#   'Repository URL': 'https://github.com/laurent22/joplin'},
#  {'Sr No': 73,
#   'Repository Name': 'awesome-cheatsheets',
#   'User Name': 'LeCoupa',
#   'stars': '29.4k',
#   'Repository URL': 'https://github.com/LeCoupa/awesome-cheatsheets'},
#  {'Sr No': 74,
#   'Repository Name': 'date-fns',
#   'User Name': 'date-fns',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/date-fns/date-fns'},
#  {'Sr No': 75,
#   'Repository Name': 'leetcode-master',
#   'User Name': 'youngyangyang04',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/youngyangyang04/leetcode-master'},
#  {'Sr No': 76,
#   'Repository Name': 'typeorm',
#   'User Name': 'typeorm',
#   'stars': '28.7k',
#   'Repository URL': 'https://github.com/typeorm/typeorm'},
#  {'Sr No': 77,
#   'Repository Name': 'vuex',
#   'User Name': 'vuejs',
#   'stars': '27.6k',
#   'Repository URL': 'https://github.com/vuejs/vuex'},
#  {'Sr No': 78,
#   'Repository Name': 'async',
#   'User Name': 'caolan',
#   'stars': '27.6k',
#   'Repository URL': 'https://github.com/caolan/async'},
#  {'Sr No': 79,
#   'Repository Name': 'Blog',
#   'User Name': 'mqyqingfeng',
#   'stars': '27.3k',
#   'Repository URL': 'https://github.com/mqyqingfeng/Blog'},
#  {'Sr No': 80,
#   'Repository Name': 'rxjs',
#   'User Name': 'ReactiveX',
#   'stars': '27.3k',
#   'Repository URL': 'https://github.com/ReactiveX/rxjs'},
#  {'Sr No': 81,
#   'Repository Name': 'standard',
#   'User Name': 'standard',
#   'stars': '27.2k',
#   'Repository URL': 'https://github.com/standard/standard'},
#  {'Sr No': 82,
#   'Repository Name': 'tesseract.js',
#   'User Name': 'naptha',
#   'stars': '27.1k',
#   'Repository URL': 'https://github.com/naptha/tesseract.js'},
#  {'Sr No': 83,
#   'Repository Name': 'project-guidelines',
#   'User Name': 'elsewhencode',
#   'stars': '27k',
#   'Repository URL': 'https://github.com/elsewhencode/project-guidelines'},
#  {'Sr No': 84,
#   'Repository Name': 'wtfjs',
#   'User Name': 'denysdovhan',
#   'stars': '27k',
#   'Repository URL': 'https://github.com/denysdovhan/wtfjs'},
#  {'Sr No': 85,
#   'Repository Name': 'webtorrent',
#   'User Name': 'webtorrent',
#   'stars': '26.5k',
#   'Repository URL': 'https://github.com/webtorrent/webtorrent'},
#  {'Sr No': 86,
#   'Repository Name': 'sequelize',
#   'User Name': 'sequelize',
#   'stars': '26.4k',
#   'Repository URL': 'https://github.com/sequelize/sequelize'},
#  {'Sr No': 87,
#   'Repository Name': 'layui',
#   'User Name': 'layui',
#   'stars': '26.3k',
#   'Repository URL': 'https://github.com/layui/layui'},
#  {'Sr No': 88,
#   'Repository Name': 'html2canvas',
#   'User Name': 'niklasvh',
#   'stars': '26.2k',
#   'Repository URL': 'https://github.com/niklasvh/html2canvas'},
#  {'Sr No': 89,
#   'Repository Name': 'Daily-Interview-Question',
#   'User Name': 'Advanced-Frontend',
#   'stars': '25.9k',
#   'Repository URL': 'https://github.com/Advanced-Frontend/Daily-Interview-Question'},
#  {'Sr No': 90,
#   'Repository Name': 'uppy',
#   'User Name': 'transloadit',
#   'stars': '25.5k',
#   'Repository URL': 'https://github.com/transloadit/uppy'},
#  {'Sr No': 91,
#   'Repository Name': 'mobx',
#   'User Name': 'mobxjs',
#   'stars': '25.4k',
#   'Repository URL': 'https://github.com/mobxjs/mobx'},
#  {'Sr No': 92,
#   'Repository Name': 'select2',
#   'User Name': 'select2',
#   'stars': '25.4k',
#   'Repository URL': 'https://github.com/select2/select2'},
#  {'Sr No': 93,
#   'Repository Name': 'fetch',
#   'User Name': 'github',
#   'stars': '25.4k',
#   'Repository URL': 'https://github.com/github/fetch'},
#  {'Sr No': 94,
#   'Repository Name': 'Modernizr',
#   'User Name': 'Modernizr',
#   'stars': '25.3k',
#   'Repository URL': 'https://github.com/Modernizr/Modernizr'},
#  {'Sr No': 95,
#   'Repository Name': 'slate',
#   'User Name': 'ianstormtaylor',
#   'stars': '24.7k',
#   'Repository URL': 'https://github.com/ianstormtaylor/slate'},
#  {'Sr No': 96,
#   'Repository Name': 'NeteaseCloudMusicApi',
#   'User Name': 'Binaryify',
#   'stars': '24.7k',
#   'Repository URL': 'https://github.com/Binaryify/NeteaseCloudMusicApi'},
#  {'Sr No': 97,
#   'Repository Name': 'nylas-mail',
#   'User Name': 'nylas',
#   'stars': '24.7k',
#   'Repository URL': 'https://github.com/nylas/nylas-mail'},
#  {'Sr No': 98,
#   'Repository Name': 'selenium',
#   'User Name': 'SeleniumHQ',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/SeleniumHQ/selenium'},
#  {'Sr No': 99,
#   'Repository Name': 'prisma',
#   'User Name': 'prisma',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/prisma/prisma'},
#  {'Sr No': 100,
#   'Repository Name': 'iview',
#   'User Name': 'iview',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/iview/iview'},
#  {'Sr No': 101,
#   'Repository Name': 'appwrite',
#   'User Name': 'appwrite',
#   'stars': '23.4k',
#   'Repository URL': 'https://github.com/appwrite/appwrite'},
#  {'Sr No': 102,
#   'Repository Name': 'modern-js-cheatsheet',
#   'User Name': 'mbeaudru',
#   'stars': '23k',
#   'Repository URL': 'https://github.com/mbeaudru/modern-js-cheatsheet'},
#  {'Sr No': 103,
#   'Repository Name': 'swc',
#   'User Name': 'swc-project',
#   'stars': '22.8k',
#   'Repository URL': 'https://github.com/swc-project/swc'},
#  {'Sr No': 104,
#   'Repository Name': 'sharp',
#   'User Name': 'lovell',
#   'stars': '22.7k',
#   'Repository URL': 'https://github.com/lovell/sharp'},
#  {'Sr No': 105,
#   'Repository Name': 'mdb-ui-kit',
#   'User Name': 'mdbootstrap',
#   'stars': '22.4k',
#   'Repository URL': 'https://github.com/mdbootstrap/mdb-ui-kit'},
#  {'Sr No': 106,
#   'Repository Name': 'plyr',
#   'User Name': 'sampotts',
#   'stars': '22.3k',
#   'Repository URL': 'https://github.com/sampotts/plyr'},
#  {'Sr No': 107,
#   'Repository Name': 'ember.js',
#   'User Name': 'emberjs',
#   'stars': '22.2k',
#   'Repository URL': 'https://github.com/emberjs/ember.js'},
#  {'Sr No': 108,
#   'Repository Name': 'ramda',
#   'User Name': 'ramda',
#   'stars': '22.1k',
#   'Repository URL': 'https://github.com/ramda/ramda'},
#  {'Sr No': 109,
#   'Repository Name': 'sweetalert',
#   'User Name': 't4t5',
#   'stars': '22k',
#   'Repository URL': 'https://github.com/t4t5/sweetalert'},
#  {'Sr No': 110,
#   'Repository Name': 'reactjs-interview-questions',
#   'User Name': 'sudheerj',
#   'stars': '22.1k',
#   'Repository URL': 'https://github.com/sudheerj/reactjs-interview-questions'},
#  {'Sr No': 111,
#   'Repository Name': 'PhotoSwipe',
#   'User Name': 'dimsemenov',
#   'stars': '22k',
#   'Repository URL': 'https://github.com/dimsemenov/PhotoSwipe'},
#  {'Sr No': 112,
#   'Repository Name': 'feather',
#   'User Name': 'feathericons',
#   'stars': '21.8k',
#   'Repository URL': 'https://github.com/feathericons/feather'},
#  {'Sr No': 113,
#   'Repository Name': 'mostly-adequate-guide',
#   'User Name': 'MostlyAdequate',
#   'stars': '21.9k',
#   'Repository URL': 'https://github.com/MostlyAdequate/mostly-adequate-guide'},
#  {'Sr No': 114,
#   'Repository Name': 'react-redux-links',
#   'User Name': 'markerikson',
#   'stars': '21.6k',
#   'Repository URL': 'https://github.com/markerikson/react-redux-links'},
#  {'Sr No': 115,
#   'Repository Name': 'quasar',
#   'User Name': 'quasarframework',
#   'stars': '21.5k',
#   'Repository URL': 'https://github.com/quasarframework/quasar'},
#  {'Sr No': 116,
#   'Repository Name': 'mocha',
#   'User Name': 'mochajs',
#   'stars': '21.5k',
#   'Repository URL': 'https://github.com/mochajs/mocha'},
#  {'Sr No': 117,
#   'Repository Name': 'fe-interview',
#   'User Name': 'haizlin',
#   'stars': '21.5k',
#   'Repository URL': 'https://github.com/haizlin/fe-interview'},
#  {'Sr No': 118,
#   'Repository Name': 'NativeScript',
#   'User Name': 'NativeScript',
#   'stars': '21.4k',
#   'Repository URL': 'https://github.com/NativeScript/NativeScript'},
#  {'Sr No': 119,
#   'Repository Name': 'intro.js',
#   'User Name': 'usablica',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/usablica/intro.js'},
#  {'Sr No': 120,
#   'Repository Name': 'redash',
#   'User Name': 'getredash',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/getredash/redash'},
#  {'Sr No': 121,
#   'Repository Name': 'react-starter-kit',
#   'User Name': 'kriasoft',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/kriasoft/react-starter-kit'},
#  {'Sr No': 122,
#   'Repository Name': 'dragula',
#   'User Name': 'bevacqua',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/bevacqua/dragula'},
#  {'Sr No': 123,
#   'Repository Name': 'normalizr',
#   'User Name': 'paularmstrong',
#   'stars': '20.9k',
#   'Repository URL': 'https://github.com/paularmstrong/normalizr'},
#  {'Sr No': 124,
#   'Repository Name': 'react-bootstrap',
#   'User Name': 'react-bootstrap',
#   'stars': '20.9k',
#   'Repository URL': 'https://github.com/react-bootstrap/react-bootstrap'},
#  {'Sr No': 125,
#   'Repository Name': 'eslint',
#   'User Name': 'eslint',
#   'stars': '20.8k',
#   'Repository URL': 'https://github.com/eslint/eslint'},
#  {'Sr No': 126,
#   'Repository Name': 'scrollreveal',
#   'User Name': 'jlmakes',
#   'stars': '20.9k',
#   'Repository URL': 'https://github.com/jlmakes/scrollreveal'},
#  {'Sr No': 127,
#   'Repository Name': 'localForage',
#   'User Name': 'localForage',
#   'stars': '20.7k',
#   'Repository URL': 'https://github.com/localForage/localForage'},
#  {'Sr No': 128,
#   'Repository Name': 'xstate',
#   'User Name': 'statelyai',
#   'stars': '20.6k',
#   'Repository URL': 'https://github.com/statelyai/xstate'},
#  {'Sr No': 129,
#   'Repository Name': 'Web',
#   'User Name': 'qianguyihao',
#   'stars': '20.6k',
#   'Repository URL': 'https://github.com/qianguyihao/Web'},
#  {'Sr No': 130,
#   'Repository Name': 'JavaScript',
#   'User Name': 'TheAlgorithms',
#   'stars': '20.4k',
#   'Repository URL': 'https://github.com/TheAlgorithms/JavaScript'},
#  {'Sr No': 131,
#   'Repository Name': 'howler.js',
#   'User Name': 'goldfire',
#   'stars': '20.3k',
#   'Repository URL': 'https://github.com/goldfire/howler.js'},
#  {'Sr No': 132,
#   'Repository Name': 'highlight.js',
#   'User Name': 'highlightjs',
#   'stars': '20.2k',
#   'Repository URL': 'https://github.com/highlightjs/highlight.js'},
#  {'Sr No': 133,
#   'Repository Name': 'ava',
#   'User Name': 'avajs',
#   'stars': '19.9k',
#   'Repository URL': 'https://github.com/avajs/ava'},
#  {'Sr No': 134,
#   'Repository Name': 'electron-react-boilerplate',
#   'User Name': 'electron-react-boilerplate',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/electron-react-boilerplate/electron-react-boilerplate'},
#  {'Sr No': 135,
#   'Repository Name': 'solid',
#   'User Name': 'solidjs',
#   'stars': '20k',
#   'Repository URL': 'https://github.com/solidjs/solid'},
#  {'Sr No': 136,
#   'Repository Name': 'validator.js',
#   'User Name': 'validatorjs',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/validatorjs/validator.js'},
#  {'Sr No': 137,
#   'Repository Name': 'v8',
#   'User Name': 'v8',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/v8/v8'},
#  {'Sr No': 138,
#   'Repository Name': 'js-cookie',
#   'User Name': 'js-cookie',
#   'stars': '19.6k',
#   'Repository URL': 'https://github.com/js-cookie/js-cookie'},
#  {'Sr No': 139,
#   'Repository Name': 'server',
#   'User Name': 'nextcloud',
#   'stars': '19.5k',
#   'Repository URL': 'https://github.com/nextcloud/server'},
#  {'Sr No': 140,
#   'Repository Name': 'appsmith',
#   'User Name': 'appsmithorg',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/appsmithorg/appsmith'},
#  {'Sr No': 141,
#   'Repository Name': 'editor.js',
#   'User Name': 'codex-team',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/codex-team/editor.js'},
#  {'Sr No': 142,
#   'Repository Name': 'stackedit',
#   'User Name': 'benweet',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/benweet/stackedit'},
#  {'Sr No': 143,
#   'Repository Name': 'js-stack-from-scratch',
#   'User Name': 'verekia',
#   'stars': '19.2k',
#   'Repository URL': 'https://github.com/verekia/js-stack-from-scratch'},
#  {'Sr No': 144,
#   'Repository Name': 'lx-music-desktop',
#   'User Name': 'lyswhut',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/lyswhut/lx-music-desktop'},
#  {'Sr No': 145,
#   'Repository Name': 'joi',
#   'User Name': 'sideway',
#   'stars': '18.9k',
#   'Repository URL': 'https://github.com/sideway/joi'},
#  {'Sr No': 146,
#   'Repository Name': 'vue-router',
#   'User Name': 'vuejs',
#   'stars': '18.8k',
#   'Repository URL': 'https://github.com/vuejs/vue-router'},
#  {'Sr No': 147,
#   'Repository Name': 'hyperapp',
#   'User Name': 'jorgebucaran',
#   'stars': '18.8k',
#   'Repository URL': 'https://github.com/jorgebucaran/hyperapp'},
#  {'Sr No': 148,
#   'Repository Name': 'chalk',
#   'User Name': 'chalk',
#   'stars': '18.7k',
#   'Repository URL': 'https://github.com/chalk/chalk'},
#  {'Sr No': 149,
#   'Repository Name': 'ink',
#   'User Name': 'vadimdemedes',
#   'stars': '18.7k',
#   'Repository URL': 'https://github.com/vadimdemedes/ink'},
#  {'Sr No': 150,
#   'Repository Name': 'ws',
#   'User Name': 'websockets',
#   'stars': '18.4k',
#   'Repository URL': 'https://github.com/websockets/ws'},
#  {'Sr No': 151,
#   'Repository Name': 'YesPlayMusic',
#   'User Name': 'qier222',
#   'stars': '18.2k',
#   'Repository URL': 'https://github.com/qier222/YesPlayMusic'},
#  {'Sr No': 152,
#   'Repository Name': 'flatbuffers',
#   'User Name': 'google',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/google/flatbuffers'},
#  {'Sr No': 153,
#   'Repository Name': 'pnpm',
#   'User Name': 'pnpm',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/pnpm/pnpm'},
#  {'Sr No': 154,
#   'Repository Name': 'wekan',
#   'User Name': 'wekan',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/wekan/wekan'},
#  {'Sr No': 155,
#   'Repository Name': 'table',
#   'User Name': 'TanStack',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/TanStack/table'},
#  {'Sr No': 156,
#   'Repository Name': 'javascript-testing-best-practices',
#   'User Name': 'goldbergyoni',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/goldbergyoni/javascript-testing-best-practices'},
#  {'Sr No': 157,
#   'Repository Name': 'svgo',
#   'User Name': 'svg',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/svg/svgo'},
#  {'Sr No': 158,
#   'Repository Name': 'CS-Interview-Knowledge-Map',
#   'User Name': 'InterviewMap',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/InterviewMap/CS-Interview-Knowledge-Map'},
#  {'Sr No': 159,
#   'Repository Name': 'lowdb',
#   'User Name': 'typicode',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/typicode/lowdb'},
#  {'Sr No': 160,
#   'Repository Name': 'p5.js',
#   'User Name': 'processing',
#   'stars': '17.7k',
#   'Repository URL': 'https://github.com/processing/p5.js'},
#  {'Sr No': 161,
#   'Repository Name': 'vux',
#   'User Name': 'airyland',
#   'stars': '17.6k',
#   'Repository URL': 'https://github.com/airyland/vux'},
#  {'Sr No': 162,
#   'Repository Name': 'mojs',
#   'User Name': 'mojs',
#   'stars': '17.6k',
#   'Repository URL': 'https://github.com/mojs/mojs'},
#  {'Sr No': 163,
#   'Repository Name': 'jsdom',
#   'User Name': 'jsdom',
#   'stars': '17.6k',
#   'Repository URL': 'https://github.com/jsdom/jsdom'},
#  {'Sr No': 164,
#   'Repository Name': 'mysql',
#   'User Name': 'mysqljs',
#   'stars': '17.3k',
#   'Repository URL': 'https://github.com/mysqljs/mysql'},
#  {'Sr No': 165,
#   'Repository Name': 'You-Dont-Need-JavaScript',
#   'User Name': 'you-dont-need',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/you-dont-need/You-Dont-Need-JavaScript'},
#  {'Sr No': 166,
#   'Repository Name': 'graal',
#   'User Name': 'oracle',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/oracle/graal'},
#  {'Sr No': 167,
#   'Repository Name': 'k6',
#   'User Name': 'grafana',
#   'stars': '17k',
#   'Repository URL': 'https://github.com/grafana/k6'},
#  {'Sr No': 168,
#   'Repository Name': 'core-js',
#   'User Name': 'zloirock',
#   'stars': '17k',
#   'Repository URL': 'https://github.com/zloirock/core-js'},
#  {'Sr No': 169,
#   'Repository Name': 'fingerprintjs',
#   'User Name': 'fingerprintjs',
#   'stars': '17k',
#   'Repository URL': 'https://github.com/fingerprintjs/fingerprintjs'},
#  {'Sr No': 170,
#   'Repository Name': 'trix',
#   'User Name': 'basecamp',
#   'stars': '16.9k',
#   'Repository URL': 'https://github.com/basecamp/trix'},
#  {'Sr No': 171,
#   'Repository Name': 'gotty',
#   'User Name': 'yudai',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/yudai/gotty'},
#  {'Sr No': 172,
#   'Repository Name': 'responsively-app',
#   'User Name': 'responsively-org',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/responsively-org/responsively-app'},
#  {'Sr No': 173,
#   'Repository Name': 'material',
#   'User Name': 'angular',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/angular/material'},
#  {'Sr No': 174,
#   'Repository Name': 'directus',
#   'User Name': 'directus',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/directus/directus'},
#  {'Sr No': 175,
#   'Repository Name': 'MagicMirror',
#   'User Name': 'MichMich',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/MichMich/MagicMirror'},
#  {'Sr No': 176,
#   'Repository Name': 'dropzone',
#   'User Name': 'dropzone',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/dropzone/dropzone'},
#  {'Sr No': 177,
#   'Repository Name': 'vue-admin-template',
#   'User Name': 'PanJiaChen',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/PanJiaChen/vue-admin-template'},
#  {'Sr No': 178,
#   'Repository Name': 'react-testing-library',
#   'User Name': 'testing-library',
#   'stars': '16.6k',
#   'Repository URL': 'https://github.com/testing-library/react-testing-library'},
#  {'Sr No': 179,
#   'Repository Name': 'statsd',
#   'User Name': 'statsd',
#   'stars': '16.5k',
#   'Repository URL': 'https://github.com/statsd/statsd'},
#  {'Sr No': 180,
#   'Repository Name': 'bokeh',
#   'User Name': 'bokeh',
#   'stars': '16.5k',
#   'Repository URL': 'https://github.com/bokeh/bokeh'},
#  {'Sr No': 181,
#   'Repository Name': 'node-lessons',
#   'User Name': 'alsotang',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/alsotang/node-lessons'},
#  {'Sr No': 182,
#   'Repository Name': 'tfjs',
#   'User Name': 'tensorflow',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/tensorflow/tfjs'},
#  {'Sr No': 183,
#   'Repository Name': 'material-components-web',
#   'User Name': 'material-components',
#   'stars': '16.3k',
#   'Repository URL': 'https://github.com/material-components/material-components-web'},
#  {'Sr No': 184,
#   'Repository Name': 'lazysizes',
#   'User Name': 'aFarkas',
#   'stars': '16.2k',
#   'Repository URL': 'https://github.com/aFarkas/lazysizes'},
#  {'Sr No': 185,
#   'Repository Name': 'draggable',
#   'User Name': 'Shopify',
#   'stars': '16.2k',
#   'Repository URL': 'https://github.com/Shopify/draggable'},
#  {'Sr No': 186,
#   'Repository Name': 'reddit',
#   'User Name': 'reddit-archive',
#   'stars': '16.1k',
#   'Repository URL': 'https://github.com/reddit-archive/reddit'},
#  {'Sr No': 187,
#   'Repository Name': 'zulip',
#   'User Name': 'zulip',
#   'stars': '16.1k',
#   'Repository URL': 'https://github.com/zulip/zulip'},
#  {'Sr No': 188,
#   'Repository Name': 'knex',
#   'User Name': 'knex',
#   'stars': '16k',
#   'Repository URL': 'https://github.com/knex/knex'},
#  {'Sr No': 189,
#   'Repository Name': 'react-grid-layout',
#   'User Name': 'react-grid-layout',
#   'stars': '16k',
#   'Repository URL': 'https://github.com/react-grid-layout/react-grid-layout'},
#  {'Sr No': 190,
#   'Repository Name': 'outline',
#   'User Name': 'outline',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/outline/outline'},
#  {'Sr No': 191,
#   'Repository Name': 'GitHubDaily',
#   'User Name': 'GitHubDaily',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/GitHubDaily/GitHubDaily'},
#  {'Sr No': 192,
#   'Repository Name': 'proposals',
#   'User Name': 'tc39',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/tc39/proposals'},
#  {'Sr No': 193,
#   'Repository Name': 'medium-editor',
#   'User Name': 'yabwe',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/yabwe/medium-editor'},
#  {'Sr No': 194,
#   'Repository Name': 'KaTeX',
#   'User Name': 'KaTeX',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/KaTeX/KaTeX'},
#  {'Sr No': 195,
#   'Repository Name': 'web3.js',
#   'User Name': 'ChainSafe',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/ChainSafe/web3.js'},
#  {'Sr No': 196,
#   'Repository Name': 'best-resume-ever',
#   'User Name': 'salomonelli',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/salomonelli/best-resume-ever'},
#  {'Sr No': 197,
#   'Repository Name': 'tiptap',
#   'User Name': 'ueberdosis',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/ueberdosis/tiptap'},
#  {'Sr No': 198,
#   'Repository Name': 'netlify-cms',
#   'User Name': 'netlify',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/netlify/netlify-cms'},
#  {'Sr No': 199,
#   'Repository Name': 'Functional-Light-JS',
#   'User Name': 'getify',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/getify/Functional-Light-JS'},
#  {'Sr No': 200,
#   'Repository Name': 'jasmine',
#   'User Name': 'jasmine',
#   'stars': '15.4k',
#   'Repository URL': 'https://github.com/jasmine/jasmine'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No      Repository Name     User Name  stars  \
# 0        1         freeCodeCamp  freeCodeCamp   348k
# 1        2                  vue         vuejs   197k
# 2        3                react      facebook   191k
# 3        4            bootstrap          twbs   158k
# 4        5     You-Dont-Know-JS        getify   156k
# ..     ...                  ...           ...    ...
# 195    196     best-resume-ever   salomonelli  15.5k
# 196    197               tiptap    ueberdosis  15.5k
# 197    198          netlify-cms       netlify  15.5k
# 198    199  Functional-Light-JS        getify  15.5k
# 199    200              jasmine       jasmine  15.4k
#
#                                       Repository URL
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                       https://github.com/vuejs/vue
# 2                  https://github.com/facebook/react
# 3                  https://github.com/twbs/bootstrap
# 4         https://github.com/getify/You-Dont-Know-JS
# ..                                               ...
# 195  https://github.com/salomonelli/best-resume-ever
# 196             https://github.com/ueberdosis/tiptap
# 197           https://github.com/netlify/netlify-cms
# 198    https://github.com/getify/Functional-Light-JS
# 199               https://github.com/jasmine/jasmine
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_java_script.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
