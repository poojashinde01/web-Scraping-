# %%
#react web scraping

# %%
import requests

# %%
url=requests.get('https://github.com/topics/react').text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-10084108b209.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" rel="stylesheet" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" rel="stylesheet" href="https://github.githubassets.com/assets/github-f815d05d371a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYw ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-92c7d381038e.css" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-10084108b209.css" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f815d05d371a.css" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-d31ea144555c.css" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYwk1Z+BnSLOwYorhPLm6jrWoV3c7Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-44mCWWd9he+TZlQdLzIEo+cbYo6tgMXkx8954MY/9DknkwxQmYGmKJrGKCgbWmcMYmBgxLX6uOEgcRoDL/5eCA==" src="https://github.githubassets.com/assets/runtime-e3898259677d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZXV4TpPmxfyBQ9eFqJaVR/Z8Rrt+f/In8yBbbMmt6pqCRMVcnlTWS7/Xy5aedmiIj1tNZXmsvW3cf/vRas/mvQ==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-74aed8-6575784e93e6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-km+JVvSjuMukaGXFPj5OuzW1lNCVhWt0dB2EAkW4NpEj6x301u0l22+XLYaKm9+hvluGH0OlM6BE4hoTjxtFoQ==" src="https://github.githubassets.com/assets/environment-926f8956f4a3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-57NPhP0wWFMwvRygugK3iI3z+Sv0WTNy8MGBcwfMPYE7SoHKEoH1B89v+ANBqnW9GGvUYzf4gLT6UrP/VmhY2g==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-e7b34f84fd30.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Es25N4GyPa8Yfp5wpahoe5b2fyPtkRMyR6mKIXyCJC0ocqQazeWvxhGZhx3StRxOfqDfHDR5SS35u/R3Wux6Cg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-12cdb93781b2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-lmiecOIgf+hakg5oKMNM7grVhEDyPoIrT39Px448JJH5PSAaK21PH0Twgyz5O5oi8+dnlLr3Jt8bBCtAcpNdRw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-c7e9ed-96689e70e220.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-FhIi1nHjAzm1txsZ2LPPUfqIASARJ44qRQ09VSY4p/NVvWz/1reBy21+3an4fDIi6QhfrHNUI4ldKz3NW5by/Q==" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_time-elements_dist_index_js-161222d671e3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-DE9GK/TS3Hf/dJfP1GMiyjvsGRnpR4A1eGH64s0Ot7Vy7Tj7/aD1d5EOMWHFWQXlXy/ZSwu5MHInG6RZN31bMA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-52e104-0c4f462bf4d2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-fcVStVRolV54DldAqKbEzSE1OB6Rd/jIIpSj/dcCRRaSc8EgN68GT9sT/Ya0gtpNTq0aAPzs9OLlhWY7l0s4eA==" src="https://github.githubassets.com/assets/github-elements-7dc552b55468.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-n0EqohMRhyf2gYDkWAvqYJsBzb8qCciNwqGUpwOEjVfSLESviOFqm7IrHsihpfLAm+ZhteYJkQ+PPwqjJTUTrQ==" src="https://github.githubassets.com/assets/element-registry-9f412aa21311.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ULHDrjH3Nz+5xGQnGJ+51ZBv5qENKe3TikjwAxKli4TyT+8KZ5mnWUJxUdXaFwRVMGRJD+8CjfCVhj7913OiOA==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-50b1c3ae31f7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-XubU6uMX6y2ka6JR/QVSIS8aAdXBH9Jhm1lLCNFS5Dy3xbDEdS6W4ENFx71XaEAwW3d8xzgiS4cS0J/zsnYm6w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_github_catalyst_lib_index_-bd1f73-5ee6d4eae317.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-0r1nf/rfPz54kyePp4f63bcPxkFo7wyaUZJD/SwIVDK3q0WzurAK9ydOm88tzKtPJm8xWI0Vo25NyCfecwxJ9g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-d2bd677ffadf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-b6LnssJjHkph4nI0CxyYnXJ/d7eWTCd6fDCQZkhXUwNTMcB55fwq4nPNUDdsFG3h/KS3VEsMjhkqC8jBcQVazA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-f71f15-6fa2e7b2c263.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-aD+lpuc5jHemEy0Cf2KYz46MdwOIlj3+2cZ59XIi+mentNdewI1LzaDqroNLJzONIiL4IeUUZ7hJzhPYV4DQVA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_pjax_ts-683fa5a6e739.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-i6G+/7pwOhMb9q+i08xUSvHWO8fWX9lkXtuIJQGpHGn299Mb74hWyc5ikFQAuqgd2i/cV9c5Jw6O9Z10jDfAwg==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_be-af52ef-8ba1beffba70.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sGIJsMNVLhivulsWgcWql7t/JEs3gUQQt/9GHRjArviQLj6smy1Cei4X6Bg51OC/rZMDXeTNSL733VSNtdlynA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-019af8-b06209b0c355.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-1CN8HrSEXNbvvtNrIvzOMA1IkGwLyUOaFBl/N2UE91/8EvcqBFxy3M83mJVi/n50Kdq4oIRIeZG5D5oTpFTBDg==" src="https://github.githubassets.com/assets/behaviors-d4237c1eb484.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5nWr6hoxY6oc8ngCIfUbQS8h+5n8/1XZVb9KFgP0ak4NzsfM7ERe6b5639AYjyAbYZGs6I/7hC3eieSbWkHx9w==" src="https://github.githubassets.com/assets/notifications-global-e675abea1a31.js" type="application/javascript"></script>
# <title>react · GitHub Topics · GitHub</title>
# <meta content="EF80:4655:3C1F50:41784B:62C42024" data-pjax-transient="true" name="request-id"/><meta content="fc87782c5b6bafea629e2ce7f654b6efd08214a0ba39a3cafdd67c0eee5e726f" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFRjgwOjQ2NTU6M0MxRjUwOjQxNzg0Qjo2MkM0MjAyNCIsInZpc2l0b3JfaWQiOiI2Njg4Njg0OTI5NzI0OTgxMjg0IiwicmVnaW9uX2VkZ2UiOiJhcC1zb3V0aC0xIiwicmVnaW9uX3JlbmRlciI6ImFwLXNvdXRoLTEifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="d3e5e51c790f8f4291a5189db03adbfa051dbb571b8cf6584c38159e979cc814" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/react"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/react","user_id":null}}' data-hydro-click-hmac="4e9af37ef16b92cea15c38925a96143b93380239d85510250354660f60ec232e" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Freact&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/react;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/react;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/react;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/react;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/react;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/react;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/react;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/react;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/react;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/react;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/react;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/react;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/react;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/react;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/react;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/react;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/react;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/react;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/react;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/react;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/react;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/react;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/react;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/react;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/react;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/react;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/react;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/react;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/react;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/react;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/react;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/react" aria-label="Site" class="js-site-search-form" data-scope-id="12" data-scope-type="Topic" data-scoped-search-url="/topics/react" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="xQsDHj5PUnJsOFQto0Co3SZOGb5/fPWJl9nZJIPMROxAFFBBUW5EI2OabWZtoAIDwd7DQolFIczRgab2ZhMwPQ=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </label>
# </form> </div>
# </div>
# </div>
# ...
#               rest
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":12079,"originating_url":"https://github.com/topics/react","user_id":null}}' data-hydro-click-hmac="b333ed0fb0045a911cc0d4d063ee7c68ea435ef8692a867ed3d2457171892a49" data-view-component="true" href="/topics/async" title="Topic: async">
#               async
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":13128,"originating_url":"https://github.com/topics/react","user_id":null}}' data-hydro-click-hmac="ef268fd93756c3c941c52c41a8d79085b52af85702223c119581cd396c630a9d" data-view-component="true" href="/topics/cache" title="Topic: cache">
#               cache
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22261,"originating_url":"https://github.com/topics/react","user_id":null}}' data-hydro-click-hmac="41eef1535be8ba82ad35de788fcb6c78eacf20bccf7c3055750c2f82314c59e7" data-view-component="true" href="/topics/update" title="Topic: update">
#               update
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":95672,"originating_url":"https://github.com/topics/react","user_id":null}}' data-hydro-click-hmac="144631f1513d8f869a54db640b3083f0617f70812e0c46867512f768b9312545" data-view-component="true" href="/topics/stale" title="Topic: stale">
#               stale
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":659228,"originating_url":"https://github.com/topics/react","user_id":null}}' data-hydro-click-hmac="694b76c4af3f605c99ffdac00721fc62bd9c3fe87720730266de5e0186cc7394" data-view-component="true" href="/topics/stale-while-revalidate" title="Topic: stale-while-revalidate">
#               stale-while-revalidate
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-07-03T15:08:42Z">Jul 3, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #3178c6"></span>
# <span itemprop="programmingLanguage">TypeScript</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/react" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Jordan Walke
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> March 2013
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Latest release</span>
# <a alt="Latest release" href="https://github.com/facebook/react/releases/latest">
#         21 days ago
#       </a>
# </p>
# <dl class="my-4">
# <dt class="d-none">
#         Repository
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to facebook/react, location:topic page" href="https://github.com/facebook/react">
# <span class="css-truncate css-truncate-target" title="facebook/react">
#           facebook/react
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="https://reactjs.org/">
# <span class="css-truncate css-truncate-target" title="reactjs.org">
#           reactjs.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/React_(JavaScript_library)">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/React_(JavaScript_library)">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# <h2 class="h4 mb-2">
#     Related Topics
#   </h2>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:angular" data-view-component="true" href="/topics/angular" title="Topic: angular">
#   angular
# </a>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:react-native" data-view-component="true" href="/topics/react-native" title="Topic: react-native">
#   react-native
# </a>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:vue" data-view-component="true" href="/topics/vue" title="Topic: vue">
#   vue
# </a>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'freeCodeCamp'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'freeCodeCamp'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text

# %%
stars
# Out:
# '348k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/freeCodeCamp/freeCodeCamp'

# %%
base_url='https://github.com/topics/react'

# %%
base_url
# Out:
# 'https://github.com/topics/react'

# %%
Repository_url=base_url+url_link

# %%
Repository_url
# Out:
# 'https://github.com/topics/react/freeCodeCamp/freeCodeCamp'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
base_url='https://github.com/topics/react'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
Repository_1_lst
# Out:
# [{'Repository Name': 'freeCodeCamp',
#   'User Name': 'freeCodeCamp',
#   'stars': '348k',
#   'Repository URL': 'https://github.com/topics/reactfreeCodeCamp/freeCodeCamp'},
#  {'Repository Name': 'react',
#   'User Name': 'facebook',
#   'stars': '191k',
#   'Repository URL': 'https://github.com/topics/reactfacebook/react'},
#  {'Repository Name': 'create-react-app',
#   'User Name': 'facebook',
#   'stars': '95.8k',
#   'Repository URL': 'https://github.com/topics/reactfacebook/create-react-app'},
#  {'Repository Name': 'free-programming-books-zh_CN',
#   'User Name': 'justjavac',
#   'stars': '94.1k',
#   'Repository URL': 'https://github.com/topics/reactjustjavac/free-programming-books-zh_CN'},
#  {'Repository Name': 'next.js',
#   'User Name': 'vercel',
#   'stars': '89.1k',
#   'Repository URL': 'https://github.com/topics/reactvercel/next.js'},
#  {'Repository Name': 'ant-design',
#   'User Name': 'ant-design',
#   'stars': '80.9k',
#   'Repository URL': 'https://github.com/topics/reactant-design/ant-design'},
#  {'Repository Name': 'material-ui',
#   'User Name': 'mui',
#   'stars': '79.5k',
#   'Repository URL': 'https://github.com/topics/reactmui/material-ui'},
#  {'Repository Name': 'storybook',
#   'User Name': 'storybookjs',
#   'stars': '72.5k',
#   'Repository URL': 'https://github.com/topics/reactstorybookjs/storybook'},
#  {'Repository Name': 'gatsby',
#   'User Name': 'gatsbyjs',
#   'stars': '53.2k',
#   'Repository URL': 'https://github.com/topics/reactgatsbyjs/gatsby'},
#  {'Repository Name': '33-js-concepts',
#   'User Name': 'leonardomso',
#   'stars': '49.7k',
#   'Repository URL': 'https://github.com/topics/reactleonardomso/33-js-concepts'},
#  {'Repository Name': 'awesome-react',
#   'User Name': 'enaqx',
#   'stars': '49k',
#   'Repository URL': 'https://github.com/topics/reactenaqx/awesome-react'},
#  {'Repository Name': 'ionic-framework',
#   'User Name': 'ionic-team',
#   'stars': '47.6k',
#   'Repository URL': 'https://github.com/topics/reactionic-team/ionic-framework'},
#  {'Repository Name': 'superset',
#   'User Name': 'apache',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/topics/reactapache/superset'},
#  {'Repository Name': 'hyper',
#   'User Name': 'vercel',
#   'stars': '38.8k',
#   'Repository URL': 'https://github.com/topics/reactvercel/hyper'},
#  {'Repository Name': 'styled-components',
#   'User Name': 'styled-components',
#   'stars': '36.9k',
#   'Repository URL': 'https://github.com/topics/reactstyled-components/styled-components'},
#  {'Repository Name': 'freecodecamp.cn',
#   'User Name': 'FreeCodeCampChina',
#   'stars': '36.5k',
#   'Repository URL': 'https://github.com/topics/reactFreeCodeCampChina/freecodecamp.cn'},
#  {'Repository Name': 'react',
#   'User Name': 'typescript-cheatsheets',
#   'stars': '34.7k',
#   'Repository URL': 'https://github.com/topics/reacttypescript-cheatsheets/react'},
#  {'Repository Name': 'docusaurus',
#   'User Name': 'facebook',
#   'stars': '34.6k',
#   'Repository URL': 'https://github.com/topics/reactfacebook/docusaurus'},
#  {'Repository Name': 'ant-design-pro',
#   'User Name': 'ant-design',
#   'stars': '32.4k',
#   'Repository URL': 'https://github.com/topics/reactant-design/ant-design-pro'},
#  {'Repository Name': 'esbuild',
#   'User Name': 'evanw',
#   'stars': '32.3k',
#   'Repository URL': 'https://github.com/topics/reactevanw/esbuild'},
#  {'Repository Name': 'preact',
#   'User Name': 'preactjs',
#   'stars': '32.1k',
#   'Repository URL': 'https://github.com/topics/reactpreactjs/preact'},
#  {'Repository Name': 'awesome-react-native',
#   'User Name': 'jondot',
#   'stars': '31.6k',
#   'Repository URL': 'https://github.com/topics/reactjondot/awesome-react-native'},
#  {'Repository Name': 'taro',
#   'User Name': 'NervJS',
#   'stars': '31.2k',
#   'Repository URL': 'https://github.com/topics/reactNervJS/taro'},
#  {'Repository Name': 'gold-miner',
#   'User Name': 'xitu',
#   'stars': '30.9k',
#   'Repository URL': 'https://github.com/topics/reactxitu/gold-miner'},
#  {'Repository Name': 'formik',
#   'User Name': 'jaredpalmer',
#   'stars': '30.7k',
#   'Repository URL': 'https://github.com/topics/reactjaredpalmer/formik'},
#  {'Repository Name': 'sheetjs',
#   'User Name': 'SheetJS',
#   'stars': '30.6k',
#   'Repository URL': 'https://github.com/topics/reactSheetJS/sheetjs'},
#  {'Repository Name': 'awesome-react-components',
#   'User Name': 'brillout',
#   'stars': '30.3k',
#   'Repository URL': 'https://github.com/topics/reactbrillout/awesome-react-components'},
#  {'Repository Name': 'react-hook-form',
#   'User Name': 'react-hook-form',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/topics/reactreact-hook-form/react-hook-form'},
#  {'Repository Name': 'react-boilerplate',
#   'User Name': 'react-boilerplate',
#   'stars': '28.5k',
#   'Repository URL': 'https://github.com/topics/reactreact-boilerplate/react-boilerplate'},
#  {'Repository Name': 'query',
#   'User Name': 'TanStack',
#   'stars': '28.2k',
#   'Repository URL': 'https://github.com/topics/reactTanStack/query'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                  Repository Name               User Name  stars  \
# 0                   freeCodeCamp            freeCodeCamp   348k
# 1                          react                facebook   191k
# 2               create-react-app                facebook  95.8k
# 3   free-programming-books-zh_CN               justjavac  94.1k
# 4                        next.js                  vercel  89.1k
# 5                     ant-design              ant-design  80.9k
# 6                    material-ui                     mui  79.5k
# 7                      storybook             storybookjs  72.5k
# 8                         gatsby                gatsbyjs  53.2k
# 9                 33-js-concepts             leonardomso  49.7k
# 10                 awesome-react                   enaqx    49k
# 11               ionic-framework              ionic-team  47.6k
# 12                      superset                  apache  46.9k
# 13                         hyper                  vercel  38.8k
# 14             styled-components       styled-components  36.9k
# 15               freecodecamp.cn       FreeCodeCampChina  36.5k
# 16                         react  typescript-cheatsheets  34.7k
# 17                    docusaurus                facebook  34.6k
# 18                ant-design-pro              ant-design  32.4k
# 19                       esbuild                   evanw  32.3k
# 20                        preact                preactjs  32.1k
# 21          awesome-react-native                  jondot  31.6k
# 22                          taro                  NervJS  31.2k
# 23                    gold-miner                    xitu  30.9k
# 24                        formik             jaredpalmer  30.7k
# 25                       sheetjs                 SheetJS  30.6k
# 26      awesome-react-components                brillout  30.3k
# 27               react-hook-form         react-hook-form  29.1k
# 28             react-boilerplate       react-boilerplate  28.5k
# 29                         query                TanStack  28.2k
#
#                                        Repository URL
# 0   https://github.com/topics/reactfreeCodeCamp/fr...
# 1       https://github.com/topics/reactfacebook/react
# 2   https://github.com/topics/reactfacebook/create...
# 3   https://github.com/topics/reactjustjavac/free-...
# 4       https://github.com/topics/reactvercel/next.js
# 5   https://github.com/topics/reactant-design/ant-...
# 6      https://github.com/topics/reactmui/material-ui
# 7   https://github.com/topics/reactstorybookjs/sto...
# 8      https://github.com/topics/reactgatsbyjs/gatsby
# 9   https://github.com/topics/reactleonardomso/33-...
# 10  https://github.com/topics/reactenaqx/awesome-r...
# 11  https://github.com/topics/reactionic-team/ioni...
# 12     https://github.com/topics/reactapache/superset
# 13        https://github.com/topics/reactvercel/hyper
# 14  https://github.com/topics/reactstyled-componen...
# 15  https://github.com/topics/reactFreeCodeCampChi...
# 16  https://github.com/topics/reacttypescript-chea...
# 17  https://github.com/topics/reactfacebook/docusa...
# 18  https://github.com/topics/reactant-design/ant-...
# 19       https://github.com/topics/reactevanw/esbuild
# 20     https://github.com/topics/reactpreactjs/preact
# 21  https://github.com/topics/reactjondot/awesome-...
# 22         https://github.com/topics/reactNervJS/taro
# 23     https://github.com/topics/reactxitu/gold-miner
# 24  https://github.com/topics/reactjaredpalmer/formik
# 25     https://github.com/topics/reactSheetJS/sheetjs
# 26  https://github.com/topics/reactbrillout/awesom...
# 27  https://github.com/topics/reactreact-hook-form...
# 28  https://github.com/topics/reactreact-boilerpla...
# 29      https://github.com/topics/reactTanStack/query

# %%
df.to_excel('react.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/react?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/react?page=1',
#  'https://github.com/topics/react?page=2',
#  'https://github.com/topics/react?page=3',
#  'https://github.com/topics/react?page=4',
#  'https://github.com/topics/react?page=5',
#  'https://github.com/topics/react?page=6',
#  'https://github.com/topics/react?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/react?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'freeCodeCamp',
#   'User Name': 'freeCodeCamp',
#   'stars': '348k',
#   'Repository URL': 'https://github.com/freeCodeCamp/freeCodeCamp'},
#  {'Sr No': 2,
#   'Repository Name': 'react',
#   'User Name': 'facebook',
#   'stars': '191k',
#   'Repository URL': 'https://github.com/facebook/react'},
#  {'Sr No': 3,
#   'Repository Name': 'create-react-app',
#   'User Name': 'facebook',
#   'stars': '95.8k',
#   'Repository URL': 'https://github.com/facebook/create-react-app'},
#  {'Sr No': 4,
#   'Repository Name': 'free-programming-books-zh_CN',
#   'User Name': 'justjavac',
#   'stars': '94.1k',
#   'Repository URL': 'https://github.com/justjavac/free-programming-books-zh_CN'},
#  {'Sr No': 5,
#   'Repository Name': 'next.js',
#   'User Name': 'vercel',
#   'stars': '89.1k',
#   'Repository URL': 'https://github.com/vercel/next.js'},
#  {'Sr No': 6,
#   'Repository Name': 'ant-design',
#   'User Name': 'ant-design',
#   'stars': '80.9k',
#   'Repository URL': 'https://github.com/ant-design/ant-design'},
#  {'Sr No': 7,
#   'Repository Name': 'material-ui',
#   'User Name': 'mui',
#   'stars': '79.5k',
#   'Repository URL': 'https://github.com/mui/material-ui'},
#  {'Sr No': 8,
#   'Repository Name': 'storybook',
#   'User Name': 'storybookjs',
#   'stars': '72.5k',
#   'Repository URL': 'https://github.com/storybookjs/storybook'},
#  {'Sr No': 9,
#   'Repository Name': 'gatsby',
#   'User Name': 'gatsbyjs',
#   'stars': '53.2k',
#   'Repository URL': 'https://github.com/gatsbyjs/gatsby'},
#  {'Sr No': 10,
#   'Repository Name': '33-js-concepts',
#   'User Name': 'leonardomso',
#   'stars': '49.7k',
#   'Repository URL': 'https://github.com/leonardomso/33-js-concepts'},
#  {'Sr No': 11,
#   'Repository Name': 'awesome-react',
#   'User Name': 'enaqx',
#   'stars': '49k',
#   'Repository URL': 'https://github.com/enaqx/awesome-react'},
#  {'Sr No': 12,
#   'Repository Name': 'ionic-framework',
#   'User Name': 'ionic-team',
#   'stars': '47.6k',
#   'Repository URL': 'https://github.com/ionic-team/ionic-framework'},
#  {'Sr No': 13,
#   'Repository Name': 'superset',
#   'User Name': 'apache',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/apache/superset'},
#  {'Sr No': 14,
#   'Repository Name': 'hyper',
#   'User Name': 'vercel',
#   'stars': '38.8k',
#   'Repository URL': 'https://github.com/vercel/hyper'},
#  {'Sr No': 15,
#   'Repository Name': 'styled-components',
#   'User Name': 'styled-components',
#   'stars': '36.9k',
#   'Repository URL': 'https://github.com/styled-components/styled-components'},
#  {'Sr No': 16,
#   'Repository Name': 'freecodecamp.cn',
#   'User Name': 'FreeCodeCampChina',
#   'stars': '36.5k',
#   'Repository URL': 'https://github.com/FreeCodeCampChina/freecodecamp.cn'},
#  {'Sr No': 17,
#   'Repository Name': 'react',
#   'User Name': 'typescript-cheatsheets',
#   'stars': '34.7k',
#   'Repository URL': 'https://github.com/typescript-cheatsheets/react'},
#  {'Sr No': 18,
#   'Repository Name': 'docusaurus',
#   'User Name': 'facebook',
#   'stars': '34.6k',
#   'Repository URL': 'https://github.com/facebook/docusaurus'},
#  {'Sr No': 19,
#   'Repository Name': 'ant-design-pro',
#   'User Name': 'ant-design',
#   'stars': '32.4k',
#   'Repository URL': 'https://github.com/ant-design/ant-design-pro'},
#  {'Sr No': 20,
#   'Repository Name': 'esbuild',
#   'User Name': 'evanw',
#   'stars': '32.3k',
#   'Repository URL': 'https://github.com/evanw/esbuild'},
#  {'Sr No': 21,
#   'Repository Name': 'preact',
#   'User Name': 'preactjs',
#   'stars': '32.1k',
#   'Repository URL': 'https://github.com/preactjs/preact'},
#  {'Sr No': 22,
#   'Repository Name': 'awesome-react-native',
#   'User Name': 'jondot',
#   'stars': '31.6k',
#   'Repository URL': 'https://github.com/jondot/awesome-react-native'},
#  {'Sr No': 23,
#   'Repository Name': 'taro',
#   'User Name': 'NervJS',
#   'stars': '31.2k',
#   'Repository URL': 'https://github.com/NervJS/taro'},
#  {'Sr No': 24,
#   'Repository Name': 'gold-miner',
#   'User Name': 'xitu',
#   'stars': '30.9k',
#   'Repository URL': 'https://github.com/xitu/gold-miner'},
#  {'Sr No': 25,
#   'Repository Name': 'formik',
#   'User Name': 'jaredpalmer',
#   'stars': '30.7k',
#   'Repository URL': 'https://github.com/jaredpalmer/formik'},
#  {'Sr No': 26,
#   'Repository Name': 'sheetjs',
#   'User Name': 'SheetJS',
#   'stars': '30.6k',
#   'Repository URL': 'https://github.com/SheetJS/sheetjs'},
#  {'Sr No': 27,
#   'Repository Name': 'awesome-react-components',
#   'User Name': 'brillout',
#   'stars': '30.3k',
#   'Repository URL': 'https://github.com/brillout/awesome-react-components'},
#  {'Sr No': 28,
#   'Repository Name': 'react-hook-form',
#   'User Name': 'react-hook-form',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/react-hook-form/react-hook-form'},
#  {'Sr No': 29,
#   'Repository Name': 'react-boilerplate',
#   'User Name': 'react-boilerplate',
#   'stars': '28.5k',
#   'Repository URL': 'https://github.com/react-boilerplate/react-boilerplate'},
#  {'Sr No': 30,
#   'Repository Name': 'query',
#   'User Name': 'TanStack',
#   'stars': '28.2k',
#   'Repository URL': 'https://github.com/TanStack/query'},
#  {'Sr No': 31,
#   'Repository Name': 'chakra-ui',
#   'User Name': 'chakra-ui',
#   'stars': '27.4k',
#   'Repository URL': 'https://github.com/chakra-ui/chakra-ui'},
#  {'Sr No': 32,
#   'Repository Name': 'react-beautiful-dnd',
#   'User Name': 'atlassian',
#   'stars': '27.4k',
#   'Repository URL': 'https://github.com/atlassian/react-beautiful-dnd'},
#  {'Sr No': 33,
#   'Repository Name': 'Daily-Interview-Question',
#   'User Name': 'Advanced-Frontend',
#   'stars': '25.9k',
#   'Repository URL': 'https://github.com/Advanced-Frontend/Daily-Interview-Question'},
#  {'Sr No': 34,
#   'Repository Name': 'mobx',
#   'User Name': 'mobxjs',
#   'stars': '25.4k',
#   'Repository URL': 'https://github.com/mobxjs/mobx'},
#  {'Sr No': 35,
#   'Repository Name': 'slate',
#   'User Name': 'ianstormtaylor',
#   'stars': '24.7k',
#   'Repository URL': 'https://github.com/ianstormtaylor/slate'},
#  {'Sr No': 36,
#   'Repository Name': 'nylas-mail',
#   'User Name': 'nylas',
#   'stars': '24.7k',
#   'Repository URL': 'https://github.com/nylas/nylas-mail'},
#  {'Sr No': 37,
#   'Repository Name': 'react-virtualized',
#   'User Name': 'bvaughn',
#   'stars': '23.9k',
#   'Repository URL': 'https://github.com/bvaughn/react-virtualized'},
#  {'Sr No': 38,
#   'Repository Name': 'influxdb',
#   'User Name': 'influxdata',
#   'stars': '23.7k',
#   'Repository URL': 'https://github.com/influxdata/influxdb'},
#  {'Sr No': 39,
#   'Repository Name': 'react-spring',
#   'User Name': 'pmndrs',
#   'stars': '23.5k',
#   'Repository URL': 'https://github.com/pmndrs/react-spring'},
#  {'Sr No': 40,
#   'Repository Name': 'swr',
#   'User Name': 'vercel',
#   'stars': '23.1k',
#   'Repository URL': 'https://github.com/vercel/swr'},
#  {'Sr No': 41,
#   'Repository Name': 'docz',
#   'User Name': 'doczjs',
#   'stars': '22.8k',
#   'Repository URL': 'https://github.com/doczjs/docz'},
#  {'Sr No': 42,
#   'Repository Name': 'react-native-elements',
#   'User Name': 'react-native-elements',
#   'stars': '22.5k',
#   'Repository URL': 'https://github.com/react-native-elements/react-native-elements'},
#  {'Sr No': 43,
#   'Repository Name': 'react-redux',
#   'User Name': 'reduxjs',
#   'stars': '22.2k',
#   'Repository URL': 'https://github.com/reduxjs/react-redux'},
#  {'Sr No': 44,
#   'Repository Name': 'reactjs-interview-questions',
#   'User Name': 'sudheerj',
#   'stars': '22.1k',
#   'Repository URL': 'https://github.com/sudheerj/reactjs-interview-questions'},
#  {'Sr No': 45,
#   'Repository Name': 'react-redux-links',
#   'User Name': 'markerikson',
#   'stars': '21.6k',
#   'Repository URL': 'https://github.com/markerikson/react-redux-links'},
#  {'Sr No': 46,
#   'Repository Name': 'fe-interview',
#   'User Name': 'haizlin',
#   'stars': '21.5k',
#   'Repository URL': 'https://github.com/haizlin/fe-interview'},
#  {'Sr No': 47,
#   'Repository Name': 'NativeScript',
#   'User Name': 'NativeScript',
#   'stars': '21.4k',
#   'Repository URL': 'https://github.com/NativeScript/NativeScript'},
#  {'Sr No': 48,
#   'Repository Name': 'react-navigation',
#   'User Name': 'react-navigation',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/react-navigation/react-navigation'},
#  {'Sr No': 49,
#   'Repository Name': 'react-starter-kit',
#   'User Name': 'kriasoft',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/kriasoft/react-starter-kit'},
#  {'Sr No': 50,
#   'Repository Name': 'react-bootstrap',
#   'User Name': 'react-bootstrap',
#   'stars': '20.9k',
#   'Repository URL': 'https://github.com/react-bootstrap/react-bootstrap'},
#  {'Sr No': 51,
#   'Repository Name': 'react-native-web',
#   'User Name': 'necolas',
#   'stars': '20.1k',
#   'Repository URL': 'https://github.com/necolas/react-native-web'},
#  {'Sr No': 52,
#   'Repository Name': 'react-admin',
#   'User Name': 'marmelab',
#   'stars': '20k',
#   'Repository URL': 'https://github.com/marmelab/react-admin'},
#  {'Sr No': 53,
#   'Repository Name': 'notable',
#   'User Name': 'notable',
#   'stars': '20k',
#   'Repository URL': 'https://github.com/notable/notable'},
#  {'Sr No': 54,
#   'Repository Name': 'enzyme',
#   'User Name': 'enzymejs',
#   'stars': '19.9k',
#   'Repository URL': 'https://github.com/enzymejs/enzyme'},
#  {'Sr No': 55,
#   'Repository Name': 'electron-react-boilerplate',
#   'User Name': 'electron-react-boilerplate',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/electron-react-boilerplate/electron-react-boilerplate'},
#  {'Sr No': 56,
#   'Repository Name': 'generator-jhipster',
#   'User Name': 'jhipster',
#   'stars': '19.7k',
#   'Repository URL': 'https://github.com/jhipster/generator-jhipster'},
#  {'Sr No': 57,
#   'Repository Name': 'appsmith',
#   'User Name': 'appsmithorg',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/appsmithorg/appsmith'},
#  {'Sr No': 58,
#   'Repository Name': 'upterm',
#   'User Name': 'railsware',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/railsware/upterm'},
#  {'Sr No': 59,
#   'Repository Name': 'js-stack-from-scratch',
#   'User Name': 'verekia',
#   'stars': '19.2k',
#   'Repository URL': 'https://github.com/verekia/js-stack-from-scratch'},
#  {'Sr No': 60,
#   'Repository Name': 'blueprint',
#   'User Name': 'palantir',
#   'stars': '19.1k',
#   'Repository URL': 'https://github.com/palantir/blueprint'},
#  {'Sr No': 61,
#   'Repository Name': 'ink',
#   'User Name': 'vadimdemedes',
#   'stars': '18.7k',
#   'Repository URL': 'https://github.com/vadimdemedes/ink'},
#  {'Sr No': 62,
#   'Repository Name': 'react-three-fiber',
#   'User Name': 'pmndrs',
#   'stars': '18.6k',
#   'Repository URL': 'https://github.com/pmndrs/react-three-fiber'},
#  {'Sr No': 63,
#   'Repository Name': 'recharts',
#   'User Name': 'recharts',
#   'stars': '18.5k',
#   'Repository URL': 'https://github.com/recharts/recharts'},
#  {'Sr No': 64,
#   'Repository Name': 'table',
#   'User Name': 'TanStack',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/TanStack/table'},
#  {'Sr No': 65,
#   'Repository Name': 'javascript-testing-best-practices',
#   'User Name': 'goldbergyoni',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/goldbergyoni/javascript-testing-best-practices'},
#  {'Sr No': 66,
#   'Repository Name': 'CS-Interview-Knowledge-Map',
#   'User Name': 'InterviewMap',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/InterviewMap/CS-Interview-Knowledge-Map'},
#  {'Sr No': 67,
#   'Repository Name': 'NativeBase',
#   'User Name': 'GeekyAnts',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/GeekyAnts/NativeBase'},
#  {'Sr No': 68,
#   'Repository Name': 'react-dnd',
#   'User Name': 'react-dnd',
#   'stars': '17.8k',
#   'Repository URL': 'https://github.com/react-dnd/react-dnd'},
#  {'Sr No': 69,
#   'Repository Name': 'rxdb',
#   'User Name': 'pubkey',
#   'stars': '17.7k',
#   'Repository URL': 'https://github.com/pubkey/rxdb'},
#  {'Sr No': 70,
#   'Repository Name': 'BoostNote-Legacy',
#   'User Name': 'BoostIO',
#   'stars': '17.3k',
#   'Repository URL': 'https://github.com/BoostIO/BoostNote-Legacy'},
#  {'Sr No': 71,
#   'Repository Name': 'ice',
#   'User Name': 'alibaba',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/alibaba/ice'},
#  {'Sr No': 72,
#   'Repository Name': 'expo',
#   'User Name': 'expo',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/expo/expo'},
#  {'Sr No': 73,
#   'Repository Name': 'ant-design-vue',
#   'User Name': 'vueComponent',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/vueComponent/ant-design-vue'},
#  {'Sr No': 74,
#   'Repository Name': 'handsontable',
#   'User Name': 'handsontable',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/handsontable/handsontable'},
#  {'Sr No': 75,
#   'Repository Name': 'dash',
#   'User Name': 'plotly',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/plotly/dash'},
#  {'Sr No': 76,
#   'Repository Name': 'responsively-app',
#   'User Name': 'responsively-org',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/responsively-org/responsively-app'},
#  {'Sr No': 77,
#   'Repository Name': 'saleor',
#   'User Name': 'saleor',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/saleor/saleor'},
#  {'Sr No': 78,
#   'Repository Name': 'react-loadable',
#   'User Name': 'jamiebuilds',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/jamiebuilds/react-loadable'},
#  {'Sr No': 79,
#   'Repository Name': 'react-helmet',
#   'User Name': 'nfl',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/nfl/react-helmet'},
#  {'Sr No': 80,
#   'Repository Name': 'react-grid-layout',
#   'User Name': 'react-grid-layout',
#   'stars': '16k',
#   'Repository URL': 'https://github.com/react-grid-layout/react-grid-layout'},
#  {'Sr No': 81,
#   'Repository Name': 'outline',
#   'User Name': 'outline',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/outline/outline'},
#  {'Sr No': 82,
#   'Repository Name': 'headlessui',
#   'User Name': 'tailwindlabs',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/tailwindlabs/headlessui'},
#  {'Sr No': 83,
#   'Repository Name': 'tiptap',
#   'User Name': 'ueberdosis',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/ueberdosis/tiptap'},
#  {'Sr No': 84,
#   'Repository Name': 'netlify-cms',
#   'User Name': 'netlify',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/netlify/netlify-cms'},
#  {'Sr No': 85,
#   'Repository Name': 'inferno',
#   'User Name': 'infernojs',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/infernojs/inferno'},
#  {'Sr No': 86,
#   'Repository Name': 'visx',
#   'User Name': 'airbnb',
#   'stars': '15.4k',
#   'Repository URL': 'https://github.com/airbnb/visx'},
#  {'Sr No': 87,
#   'Repository Name': 'bit',
#   'User Name': 'teambit',
#   'stars': '15.4k',
#   'Repository URL': 'https://github.com/teambit/bit'},
#  {'Sr No': 88,
#   'Repository Name': 'lottie-react-native',
#   'User Name': 'lottie-react-native',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/lottie-react-native/lottie-react-native'},
#  {'Sr No': 89,
#   'Repository Name': 'emotion',
#   'User Name': 'emotion-js',
#   'stars': '15.1k',
#   'Repository URL': 'https://github.com/emotion-js/emotion'},
#  {'Sr No': 90,
#   'Repository Name': 'react-sketchapp',
#   'User Name': 'airbnb',
#   'stars': '14.9k',
#   'Repository URL': 'https://github.com/airbnb/react-sketchapp'},
#  {'Sr No': 91,
#   'Repository Name': 'react-native-windows',
#   'User Name': 'microsoft',
#   'stars': '14.9k',
#   'Repository URL': 'https://github.com/microsoft/react-native-windows'},
#  {'Sr No': 92,
#   'Repository Name': 'sweetalert2',
#   'User Name': 'sweetalert2',
#   'stars': '14.7k',
#   'Repository URL': 'https://github.com/sweetalert2/sweetalert2'},
#  {'Sr No': 93,
#   'Repository Name': 'front-end-guide',
#   'User Name': 'grab',
#   'stars': '14.5k',
#   'Repository URL': 'https://github.com/grab/front-end-guide'},
#  {'Sr No': 94,
#   'Repository Name': 'A-to-Z-Resources-for-Students',
#   'User Name': 'dipakkr',
#   'stars': '14.1k',
#   'Repository URL': 'https://github.com/dipakkr/A-to-Z-Resources-for-Students'},
#  {'Sr No': 95,
#   'Repository Name': 'redwood',
#   'User Name': 'redwoodjs',
#   'stars': '14.1k',
#   'Repository URL': 'https://github.com/redwoodjs/redwood'},
#  {'Sr No': 96,
#   'Repository Name': 'fluentui',
#   'User Name': 'microsoft',
#   'stars': '13.6k',
#   'Repository URL': 'https://github.com/microsoft/fluentui'},
#  {'Sr No': 97,
#   'Repository Name': 'nx',
#   'User Name': 'nrwl',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/nrwl/nx'},
#  {'Sr No': 98,
#   'Repository Name': 'mdx',
#   'User Name': 'mdx-js',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/mdx-js/mdx'},
#  {'Sr No': 99,
#   'Repository Name': 'remotion',
#   'User Name': 'remotion-dev',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/remotion-dev/remotion'},
#  {'Sr No': 100,
#   'Repository Name': 'formatjs',
#   'User Name': 'formatjs',
#   'stars': '13.2k',
#   'Repository URL': 'https://github.com/formatjs/formatjs'},
#  {'Sr No': 101,
#   'Repository Name': 'Semantic-UI-React',
#   'User Name': 'Semantic-Org',
#   'stars': '12.8k',
#   'Repository URL': 'https://github.com/Semantic-Org/Semantic-UI-React'},
#  {'Sr No': 102,
#   'Repository Name': 'medusa',
#   'User Name': 'medusajs',
#   'stars': '12.7k',
#   'Repository URL': 'https://github.com/medusajs/medusa'},
#  {'Sr No': 103,
#   'Repository Name': 'umi',
#   'User Name': 'umijs',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/umijs/umi'},
#  {'Sr No': 104,
#   'Repository Name': 'redux-form',
#   'User Name': 'redux-form',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/redux-form/redux-form'},
#  {'Sr No': 105,
#   'Repository Name': 'react-content-loader',
#   'User Name': 'danilowoz',
#   'stars': '12.3k',
#   'Repository URL': 'https://github.com/danilowoz/react-content-loader'},
#  {'Sr No': 106,
#   'Repository Name': 'mantine',
#   'User Name': 'mantinedev',
#   'stars': '12.2k',
#   'Repository URL': 'https://github.com/mantinedev/mantine'},
#  {'Sr No': 107,
#   'Repository Name': 'tabler-icons',
#   'User Name': 'tabler',
#   'stars': '12.2k',
#   'Repository URL': 'https://github.com/tabler/tabler-icons'},
#  {'Sr No': 108,
#   'Repository Name': 'wp-calypso',
#   'User Name': 'Automattic',
#   'stars': '12.1k',
#   'Repository URL': 'https://github.com/Automattic/wp-calypso'},
#  {'Sr No': 109,
#   'Repository Name': 'react-redux-typescript-guide',
#   'User Name': 'piotrwitek',
#   'stars': '12k',
#   'Repository URL': 'https://github.com/piotrwitek/react-redux-typescript-guide'},
#  {'Sr No': 110,
#   'Repository Name': 'react-dates',
#   'User Name': 'react-dates',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/react-dates/react-dates'},
#  {'Sr No': 111,
#   'Repository Name': 'react-bits',
#   'User Name': 'vasanthk',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/vasanthk/react-bits'},
#  {'Sr No': 112,
#   'Repository Name': 'bulletproof-react',
#   'User Name': 'alan2207',
#   'stars': '11.8k',
#   'Repository URL': 'https://github.com/alan2207/bulletproof-react'},
#  {'Sr No': 113,
#   'Repository Name': 'evergreen',
#   'User Name': 'segmentio',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/segmentio/evergreen'},
#  {'Sr No': 114,
#   'Repository Name': 'codesandbox-client',
#   'User Name': 'codesandbox',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/codesandbox/codesandbox-client'},
#  {'Sr No': 115,
#   'Repository Name': 'react-jsonschema-form',
#   'User Name': 'rjsf-team',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/rjsf-team/react-jsonschema-form'},
#  {'Sr No': 116,
#   'Repository Name': 'blitz',
#   'User Name': 'blitz-js',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/blitz-js/blitz'},
#  {'Sr No': 117,
#   'Repository Name': 'oni',
#   'User Name': 'onivim',
#   'stars': '11.4k',
#   'Repository URL': 'https://github.com/onivim/oni'},
#  {'Sr No': 118,
#   'Repository Name': 'react-flow',
#   'User Name': 'wbkd',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/wbkd/react-flow'},
#  {'Sr No': 119,
#   'Repository Name': 'react-in-patterns',
#   'User Name': 'krasimir',
#   'stars': '11.1k',
#   'Repository URL': 'https://github.com/krasimir/react-in-patterns'},
#  {'Sr No': 120,
#   'Repository Name': 'proton-native',
#   'User Name': 'kusti8',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/kusti8/proton-native'},
#  {'Sr No': 121,
#   'Repository Name': 'react-pdf',
#   'User Name': 'diegomura',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/diegomura/react-pdf'},
#  {'Sr No': 122,
#   'Repository Name': 'razzle',
#   'User Name': 'jaredpalmer',
#   'stars': '10.8k',
#   'Repository URL': 'https://github.com/jaredpalmer/razzle'},
#  {'Sr No': 123,
#   'Repository Name': 'javascript-interview-questions',
#   'User Name': 'sudheerj',
#   'stars': '10.8k',
#   'Repository URL': 'https://github.com/sudheerj/javascript-interview-questions'},
#  {'Sr No': 124,
#   'Repository Name': 'mdx-deck',
#   'User Name': 'jxnblk',
#   'stars': '10.8k',
#   'Repository URL': 'https://github.com/jxnblk/mdx-deck'},
#  {'Sr No': 125,
#   'Repository Name': 'react-color',
#   'User Name': 'casesandberg',
#   'stars': '10.8k',
#   'Repository URL': 'https://github.com/casesandberg/react-color'},
#  {'Sr No': 126,
#   'Repository Name': 'next-auth',
#   'User Name': 'nextauthjs',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/nextauthjs/next-auth'},
#  {'Sr No': 127,
#   'Repository Name': 'github-profile-readme-generator',
#   'User Name': 'rahuldkjain',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/rahuldkjain/github-profile-readme-generator'},
#  {'Sr No': 128,
#   'Repository Name': 'downshift',
#   'User Name': 'downshift-js',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/downshift-js/downshift'},
#  {'Sr No': 129,
#   'Repository Name': 'frontend-bootcamp',
#   'User Name': 'microsoft',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/microsoft/frontend-bootcamp'},
#  {'Sr No': 130,
#   'Repository Name': 'spectrum',
#   'User Name': 'withspectrum',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/withspectrum/spectrum'},
#  {'Sr No': 131,
#   'Repository Name': 'react-slick',
#   'User Name': 'akiran',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/akiran/react-slick'},
#  {'Sr No': 132,
#   'Repository Name': 'reactide',
#   'User Name': 'reactide',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/reactide/reactide'},
#  {'Sr No': 133,
#   'Repository Name': 'react-styleguidist',
#   'User Name': 'styleguidist',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/styleguidist/react-styleguidist'},
#  {'Sr No': 134,
#   'Repository Name': 'ant-design-mobile',
#   'User Name': 'ant-design',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/ant-design/ant-design-mobile'},
#  {'Sr No': 135,
#   'Repository Name': 'reactstrap',
#   'User Name': 'reactstrap',
#   'stars': '10.3k',
#   'Repository URL': 'https://github.com/reactstrap/reactstrap'},
#  {'Sr No': 136,
#   'Repository Name': 'nivo',
#   'User Name': 'plouc',
#   'stars': '10.3k',
#   'Repository URL': 'https://github.com/plouc/nivo'},
#  {'Sr No': 137,
#   'Repository Name': 'react-static',
#   'User Name': 'react-static',
#   'stars': '10.1k',
#   'Repository URL': 'https://github.com/react-static/react-static'},
#  {'Sr No': 138,
#   'Repository Name': 'react-native-firebase',
#   'User Name': 'invertase',
#   'stars': '10.1k',
#   'Repository URL': 'https://github.com/invertase/react-native-firebase'},
#  {'Sr No': 139,
#   'Repository Name': 'react-sortable-hoc',
#   'User Name': 'clauderic',
#   'stars': '10.1k',
#   'Repository URL': 'https://github.com/clauderic/react-sortable-hoc'},
#  {'Sr No': 140,
#   'Repository Name': 'react-native-swiper',
#   'User Name': 'leecade',
#   'stars': '9.9k',
#   'Repository URL': 'https://github.com/leecade/react-native-swiper'},
#  {'Sr No': 141,
#   'Repository Name': 'blog',
#   'User Name': 'yygmind',
#   'stars': '9.9k',
#   'Repository URL': 'https://github.com/yygmind/blog'},
#  {'Sr No': 142,
#   'Repository Name': 'tsdx',
#   'User Name': 'jaredpalmer',
#   'stars': '9.9k',
#   'Repository URL': 'https://github.com/jaredpalmer/tsdx'},
#  {'Sr No': 143,
#   'Repository Name': 'react-slingshot',
#   'User Name': 'coryhouse',
#   'stars': '9.8k',
#   'Repository URL': 'https://github.com/coryhouse/react-slingshot'},
#  {'Sr No': 144,
#   'Repository Name': 'victory',
#   'User Name': 'FormidableLabs',
#   'stars': '9.7k',
#   'Repository URL': 'https://github.com/FormidableLabs/victory'},
#  {'Sr No': 145,
#   'Repository Name': 'hooks',
#   'User Name': 'alibaba',
#   'stars': '9.5k',
#   'Repository URL': 'https://github.com/alibaba/hooks'},
#  {'Sr No': 146,
#   'Repository Name': 'Lepton',
#   'User Name': 'hackjutsu',
#   'stars': '9.4k',
#   'Repository URL': 'https://github.com/hackjutsu/Lepton'},
#  {'Sr No': 147,
#   'Repository Name': 'ext-saladict',
#   'User Name': 'crimx',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/crimx/ext-saladict'},
#  {'Sr No': 148,
#   'Repository Name': 'spectacle',
#   'User Name': 'FormidableLabs',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/FormidableLabs/spectacle'},
#  {'Sr No': 149,
#   'Repository Name': 'react-toastify',
#   'User Name': 'fkhadra',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/fkhadra/react-toastify'},
#  {'Sr No': 150,
#   'Repository Name': 'linaria',
#   'User Name': 'callstack',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/callstack/linaria'},
#  {'Sr No': 151,
#   'Repository Name': 'boardgame.io',
#   'User Name': 'boardgameio',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/boardgameio/boardgame.io'},
#  {'Sr No': 152,
#   'Repository Name': 'dogehouse',
#   'User Name': 'benawad',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/benawad/dogehouse'},
#  {'Sr No': 153,
#   'Repository Name': 'react-native-ui-kitten',
#   'User Name': 'akveo',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/akveo/react-native-ui-kitten'},
#  {'Sr No': 154,
#   'Repository Name': 'react-app-rewired',
#   'User Name': 'timarney',
#   'stars': '9.1k',
#   'Repository URL': 'https://github.com/timarney/react-app-rewired'},
#  {'Sr No': 155,
#   'Repository Name': 'react-dropzone',
#   'User Name': 'react-dropzone',
#   'stars': '9.1k',
#   'Repository URL': 'https://github.com/react-dropzone/react-dropzone'},
#  {'Sr No': 156,
#   'Repository Name': 'jotai',
#   'User Name': 'pmndrs',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/pmndrs/jotai'},
#  {'Sr No': 157,
#   'Repository Name': 'react-markdown',
#   'User Name': 'remarkjs',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/remarkjs/react-markdown'},
#  {'Sr No': 158,
#   'Repository Name': 'antd-admin',
#   'User Name': 'zuiidea',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/zuiidea/antd-admin'},
#  {'Sr No': 159,
#   'Repository Name': 'graphql-code-generator',
#   'User Name': 'dotansimha',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/dotansimha/graphql-code-generator'},
#  {'Sr No': 160,
#   'Repository Name': 'react-page',
#   'User Name': 'react-page',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/react-page/react-page'},
#  {'Sr No': 161,
#   'Repository Name': 'ag-grid',
#   'User Name': 'ag-grid',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/ag-grid/ag-grid'},
#  {'Sr No': 162,
#   'Repository Name': 'amplify-js',
#   'User Name': 'aws-amplify',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/aws-amplify/amplify-js'},
#  {'Sr No': 163,
#   'Repository Name': 'why-did-you-render',
#   'User Name': 'welldone-software',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/welldone-software/why-did-you-render'},
#  {'Sr No': 164,
#   'Repository Name': 'svgr',
#   'User Name': 'gregberge',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/gregberge/svgr'},
#  {'Sr No': 165,
#   'Repository Name': 'react-toolbox',
#   'User Name': 'react-toolbox',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/react-toolbox/react-toolbox'},
#  {'Sr No': 166,
#   'Repository Name': 'ieaseMusic',
#   'User Name': 'trazyn',
#   'stars': '8.6k',
#   'Repository URL': 'https://github.com/trazyn/ieaseMusic'},
#  {'Sr No': 167,
#   'Repository Name': 'Winds',
#   'User Name': 'GetStream',
#   'stars': '8.6k',
#   'Repository URL': 'https://github.com/GetStream/Winds'},
#  {'Sr No': 168,
#   'Repository Name': 'OnsenUI',
#   'User Name': 'OnsenUI',
#   'stars': '8.6k',
#   'Repository URL': 'https://github.com/OnsenUI/OnsenUI'},
#  {'Sr No': 169,
#   'Repository Name': 'WatermelonDB',
#   'User Name': 'Nozbe',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/Nozbe/WatermelonDB'},
#  {'Sr No': 170,
#   'Repository Name': 'posthog',
#   'User Name': 'PostHog',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/PostHog/posthog'},
#  {'Sr No': 171,
#   'Repository Name': 'react-vis',
#   'User Name': 'uber',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/uber/react-vis'},
#  {'Sr No': 172,
#   'Repository Name': 'devhub',
#   'User Name': 'devhubapp',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/devhubapp/devhub'},
#  {'Sr No': 173,
#   'Repository Name': 'awesome-react-hooks',
#   'User Name': 'rehooks',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/rehooks/awesome-react-hooks'},
#  {'Sr No': 174,
#   'Repository Name': 'wails',
#   'User Name': 'wailsapp',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/wailsapp/wails'},
#  {'Sr No': 175,
#   'Repository Name': 'text-mask',
#   'User Name': 'text-mask',
#   'stars': '8.1k',
#   'Repository URL': 'https://github.com/text-mask/text-mask'},
#  {'Sr No': 176,
#   'Repository Name': 'client',
#   'User Name': 'keybase',
#   'stars': '8.1k',
#   'Repository URL': 'https://github.com/keybase/client'},
#  {'Sr No': 177,
#   'Repository Name': 'Vulcan',
#   'User Name': 'VulcanJS',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/VulcanJS/Vulcan'},
#  {'Sr No': 178,
#   'Repository Name': 'formily',
#   'User Name': 'alibaba',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/alibaba/formily'},
#  {'Sr No': 179,
#   'Repository Name': 'grommet',
#   'User Name': 'grommet',
#   'stars': '7.9k',
#   'Repository URL': 'https://github.com/grommet/grommet'},
#  {'Sr No': 180,
#   'Repository Name': 'rematch',
#   'User Name': 'rematch',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/rematch/rematch'},
#  {'Sr No': 181,
#   'Repository Name': 'revery',
#   'User Name': 'revery-ui',
#   'stars': '7.9k',
#   'Repository URL': 'https://github.com/revery-ui/revery'},
#  {'Sr No': 182,
#   'Repository Name': 'eslint-plugin-react',
#   'User Name': 'jsx-eslint',
#   'stars': '7.9k',
#   'Repository URL': 'https://github.com/jsx-eslint/eslint-plugin-react'},
#  {'Sr No': 183,
#   'Repository Name': 'baseweb',
#   'User Name': 'uber',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/uber/baseweb'},
#  {'Sr No': 184,
#   'Repository Name': 'dejavu',
#   'User Name': 'appbaseio',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/appbaseio/dejavu'},
#  {'Sr No': 185,
#   'Repository Name': 'unstated',
#   'User Name': 'jamiebuilds',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/jamiebuilds/unstated'},
#  {'Sr No': 186,
#   'Repository Name': 'rebass',
#   'User Name': 'rebassjs',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/rebassjs/rebass'},
#  {'Sr No': 187,
#   'Repository Name': 'reactjs.org',
#   'User Name': 'reactjs',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/reactjs/reactjs.org'},
#  {'Sr No': 188,
#   'Repository Name': 'trpc',
#   'User Name': 'trpc',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/trpc/trpc'},
#  {'Sr No': 189,
#   'Repository Name': 'tinacms',
#   'User Name': 'tinacms',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/tinacms/tinacms'},
#  {'Sr No': 190,
#   'Repository Name': 'react-cosmos',
#   'User Name': 'react-cosmos',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/react-cosmos/react-cosmos'},
#  {'Sr No': 191,
#   'Repository Name': 'server',
#   'User Name': 'gotify',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/gotify/server'},
#  {'Sr No': 192,
#   'Repository Name': 'api-platform',
#   'User Name': 'api-platform',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/api-platform/api-platform'},
#  {'Sr No': 193,
#   'Repository Name': 'react-i18next',
#   'User Name': 'i18next',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/i18next/react-i18next'},
#  {'Sr No': 194,
#   'Repository Name': 'fast',
#   'User Name': 'microsoft',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/microsoft/fast'},
#  {'Sr No': 195,
#   'Repository Name': 'scaffold-eth',
#   'User Name': 'scaffold-eth',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/scaffold-eth/scaffold-eth'},
#  {'Sr No': 196,
#   'Repository Name': 'majestic',
#   'User Name': 'Raathigesh',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/Raathigesh/majestic'},
#  {'Sr No': 197,
#   'Repository Name': 'styled-system',
#   'User Name': 'styled-system',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/styled-system/styled-system'},
#  {'Sr No': 198,
#   'Repository Name': 'react-pxq',
#   'User Name': 'bailicangdu',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/bailicangdu/react-pxq'},
#  {'Sr No': 199,
#   'Repository Name': 'Reactive-Resume',
#   'User Name': 'AmruthPillai',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/AmruthPillai/Reactive-Resume'},
#  {'Sr No': 200,
#   'Repository Name': 'styled-jsx',
#   'User Name': 'vercel',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/vercel/styled-jsx'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No               Repository Name      User Name  stars  \
# 0        1                  freeCodeCamp   freeCodeCamp   348k
# 1        2                         react       facebook   191k
# 2        3              create-react-app       facebook  95.8k
# 3        4  free-programming-books-zh_CN      justjavac  94.1k
# 4        5                       next.js         vercel  89.1k
# ..     ...                           ...            ...    ...
# 195    196                      majestic     Raathigesh   7.3k
# 196    197                 styled-system  styled-system   7.4k
# 197    198                     react-pxq    bailicangdu   7.3k
# 198    199               Reactive-Resume   AmruthPillai   7.3k
# 199    200                    styled-jsx         vercel   7.1k
#
#                                         Repository URL
# 0         https://github.com/freeCodeCamp/freeCodeCamp
# 1                    https://github.com/facebook/react
# 2         https://github.com/facebook/create-react-app
# 3    https://github.com/justjavac/free-programming-...
# 4                    https://github.com/vercel/next.js
# ..                                                 ...
# 195             https://github.com/Raathigesh/majestic
# 196     https://github.com/styled-system/styled-system
# 197           https://github.com/bailicangdu/react-pxq
# 198    https://github.com/AmruthPillai/Reactive-Resume
# 199               https://github.com/vercel/styled-jsx
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_react.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
