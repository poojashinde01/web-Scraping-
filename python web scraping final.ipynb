# %%
import requests

# %%
url=requests.get("https://github.com/topics/python").text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-10084108b209.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" rel="stylesheet" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" rel="stylesheet" href="https://github.githubassets.com/assets/github-f815d05d371a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYw ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-92c7d381038e.css" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-10084108b209.css" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f815d05d371a.css" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-d31ea144555c.css" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYwk1Z+BnSLOwYorhPLm6jrWoV3c7Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-44mCWWd9he+TZlQdLzIEo+cbYo6tgMXkx8954MY/9DknkwxQmYGmKJrGKCgbWmcMYmBgxLX6uOEgcRoDL/5eCA==" src="https://github.githubassets.com/assets/runtime-e3898259677d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZXV4TpPmxfyBQ9eFqJaVR/Z8Rrt+f/In8yBbbMmt6pqCRMVcnlTWS7/Xy5aedmiIj1tNZXmsvW3cf/vRas/mvQ==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-74aed8-6575784e93e6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-km+JVvSjuMukaGXFPj5OuzW1lNCVhWt0dB2EAkW4NpEj6x301u0l22+XLYaKm9+hvluGH0OlM6BE4hoTjxtFoQ==" src="https://github.githubassets.com/assets/environment-926f8956f4a3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-57NPhP0wWFMwvRygugK3iI3z+Sv0WTNy8MGBcwfMPYE7SoHKEoH1B89v+ANBqnW9GGvUYzf4gLT6UrP/VmhY2g==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-e7b34f84fd30.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Es25N4GyPa8Yfp5wpahoe5b2fyPtkRMyR6mKIXyCJC0ocqQazeWvxhGZhx3StRxOfqDfHDR5SS35u/R3Wux6Cg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-12cdb93781b2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-lmiecOIgf+hakg5oKMNM7grVhEDyPoIrT39Px448JJH5PSAaK21PH0Twgyz5O5oi8+dnlLr3Jt8bBCtAcpNdRw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-c7e9ed-96689e70e220.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-FhIi1nHjAzm1txsZ2LPPUfqIASARJ44qRQ09VSY4p/NVvWz/1reBy21+3an4fDIi6QhfrHNUI4ldKz3NW5by/Q==" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_time-elements_dist_index_js-161222d671e3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-DE9GK/TS3Hf/dJfP1GMiyjvsGRnpR4A1eGH64s0Ot7Vy7Tj7/aD1d5EOMWHFWQXlXy/ZSwu5MHInG6RZN31bMA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-52e104-0c4f462bf4d2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-fcVStVRolV54DldAqKbEzSE1OB6Rd/jIIpSj/dcCRRaSc8EgN68GT9sT/Ya0gtpNTq0aAPzs9OLlhWY7l0s4eA==" src="https://github.githubassets.com/assets/github-elements-7dc552b55468.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-n0EqohMRhyf2gYDkWAvqYJsBzb8qCciNwqGUpwOEjVfSLESviOFqm7IrHsihpfLAm+ZhteYJkQ+PPwqjJTUTrQ==" src="https://github.githubassets.com/assets/element-registry-9f412aa21311.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ULHDrjH3Nz+5xGQnGJ+51ZBv5qENKe3TikjwAxKli4TyT+8KZ5mnWUJxUdXaFwRVMGRJD+8CjfCVhj7913OiOA==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-50b1c3ae31f7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-XubU6uMX6y2ka6JR/QVSIS8aAdXBH9Jhm1lLCNFS5Dy3xbDEdS6W4ENFx71XaEAwW3d8xzgiS4cS0J/zsnYm6w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_github_catalyst_lib_index_-bd1f73-5ee6d4eae317.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-0r1nf/rfPz54kyePp4f63bcPxkFo7wyaUZJD/SwIVDK3q0WzurAK9ydOm88tzKtPJm8xWI0Vo25NyCfecwxJ9g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-d2bd677ffadf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-b6LnssJjHkph4nI0CxyYnXJ/d7eWTCd6fDCQZkhXUwNTMcB55fwq4nPNUDdsFG3h/KS3VEsMjhkqC8jBcQVazA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-f71f15-6fa2e7b2c263.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-aD+lpuc5jHemEy0Cf2KYz46MdwOIlj3+2cZ59XIi+mentNdewI1LzaDqroNLJzONIiL4IeUUZ7hJzhPYV4DQVA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_pjax_ts-683fa5a6e739.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-i6G+/7pwOhMb9q+i08xUSvHWO8fWX9lkXtuIJQGpHGn299Mb74hWyc5ikFQAuqgd2i/cV9c5Jw6O9Z10jDfAwg==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_be-af52ef-8ba1beffba70.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sGIJsMNVLhivulsWgcWql7t/JEs3gUQQt/9GHRjArviQLj6smy1Cei4X6Bg51OC/rZMDXeTNSL733VSNtdlynA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-019af8-b06209b0c355.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-1CN8HrSEXNbvvtNrIvzOMA1IkGwLyUOaFBl/N2UE91/8EvcqBFxy3M83mJVi/n50Kdq4oIRIeZG5D5oTpFTBDg==" src="https://github.githubassets.com/assets/behaviors-d4237c1eb484.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5nWr6hoxY6oc8ngCIfUbQS8h+5n8/1XZVb9KFgP0ak4NzsfM7ERe6b5639AYjyAbYZGs6I/7hC3eieSbWkHx9w==" src="https://github.githubassets.com/assets/notifications-global-e675abea1a31.js" type="application/javascript"></script>
# <title>python · GitHub Topics · GitHub</title>
# <meta content="D395:79B8:1F8C75:246ADE:62C419CF" data-pjax-transient="true" name="request-id"/><meta content="14c1b4fff423968bd84ca0741d4c5f36c4689cb6439a08accc6fea743db4c1ae" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJEMzk1Ojc5Qjg6MUY4Qzc1OjI0NkFERTo2MkM0MTlDRiIsInZpc2l0b3JfaWQiOiIyMTUzODIzMTMzMDU1MDY0NTI3IiwicmVnaW9uX2VkZ2UiOiJhcC1zb3V0aC0xIiwicmVnaW9uX3JlbmRlciI6ImFwLXNvdXRoLTEifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="57cda79351dd8e3f84d63e5cc876c23f066f8b40f0b7b79d8e216e1ba2685e15" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/python"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="026ed2dea13926ab803bbd118a7b0de1391e5e5f76c1a76806f440cf783ada4b" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fpython&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/python;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/python;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/python;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/python;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/python;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/python;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/python;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/python;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/python;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/python;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/python;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/python;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/python;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/python;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/python;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/python;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/python;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/python;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/python;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/python;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/python;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/python;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/python;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/python;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/python;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/python;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/python;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/python;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/python;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/python;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/python;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/python" aria-label="Site" class="js-site-search-form" data-scope-id="84" data-scope-type="Topic" data-scoped-search-url="/topics/python" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="lyXLW5UuXLvnYuh7ifoOu6f0gAloKfHkd76SaZrnwlpqR8t9XUOImHTyUTGFdjWYLidiAIUWEsgSBMXm/je6Sg=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </label>
# </form> </div>
# ...
#               font-awesome
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":39446,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="012f8a0c945b3f59e511fc45fb91352bfda57f8117fcd2a190e6b134e05e3c99" data-view-component="true" href="/topics/icon-font" title="Topic: icon-font">
#               icon-font
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":43946,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="93ed611a045beab6144fdc40e2becb8462d0dbe80abac6253870fffa74752ce2" data-view-component="true" href="/topics/powerline" title="Topic: powerline">
#               powerline
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":99376,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="9d4c5976ebdf236706335c488dd3deffd315632251fa25d164ed73ebe33afc55" data-view-component="true" href="/topics/statusline" title="Topic: statusline">
#               statusline
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":163690,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="d1f7dd027f9816635357a2e1e873c784d26f1585626113521ca80b0ea7dcb480" data-view-component="true" href="/topics/iconic-fonts" title="Topic: iconic-fonts">
#               iconic-fonts
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":249218,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="a84d73eb3a4f4b2150f2414549ad193099fdcb630229a71834ca6e7c9b49df3b" data-view-component="true" href="/topics/patched-fonts" title="Topic: patched-fonts">
#               patched-fonts
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-06-29T05:23:31Z">Jun 29, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #563d7c"></span>
# <span itemprop="programmingLanguage">CSS</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/python" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Guido van Rossum
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> February 20, 1991
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#         Organization
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-organization color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.5 14.25c0 .138.112.25.25.25H4v-1.25a.75.75 0 01.75-.75h2.5a.75.75 0 01.75.75v1.25h2.25a.25.25 0 00.25-.25V1.75a.25.25 0 00-.25-.25h-8.5a.25.25 0 00-.25.25v12.5zM1.75 16A1.75 1.75 0 010 14.25V1.75C0 .784.784 0 1.75 0h8.5C11.216 0 12 .784 12 1.75v12.5c0 .085-.006.168-.018.25h2.268a.25.25 0 00.25-.25V8.285a.25.25 0 00-.111-.208l-1.055-.703a.75.75 0 11.832-1.248l1.055.703c.487.325.779.871.779 1.456v5.965A1.75 1.75 0 0114.25 16h-3.5a.75.75 0 01-.197-.026c-.099.017-.2.026-.303.026h-3a.75.75 0 01-.75-.75V14h-1v1.25a.75.75 0 01-.75.75h-3zM3 3.75A.75.75 0 013.75 3h.5a.75.75 0 010 1.5h-.5A.75.75 0 013 3.75zM3.75 6a.75.75 0 000 1.5h.5a.75.75 0 000-1.5h-.5zM3 9.75A.75.75 0 013.75 9h.5a.75.75 0 010 1.5h-.5A.75.75 0 013 9.75zM7.75 9a.75.75 0 000 1.5h.5a.75.75 0 000-1.5h-.5zM7 6.75A.75.75 0 017.75 6h.5a.75.75 0 010 1.5h-.5A.75.75 0 017 6.75zM7.75 3a.75.75 0 000 1.5h.5a.75.75 0 000-1.5h-.5z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to python, location:topic page" href="https://github.com/python">
# <span class="css-truncate css-truncate-target" title="python">
#           python
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="https://www.python.org/">
# <span class="css-truncate css-truncate-target" title="www.python.org">
#           www.python.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/Python_(programming_language)">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/Python_(programming_language)">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# <h2 class="h4 mb-2">
#     Related Topics
#   </h2>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:language" data-view-component="true" href="/topics/language" title="Topic: language">
#   language
# </a>
# <a class="topic-tag topic-tag-link f6 my-1" data-ga-click="Explore, go to topic, location:star topics callout;text:ruby" data-view-component="true" href="/topics/ruby" title="Topic: ruby">
#   ruby
# </a>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
first_rep1
# Out:
# <article class="border rounded color-shadow-small color-bg-subtle my-4">
# <div class="px-3">
# <div class="d-flex flex-justify-between my-3">
# <div class="d-flex flex-auto">
# <span style="margin-top:2px">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# </span>
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":5458997,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="9273a1a3ddd3f93147d8ef5b9246e3ac17f20b7247582ab87ac4c3a6d5d18668" data-turbo="false" data-view-component="true" href="/donnemartin">
#             donnemartin
# </a>          /
#           <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":83222441,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="b08602d062bd3f5d2ddc9e9c7b66e2bc94c2c0db4809d17a32eae4aba4549149" data-turbo="false" data-view-component="true" href="/donnemartin/system-design-primer">
#             system-design-primer
# </a> </h3>
# </div>
# <div class="d-flex flex-items-center ml-3">
# <div class="BtnGroup d-flex" data-view-component="true">
# <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":83222441,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="a0ebf3b15a2eeab08cb35960d1252438f68d8c963efd1b7eacf5c0be92cc3a61" data-view-component="true" href="/login?return_to=%2Fdonnemartin%2Fsystem-design-primer" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
# </svg><span class="d-inline" data-view-component="true">
#           Star
# </span> <span aria-label="186616 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="186,616">187k</span>
# </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
# </svg>
# </button></div>
# </div>
# </div>
# </div>
# <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
# <ul class="tabnav-tabs" data-view-component="true">
# <li class="d-inline-flex" data-view-component="true">
# <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":83222441,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="54d0829c485bb5b5bbc0e5a31fa446c42137fc25de455d200cc00b8db99acbfa" data-turbo="false" data-view-component="true" href="/donnemartin/system-design-primer" id="code-tab-83222441">
# <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
# </svg> Code
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":83222441,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="e6e9ef609faba228c6a0923733999e6c182d974272fd7fe6433da0af6efd05ea" data-turbo="false" data-view-component="true" href="/donnemartin/system-design-primer/issues" id="issues-tab-83222441">
# <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
# </a></li>
# <li class="d-inline-flex" data-view-component="true">
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":83222441,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="235c2035adf6ca7be4c334c8548247678238757cac9d444e13f0777a1e493f86" data-turbo="false" data-view-component="true" href="/donnemartin/system-design-primer/pulls" id="pull-requests-tab-83222441">
# <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
# </svg> Pull requests
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <div class="px-3 pt-3">
# <p class="color-fg-muted mb-0"></p><div>Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.</div>
# </div>
# <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
# <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":84,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="ca5dff6d799df8c0957c92446180d3b21ca7b41c65fd5182471e5f51ba8ca8a9" data-view-component="true" href="/topics/python" title="Topic: python">
#               python
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":849,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="d7641ad8054d6730e4358ace29a78869beefcef6f3200691b4ca800aa6edf700" data-view-component="true" href="/topics/design" title="Topic: design">
#               design
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2179,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="c824abc14b3521487ba8a78fd7ebcf7972dc2197ce3d26f30cffdeee419bf8dc" data-view-component="true" href="/topics/development" title="Topic: development">
#               development
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":8898,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="088e4b743156a078a8198a9ca65b03b6577232480d359fcaa6de76ddb9fb14e2" data-view-component="true" href="/topics/programming" title="Topic: programming">
#               programming
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":8976,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="5836d532b28f8febc184312ddbae0d7dde83574cfbac2e393101de1bea1040bb" data-view-component="true" href="/topics/web" title="Topic: web">
#               web
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9240,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="72a1c253c1c873a17d49703043c6e2798d395de43a09a7941157e8519a8d57d1" data-view-component="true" href="/topics/system" title="Topic: system">
#               system
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22034,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="8efbb8eed3a1b6f9e7b9c0ee888972979ea7c840b353d1b36e1d6a4d15891253" data-view-component="true" href="/topics/design-patterns" title="Topic: design-patterns">
#               design-patterns
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22469,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="8cdc81d1c450b24fcde8564af6ed96bf1eea3efbd4b1e9670174b4ddda673ad5" data-view-component="true" href="/topics/interview" title="Topic: interview">
#               interview
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":23514,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="ed100d7f00d2bd6d804358b503908d399b289940e6376d7c83bf8ae3729ef2a0" data-view-component="true" href="/topics/web-application" title="Topic: web-application">
#               web-application
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":39330,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="f326b9ef5769b5c5fa0c9ad467b20859edc0ccef543ece82734ecc78b3688ff2" data-view-component="true" href="/topics/webapp" title="Topic: webapp">
#               webapp
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":83319,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="ec3a32836c3d094c1202ac9061314c1e30a76560e2b12e7bf53dc7ab4a83fa92" data-view-component="true" href="/topics/interview-practice" title="Topic: interview-practice">
#               interview-practice
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":94583,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="9fd463eeb24da78f8ddad26587e39f717118a720e5969fad219652d8f40bff18" data-view-component="true" href="/topics/interview-questions" title="Topic: interview-questions">
#               interview-questions
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":387026,"originating_url":"https://github.com/topics/python","user_id":null}}' data-hydro-click-hmac="4e204d0d9b7032a25bcfa2d1962da1b21613698526ff02b29e200be4b887ec7a" data-view-component="true" href="/topics/design-system" title="Topic: design-system">
#               design-system
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-06-28T19:13:20Z">Jun 28, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #3572A5"></span>
# <span itemprop="programmingLanguage">Python</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text

# %%
Repository_name.strip()
# Out:
# 'system-design-primer'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name.strip()
# Out:
# 'donnemartin'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text

# %%
stars
# Out:
# '187k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/donnemartin/system-design-primer'

# %%
base_url='https://github.com/topics/python'

# %%
base_url
# Out:
# 'https://github.com/topics/python'

# %%
Repository_url=base_url+url_link

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
base_url='https://github.com/'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
print(Repository_1_lst)
# Out:
# [{'Repository Name': 'system-design-primer', 'User Name': 'donnemartin', 'stars': '187k', 'Repository URL': 'https://github.com/donnemartin/system-design-primer'}, {'Repository Name': 'tensorflow', 'User Name': 'tensorflow', 'stars': '166k', 'Repository URL': 'https://github.com/tensorflow/tensorflow'}, {'Repository Name': 'CS-Notes', 'User Name': 'CyC2018', 'stars': '154k', 'Repository URL': 'https://github.com/CyC2018/CS-Notes'}, {'Repository Name': 'Python', 'User Name': 'TheAlgorithms', 'stars': '140k', 'Repository URL': 'https://github.com/TheAlgorithms/Python'}, {'Repository Name': 'awesome-python', 'User Name': 'vinta', 'stars': '132k', 'Repository URL': 'https://github.com/vinta/awesome-python'}, {'Repository Name': 'free-programming-books-zh_CN', 'User Name': 'justjavac', 'stars': '94.1k', 'Repository URL': 'https://github.com/justjavac/free-programming-books-zh_CN'}, {'Repository Name': 'thefuck', 'User Name': 'nvbn', 'stars': '71.9k', 'Repository URL': 'https://github.com/nvbn/thefuck'}, {'Repository Name': 'project-based-learning', 'User Name': 'practical-tutorials', 'stars': '71.2k', 'Repository URL': 'https://github.com/practical-tutorials/project-based-learning'}, {'Repository Name': 'transformers', 'User Name': 'huggingface', 'stars': '66.4k', 'Repository URL': 'https://github.com/huggingface/transformers'}, {'Repository Name': 'django', 'User Name': 'django', 'stars': '65k', 'Repository URL': 'https://github.com/django/django'}, {'Repository Name': 'flask', 'User Name': 'pallets', 'stars': '59.7k', 'Repository URL': 'https://github.com/pallets/flask'}, {'Repository Name': 'pytorch', 'User Name': 'pytorch', 'stars': '57.1k', 'Repository URL': 'https://github.com/pytorch/pytorch'}, {'Repository Name': 'HelloGitHub', 'User Name': '521xueweihan', 'stars': '57k', 'Repository URL': 'https://github.com/521xueweihan/HelloGitHub'}, {'Repository Name': 'keras', 'User Name': 'keras-team', 'stars': '55.6k', 'Repository URL': 'https://github.com/keras-team/keras'}, {'Repository Name': 'core', 'User Name': 'home-assistant', 'stars': '53.7k', 'Repository URL': 'https://github.com/home-assistant/core'}, {'Repository Name': 'ansible', 'User Name': 'ansible', 'stars': '53.7k', 'Repository URL': 'https://github.com/ansible/ansible'}, {'Repository Name': 'scikit-learn', 'User Name': 'scikit-learn', 'stars': '50.6k', 'Repository URL': 'https://github.com/scikit-learn/scikit-learn'}, {'Repository Name': 'leetcode', 'User Name': 'azl397985856', 'stars': '48.6k', 'Repository URL': 'https://github.com/azl397985856/leetcode'}, {'Repository Name': 'requests', 'User Name': 'psf', 'stars': '47.7k', 'Repository URL': 'https://github.com/psf/requests'}, {'Repository Name': 'superset', 'User Name': 'apache', 'stars': '46.9k', 'Repository URL': 'https://github.com/apache/superset'}, {'Repository Name': 'fastapi', 'User Name': 'tiangolo', 'stars': '46.9k', 'Repository URL': 'https://github.com/tiangolo/fastapi'}, {'Repository Name': 'manim', 'User Name': '3b1b', 'stars': '45.6k', 'Repository URL': 'https://github.com/3b1b/manim'}, {'Repository Name': 'face_recognition', 'User Name': 'ageitgey', 'stars': '45.1k', 'Repository URL': 'https://github.com/ageitgey/face_recognition'}, {'Repository Name': 'scrapy', 'User Name': 'scrapy', 'stars': '43.9k', 'Repository URL': 'https://github.com/scrapy/scrapy'}, {'Repository Name': 'TensorFlow-Examples', 'User Name': 'aymericdamien', 'stars': '42k', 'Repository URL': 'https://github.com/aymericdamien/TensorFlow-Examples'}, {'Repository Name': 'localstack', 'User Name': 'localstack', 'stars': '41.9k', 'Repository URL': 'https://github.com/localstack/localstack'}, {'Repository Name': 'ML-For-Beginners', 'User Name': 'microsoft', 'stars': '38.9k', 'Repository URL': 'https://github.com/microsoft/ML-For-Beginners'}, {'Repository Name': 'rich', 'User Name': 'Textualize', 'stars': '38.3k', 'Repository URL': 'https://github.com/Textualize/rich'}, {'Repository Name': '100-Days-Of-ML-Code', 'User Name': 'Avik-Jain ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                  Repository Name            User Name  stars  \
# 0           system-design-primer          donnemartin   187k
# 1                     tensorflow           tensorflow   166k
# 2                       CS-Notes              CyC2018   154k
# 3                         Python        TheAlgorithms   140k
# 4                 awesome-python                vinta   132k
# 5   free-programming-books-zh_CN            justjavac  94.1k
# 6                        thefuck                 nvbn  71.9k
# 7         project-based-learning  practical-tutorials  71.2k
# 8                   transformers          huggingface  66.4k
# 9                         django               django    65k
# 10                         flask              pallets  59.7k
# 11                       pytorch              pytorch  57.1k
# 12                   HelloGitHub         521xueweihan    57k
# 13                         keras           keras-team  55.6k
# 14                          core       home-assistant  53.7k
# 15                       ansible              ansible  53.7k
# 16                  scikit-learn         scikit-learn  50.6k
# 17                      leetcode         azl397985856  48.6k
# 18                      requests                  psf  47.7k
# 19                      superset               apache  46.9k
# 20                       fastapi             tiangolo  46.9k
# 21                         manim                 3b1b  45.6k
# 22              face_recognition             ageitgey  45.1k
# 23                        scrapy               scrapy  43.9k
# 24           TensorFlow-Examples        aymericdamien    42k
# 25                    localstack           localstack  41.9k
# 26              ML-For-Beginners            microsoft  38.9k
# 27                          rich           Textualize  38.3k
# 28           100-Days-Of-ML-Code            Avik-Jain  37.8k
# 29                    nerd-fonts            ryanoasis  36.5k
#
#                                        Repository URL
# 0   https://github.com/donnemartin/system-design-p...
# 1            https://github.com/tensorflow/tensorflow
# 2                 https://github.com/CyC2018/CS-Notes
# 3             https://github.com/TheAlgorithms/Python
# 4             https://github.com/vinta/awesome-python
# 5   https://github.com/justjavac/free-programming-...
# 6                     https://github.com/nvbn/thefuck
# 7   https://github.com/practical-tutorials/project...
# 8         https://github.com/huggingface/transformers
# 9                    https://github.com/django/django
# 10                   https://github.com/pallets/flask
# 11                 https://github.com/pytorch/pytorch
# 12        https://github.com/521xueweihan/HelloGitHub
# 13                https://github.com/keras-team/keras
# 14             https://github.com/home-assistant/core
# 15                 https://github.com/ansible/ansible
# 16       https://github.com/scikit-learn/scikit-learn
# 17           https://github.com/azl397985856/leetcode
# 18                    https://github.com/psf/requests
# 19                 https://github.com/apache/superset
# 20                https://github.com/tiangolo/fastapi
# 21                      https://github.com/3b1b/manim
# 22       https://github.com/ageitgey/face_recognition
# 23                   https://github.com/scrapy/scrapy
# 24  https://github.com/aymericdamien/TensorFlow-Ex...
# 25           https://github.com/localstack/localstack
# 26      https://github.com/microsoft/ML-For-Beginners
# 27                 https://github.com/Textualize/rich
# 28   https://github.com/Avik-Jain/100-Days-Of-ML-Code
# 29            https://github.com/ryanoasis/nerd-fonts

# %%
df.to_excel('webScraping.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
num=1
all_page_url='https://github.com/topics/python?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/python?page=1',
#  'https://github.com/topics/python?page=2',
#  'https://github.com/topics/python?page=3',
#  'https://github.com/topics/python?page=4',
#  'https://github.com/topics/python?page=5',
#  'https://github.com/topics/python?page=6',
#  'https://github.com/topics/python?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href']
Repository_url=base_url+url_link

# %%
final_url
# Out:
# ['https://github.com/topics/python?page=1',
#  'https://github.com/topics/python?page=2',
#  'https://github.com/topics/python?page=3',
#  'https://github.com/topics/python?page=4',
#  'https://github.com/topics/python?page=5',
#  'https://github.com/topics/python?page=6',
#  'https://github.com/topics/python?page=7']

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/python?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source = requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()
        
            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
        
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
        
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'SrNo':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
              
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'SrNo': 1,
#   'Repository Name': 'system-design-primer',
#   'User Name': 'donnemartin',
#   'stars': '187k',
#   'Repository URL': 'https://github.com/donnemartin/system-design-primer'},
#  {'SrNo': 2,
#   'Repository Name': 'tensorflow',
#   'User Name': 'tensorflow',
#   'stars': '166k',
#   'Repository URL': 'https://github.com/tensorflow/tensorflow'},
#  {'SrNo': 3,
#   'Repository Name': 'CS-Notes',
#   'User Name': 'CyC2018',
#   'stars': '154k',
#   'Repository URL': 'https://github.com/CyC2018/CS-Notes'},
#  {'SrNo': 4,
#   'Repository Name': 'Python',
#   'User Name': 'TheAlgorithms',
#   'stars': '140k',
#   'Repository URL': 'https://github.com/TheAlgorithms/Python'},
#  {'SrNo': 5,
#   'Repository Name': 'awesome-python',
#   'User Name': 'vinta',
#   'stars': '132k',
#   'Repository URL': 'https://github.com/vinta/awesome-python'},
#  {'SrNo': 6,
#   'Repository Name': 'free-programming-books-zh_CN',
#   'User Name': 'justjavac',
#   'stars': '94.1k',
#   'Repository URL': 'https://github.com/justjavac/free-programming-books-zh_CN'},
#  {'SrNo': 7,
#   'Repository Name': 'thefuck',
#   'User Name': 'nvbn',
#   'stars': '71.9k',
#   'Repository URL': 'https://github.com/nvbn/thefuck'},
#  {'SrNo': 8,
#   'Repository Name': 'project-based-learning',
#   'User Name': 'practical-tutorials',
#   'stars': '71.2k',
#   'Repository URL': 'https://github.com/practical-tutorials/project-based-learning'},
#  {'SrNo': 9,
#   'Repository Name': 'transformers',
#   'User Name': 'huggingface',
#   'stars': '66.4k',
#   'Repository URL': 'https://github.com/huggingface/transformers'},
#  {'SrNo': 10,
#   'Repository Name': 'django',
#   'User Name': 'django',
#   'stars': '65k',
#   'Repository URL': 'https://github.com/django/django'},
#  {'SrNo': 11,
#   'Repository Name': 'flask',
#   'User Name': 'pallets',
#   'stars': '59.7k',
#   'Repository URL': 'https://github.com/pallets/flask'},
#  {'SrNo': 12,
#   'Repository Name': 'pytorch',
#   'User Name': 'pytorch',
#   'stars': '57.1k',
#   'Repository URL': 'https://github.com/pytorch/pytorch'},
#  {'SrNo': 13,
#   'Repository Name': 'HelloGitHub',
#   'User Name': '521xueweihan',
#   'stars': '57k',
#   'Repository URL': 'https://github.com/521xueweihan/HelloGitHub'},
#  {'SrNo': 14,
#   'Repository Name': 'keras',
#   'User Name': 'keras-team',
#   'stars': '55.6k',
#   'Repository URL': 'https://github.com/keras-team/keras'},
#  {'SrNo': 15,
#   'Repository Name': 'core',
#   'User Name': 'home-assistant',
#   'stars': '53.7k',
#   'Repository URL': 'https://github.com/home-assistant/core'},
#  {'SrNo': 16,
#   'Repository Name': 'ansible',
#   'User Name': 'ansible',
#   'stars': '53.7k',
#   'Repository URL': 'https://github.com/ansible/ansible'},
#  {'SrNo': 17,
#   'Repository Name': 'scikit-learn',
#   'User Name': 'scikit-learn',
#   'stars': '50.6k',
#   'Repository URL': 'https://github.com/scikit-learn/scikit-learn'},
#  {'SrNo': 18,
#   'Repository Name': 'leetcode',
#   'User Name': 'azl397985856',
#   'stars': '48.6k',
#   'Repository URL': 'https://github.com/azl397985856/leetcode'},
#  {'SrNo': 19,
#   'Repository Name': 'requests',
#   'User Name': 'psf',
#   'stars': '47.7k',
#   'Repository URL': 'https://github.com/psf/requests'},
#  {'SrNo': 20,
#   'Repository Name': 'superset',
#   'User Name': 'apache',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/apache/superset'},
#  {'SrNo': 21,
#   'Repository Name': 'fastapi',
#   'User Name': 'tiangolo',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/tiangolo/fastapi'},
#  {'SrNo': 22,
#   'Repository Name': 'manim',
#   'User Name': '3b1b',
#   'stars': '45.6k',
#   'Repository URL': 'https://github.com/3b1b/manim'},
#  {'SrNo': 23,
#   'Repository Name': 'face_recognition',
#   'User Name': 'ageitgey',
#   'stars': '45.1k',
#   'Repository URL': 'https://github.com/ageitgey/face_recognition'},
#  {'SrNo': 24,
#   'Repository Name': 'scrapy',
#   'User Name': 'scrapy',
#   'stars': '43.9k',
#   'Repository URL': 'https://github.com/scrapy/scrapy'},
#  {'SrNo': 25,
#   'Repository Name': 'TensorFlow-Examples',
#   'User Name': 'aymericdamien',
#   'stars': '42k',
#   'Repository URL': 'https://github.com/aymericdamien/TensorFlow-Examples'},
#  {'SrNo': 26,
#   'Repository Name': 'localstack',
#   'User Name': 'localstack',
#   'stars': '41.9k',
#   'Repository URL': 'https://github.com/localstack/localstack'},
#  {'SrNo': 27,
#   'Repository Name': 'ML-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '38.9k',
#   'Repository URL': 'https://github.com/microsoft/ML-For-Beginners'},
#  {'SrNo': 28,
#   'Repository Name': 'rich',
#   'User Name': 'Textualize',
#   'stars': '38.3k',
#   'Repository URL': 'https://github.com/Textualize/rich'},
#  {'SrNo': 29,
#   'Repository Name': '100-Days-Of-ML-Code',
#   'User Name': 'Avik-Jain',
#   'stars': '37.8k',
#   'Repository URL': 'https://github.com/Avik-Jain/100-Days-Of-ML-Code'},
#  {'SrNo': 30,
#   'Repository Name': 'nerd-fonts',
#   'User Name': 'ryanoasis',
#   'stars': '36.5k',
#   'Repository URL': 'https://github.com/ryanoasis/nerd-fonts'},
#  {'SrNo': 31,
#   'Repository Name': 'Real-Time-Voice-Cloning',
#   'User Name': 'CorentinJ',
#   'stars': '35.5k',
#   'Repository URL': 'https://github.com/CorentinJ/Real-Time-Voice-Cloning'},
#  {'SrNo': 32,
#   'Repository Name': 'PythonDataScienceHandbook',
#   'User Name': 'jakevdp',
#   'stars': '35.1k',
#   'Repository URL': 'https://github.com/jakevdp/PythonDataScienceHandbook'},
#  {'SrNo': 33,
#   'Repository Name': 'pandas',
#   'User Name': 'pandas-dev',
#   'stars': '34.4k',
#   'Repository URL': 'https://github.com/pandas-dev/pandas'},
#  {'SrNo': 34,
#   'Repository Name': 'python-patterns',
#   'User Name': 'faif',
#   'stars': '34.3k',
#   'Repository URL': 'https://github.com/faif/python-patterns'},
#  {'SrNo': 35,
#   'Repository Name': 'ailearning',
#   'User Name': 'apachecn',
#   'stars': '33.6k',
#   'Repository URL': 'https://github.com/apachecn/ailearning'},
#  {'SrNo': 36,
#   'Repository Name': 'd2l-zh',
#   'User Name': 'd2l-ai',
#   'stars': '33.4k',
#   'Repository URL': 'https://github.com/d2l-ai/d2l-zh'},
#  {'SrNo': 37,
#   'Repository Name': 'spark',
#   'User Name': 'apache',
#   'stars': '33.3k',
#   'Repository URL': 'https://github.com/apache/spark'},
#  {'SrNo': 38,
#   'Repository Name': 'sentry',
#   'User Name': 'getsentry',
#   'stars': '31.2k',
#   'Repository URL': 'https://github.com/getsentry/sentry'},
#  {'SrNo': 39,
#   'Repository Name': 'wtfpython',
#   'User Name': 'satwikkansal',
#   'stars': '31.2k',
#   'Repository URL': 'https://github.com/satwikkansal/wtfpython'},
#  {'SrNo': 40,
#   'Repository Name': 'open-source-mac-os-apps',
#   'User Name': 'serhii-londar',
#   'stars': '31k',
#   'Repository URL': 'https://github.com/serhii-londar/open-source-mac-os-apps'},
#  {'SrNo': 41,
#   'Repository Name': 'Made-With-ML',
#   'User Name': 'GokuMohandas',
#   'stars': '30.3k',
#   'Repository URL': 'https://github.com/GokuMohandas/Made-With-ML'},
#  {'SrNo': 42,
#   'Repository Name': 'python-cheatsheet',
#   'User Name': 'gto76',
#   'stars': '29.5k',
#   'Repository URL': 'https://github.com/gto76/python-cheatsheet'},
#  {'SrNo': 43,
#   'Repository Name': 'leetcode-master',
#   'User Name': 'youngyangyang04',
#   'stars': '29.1k',
#   'Repository URL': 'https://github.com/youngyangyang04/leetcode-master'},
#  {'SrNo': 44,
#   'Repository Name': 'certbot',
#   'User Name': 'certbot',
#   'stars': '29k',
#   'Repository URL': 'https://github.com/certbot/certbot'},
#  {'SrNo': 45,
#   'Repository Name': 'black',
#   'User Name': 'psf',
#   'stars': '28.4k',
#   'Repository URL': 'https://github.com/psf/black'},
#  {'SrNo': 46,
#   'Repository Name': 'mitmproxy',
#   'User Name': 'mitmproxy',
#   'stars': '28k',
#   'Repository URL': 'https://github.com/mitmproxy/mitmproxy'},
#  {'SrNo': 47,
#   'Repository Name': 'yt-dlp',
#   'User Name': 'yt-dlp',
#   'stars': '28k',
#   'Repository URL': 'https://github.com/yt-dlp/yt-dlp'},
#  {'SrNo': 48,
#   'Repository Name': 'pyenv',
#   'User Name': 'pyenv',
#   'stars': '27.9k',
#   'Repository URL': 'https://github.com/pyenv/pyenv'},
#  {'SrNo': 49,
#   'Repository Name': 'devops-exercises',
#   'User Name': 'bregman-arie',
#   'stars': '27.6k',
#   'Repository URL': 'https://github.com/bregman-arie/devops-exercises'},
#  {'SrNo': 50,
#   'Repository Name': 'airflow',
#   'User Name': 'apache',
#   'stars': '26.6k',
#   'Repository URL': 'https://github.com/apache/airflow'},
#  {'SrNo': 51,
#   'Repository Name': 'interactive-coding-challenges',
#   'User Name': 'donnemartin',
#   'stars': '25.7k',
#   'Repository URL': 'https://github.com/donnemartin/interactive-coding-challenges'},
#  {'SrNo': 52,
#   'Repository Name': 'odoo',
#   'User Name': 'odoo',
#   'stars': '25.6k',
#   'Repository URL': 'https://github.com/odoo/odoo'},
#  {'SrNo': 53,
#   'Repository Name': 'python-guide',
#   'User Name': 'realpython',
#   'stars': '25k',
#   'Repository URL': 'https://github.com/realpython/python-guide'},
#  {'SrNo': 54,
#   'Repository Name': 'handson-ml',
#   'User Name': 'ageron',
#   'stars': '24.6k',
#   'Repository URL': 'https://github.com/ageron/handson-ml'},
#  {'SrNo': 55,
#   'Repository Name': 'awesome-python-cn',
#   'User Name': 'jobbole',
#   'stars': '24.5k',
#   'Repository URL': 'https://github.com/jobbole/awesome-python-cn'},
#  {'SrNo': 56,
#   'Repository Name': 'selenium',
#   'User Name': 'SeleniumHQ',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/SeleniumHQ/selenium'},
#  {'SrNo': 57,
#   'Repository Name': 'sqlmap',
#   'User Name': 'sqlmapproject',
#   'stars': '23.9k',
#   'Repository URL': 'https://github.com/sqlmapproject/sqlmap'},
#  {'SrNo': 58,
#   'Repository Name': 'spaCy',
#   'User Name': 'explosion',
#   'stars': '23.7k',
#   'Repository URL': 'https://github.com/explosion/spaCy'},
#  {'SrNo': 59,
#   'Repository Name': 'django-rest-framework',
#   'User Name': 'encode',
#   'stars': '23.7k',
#   'Repository URL': 'https://github.com/encode/django-rest-framework'},
#  {'SrNo': 60,
#   'Repository Name': 'data-science-ipython-notebooks',
#   'User Name': 'donnemartin',
#   'stars': '23.3k',
#   'Repository URL': 'https://github.com/donnemartin/data-science-ipython-notebooks'},
#  {'SrNo': 61,
#   'Repository Name': 'pipenv',
#   'User Name': 'pypa',
#   'stars': '23.1k',
#   'Repository URL': 'https://github.com/pypa/pipenv'},
#  {'SrNo': 62,
#   'Repository Name': 'python-fire',
#   'User Name': 'google',
#   'stars': '22.7k',
#   'Repository URL': 'https://github.com/google/python-fire'},
#  {'SrNo': 63,
#   'Repository Name': 'fastai',
#   'User Name': 'fastai',
#   'stars': '22.5k',
#   'Repository URL': 'https://github.com/fastai/fastai'},
#  {'SrNo': 64,
#   'Repository Name': 'tqdm',
#   'User Name': 'tqdm',
#   'stars': '22.3k',
#   'Repository URL': 'https://github.com/tqdm/tqdm'},
#  {'SrNo': 65,
#   'Repository Name': 'httpie',
#   'User Name': 'httpie',
#   'stars': '22.3k',
#   'Repository URL': 'https://github.com/httpie/httpie'},
#  {'SrNo': 66,
#   'Repository Name': 'redash',
#   'User Name': 'getredash',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/getredash/redash'},
#  {'SrNo': 67,
#   'Repository Name': 'algorithms',
#   'User Name': 'keon',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/keon/algorithms'},
#  {'SrNo': 68,
#   'Repository Name': 'ray',
#   'User Name': 'ray-project',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/ray-project/ray'},
#  {'SrNo': 69,
#   'Repository Name': 'hosts',
#   'User Name': 'StevenBlack',
#   'stars': '21.1k',
#   'Repository URL': 'https://github.com/StevenBlack/hosts'},
#  {'SrNo': 70,
#   'Repository Name': 'numpy',
#   'User Name': 'numpy',
#   'stars': '20.8k',
#   'Repository URL': 'https://github.com/numpy/numpy'},
#  {'SrNo': 71,
#   'Repository Name': 'glances',
#   'User Name': 'nicolargo',
#   'stars': '20.8k',
#   'Repository URL': 'https://github.com/nicolargo/glances'},
#  {'SrNo': 72,
#   'Repository Name': 'tornado',
#   'User Name': 'tornadoweb',
#   'stars': '20.6k',
#   'Repository URL': 'https://github.com/tornadoweb/tornado'},
#  {'SrNo': 73,
#   'Repository Name': 'poetry',
#   'User Name': 'python-poetry',
#   'stars': '20.4k',
#   'Repository URL': 'https://github.com/python-poetry/poetry'},
#  {'SrNo': 74,
#   'Repository Name': 'spleeter',
#   'User Name': 'deezer',
#   'stars': '19.9k',
#   'Repository URL': 'https://github.com/deezer/spleeter'},
#  {'SrNo': 75,
#   'Repository Name': 'streamlit',
#   'User Name': 'streamlit',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/streamlit/streamlit'},
#  {'SrNo': 76,
#   'Repository Name': 'celery',
#   'User Name': 'celery',
#   'stars': '19.6k',
#   'Repository URL': 'https://github.com/celery/celery'},
#  {'SrNo': 77,
#   'Repository Name': 'homemade-machine-learning',
#   'User Name': 'trekhleb',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/trekhleb/homemade-machine-learning'},
#  {'SrNo': 78,
#   'Repository Name': 'flink',
#   'User Name': 'apache',
#   'stars': '19.3k',
#   'Repository URL': 'https://github.com/apache/flink'},
#  {'SrNo': 79,
#   'Repository Name': 'lightning',
#   'User Name': 'Lightning-AI',
#   'stars': '19.3k',
#   'Repository URL': 'https://github.com/Lightning-AI/lightning'},
#  {'SrNo': 80,
#   'Repository Name': 'locust',
#   'User Name': 'locustio',
#   'stars': '19.2k',
#   'Repository URL': 'https://github.com/locustio/locust'},
#  {'SrNo': 81,
#   'Repository Name': 'python-telegram-bot',
#   'User Name': 'python-telegram-bot',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/python-telegram-bot/python-telegram-bot'},
#  {'SrNo': 82,
#   'Repository Name': 'pytudes',
#   'User Name': 'norvig',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/norvig/pytudes'},
#  {'SrNo': 83,
#   'Repository Name': '100-Days-Of-ML-Code',
#   'User Name': 'MLEveryday',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/MLEveryday/100-Days-Of-ML-Code'},
#  {'SrNo': 84,
#   'Repository Name': 'jumpserver',
#   'User Name': 'jumpserver',
#   'stars': '18.7k',
#   'Repository URL': 'https://github.com/jumpserver/jumpserver'},
#  {'SrNo': 85,
#   'Repository Name': 'vnpy',
#   'User Name': 'vnpy',
#   'stars': '18.7k',
#   'Repository URL': 'https://github.com/vnpy/vnpy'},
#  {'SrNo': 86,
#   'Repository Name': 'Paddle',
#   'User Name': 'PaddlePaddle',
#   'stars': '18.5k',
#   'Repository URL': 'https://github.com/PaddlePaddle/Paddle'},
#  {'SrNo': 87,
#   'Repository Name': 'freqtrade',
#   'User Name': 'freqtrade',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/freqtrade/freqtrade'},
#  {'SrNo': 88,
#   'Repository Name': 'flatbuffers',
#   'User Name': 'google',
#   'stars': '18.1k',
#   'Repository URL': 'https://github.com/google/flatbuffers'},
#  {'SrNo': 89,
#   'Repository Name': 'awesome-spider',
#   'User Name': 'facert',
#   'stars': '17.6k',
#   'Repository URL': 'https://github.com/facert/awesome-spider'},
#  {'SrNo': 90,
#   'Repository Name': 'ZeroNet',
#   'User Name': 'HelloZeroNet',
#   'stars': '17.5k',
#   'Repository URL': 'https://github.com/HelloZeroNet/ZeroNet'},
#  {'SrNo': 91,
#   'Repository Name': 'cookiecutter',
#   'User Name': 'cookiecutter',
#   'stars': '17.5k',
#   'Repository URL': 'https://github.com/cookiecutter/cookiecutter'},
#  {'SrNo': 92,
#   'Repository Name': 'fairseq',
#   'User Name': 'facebookresearch',
#   'stars': '17.4k',
#   'Repository URL': 'https://github.com/facebookresearch/fairseq'},
#  {'SrNo': 93,
#   'Repository Name': 'graal',
#   'User Name': 'oracle',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/oracle/graal'},
#  {'SrNo': 94,
#   'Repository Name': 'CNTK',
#   'User Name': 'microsoft',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/microsoft/CNTK'},
#  {'SrNo': 95,
#   'Repository Name': 'dash',
#   'User Name': 'plotly',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/plotly/dash'},
#  {'SrNo': 96,
#   'Repository Name': 'bokeh',
#   'User Name': 'bokeh',
#   'stars': '16.5k',
#   'Repository URL': 'https://github.com/bokeh/bokeh'},
#  {'SrNo': 97,
#   'Repository Name': 'saleor',
#   'User Name': 'saleor',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/saleor/saleor'},
#  {'SrNo': 98,
#   'Repository Name': 'pdf',
#   'User Name': 'itdevbooks',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/itdevbooks/pdf'},
#  {'SrNo': 99,
#   'Repository Name': 'sanic',
#   'User Name': 'sanic-org',
#   'stars': '16.2k',
#   'Repository URL': 'https://github.com/sanic-org/sanic'},
#  {'SrNo': 100,
#   'Repository Name': 'TensorFlow-Course',
#   'User Name': 'instillai',
#   'stars': '16.1k',
#   'Repository URL': 'https://github.com/instillai/TensorFlow-Course'},
#  {'SrNo': 101,
#   'Repository Name': 'reddit',
#   'User Name': 'reddit-archive',
#   'stars': '16.1k',
#   'Repository URL': 'https://github.com/reddit-archive/reddit'},
#  {'SrNo': 102,
#   'Repository Name': 'zulip',
#   'User Name': 'zulip',
#   'stars': '16.1k',
#   'Repository URL': 'https://github.com/zulip/zulip'},
#  {'SrNo': 103,
#   'Repository Name': 'luigi',
#   'User Name': 'spotify',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/spotify/luigi'},
#  {'SrNo': 104,
#   'Repository Name': 'matplotlib',
#   'User Name': 'matplotlib',
#   'stars': '15.7k',
#   'Repository URL': 'https://github.com/matplotlib/matplotlib'},
#  {'SrNo': 105,
#   'Repository Name': 'GitHubDaily',
#   'User Name': 'GitHubDaily',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/GitHubDaily/GitHubDaily'},
#  {'SrNo': 106,
#   'Repository Name': 'PythonRobotics',
#   'User Name': 'AtsushiSakai',
#   'stars': '15.6k',
#   'Repository URL': 'https://github.com/AtsushiSakai/PythonRobotics'},
#  {'SrNo': 107,
#   'Repository Name': 'pyspider',
#   'User Name': 'binux',
#   'stars': '15.5k',
#   'Repository URL': 'https://github.com/binux/pyspider'},
#  {'SrNo': 108,
#   'Repository Name': 'ipython',
#   'User Name': 'ipython',
#   'stars': '15.4k',
#   'Repository URL': 'https://github.com/ipython/ipython'},
#  {'SrNo': 109,
#   'Repository Name': 'Data-Science-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '15.3k',
#   'Repository URL': 'https://github.com/microsoft/Data-Science-For-Beginners'},
#  {'SrNo': 110,
#   'Repository Name': 'zipline',
#   'User Name': 'quantopian',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/quantopian/zipline'},
#  {'SrNo': 111,
#   'Repository Name': 'fastbook',
#   'User Name': 'fastai',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/fastai/fastbook'},
#  {'SrNo': 112,
#   'Repository Name': 'EasyOCR',
#   'User Name': 'JaidedAI',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/JaidedAI/EasyOCR'},
#  {'SrNo': 113,
#   'Repository Name': 'kitty',
#   'User Name': 'kovidgoyal',
#   'stars': '15.1k',
#   'Repository URL': 'https://github.com/kovidgoyal/kitty'},
#  {'SrNo': 114,
#   'Repository Name': 'PySnooper',
#   'User Name': 'cool-RR',
#   'stars': '15.1k',
#   'Repository URL': 'https://github.com/cool-RR/PySnooper'},
#  {'SrNo': 115,
#   'Repository Name': 'python-spider',
#   'User Name': 'Jack-Cherish',
#   'stars': '15k',
#   'Repository URL': 'https://github.com/Jack-Cherish/python-spider'},
#  {'SrNo': 116,
#   'Repository Name': 'kivy',
#   'User Name': 'kivy',
#   'stars': '14.7k',
#   'Repository URL': 'https://github.com/kivy/kivy'},
#  {'SrNo': 117,
#   'Repository Name': 'micropython',
#   'User Name': 'micropython',
#   'stars': '14.7k',
#   'Repository URL': 'https://github.com/micropython/micropython'},
#  {'SrNo': 118,
#   'Repository Name': 'MMKV',
#   'User Name': 'Tencent',
#   'stars': '14.7k',
#   'Repository URL': 'https://github.com/Tencent/MMKV'},
#  {'SrNo': 119,
#   'Repository Name': 'prophet',
#   'User Name': 'facebook',
#   'stars': '14.6k',
#   'Repository URL': 'https://github.com/facebook/prophet'},
#  {'SrNo': 120,
#   'Repository Name': 'mkdocs',
#   'User Name': 'mkdocs',
#   'stars': '14.4k',
#   'Repository URL': 'https://github.com/mkdocs/mkdocs'},
#  {'SrNo': 121,
#   'Repository Name': 'faker',
#   'User Name': 'joke2k',
#   'stars': '14.4k',
#   'Repository URL': 'https://github.com/joke2k/faker'},
#  {'SrNo': 122,
#   'Repository Name': 'InstaPy',
#   'User Name': 'InstaPy',
#   'stars': '14.4k',
#   'Repository URL': 'https://github.com/InstaPy/InstaPy'},
#  {'SrNo': 123,
#   'Repository Name': 'awesome-python-login-model',
#   'User Name': 'Kr1s77',
#   'stars': '14.4k',
#   'Repository URL': 'https://github.com/Kr1s77/awesome-python-login-model'},
#  {'SrNo': 124,
#   'Repository Name': 'LightGBM',
#   'User Name': 'microsoft',
#   'stars': '14k',
#   'Repository URL': 'https://github.com/microsoft/LightGBM'},
#  {'SrNo': 125,
#   'Repository Name': 'xbmc',
#   'User Name': 'xbmc',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/xbmc/xbmc'},
#  {'SrNo': 126,
#   'Repository Name': 'wechat_jump_game',
#   'User Name': 'wangshub',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/wangshub/wechat_jump_game'},
#  {'SrNo': 127,
#   'Repository Name': 'd2l-en',
#   'User Name': 'd2l-ai',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/d2l-ai/d2l-en'},
#  {'SrNo': 128,
#   'Repository Name': 'autojump',
#   'User Name': 'wting',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/wting/autojump'},
#  {'SrNo': 129,
#   'Repository Name': 'awesome-python-applications',
#   'User Name': 'mahmoud',
#   'stars': '13.8k',
#   'Repository URL': 'https://github.com/mahmoud/awesome-python-applications'},
#  {'SrNo': 130,
#   'Repository Name': 'ArchiveBox',
#   'User Name': 'ArchiveBox',
#   'stars': '13.8k',
#   'Repository URL': 'https://github.com/ArchiveBox/ArchiveBox'},
#  {'SrNo': 131,
#   'Repository Name': 'pyscript',
#   'User Name': 'pyscript',
#   'stars': '13.6k',
#   'Repository URL': 'https://github.com/pyscript/pyscript'},
#  {'SrNo': 132,
#   'Repository Name': 'recommenders',
#   'User Name': 'microsoft',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/microsoft/recommenders'},
#  {'SrNo': 133,
#   'Repository Name': 'awesome-cs-books',
#   'User Name': 'imarvinle',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/imarvinle/awesome-cs-books'},
#  {'SrNo': 134,
#   'Repository Name': 'twint',
#   'User Name': 'twintproject',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/twintproject/twint'},
#  {'SrNo': 135,
#   'Repository Name': 'powerline',
#   'User Name': 'powerline',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/powerline/powerline'},
#  {'SrNo': 136,
#   'Repository Name': 'mypy',
#   'User Name': 'python',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/python/mypy'},
#  {'SrNo': 137,
#   'Repository Name': 'Virgilio',
#   'User Name': 'virgili0',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/virgili0/Virgilio'},
#  {'SrNo': 138,
#   'Repository Name': 'gensim',
#   'User Name': 'RaRe-Technologies',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/RaRe-Technologies/gensim'},
#  {'SrNo': 139,
#   'Repository Name': 'Awesome-pytorch-list',
#   'User Name': 'bharathgs',
#   'stars': '13.2k',
#   'Repository URL': 'https://github.com/bharathgs/Awesome-pytorch-list'},
#  {'SrNo': 140,
#   'Repository Name': 'learn-python',
#   'User Name': 'trekhleb',
#   'stars': '12.9k',
#   'Repository URL': 'https://github.com/trekhleb/learn-python'},
#  {'SrNo': 141,
#   'Repository Name': 'pulumi',
#   'User Name': 'pulumi',
#   'stars': '12.9k',
#   'Repository URL': 'https://github.com/pulumi/pulumi'},
#  {'SrNo': 142,
#   'Repository Name': 'Sourcetrail',
#   'User Name': 'CoatiSoftware',
#   'stars': '12.8k',
#   'Repository URL': 'https://github.com/CoatiSoftware/Sourcetrail'},
#  {'SrNo': 143,
#   'Repository Name': 'calibre',
#   'User Name': 'kovidgoyal',
#   'stars': '12.7k',
#   'Repository URL': 'https://github.com/kovidgoyal/calibre'},
#  {'SrNo': 144,
#   'Repository Name': 'Deep-Learning-with-TensorFlow-book',
#   'User Name': 'dragen1860',
#   'stars': '12.7k',
#   'Repository URL': 'https://github.com/dragen1860/Deep-Learning-with-TensorFlow-book'},
#  {'SrNo': 145,
#   'Repository Name': 'yapf',
#   'User Name': 'google',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/google/yapf'},
#  {'SrNo': 146,
#   'Repository Name': 'click',
#   'User Name': 'pallets',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/pallets/click'},
#  {'SrNo': 147,
#   'Repository Name': 'requests-html',
#   'User Name': 'psf',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/psf/requests-html'},
#  {'SrNo': 148,
#   'Repository Name': 'aiohttp',
#   'User Name': 'aio-libs',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/aio-libs/aiohttp'},
#  {'SrNo': 149,
#   'Repository Name': 'salt',
#   'User Name': 'saltstack',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/saltstack/salt'},
#  {'SrNo': 150,
#   'Repository Name': 'deeplearning4j',
#   'User Name': 'eclipse',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/eclipse/deeplearning4j'},
#  {'SrNo': 151,
#   'Repository Name': 'OpenBBTerminal',
#   'User Name': 'OpenBB-finance',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/OpenBB-finance/OpenBBTerminal'},
#  {'SrNo': 152,
#   'Repository Name': 'antlr4',
#   'User Name': 'antlr',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/antlr/antlr4'},
#  {'SrNo': 153,
#   'Repository Name': 'Python',
#   'User Name': 'walter201230',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/walter201230/Python'},
#  {'SrNo': 154,
#   'Repository Name': 'show-me-the-code',
#   'User Name': 'Yixiaohan',
#   'stars': '12.4k',
#   'Repository URL': 'https://github.com/Yixiaohan/show-me-the-code'},
#  {'SrNo': 155,
#   'Repository Name': 'pyecharts',
#   'User Name': 'pyecharts',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/pyecharts/pyecharts'},
#  {'SrNo': 156,
#   'Repository Name': 'ChatterBot',
#   'User Name': 'gunthercox',
#   'stars': '12.4k',
#   'Repository URL': 'https://github.com/gunthercox/ChatterBot'},
#  {'SrNo': 157,
#   'Repository Name': 'wagtail',
#   'User Name': 'wagtail',
#   'stars': '12.3k',
#   'Repository URL': 'https://github.com/wagtail/wagtail'},
#  {'SrNo': 158,
#   'Repository Name': 'loguru',
#   'User Name': 'Delgan',
#   'stars': '12.2k',
#   'Repository URL': 'https://github.com/Delgan/loguru'},
#  {'SrNo': 159,
#   'Repository Name': 'speedtest-cli',
#   'User Name': 'sivel',
#   'stars': '12k',
#   'Repository URL': 'https://github.com/sivel/speedtest-cli'},
#  {'SrNo': 160,
#   'Repository Name': 'newspaper',
#   'User Name': 'codelucas',
#   'stars': '12k',
#   'Repository URL': 'https://github.com/codelucas/newspaper'},
#  {'SrNo': 161,
#   'Repository Name': 'textual',
#   'User Name': 'Textualize',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/Textualize/textual'},
#  {'SrNo': 162,
#   'Repository Name': 'Zappa',
#   'User Name': 'Miserlou',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/Miserlou/Zappa'},
#  {'SrNo': 163,
#   'Repository Name': 'plotly.py',
#   'User Name': 'plotly',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/plotly/plotly.py'},
#  {'SrNo': 164,
#   'Repository Name': 'nni',
#   'User Name': 'microsoft',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/microsoft/nni'},
#  {'SrNo': 165,
#   'Repository Name': 'python-machine-learning-book',
#   'User Name': 'rasbt',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/rasbt/python-machine-learning-book'},
#  {'SrNo': 166,
#   'Repository Name': 'tushare',
#   'User Name': 'waditu',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/waditu/tushare'},
#  {'SrNo': 167,
#   'Repository Name': 'Mobile-Security-Framework-MobSF',
#   'User Name': 'MobSF',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/MobSF/Mobile-Security-Framework-MobSF'},
#  {'SrNo': 168,
#   'Repository Name': 'searx',
#   'User Name': 'searx',
#   'stars': '11.5k',
#   'Repository URL': 'https://github.com/searx/searx'},
#  {'SrNo': 169,
#   'Repository Name': 'erpnext',
#   'User Name': 'frappe',
#   'stars': '11.5k',
#   'Repository URL': 'https://github.com/frappe/erpnext'},
#  {'SrNo': 170,
#   'Repository Name': 'walle-web',
#   'User Name': 'meolu',
#   'stars': '11.4k',
#   'Repository URL': 'https://github.com/meolu/walle-web'},
#  {'SrNo': 171,
#   'Repository Name': 'awesome-oss-alternatives',
#   'User Name': 'RunaCapital',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/RunaCapital/awesome-oss-alternatives'},
#  {'SrNo': 172,
#   'Repository Name': 'dlib',
#   'User Name': 'davisking',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/davisking/dlib'},
#  {'SrNo': 173,
#   'Repository Name': 'examples-of-web-crawlers',
#   'User Name': 'shengqiangzhang',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/shengqiangzhang/examples-of-web-crawlers'},
#  {'SrNo': 174,
#   'Repository Name': 'pybind11',
#   'User Name': 'pybind',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/pybind/pybind11'},
#  {'SrNo': 175,
#   'Repository Name': 'awx',
#   'User Name': 'ansible',
#   'stars': '11.1k',
#   'Repository URL': 'https://github.com/ansible/awx'},
#  {'SrNo': 176,
#   'Repository Name': 'allennlp',
#   'User Name': 'allenai',
#   'stars': '11.1k',
#   'Repository URL': 'https://github.com/allenai/allennlp'},
#  {'SrNo': 177,
#   'Repository Name': 'openage',
#   'User Name': 'SFTtech',
#   'stars': '11.1k',
#   'Repository URL': 'https://github.com/SFTtech/openage'},
#  {'SrNo': 178,
#   'Repository Name': 'python-mini-projects',
#   'User Name': 'Python-World',
#   'stars': '11.1k',
#   'Repository URL': 'https://github.com/Python-World/python-mini-projects'},
#  {'SrNo': 179,
#   'Repository Name': 'beets',
#   'User Name': 'beetbox',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/beetbox/beets'},
#  {'SrNo': 180,
#   'Repository Name': 'pelican',
#   'User Name': 'getpelican',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/getpelican/pelican'},
#  {'SrNo': 181,
#   'Repository Name': 'httpbin',
#   'User Name': 'postmanlabs',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/postmanlabs/httpbin'},
#  {'SrNo': 182,
#   'Repository Name': 'networkx',
#   'User Name': 'networkx',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/networkx/networkx'},
#  {'SrNo': 183,
#   'Repository Name': 'discord.py',
#   'User Name': 'Rapptz',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/Rapptz/discord.py'},
#  {'SrNo': 184,
#   'Repository Name': 'best-of-ml-python',
#   'User Name': 'ml-tooling',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/ml-tooling/best-of-ml-python'},
#  {'SrNo': 185,
#   'Repository Name': '30-Days-Of-Python',
#   'User Name': 'Asabeneh',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/Asabeneh/30-Days-Of-Python'},
#  {'SrNo': 186,
#   'Repository Name': 'nltk',
#   'User Name': 'nltk',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/nltk/nltk'},
#  {'SrNo': 187,
#   'Repository Name': 'wifiphisher',
#   'User Name': 'wifiphisher',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/wifiphisher/wifiphisher'},
#  {'SrNo': 188,
#   'Repository Name': 'turicreate',
#   'User Name': 'apple',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/apple/turicreate'},
#  {'SrNo': 189,
#   'Repository Name': 'ds-cheatsheets',
#   'User Name': 'FavioVazquez',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/FavioVazquez/ds-cheatsheets'},
#  {'SrNo': 190,
#   'Repository Name': 'apachecn-algo-zh',
#   'User Name': 'apachecn',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/apachecn/apachecn-algo-zh'},
#  {'SrNo': 191,
#   'Repository Name': 'PRML',
#   'User Name': 'ctgk',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/ctgk/PRML'},
#  {'SrNo': 192,
#   'Repository Name': 'netbox',
#   'User Name': 'netbox-community',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/netbox-community/netbox'},
#  {'SrNo': 193,
#   'Repository Name': 'manim',
#   'User Name': 'ManimCommunity',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/ManimCommunity/manim'},
#  {'SrNo': 194,
#   'Repository Name': 'IoT-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/microsoft/IoT-For-Beginners'},
#  {'SrNo': 195,
#   'Repository Name': 'pgcli',
#   'User Name': 'dbcli',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/dbcli/pgcli'},
#  {'SrNo': 196,
#   'Repository Name': 'albumentations',
#   'User Name': 'albumentations-team',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/albumentations-team/albumentations'},
#  {'SrNo': 197,
#   'Repository Name': 'mycli',
#   'User Name': 'dbcli',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/dbcli/mycli'},
#  {'SrNo': 198,
#   'Repository Name': 'routersploit',
#   'User Name': 'threat9',
#   'stars': '10.3k',
#   'Repository URL': 'https://github.com/threat9/routersploit'},
#  {'SrNo': 199,
#   'Repository Name': 'pydantic',
#   'User Name': 'samuelcolvin',
#   'stars': '10.3k',
#   'Repository URL': 'https://github.com/samuelcolvin/pydantic'},
#  {'SrNo': 200,
#   'Repository Name': 'PySimpleGUI',
#   'User Name': 'PySimpleGUI',
#   'stars': '10.3k',
#   'Repository URL': 'https://github.com/PySimpleGUI/PySimpleGUI'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      SrNo       Repository Name            User Name  stars  \
# 0       1  system-design-primer          donnemartin   187k
# 1       2            tensorflow           tensorflow   166k
# 2       3              CS-Notes              CyC2018   154k
# 3       4                Python        TheAlgorithms   140k
# 4       5        awesome-python                vinta   132k
# ..    ...                   ...                  ...    ...
# 195   196        albumentations  albumentations-team  10.5k
# 196   197                 mycli                dbcli  10.4k
# 197   198          routersploit              threat9  10.3k
# 198   199              pydantic         samuelcolvin  10.3k
# 199   200           PySimpleGUI          PySimpleGUI  10.3k
#
#                                         Repository URL
# 0    https://github.com/donnemartin/system-design-p...
# 1             https://github.com/tensorflow/tensorflow
# 2                  https://github.com/CyC2018/CS-Notes
# 3              https://github.com/TheAlgorithms/Python
# 4              https://github.com/vinta/awesome-python
# ..                                                 ...
# 195  https://github.com/albumentations-team/albumen...
# 196                     https://github.com/dbcli/mycli
# 197            https://github.com/threat9/routersploit
# 198           https://github.com/samuelcolvin/pydantic
# 199         https://github.com/PySimpleGUI/PySimpleGUI
#
# [200 rows x 5 columns]

# %%
df.to_excel('All_Product.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
