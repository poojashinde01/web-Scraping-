# %%
import requests

# %%
url=requests.get('https://github.com/topics/machine-learning').text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-10084108b209.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" rel="stylesheet" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" rel="stylesheet" href="https://github.githubassets.com/assets/github-f815d05d371a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYw ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-92c7d381038e.css" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-10084108b209.css" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f815d05d371a.css" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-d31ea144555c.css" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYwk1Z+BnSLOwYorhPLm6jrWoV3c7Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-44mCWWd9he+TZlQdLzIEo+cbYo6tgMXkx8954MY/9DknkwxQmYGmKJrGKCgbWmcMYmBgxLX6uOEgcRoDL/5eCA==" src="https://github.githubassets.com/assets/runtime-e3898259677d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZXV4TpPmxfyBQ9eFqJaVR/Z8Rrt+f/In8yBbbMmt6pqCRMVcnlTWS7/Xy5aedmiIj1tNZXmsvW3cf/vRas/mvQ==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-74aed8-6575784e93e6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-km+JVvSjuMukaGXFPj5OuzW1lNCVhWt0dB2EAkW4NpEj6x301u0l22+XLYaKm9+hvluGH0OlM6BE4hoTjxtFoQ==" src="https://github.githubassets.com/assets/environment-926f8956f4a3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-57NPhP0wWFMwvRygugK3iI3z+Sv0WTNy8MGBcwfMPYE7SoHKEoH1B89v+ANBqnW9GGvUYzf4gLT6UrP/VmhY2g==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-e7b34f84fd30.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Es25N4GyPa8Yfp5wpahoe5b2fyPtkRMyR6mKIXyCJC0ocqQazeWvxhGZhx3StRxOfqDfHDR5SS35u/R3Wux6Cg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-12cdb93781b2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-lmiecOIgf+hakg5oKMNM7grVhEDyPoIrT39Px448JJH5PSAaK21PH0Twgyz5O5oi8+dnlLr3Jt8bBCtAcpNdRw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-c7e9ed-96689e70e220.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-FhIi1nHjAzm1txsZ2LPPUfqIASARJ44qRQ09VSY4p/NVvWz/1reBy21+3an4fDIi6QhfrHNUI4ldKz3NW5by/Q==" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_time-elements_dist_index_js-161222d671e3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-DE9GK/TS3Hf/dJfP1GMiyjvsGRnpR4A1eGH64s0Ot7Vy7Tj7/aD1d5EOMWHFWQXlXy/ZSwu5MHInG6RZN31bMA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-52e104-0c4f462bf4d2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-fcVStVRolV54DldAqKbEzSE1OB6Rd/jIIpSj/dcCRRaSc8EgN68GT9sT/Ya0gtpNTq0aAPzs9OLlhWY7l0s4eA==" src="https://github.githubassets.com/assets/github-elements-7dc552b55468.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-n0EqohMRhyf2gYDkWAvqYJsBzb8qCciNwqGUpwOEjVfSLESviOFqm7IrHsihpfLAm+ZhteYJkQ+PPwqjJTUTrQ==" src="https://github.githubassets.com/assets/element-registry-9f412aa21311.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ULHDrjH3Nz+5xGQnGJ+51ZBv5qENKe3TikjwAxKli4TyT+8KZ5mnWUJxUdXaFwRVMGRJD+8CjfCVhj7913OiOA==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-50b1c3ae31f7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-XubU6uMX6y2ka6JR/QVSIS8aAdXBH9Jhm1lLCNFS5Dy3xbDEdS6W4ENFx71XaEAwW3d8xzgiS4cS0J/zsnYm6w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_github_catalyst_lib_index_-bd1f73-5ee6d4eae317.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-0r1nf/rfPz54kyePp4f63bcPxkFo7wyaUZJD/SwIVDK3q0WzurAK9ydOm88tzKtPJm8xWI0Vo25NyCfecwxJ9g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-d2bd677ffadf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-b6LnssJjHkph4nI0CxyYnXJ/d7eWTCd6fDCQZkhXUwNTMcB55fwq4nPNUDdsFG3h/KS3VEsMjhkqC8jBcQVazA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-f71f15-6fa2e7b2c263.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-aD+lpuc5jHemEy0Cf2KYz46MdwOIlj3+2cZ59XIi+mentNdewI1LzaDqroNLJzONIiL4IeUUZ7hJzhPYV4DQVA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_pjax_ts-683fa5a6e739.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-i6G+/7pwOhMb9q+i08xUSvHWO8fWX9lkXtuIJQGpHGn299Mb74hWyc5ikFQAuqgd2i/cV9c5Jw6O9Z10jDfAwg==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_be-af52ef-8ba1beffba70.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sGIJsMNVLhivulsWgcWql7t/JEs3gUQQt/9GHRjArviQLj6smy1Cei4X6Bg51OC/rZMDXeTNSL733VSNtdlynA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-019af8-b06209b0c355.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-1CN8HrSEXNbvvtNrIvzOMA1IkGwLyUOaFBl/N2UE91/8EvcqBFxy3M83mJVi/n50Kdq4oIRIeZG5D5oTpFTBDg==" src="https://github.githubassets.com/assets/behaviors-d4237c1eb484.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5nWr6hoxY6oc8ngCIfUbQS8h+5n8/1XZVb9KFgP0ak4NzsfM7ERe6b5639AYjyAbYZGs6I/7hC3eieSbWkHx9w==" src="https://github.githubassets.com/assets/notifications-global-e675abea1a31.js" type="application/javascript"></script>
# <title>machine-learning · GitHub Topics · GitHub</title>
# <meta content="C5DE:3F5D:4EBB0C:558FE2:62C43FD7" data-pjax-transient="true" name="request-id"/><meta content="4c579284bb27ed29a26ce69f25e779a0861994f774c53b7b8026bacbed2a6639" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJDNURFOjNGNUQ6NEVCQjBDOjU1OEZFMjo2MkM0M0ZENyIsInZpc2l0b3JfaWQiOiI4OTg3MDg2NzAxOTM5OTMzMTQ0IiwicmVnaW9uX2VkZ2UiOiJhcC1zb3V0aC0xIiwicmVnaW9uX3JlbmRlciI6ImFwLXNvdXRoLTEifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="048d5b9fee3d2c4f960efbb4f9a5263b0f26771bb9a5ff9abbe22e9efff4e0e4" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/machine-learning"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="e755e218b5b5c8ea0dcf7c1afea104ce5b0e7bb40929d477942f46cf5b206533" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fmachine-learning&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/machine-learning;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/machine-learning;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/machine-learning;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/machine-learning;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/machine-learning;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/machine-learning;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/machine-learning;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/machine-learning;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/machine-learning;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/machine-learning;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/machine-learning;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/machine-learning;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/machine-learning;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/machine-learning;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/machine-learning;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/machine-learning;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/machine-learning;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/machine-learning;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/machine-learning;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/machine-learning;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/machine-learning;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/machine-learning;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/machine-learning;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/machine-learning;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/machine-learning;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/machine-learning;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/machine-learning;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/machine-learning;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/machine-learning;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/machine-learning;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/machine-learning;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/machine-learning" aria-label="Site" class="js-site-search-form" data-scope-id="2169" data-scope-type="Topic" data-scoped-search-url="/topics/machine-learning" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="gYp98NtMmFIGokD7F56jAupmrR4Phdt69a29CGaKkW2aJCgkvwUgkRmdEIN78ZzWodjcJtq8YdecjOb3A0ZNFA=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# ...
# <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":80990461,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="264b7644f4beb3f97867061e84228b9dbe8ddbe760ef5259814d7a7fdb47ce3a" data-turbo="false" data-view-component="true" href="/eriklindernoren/ML-From-Scratch/pulls" id="pull-requests-tab-80990461">
# <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
# </svg> Pull requests
#
#
# </a></li>
# </ul>
# </nav>
# <div class="color-bg-default rounded-bottom-2">
# <div class="px-3 pt-3">
# <p class="color-fg-muted mb-0"></p><div>Machine Learning From Scratch. Bare bones NumPy implementations of machine learning models and algorithms with a focus on accessibility. Aims to cover everything from linear regression to deep learning.</div>
# </div>
# <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
# <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2129,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="73d4c2c2bf343d2e4072e6fb52a7163ce910ae6e8c21f29ffdb9d8cbe0168248" data-view-component="true" href="/topics/data-science" title="Topic: data-science">
#               data-science
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2169,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="2ae010ad1be3e78b1c6ad952e345c55d08969a9561b27d50e493f46d399ebfcb" data-view-component="true" href="/topics/machine-learning" title="Topic: machine-learning">
#               machine-learning
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2289,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="d88538e2871bdda721e4ecea6c36247415c0157875a33b6faf60de34a074f034" data-view-component="true" href="/topics/data-mining" title="Topic: data-mining">
#               data-mining
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9290,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="13ac36f523baff6bf609fe5c5d46e3970e658d90f9fb40bb33e9174ee33fb38d" data-view-component="true" href="/topics/deep-learning" title="Topic: deep-learning">
#               deep-learning
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":13654,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="a3ded2896dfeb08e1fb4afb747303e8be3c2d46645c49ac0886f6ebcb1981479" data-view-component="true" href="/topics/genetic-algorithm" title="Topic: genetic-algorithm">
#               genetic-algorithm
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":21287,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="90e1d0e851064ba5a5c3ef317c0edc028f2f7cd36f02ed506872dd1485dcb22e" data-view-component="true" href="/topics/deep-reinforcement-learning" title="Topic: deep-reinforcement-learning">
#               deep-reinforcement-learning
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":381793,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="ccda03bdbf0f73629a4b66ca0c0f07946764a41e40ddc564e429c17aac0cc7de" data-view-component="true" href="/topics/machine-learning-from-scratch" title="Topic: machine-learning-from-scratch">
#               machine-learning-from-scratch
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-06-13T17:07:27Z">Jun 13, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #3572A5"></span>
# <span itemprop="programmingLanguage">Python</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/machine-learning" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <dl class="my-4">
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/Machine_learning">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/Machine_learning">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'tensorflow'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'tensorflow'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text
stars
# Out:
# '166k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/tensorflow/tensorflow'

# %%
base_url='https://github.com/topics/machine-learning'

# %%
base_url
# Out:
# 'https://github.com/topics/machine-learning'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
Repository_page
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":15658638,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="b00f41ff6d39cbe8b2ba57a2121412679410dc5657f69051b91b293a5e76cb9a" data-turbo="false" data-view-component="true" href="/tensorflow">
#              tensorflow
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":45717250,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="5162b8742768d23c1f4e26d74e6474a980744831321eb8115df7c4ffc584d901" data-turbo="false" data-view-component="true" href="/tensorflow/tensorflow">
#              tensorflow
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":45717250,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="8376bbf7b028024c8adaeab7b3b4ab91da459db6f739d84e22474c73a6ea0c04" data-view-component="true" href="/login?return_to=%2Ftensorflow%2Ftensorflow" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="166187 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="166,187">166k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":45717250,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="0613adea69fda0c76e8f519aa345f09674120d0dc2c158e1ba390396038f033d" data-turbo="false" data-view-component="true" href="/tensorflow/tensorflow" id="code-tab-45717250">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":45717250,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="5b6408a06f317eca57eb37a9fdaa6d10741275b401edc5626dc064cbfda902d0" data-turbo="false" data-view-component="true" href="/tensorflow/tensorflow/issues" id="issues-tab-45717250">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":45717250,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="ab9193139ed6fa3353f2962e97f5c8e746891471ece9cfcf2f41b4b3040fe5ec" data-turbo="false" data-view-component="true" href="/tensorflow/tensorflow/pulls" id="pull-requests-tab-45717250">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":369400171,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="a092234a1e51f927cca69dedd6f0154cd368d16c31e4b9bed90494048cdd2f9d" data-turbo="false" data-view-component="true" href="https://github.com/tensorflow/tensorflow/issues/22926">
#                  Feature Request: GPUOptions for Go binding
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                59
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="mattn" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/10111?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    mattn
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2018-10-12T05:02:11Z">Oct 12, 2018</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p>Current implementation of Go binding can not specify options.</p>
#  <p>GPUOptions struct is in internal package. And <code class="notranslate">go generate</code> doesn't work for protobuf directory. So we can't specify GPUOptions for <code class="notranslate">NewSession</code>.</p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":369400171,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="0b05ce73efd753a1a38c758e50e24ecc78c449209b92ea2629dbcc625ef418ee" href="https://github.com/tensorflow/tensorflow/issues/22926">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":299643928,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="67702f399e70ace098d717b6789b2b4623215552fbbe277309cc44e01128c94a" data-name="stat:contributions welcome" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22stat%3Acontributions+welcome%22" id="label-78b39a" style="--label-r:244;--label-g:180;--label-b:0;--label-h:44;--label-s:100;--label-l:47;">
#                      stat:contributions welcome
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-78b39a" hidden="hidden">Status - Contributions welcome</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":473173272,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="10f3e641dc98bd3557ea41626bc506e29f2c1ed68ada6fb7baf2c135b69d3b72" data-name="type:feature" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Atype%3Afeature" id="label-38cb9e" style="--label-r:21;--label-g:155;--label-b:46;--label-h:131;--label-s:76;--label-l:34;">
#                      type:feature
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-38cb9e" hidden="hidden">Feature requests</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1256103877,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="51157f423925d170c84714cd24ad1652a604812df04dc49dce80f2c3b0ed76e0" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-ac28e1" style="--label-r:196;--label-g:239;--label-b:139;--label-h:85;--label-s:75;--label-l:74;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-ac28e1" hidden="hidden">Good first issue for newcomers.</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":155220641,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="f84276ce6f4b47147534968dc81ee26375e03c5abc4ffe32fd080ee1a9262c0d" data-turbo="false" data-view-component="true" href="/huggingface/transformers" style="max-height:275px">
#  <img alt="transformers" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/155220641/a16c4880-a501-11ea-9e8f-646cf611702e"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":25720743,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="6aafea2eb40857d403ccc23ff92e4207f03d0238eff7faa9fd913e074b03c181" data-turbo="false" data-view-component="true" href="/huggingface">
#              huggingface
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":155220641,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="544e8e49f42846b10cd63c619c2b8a5ae33f6c3643372221cfa87f8e26b42398" data-turbo="false" data-view-component="true" href="/huggingface/transformers">
#              transformers
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":155220641,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="64ad407c9ddf8ad6b9d6895f082d4610e70dd3fec8c10957b1748c55405c2a58" data-view-component="true" href="/login?return_to=%2Fhuggingface%2Ftransformers" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="66418 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="66,418">66.4k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":155220641,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="9737b98827915c4adab16568b7ed969e499b3a010b6d6d0ed61b669ab64e2052" data-turbo="false" data-view-component="true" href="/huggingface/transformers" id="code-tab-155220641">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":155220641,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="511c05d647320a85675f4408c3d1cfec85693961a150b9f0e401786697c7ee25" data-turbo="false" data-view-component="true" href="/huggingface/transformers/issues" id="issues-tab-155220641">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":155220641,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="c627d098921596bad95776ea84ed07257cab6ba473f8f927c5a94ad055d4f75d" data-turbo="false" data-view-component="true" href="/huggingface/transformers/pulls" id="pull-requests-tab-155220641">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1258035475,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="b5b2af85d62762be0e8a0b02655e6e63019ac7347d9f49a3be0f878b41d38897" data-turbo="false" data-view-component="true" href="https://github.com/huggingface/transformers/issues/17525">
#                  Is the addition of the 'OPTforSequenceClassification' class scheduled?
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                6
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="penpaperkeycode" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/45441848?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    penpaperkeycode
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-06-02T11:09:33Z">Jun 2, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h3>Feature request</h3>
#  <p>Is the addition of the 'OPTforSequenceClassification' class scheduled?<br/>
#  Is someone handling it?<br/>
#  When adding these functions, I wonder if it is possible to PR one by one, or if I have to PR all classes supported by other models.</p>
#  <h3>Motivation</h3>
#  <p>Added function of OPT class, which is being actively discussed recently</p>
#  <h3>Your contribution</h3>
#  <p>I personally use the forSequenceCla</p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1258035475,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="fbaf0517b8628c17265f170ed0d3a039c3bd7be8e3ff798fb72e325cc9674e78" href="https://github.com/huggingface/transformers/issues/17525">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1990918270,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="a29363a97661527a1ab3d2b84b12a22d4b9651f7928889a607cf10c4ec9498c2" data-name="Good First Issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22Good+First+Issue%22" id="label-db692b" style="--label-r:187;--label-g:247;--label-b:148;--label-h:96;--label-s:86;--label-l:77;">
#                      Good First Issue
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1239044749,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="683d7d75e4738cfe5175455308588ac8b395999fd1c7523e24d7f66ee7cea0ce" data-turbo="false" data-view-component="true" href="https://github.com/huggingface/transformers/issues/17309">
#                      UNETR: Transformers for 3D Medical Image Segmentation
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    6
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1236622941,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="cda82fe3d2480c891c990296117c099fc77e6807866add030923483c617c7e50" data-turbo="false" data-view-component="true" href="https://github.com/huggingface/transformers/issues/17268">
#                      Swin Transformer V2
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    8
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":155220641,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="f975c21ffa32503d4e46cb460f13765fc7b62309a2c185e900a174a196b4d1f8" data-turbo="false" data-view-component="true" href="/huggingface/transformers/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":21003710,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="54f0abb130cfe0e74b4d71764f98a2204597553ecbbfeae527656c656cf4532e" data-turbo="false" data-view-component="true" href="/pytorch">
#              pytorch
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":65600975,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="f313ab187b05fa868d8b0f570c5ffca455641f39c56d65998f20f65e15bbdd39" data-turbo="false" data-view-component="true" href="/pytorch/pytorch">
#              pytorch
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":65600975,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="129731b4cf481da74fe3f4a9c9dd68b230dc75ffd81e0dcc765196e271efd9bb" data-view-component="true" href="/login?return_to=%2Fpytorch%2Fpytorch" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="57131 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="57,131">57.1k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":65600975,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="ad46f585f83451f8ccd2f8dd712e55ed95548b72296543a7e701cd697e195e6a" data-turbo="false" data-view-component="true" href="/pytorch/pytorch" id="code-tab-65600975">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":65600975,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="91d1d4ca54fbc1f63eeba1b5097d66fe54d4f62aec77382f2bbd9cf6278ac548" data-turbo="false" data-view-component="true" href="/pytorch/pytorch/issues" id="issues-tab-65600975">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":65600975,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="f589463db95b47263f7b1fdbe85e749e1ff540c44ff73394bab8d43d883c2f4c" data-turbo="false" data-view-component="true" href="/pytorch/pytorch/pulls" id="pull-requests-tab-65600975">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1269931476,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="2aeaeb1ac1c426869046e7f2aa340d0559ca90e4c6e55dfc08686df8a4ef8dd8" data-turbo="false" data-view-component="true" href="https://github.com/pytorch/pytorch/issues/79452">
#                  Use c10d broadcast_object in Zero
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                1
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="kumpera" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/5738?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    kumpera
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-06-13T20:40:30Z">Jun 13, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h3><g-emoji alias="rocket" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f680.png">🚀</g-emoji> The feature, motivation and pitch</h3>
#  <p>The current implementation of Zero Redundancy optimizer has its <a href="https://github.com/pytorch/pytorch/blob/master/torch/distributed/optim/zero_redundancy_optimizer.py#L73">own implementation</a> of object broadcasting.</p>
#  <p>We should replace it with c10d [broadcast_object_list](<a href="https://pytorch.org/docs/stable/distributed.html#torch.distributed.broadcast_object_lis" rel="nofollow">https://pytorch.org/docs/stable/distributed.html#torch.distributed.broadcast_object_lis</a></p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1269931476,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="41afc7da3e7b2e247785ee7beae8965ad2196552f7d22fe496752f87bf6b6066" href="https://github.com/pytorch/pytorch/issues/79452">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":679953883,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="dbe8a8c3be7174a156f022d17f6a32c1e525cdcdf23986ea77240e588cbee4c0" data-name="oncall: distributed" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22oncall%3A+distributed%22" id="label-aacacf" style="--label-r:247;--label-g:225;--label-b:1;--label-h:54;--label-s:99;--label-l:48;">
#                      oncall: distributed
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-aacacf" hidden="hidden">Add this issue/PR to distributed oncall triage queue</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1027606656,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="d5868fd872d71786c43574147cd2350d271f09f5512e392ac419efd9b1b59a1e" data-name="module: bootcamp" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22module%3A+bootcamp%22" id="label-49a911" style="--label-r:247;--label-g:225;--label-b:1;--label-h:54;--label-s:99;--label-l:48;">
#                      module: bootcamp
#  </a>
# ...
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    tcapelle
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-06-02T19:35:58Z">Jun 2, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <p>This is a nice first issue:</p>
#  <p>Add types/docments to the <code class="notranslate">Learner.get_preds</code> function. This function is essential to any <code class="notranslate">fastai</code> user and has almost no documentation. Add types and text to the variables as we have in many places now.</p>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1258625582,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="723168fede68188106700fe67f2fca6543b1fff5b8c79314784d1a8ed3a97999" href="https://github.com/fastai/fastai/issues/3676">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":687935847,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="7ad6a8e101577772ee856e0dca649663f6a0847177d9f27fc4b3a004df69ed54" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-24d976" style="--label-r:112;--label-g:87;--label-b:255;--label-h:248;--label-s:100;--label-l:67;">
#                      good first issue
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":7977505,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="3044f285acb4ded1a57c87607f797a9d6d8498221a4c310d78f6de1fc2770371" data-turbo="false" data-view-component="true" href="/eriklindernoren">
#              eriklindernoren
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":80990461,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="4184295d7e7539e2f0e88446c4a4324878fc37a43804e7849055109d18570781" data-turbo="false" data-view-component="true" href="/eriklindernoren/ML-From-Scratch">
#              ML-From-Scratch
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":80990461,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="75000aafe258815b18cc16a5cdb00bf049c11e39aa1b2f5460214cb9e197f8b3" data-view-component="true" href="/login?return_to=%2Feriklindernoren%2FML-From-Scratch" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="21219 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="21,219">21.2k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":80990461,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="4b25a1c9c44741d8f8ff681979d0a6fb0df5fcde34e7a2b0c384a6ffcec1328d" data-turbo="false" data-view-component="true" href="/eriklindernoren/ML-From-Scratch" id="code-tab-80990461">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":80990461,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="6eaf836ce8be5aa6acd85cbf7c64942fd7a762e0e8ccb6236de4325f85f82ba6" data-turbo="false" data-view-component="true" href="/eriklindernoren/ML-From-Scratch/issues" id="issues-tab-80990461">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":80990461,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="264b7644f4beb3f97867061e84228b9dbe8ddbe760ef5259814d7a7fdb47ce3a" data-turbo="false" data-view-component="true" href="/eriklindernoren/ML-From-Scratch/pulls" id="pull-requests-tab-80990461">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>Machine Learning From Scratch. Bare bones NumPy implementations of machine learning models and algorithms with a focus on accessibility. Aims to cover everything from linear regression to deep learning.</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2129,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="73d4c2c2bf343d2e4072e6fb52a7163ce910ae6e8c21f29ffdb9d8cbe0168248" data-view-component="true" href="/topics/data-science" title="Topic: data-science">
#                data-science
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2169,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="2ae010ad1be3e78b1c6ad952e345c55d08969a9561b27d50e493f46d399ebfcb" data-view-component="true" href="/topics/machine-learning" title="Topic: machine-learning">
#                machine-learning
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2289,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="d88538e2871bdda721e4ecea6c36247415c0157875a33b6faf60de34a074f034" data-view-component="true" href="/topics/data-mining" title="Topic: data-mining">
#                data-mining
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":9290,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="13ac36f523baff6bf609fe5c5d46e3970e658d90f9fb40bb33e9174ee33fb38d" data-view-component="true" href="/topics/deep-learning" title="Topic: deep-learning">
#                deep-learning
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":13654,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="a3ded2896dfeb08e1fb4afb747303e8be3c2d46645c49ac0886f6ebcb1981479" data-view-component="true" href="/topics/genetic-algorithm" title="Topic: genetic-algorithm">
#                genetic-algorithm
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":21287,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="90e1d0e851064ba5a5c3ef317c0edc028f2f7cd36f02ed506872dd1485dcb22e" data-view-component="true" href="/topics/deep-reinforcement-learning" title="Topic: deep-reinforcement-learning">
#                deep-reinforcement-learning
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":381793,"originating_url":"https://github.com/topics/machine-learning","user_id":null}}' data-hydro-click-hmac="ccda03bdbf0f73629a4b66ca0c0f07946764a41e40ddc564e429c17aac0cc7de" data-view-component="true" href="/topics/machine-learning-from-scratch" title="Topic: machine-learning-from-scratch">
#                machine-learning-from-scratch
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-06-13T17:07:27Z">Jun 13, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #3572A5"></span>
#  <span itemprop="programmingLanguage">Python</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
base_url='https://github.com/topics/machine-learning'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
 Repository_1_lst
# Out:
# [{'Repository Name': 'tensorflow',
#   'User Name': 'tensorflow',
#   'stars': '166k',
#   'Repository URL': 'https://github.com/topics/machine-learningtensorflow/tensorflow'},
#  {'Repository Name': 'transformers',
#   'User Name': 'huggingface',
#   'stars': '66.4k',
#   'Repository URL': 'https://github.com/topics/machine-learninghuggingface/transformers'},
#  {'Repository Name': 'pytorch',
#   'User Name': 'pytorch',
#   'stars': '57.1k',
#   'Repository URL': 'https://github.com/topics/machine-learningpytorch/pytorch'},
#  {'Repository Name': 'keras',
#   'User Name': 'keras-team',
#   'stars': '55.6k',
#   'Repository URL': 'https://github.com/topics/machine-learningkeras-team/keras'},
#  {'Repository Name': 'scikit-learn',
#   'User Name': 'scikit-learn',
#   'stars': '50.6k',
#   'Repository URL': 'https://github.com/topics/machine-learningscikit-learn/scikit-learn'},
#  {'Repository Name': 'tesseract',
#   'User Name': 'tesseract-ocr',
#   'stars': '45.8k',
#   'Repository URL': 'https://github.com/topics/machine-learningtesseract-ocr/tesseract'},
#  {'Repository Name': 'face_recognition',
#   'User Name': 'ageitgey',
#   'stars': '45.1k',
#   'Repository URL': 'https://github.com/topics/machine-learningageitgey/face_recognition'},
#  {'Repository Name': 'TensorFlow-Examples',
#   'User Name': 'aymericdamien',
#   'stars': '42k',
#   'Repository URL': 'https://github.com/topics/machine-learningaymericdamien/TensorFlow-Examples'},
#  {'Repository Name': 'faceswap',
#   'User Name': 'deepfakes',
#   'stars': '41.6k',
#   'Repository URL': 'https://github.com/topics/machine-learningdeepfakes/faceswap'},
#  {'Repository Name': 'julia',
#   'User Name': 'JuliaLang',
#   'stars': '39.8k',
#   'Repository URL': 'https://github.com/topics/machine-learningJuliaLang/julia'},
#  {'Repository Name': 'awesome-scalability',
#   'User Name': 'binhnguyennus',
#   'stars': '39.3k',
#   'Repository URL': 'https://github.com/topics/machine-learningbinhnguyennus/awesome-scalability'},
#  {'Repository Name': 'ML-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '38.9k',
#   'Repository URL': 'https://github.com/topics/machine-learningmicrosoft/ML-For-Beginners'},
#  {'Repository Name': 'cs-video-courses',
#   'User Name': 'Developer-Y',
#   'stars': '38.2k',
#   'Repository URL': 'https://github.com/topics/machine-learningDeveloper-Y/cs-video-courses'},
#  {'Repository Name': '100-Days-Of-ML-Code',
#   'User Name': 'Avik-Jain',
#   'stars': '37.8k',
#   'Repository URL': 'https://github.com/topics/machine-learningAvik-Jain/100-Days-Of-ML-Code'},
#  {'Repository Name': 'DeepFaceLab',
#   'User Name': 'iperov',
#   'stars': '33.7k',
#   'Repository URL': 'https://github.com/topics/machine-learningiperov/DeepFaceLab'},
#  {'Repository Name': 'd2l-zh',
#   'User Name': 'd2l-ai',
#   'stars': '33.4k',
#   'Repository URL': 'https://github.com/topics/machine-learningd2l-ai/d2l-zh'},
#  {'Repository Name': 'caffe',
#   'User Name': 'BVLC',
#   'stars': '32.7k',
#   'Repository URL': 'https://github.com/topics/machine-learningBVLC/caffe'},
#  {'Repository Name': 'Made-With-ML',
#   'User Name': 'GokuMohandas',
#   'stars': '30.3k',
#   'Repository URL': 'https://github.com/topics/machine-learningGokuMohandas/Made-With-ML'},
#  {'Repository Name': 'yolov5',
#   'User Name': 'ultralytics',
#   'stars': '28.2k',
#   'Repository URL': 'https://github.com/topics/machine-learningultralytics/yolov5'},
#  {'Repository Name': 'machine-learning-for-software-engineers',
#   'User Name': 'ZuzooVn',
#   'stars': '26k',
#   'Repository URL': 'https://github.com/topics/machine-learningZuzooVn/machine-learning-for-software-engineers'},
#  {'Repository Name': 'Coursera-ML-AndrewNg-Notes',
#   'User Name': 'fengdu78',
#   'stars': '25.4k',
#   'Repository URL': 'https://github.com/topics/machine-learningfengdu78/Coursera-ML-AndrewNg-Notes'},
#  {'Repository Name': 'handson-ml',
#   'User Name': 'ageron',
#   'stars': '24.6k',
#   'Repository URL': 'https://github.com/topics/machine-learningageron/handson-ml'},
#  {'Repository Name': 'openpose',
#   'User Name': 'CMU-Perceptual-Computing-Lab',
#   'stars': '24.5k',
#   'Repository URL': 'https://github.com/topics/machine-learningCMU-Perceptual-Computing-Lab/openpose'},
#  {'Repository Name': 'google-research',
#   'User Name': 'google-research',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/topics/machine-learninggoogle-research/google-research'},
#  {'Repository Name': 'awesome-deep-learning-papers',
#   'User Name': 'terryum',
#   'stars': '23.8k',
#   'Repository URL': 'https://github.com/topics/machine-learningterryum/awesome-deep-learning-papers'},
#  {'Repository Name': 'spaCy',
#   'User Name': 'explosion',
#   'stars': '23.7k',
#   'Repository URL': 'https://github.com/topics/machine-learningexplosion/spaCy'},
#  {'Repository Name': 'data-science-ipython-notebooks',
#   'User Name': 'donnemartin',
#   'stars': '23.3k',
#   'Repository URL': 'https://github.com/topics/machine-learningdonnemartin/data-science-ipython-notebooks'},
#  {'Repository Name': 'xgboost',
#   'User Name': 'dmlc',
#   'stars': '22.9k',
#   'Repository URL': 'https://github.com/topics/machine-learningdmlc/xgboost'},
#  {'Repository Name': 'fastai',
#   'User Name': 'fastai',
#   'stars': '22.5k',
#   'Repository URL': 'https://github.com/topics/machine-learningfastai/fastai'},
#  {'Repository Name': 'ML-From-Scratch',
#   'User Name': 'eriklindernoren',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/topics/machine-learningeriklindernoren/ML-From-Scratch'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                             Repository Name                     User Name  \
# 0                                tensorflow                    tensorflow
# 1                              transformers                   huggingface
# 2                                   pytorch                       pytorch
# 3                                     keras                    keras-team
# 4                              scikit-learn                  scikit-learn
# 5                                 tesseract                 tesseract-ocr
# 6                          face_recognition                      ageitgey
# 7                       TensorFlow-Examples                 aymericdamien
# 8                                  faceswap                     deepfakes
# 9                                     julia                     JuliaLang
# 10                      awesome-scalability                 binhnguyennus
# 11                         ML-For-Beginners                     microsoft
# 12                         cs-video-courses                   Developer-Y
# 13                      100-Days-Of-ML-Code                     Avik-Jain
# 14                              DeepFaceLab                        iperov
# 15                                   d2l-zh                        d2l-ai
# 16                                    caffe                          BVLC
# 17                             Made-With-ML                  GokuMohandas
# 18                                   yolov5                   ultralytics
# 19  machine-learning-for-software-engineers                       ZuzooVn
# 20               Coursera-ML-AndrewNg-Notes                      fengdu78
# 21                               handson-ml                        ageron
# 22                                 openpose  CMU-Perceptual-Computing-Lab
# 23                          google-research               google-research
# 24             awesome-deep-learning-papers                       terryum
# 25                                    spaCy                     explosion
# 26           data-science-ipython-notebooks                   donnemartin
# 27                                  xgboost                          dmlc
# 28                                   fastai                        fastai
# 29                          ML-From-Scratch               eriklindernoren
#
#     stars                                     Repository URL
# 0    166k  https://github.com/topics/machine-learningtens...
# 1   66.4k  https://github.com/topics/machine-learninghugg...
# 2   57.1k  https://github.com/topics/machine-learningpyto...
# 3   55.6k  https://github.com/topics/machine-learningkera...
# 4   50.6k  https://github.com/topics/machine-learningscik...
# 5   45.8k  https://github.com/topics/machine-learningtess...
# 6   45.1k  https://github.com/topics/machine-learningagei...
# 7     42k  https://github.com/topics/machine-learningayme...
# 8   41.6k  https://github.com/topics/machine-learningdeep...
# 9   39.8k  https://github.com/topics/machine-learningJuli...
# 10  39.3k  https://github.com/topics/machine-learningbinh...
# 11  38.9k  https://github.com/topics/machine-learningmicr...
# 12  38.2k  https://github.com/topics/machine-learningDeve...
# 13  37.8k  https://github.com/topics/machine-learningAvik...
# 14  33.7k  https://github.com/topics/machine-learningiper...
# 15  33.4k  https://github.com/topics/machine-learningd2l-...
# 16  32.7k  https://github.com/topics/machine-learningBVLC...
# 17  30.3k  https://github.com/topics/machine-learningGoku...
# 18  28.2k  https://github.com/topics/machine-learningultr...
# 19    26k  https://github.com/topics/machine-learningZuzo...
# 20  25.4k  https://github.com/topics/machine-learningfeng...
# 21  24.6k  https://github.com/topics/machine-learningager...
# 22  24.5k  https://github.com/topics/machine-learningCMU-...
# 23    24k  https://github.com/topics/machine-learninggoog...
# 24  23.8k  https://github.com/topics/machine-learningterr...
# 25  23.7k  https://github.com/topics/machine-learningexpl...
# 26  23.3k  https://github.com/topics/machine-learningdonn...
# 27  22.9k  https://github.com/topics/machine-learningdmlc...
# 28  22.5k  https://github.com/topics/machine-learningfast...
# 29  21.2k  https://github.com/topics/machine-learningerik...

# %%
df.to_excel('machine_learning.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/machine-learning?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/machine-learning?page=1',
#  'https://github.com/topics/machine-learning?page=2',
#  'https://github.com/topics/machine-learning?page=3',
#  'https://github.com/topics/machine-learning?page=4',
#  'https://github.com/topics/machine-learning?page=5',
#  'https://github.com/topics/machine-learning?page=6',
#  'https://github.com/topics/machine-learning?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/machine-learning?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'tensorflow',
#   'User Name': 'tensorflow',
#   'stars': '166k',
#   'Repository URL': 'https://github.com/tensorflow/tensorflow'},
#  {'Sr No': 2,
#   'Repository Name': 'transformers',
#   'User Name': 'huggingface',
#   'stars': '66.4k',
#   'Repository URL': 'https://github.com/huggingface/transformers'},
#  {'Sr No': 3,
#   'Repository Name': 'pytorch',
#   'User Name': 'pytorch',
#   'stars': '57.1k',
#   'Repository URL': 'https://github.com/pytorch/pytorch'},
#  {'Sr No': 4,
#   'Repository Name': 'keras',
#   'User Name': 'keras-team',
#   'stars': '55.6k',
#   'Repository URL': 'https://github.com/keras-team/keras'},
#  {'Sr No': 5,
#   'Repository Name': 'scikit-learn',
#   'User Name': 'scikit-learn',
#   'stars': '50.6k',
#   'Repository URL': 'https://github.com/scikit-learn/scikit-learn'},
#  {'Sr No': 6,
#   'Repository Name': 'tesseract',
#   'User Name': 'tesseract-ocr',
#   'stars': '45.8k',
#   'Repository URL': 'https://github.com/tesseract-ocr/tesseract'},
#  {'Sr No': 7,
#   'Repository Name': 'face_recognition',
#   'User Name': 'ageitgey',
#   'stars': '45.1k',
#   'Repository URL': 'https://github.com/ageitgey/face_recognition'},
#  {'Sr No': 8,
#   'Repository Name': 'TensorFlow-Examples',
#   'User Name': 'aymericdamien',
#   'stars': '42k',
#   'Repository URL': 'https://github.com/aymericdamien/TensorFlow-Examples'},
#  {'Sr No': 9,
#   'Repository Name': 'faceswap',
#   'User Name': 'deepfakes',
#   'stars': '41.6k',
#   'Repository URL': 'https://github.com/deepfakes/faceswap'},
#  {'Sr No': 10,
#   'Repository Name': 'julia',
#   'User Name': 'JuliaLang',
#   'stars': '39.8k',
#   'Repository URL': 'https://github.com/JuliaLang/julia'},
#  {'Sr No': 11,
#   'Repository Name': 'awesome-scalability',
#   'User Name': 'binhnguyennus',
#   'stars': '39.3k',
#   'Repository URL': 'https://github.com/binhnguyennus/awesome-scalability'},
#  {'Sr No': 12,
#   'Repository Name': 'ML-For-Beginners',
#   'User Name': 'microsoft',
#   'stars': '38.9k',
#   'Repository URL': 'https://github.com/microsoft/ML-For-Beginners'},
#  {'Sr No': 13,
#   'Repository Name': 'cs-video-courses',
#   'User Name': 'Developer-Y',
#   'stars': '38.2k',
#   'Repository URL': 'https://github.com/Developer-Y/cs-video-courses'},
#  {'Sr No': 14,
#   'Repository Name': '100-Days-Of-ML-Code',
#   'User Name': 'Avik-Jain',
#   'stars': '37.8k',
#   'Repository URL': 'https://github.com/Avik-Jain/100-Days-Of-ML-Code'},
#  {'Sr No': 15,
#   'Repository Name': 'DeepFaceLab',
#   'User Name': 'iperov',
#   'stars': '33.7k',
#   'Repository URL': 'https://github.com/iperov/DeepFaceLab'},
#  {'Sr No': 16,
#   'Repository Name': 'd2l-zh',
#   'User Name': 'd2l-ai',
#   'stars': '33.4k',
#   'Repository URL': 'https://github.com/d2l-ai/d2l-zh'},
#  {'Sr No': 17,
#   'Repository Name': 'caffe',
#   'User Name': 'BVLC',
#   'stars': '32.7k',
#   'Repository URL': 'https://github.com/BVLC/caffe'},
#  {'Sr No': 18,
#   'Repository Name': 'Made-With-ML',
#   'User Name': 'GokuMohandas',
#   'stars': '30.3k',
#   'Repository URL': 'https://github.com/GokuMohandas/Made-With-ML'},
#  {'Sr No': 19,
#   'Repository Name': 'yolov5',
#   'User Name': 'ultralytics',
#   'stars': '28.2k',
#   'Repository URL': 'https://github.com/ultralytics/yolov5'},
#  {'Sr No': 20,
#   'Repository Name': 'machine-learning-for-software-engineers',
#   'User Name': 'ZuzooVn',
#   'stars': '26k',
#   'Repository URL': 'https://github.com/ZuzooVn/machine-learning-for-software-engineers'},
#  {'Sr No': 21,
#   'Repository Name': 'Coursera-ML-AndrewNg-Notes',
#   'User Name': 'fengdu78',
#   'stars': '25.4k',
#   'Repository URL': 'https://github.com/fengdu78/Coursera-ML-AndrewNg-Notes'},
#  {'Sr No': 22,
#   'Repository Name': 'handson-ml',
#   'User Name': 'ageron',
#   'stars': '24.6k',
#   'Repository URL': 'https://github.com/ageron/handson-ml'},
#  {'Sr No': 23,
#   'Repository Name': 'openpose',
#   'User Name': 'CMU-Perceptual-Computing-Lab',
#   'stars': '24.5k',
#   'Repository URL': 'https://github.com/CMU-Perceptual-Computing-Lab/openpose'},
#  {'Sr No': 24,
#   'Repository Name': 'google-research',
#   'User Name': 'google-research',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/google-research/google-research'},
#  {'Sr No': 25,
#   'Repository Name': 'awesome-deep-learning-papers',
#   'User Name': 'terryum',
#   'stars': '23.8k',
#   'Repository URL': 'https://github.com/terryum/awesome-deep-learning-papers'},
#  {'Sr No': 26,
#   'Repository Name': 'spaCy',
#   'User Name': 'explosion',
#   'stars': '23.7k',
#   'Repository URL': 'https://github.com/explosion/spaCy'},
#  {'Sr No': 27,
#   'Repository Name': 'data-science-ipython-notebooks',
#   'User Name': 'donnemartin',
#   'stars': '23.3k',
#   'Repository URL': 'https://github.com/donnemartin/data-science-ipython-notebooks'},
#  {'Sr No': 28,
#   'Repository Name': 'xgboost',
#   'User Name': 'dmlc',
#   'stars': '22.9k',
#   'Repository URL': 'https://github.com/dmlc/xgboost'},
#  {'Sr No': 29,
#   'Repository Name': 'fastai',
#   'User Name': 'fastai',
#   'stars': '22.5k',
#   'Repository URL': 'https://github.com/fastai/fastai'},
#  {'Sr No': 30,
#   'Repository Name': 'ML-From-Scratch',
#   'User Name': 'eriklindernoren',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/eriklindernoren/ML-From-Scratch'},
#  {'Sr No': 31,
#   'Repository Name': 'ray',
#   'User Name': 'ray-project',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/ray-project/ray'},
#  {'Sr No': 32,
#   'Repository Name': 'photoprism',
#   'User Name': 'photoprism',
#   'stars': '21.2k',
#   'Repository URL': 'https://github.com/photoprism/photoprism'},
#  {'Sr No': 33,
#   'Repository Name': 'AI-Expert-Roadmap',
#   'User Name': 'AMAI-GmbH',
#   'stars': '20.8k',
#   'Repository URL': 'https://github.com/AMAI-GmbH/AI-Expert-Roadmap'},
#  {'Sr No': 34,
#   'Repository Name': 'NLP-progress',
#   'User Name': 'sebastianruder',
#   'stars': '20.6k',
#   'Repository URL': 'https://github.com/sebastianruder/NLP-progress'},
#  {'Sr No': 35,
#   'Repository Name': 'applied-ml',
#   'User Name': 'eugeneyan',
#   'stars': '20.2k',
#   'Repository URL': 'https://github.com/eugeneyan/applied-ml'},
#  {'Sr No': 36,
#   'Repository Name': 'pumpkin-book',
#   'User Name': 'datawhalechina',
#   'stars': '20.1k',
#   'Repository URL': 'https://github.com/datawhalechina/pumpkin-book'},
#  {'Sr No': 37,
#   'Repository Name': 'C-Plus-Plus',
#   'User Name': 'TheAlgorithms',
#   'stars': '20k',
#   'Repository URL': 'https://github.com/TheAlgorithms/C-Plus-Plus'},
#  {'Sr No': 38,
#   'Repository Name': 'DeepSpeech',
#   'User Name': 'mozilla',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/mozilla/DeepSpeech'},
#  {'Sr No': 39,
#   'Repository Name': 'streamlit',
#   'User Name': 'streamlit',
#   'stars': '19.8k',
#   'Repository URL': 'https://github.com/streamlit/streamlit'},
#  {'Sr No': 40,
#   'Repository Name': 'homemade-machine-learning',
#   'User Name': 'trekhleb',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/trekhleb/homemade-machine-learning'},
#  {'Sr No': 41,
#   'Repository Name': 'lightning',
#   'User Name': 'Lightning-AI',
#   'stars': '19.3k',
#   'Repository URL': 'https://github.com/Lightning-AI/lightning'},
#  {'Sr No': 42,
#   'Repository Name': 'netron',
#   'User Name': 'lutzroeder',
#   'stars': '19.2k',
#   'Repository URL': 'https://github.com/lutzroeder/netron'},
#  {'Sr No': 43,
#   'Repository Name': 'WaveFunctionCollapse',
#   'User Name': 'mxgmn',
#   'stars': '19.1k',
#   'Repository URL': 'https://github.com/mxgmn/WaveFunctionCollapse'},
#  {'Sr No': 44,
#   'Repository Name': 'awesome-datascience',
#   'User Name': 'academic',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/academic/awesome-datascience'},
#  {'Sr No': 45,
#   'Repository Name': 'awesome-deep-learning',
#   'User Name': 'ChristosChristofidis',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/ChristosChristofidis/awesome-deep-learning'},
#  {'Sr No': 46,
#   'Repository Name': '100-Days-Of-ML-Code',
#   'User Name': 'MLEveryday',
#   'stars': '19k',
#   'Repository URL': 'https://github.com/MLEveryday/100-Days-Of-ML-Code'},
#  {'Sr No': 47,
#   'Repository Name': 'Paddle',
#   'User Name': 'PaddlePaddle',
#   'stars': '18.5k',
#   'Repository URL': 'https://github.com/PaddlePaddle/Paddle'},
#  {'Sr No': 48,
#   'Repository Name': 'mediapipe',
#   'User Name': 'google',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/google/mediapipe'},
#  {'Sr No': 49,
#   'Repository Name': 'CNTK',
#   'User Name': 'microsoft',
#   'stars': '17.2k',
#   'Repository URL': 'https://github.com/microsoft/CNTK'},
#  {'Sr No': 50,
#   'Repository Name': 'pytorch-handbook',
#   'User Name': 'zergtant',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/zergtant/pytorch-handbook'},
#  {'Sr No': 51,
#   'Repository Name': 'shap',
#   'User Name': 'slundberg',
#   'stars': '16.8k',
#   'Repository URL': 'https://github.com/slundberg/shap'},
#  {'Sr No': 52,
#   'Repository Name': 'learnopencv',
#   'User Name': 'spmallick',
#   'stars': '16.6k',
#   'Repository URL': 'https://github.com/spmallick/learnopencv'},
#  {'Sr No': 53,
#   'Repository Name': 'tfjs',
#   'User Name': 'tensorflow',
#   'stars': '16.4k',
#   'Repository URL': 'https://github.com/tensorflow/tfjs'},
#  {'Sr No': 54,
#   'Repository Name': 'gun',
#   'User Name': 'amark',
#   'stars': '16.1k',
#   'Repository URL': 'https://github.com/amark/gun'},
#  {'Sr No': 55,
#   'Repository Name': 'pwc',
#   'User Name': 'zziz',
#   'stars': '15.4k',
#   'Repository URL': 'https://github.com/zziz/pwc'},
#  {'Sr No': 56,
#   'Repository Name': 'lectures',
#   'User Name': 'oxford-cs-deepnlp-2017',
#   'stars': '15.4k',
#   'Repository URL': 'https://github.com/oxford-cs-deepnlp-2017/lectures'},
#  {'Sr No': 57,
#   'Repository Name': 'fastbook',
#   'User Name': 'fastai',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/fastai/fastbook'},
#  {'Sr No': 58,
#   'Repository Name': 'EasyOCR',
#   'User Name': 'JaidedAI',
#   'stars': '15.2k',
#   'Repository URL': 'https://github.com/JaidedAI/EasyOCR'},
#  {'Sr No': 59,
#   'Repository Name': 'jina',
#   'User Name': 'jina-ai',
#   'stars': '15k',
#   'Repository URL': 'https://github.com/jina-ai/jina'},
#  {'Sr No': 60,
#   'Repository Name': 'rasa',
#   'User Name': 'RasaHQ',
#   'stars': '14.5k',
#   'Repository URL': 'https://github.com/RasaHQ/rasa'},
#  {'Sr No': 61,
#   'Repository Name': 'cheatsheets-ai',
#   'User Name': 'kailashahirwar',
#   'stars': '14.3k',
#   'Repository URL': 'https://github.com/kailashahirwar/cheatsheets-ai'},
#  {'Sr No': 62,
#   'Repository Name': 'LightGBM',
#   'User Name': 'microsoft',
#   'stars': '14k',
#   'Repository URL': 'https://github.com/microsoft/LightGBM'},
#  {'Sr No': 63,
#   'Repository Name': 'd2l-en',
#   'User Name': 'd2l-ai',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/d2l-ai/d2l-en'},
#  {'Sr No': 64,
#   'Repository Name': 'C',
#   'User Name': 'TheAlgorithms',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/TheAlgorithms/C'},
#  {'Sr No': 65,
#   'Repository Name': 'Qix',
#   'User Name': 'ty4z2008',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/ty4z2008/Qix'},
#  {'Sr No': 66,
#   'Repository Name': 'datasets',
#   'User Name': 'huggingface',
#   'stars': '13.7k',
#   'Repository URL': 'https://github.com/huggingface/datasets'},
#  {'Sr No': 67,
#   'Repository Name': 'Screenshot-to-code',
#   'User Name': 'emilwallner',
#   'stars': '13.7k',
#   'Repository URL': 'https://github.com/emilwallner/Screenshot-to-code'},
#  {'Sr No': 68,
#   'Repository Name': 'stanford-cs-229-machine-learning',
#   'User Name': 'afshinea',
#   'stars': '13.7k',
#   'Repository URL': 'https://github.com/afshinea/stanford-cs-229-machine-learning'},
#  {'Sr No': 69,
#   'Repository Name': 'recommenders',
#   'User Name': 'microsoft',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/microsoft/recommenders'},
#  {'Sr No': 70,
#   'Repository Name': 'awesome-nlp',
#   'User Name': 'keon',
#   'stars': '13.4k',
#   'Repository URL': 'https://github.com/keon/awesome-nlp'},
#  {'Sr No': 71,
#   'Repository Name': 'Virgilio',
#   'User Name': 'virgili0',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/virgili0/Virgilio'},
#  {'Sr No': 72,
#   'Repository Name': 'gensim',
#   'User Name': 'RaRe-Technologies',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/RaRe-Technologies/gensim'},
#  {'Sr No': 73,
#   'Repository Name': 'Awesome-pytorch-list',
#   'User Name': 'bharathgs',
#   'stars': '13.2k',
#   'Repository URL': 'https://github.com/bharathgs/Awesome-pytorch-list'},
#  {'Sr No': 74,
#   'Repository Name': 'ml-agents',
#   'User Name': 'Unity-Technologies',
#   'stars': '13.1k',
#   'Repository URL': 'https://github.com/Unity-Technologies/ml-agents'},
#  {'Sr No': 75,
#   'Repository Name': 'awesome-kubernetes',
#   'User Name': 'ramitsurana',
#   'stars': '12.9k',
#   'Repository URL': 'https://github.com/ramitsurana/awesome-kubernetes'},
#  {'Sr No': 76,
#   'Repository Name': 'onnx',
#   'User Name': 'onnx',
#   'stars': '12.8k',
#   'Repository URL': 'https://github.com/onnx/onnx'},
#  {'Sr No': 77,
#   'Repository Name': 'imgaug',
#   'User Name': 'aleju',
#   'stars': '12.8k',
#   'Repository URL': 'https://github.com/aleju/imgaug'},
#  {'Sr No': 78,
#   'Repository Name': 'horovod',
#   'User Name': 'horovod',
#   'stars': '12.6k',
#   'Repository URL': 'https://github.com/horovod/horovod'},
#  {'Sr No': 79,
#   'Repository Name': 'OpenBBTerminal',
#   'User Name': 'OpenBB-finance',
#   'stars': '12.5k',
#   'Repository URL': 'https://github.com/OpenBB-finance/OpenBBTerminal'},
#  {'Sr No': 80,
#   'Repository Name': 'tensor2tensor',
#   'User Name': 'tensorflow',
#   'stars': '12.4k',
#   'Repository URL': 'https://github.com/tensorflow/tensor2tensor'},
#  {'Sr No': 81,
#   'Repository Name': 'ChatterBot',
#   'User Name': 'gunthercox',
#   'stars': '12.4k',
#   'Repository URL': 'https://github.com/gunthercox/ChatterBot'},
#  {'Sr No': 82,
#   'Repository Name': 'the-gan-zoo',
#   'User Name': 'hindupuravinash',
#   'stars': '12.3k',
#   'Repository URL': 'https://github.com/hindupuravinash/the-gan-zoo'},
#  {'Sr No': 83,
#   'Repository Name': 'mlflow',
#   'User Name': 'mlflow',
#   'stars': '12.2k',
#   'Repository URL': 'https://github.com/mlflow/mlflow'},
#  {'Sr No': 84,
#   'Repository Name': 'Machine-Learning-Tutorials',
#   'User Name': 'ujjwalkarn',
#   'stars': '12.1k',
#   'Repository URL': 'https://github.com/ujjwalkarn/Machine-Learning-Tutorials'},
#  {'Sr No': 85,
#   'Repository Name': 'ML-NLP',
#   'User Name': 'NLP-LOVE',
#   'stars': '12.2k',
#   'Repository URL': 'https://github.com/NLP-LOVE/ML-NLP'},
#  {'Sr No': 86,
#   'Repository Name': 'vision',
#   'User Name': 'pytorch',
#   'stars': '12k',
#   'Repository URL': 'https://github.com/pytorch/vision'},
#  {'Sr No': 87,
#   'Repository Name': 'awesome-production-machine-learning',
#   'User Name': 'EthicalML',
#   'stars': '11.9k',
#   'Repository URL': 'https://github.com/EthicalML/awesome-production-machine-learning'},
#  {'Sr No': 88,
#   'Repository Name': 'flair',
#   'User Name': 'flairNLP',
#   'stars': '11.8k',
#   'Repository URL': 'https://github.com/flairNLP/flair'},
#  {'Sr No': 89,
#   'Repository Name': 'nsfw_data_scraper',
#   'User Name': 'alex000kim',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/alex000kim/nsfw_data_scraper'},
#  {'Sr No': 90,
#   'Repository Name': 'nni',
#   'User Name': 'microsoft',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/microsoft/nni'},
#  {'Sr No': 91,
#   'Repository Name': 'kubeflow',
#   'User Name': 'kubeflow',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/kubeflow/kubeflow'},
#  {'Sr No': 92,
#   'Repository Name': 'python-machine-learning-book',
#   'User Name': 'rasbt',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/rasbt/python-machine-learning-book'},
#  {'Sr No': 93,
#   'Repository Name': 'numpy-ml',
#   'User Name': 'ddbourgin',
#   'stars': '11.4k',
#   'Repository URL': 'https://github.com/ddbourgin/numpy-ml'},
#  {'Sr No': 94,
#   'Repository Name': 'argo-workflows',
#   'User Name': 'argoproj',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/argoproj/argo-workflows'},
#  {'Sr No': 95,
#   'Repository Name': 'dlib',
#   'User Name': 'davisking',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/davisking/dlib'},
#  {'Sr No': 96,
#   'Repository Name': 'Halfrost-Field',
#   'User Name': 'halfrost',
#   'stars': '11.2k',
#   'Repository URL': 'https://github.com/halfrost/Halfrost-Field'},
#  {'Sr No': 97,
#   'Repository Name': 'best-of-ml-python',
#   'User Name': 'ml-tooling',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/ml-tooling/best-of-ml-python'},
#  {'Sr No': 98,
#   'Repository Name': 'nltk',
#   'User Name': 'nltk',
#   'stars': '10.9k',
#   'Repository URL': 'https://github.com/nltk/nltk'},
#  {'Sr No': 99,
#   'Repository Name': 'turicreate',
#   'User Name': 'apple',
#   'stars': '10.7k',
#   'Repository URL': 'https://github.com/apple/turicreate'},
#  {'Sr No': 100,
#   'Repository Name': 'awesome-aws',
#   'User Name': 'donnemartin',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/donnemartin/awesome-aws'},
#  {'Sr No': 101,
#   'Repository Name': 'albumentations',
#   'User Name': 'albumentations-team',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/albumentations-team/albumentations'},
#  {'Sr No': 102,
#   'Repository Name': 'mit-deep-learning-book-pdf',
#   'User Name': 'janishar',
#   'stars': '10.4k',
#   'Repository URL': 'https://github.com/janishar/mit-deep-learning-book-pdf'},
#  {'Sr No': 103,
#   'Repository Name': 'deep-learning-drizzle',
#   'User Name': 'kmario23',
#   'stars': '10.2k',
#   'Repository URL': 'https://github.com/kmario23/deep-learning-drizzle'},
#  {'Sr No': 104,
#   'Repository Name': 'stanford-tensorflow-tutorials',
#   'User Name': 'chiphuyen',
#   'stars': '10.2k',
#   'Repository URL': 'https://github.com/chiphuyen/stanford-tensorflow-tutorials'},
#  {'Sr No': 105,
#   'Repository Name': 'fashion-mnist',
#   'User Name': 'zalandoresearch',
#   'stars': '10.1k',
#   'Repository URL': 'https://github.com/zalandoresearch/fashion-mnist'},
#  {'Sr No': 106,
#   'Repository Name': 'tutorials',
#   'User Name': 'MorvanZhou',
#   'stars': '10.1k',
#   'Repository URL': 'https://github.com/MorvanZhou/tutorials'},
#  {'Sr No': 107,
#   'Repository Name': 'dvc',
#   'User Name': 'iterative',
#   'stars': '10k',
#   'Repository URL': 'https://github.com/iterative/dvc'},
#  {'Sr No': 108,
#   'Repository Name': 'caire',
#   'User Name': 'esimov',
#   'stars': '10k',
#   'Repository URL': 'https://github.com/esimov/caire'},
#  {'Sr No': 109,
#   'Repository Name': 'annotated_deep_learning_paper_implementations',
#   'User Name': 'labmlai',
#   'stars': '9.9k',
#   'Repository URL': 'https://github.com/labmlai/annotated_deep_learning_paper_implementations'},
#  {'Sr No': 110,
#   'Repository Name': 'transferlearning',
#   'User Name': 'jindongwang',
#   'stars': '9.6k',
#   'Repository URL': 'https://github.com/jindongwang/transferlearning'},
#  {'Sr No': 111,
#   'Repository Name': 'tflearn',
#   'User Name': 'tflearn',
#   'stars': '9.6k',
#   'Repository URL': 'https://github.com/tflearn/tflearn'},
#  {'Sr No': 112,
#   'Repository Name': 'CVPR2022-Paper-Code-Interpretation',
#   'User Name': 'extreme-assistant',
#   'stars': '9.6k',
#   'Repository URL': 'https://github.com/extreme-assistant/CVPR2022-Paper-Code-Interpretation'},
#  {'Sr No': 113,
#   'Repository Name': 'sonnet',
#   'User Name': 'deepmind',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/deepmind/sonnet'},
#  {'Sr No': 114,
#   'Repository Name': 'abu',
#   'User Name': 'bbfamily',
#   'stars': '9.1k',
#   'Repository URL': 'https://github.com/bbfamily/abu'},
#  {'Sr No': 115,
#   'Repository Name': 'mit-deep-learning',
#   'User Name': 'lexfridman',
#   'stars': '9.1k',
#   'Repository URL': 'https://github.com/lexfridman/mit-deep-learning'},
#  {'Sr No': 116,
#   'Repository Name': 'pandas-profiling',
#   'User Name': 'ydataai',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/ydataai/pandas-profiling'},
#  {'Sr No': 117,
#   'Repository Name': 'TensorFlow-Tutorials',
#   'User Name': 'Hvass-Labs',
#   'stars': '9k',
#   'Repository URL': 'https://github.com/Hvass-Labs/TensorFlow-Tutorials'},
#  {'Sr No': 118,
#   'Repository Name': 'MLAlgorithms',
#   'User Name': 'rushter',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/rushter/MLAlgorithms'},
#  {'Sr No': 119,
#   'Repository Name': 'yolov3',
#   'User Name': 'ultralytics',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/ultralytics/yolov3'},
#  {'Sr No': 120,
#   'Repository Name': 'qlib',
#   'User Name': 'microsoft',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/microsoft/qlib'},
#  {'Sr No': 121,
#   'Repository Name': '500-AI-Machine-learning-Deep-learning-Computer-vision-NLP-Projects-with-code',
#   'User Name': 'ashishpatel26',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/ashishpatel26/500-AI-Machine-learning-Deep-learning-Computer-vision-NLP-Projects-with-code'},
#  {'Sr No': 122,
#   'Repository Name': 'EffectiveTensorflow',
#   'User Name': 'vahidk',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/vahidk/EffectiveTensorflow'},
#  {'Sr No': 123,
#   'Repository Name': 'CVPR2022-Papers-with-Code',
#   'User Name': 'amusi',
#   'stars': '8.9k',
#   'Repository URL': 'https://github.com/amusi/CVPR2022-Papers-with-Code'},
#  {'Sr No': 124,
#   'Repository Name': 'tpot',
#   'User Name': 'EpistasisLab',
#   'stars': '8.6k',
#   'Repository URL': 'https://github.com/EpistasisLab/tpot'},
#  {'Sr No': 125,
#   'Repository Name': 'Winds',
#   'User Name': 'GetStream',
#   'stars': '8.6k',
#   'Repository URL': 'https://github.com/GetStream/Winds'},
#  {'Sr No': 126,
#   'Repository Name': 'autokeras',
#   'User Name': 'keras-team',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/keras-team/autokeras'},
#  {'Sr No': 127,
#   'Repository Name': 'numerical-linear-algebra',
#   'User Name': 'fastai',
#   'stars': '8.6k',
#   'Repository URL': 'https://github.com/fastai/numerical-linear-algebra'},
#  {'Sr No': 128,
#   'Repository Name': 'tfjs-core',
#   'User Name': 'tensorflow',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/tensorflow/tfjs-core'},
#  {'Sr No': 129,
#   'Repository Name': 'computervision-recipes',
#   'User Name': 'microsoft',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/microsoft/computervision-recipes'},
#  {'Sr No': 130,
#   'Repository Name': 'ludwig',
#   'User Name': 'ludwig-ai',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/ludwig-ai/ludwig'},
#  {'Sr No': 131,
#   'Repository Name': 'caffe2',
#   'User Name': 'facebookarchive',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/facebookarchive/caffe2'},
#  {'Sr No': 132,
#   'Repository Name': 'tvm',
#   'User Name': 'apache',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/apache/tvm'},
#  {'Sr No': 133,
#   'Repository Name': 'mindsdb',
#   'User Name': 'mindsdb',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/mindsdb/mindsdb'},
#  {'Sr No': 134,
#   'Repository Name': 'mlcourse.ai',
#   'User Name': 'Yorko',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/Yorko/mlcourse.ai'},
#  {'Sr No': 135,
#   'Repository Name': 'pattern',
#   'User Name': 'clips',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/clips/pattern'},
#  {'Sr No': 136,
#   'Repository Name': 'awesome-mlops',
#   'User Name': 'visenger',
#   'stars': '8.2k',
#   'Repository URL': 'https://github.com/visenger/awesome-mlops'},
#  {'Sr No': 137,
#   'Repository Name': '3D-Machine-Learning',
#   'User Name': 'timzhang642',
#   'stars': '8.1k',
#   'Repository URL': 'https://github.com/timzhang642/3D-Machine-Learning'},
#  {'Sr No': 138,
#   'Repository Name': 'machinelearning',
#   'User Name': 'dotnet',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/dotnet/machinelearning'},
#  {'Sr No': 139,
#   'Repository Name': 'vowpal_wabbit',
#   'User Name': 'VowpalWabbit',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/VowpalWabbit/vowpal_wabbit'},
#  {'Sr No': 140,
#   'Repository Name': 'DeepLearning',
#   'User Name': 'Mikoto10032',
#   'stars': '8k',
#   'Repository URL': 'https://github.com/Mikoto10032/DeepLearning'},
#  {'Sr No': 141,
#   'Repository Name': 'cortex',
#   'User Name': 'cortexlabs',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/cortexlabs/cortex'},
#  {'Sr No': 142,
#   'Repository Name': 'gradio',
#   'User Name': 'gradio-app',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/gradio-app/gradio'},
#  {'Sr No': 143,
#   'Repository Name': 'instant-ngp',
#   'User Name': 'NVlabs',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/NVlabs/instant-ngp'},
#  {'Sr No': 144,
#   'Repository Name': 'Interview',
#   'User Name': 'apachecn',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/apachecn/Interview'},
#  {'Sr No': 145,
#   'Repository Name': 'pysc2',
#   'User Name': 'deepmind',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/deepmind/pysc2'},
#  {'Sr No': 146,
#   'Repository Name': 'pyro',
#   'User Name': 'pyro-ppl',
#   'stars': '7.5k',
#   'Repository URL': 'https://github.com/pyro-ppl/pyro'},
#  {'Sr No': 147,
#   'Repository Name': 'kedro',
#   'User Name': 'kedro-org',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/kedro-org/kedro'},
#  {'Sr No': 148,
#   'Repository Name': 'tensorboardX',
#   'User Name': 'lanpa',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/lanpa/tensorboardX'},
#  {'Sr No': 149,
#   'Repository Name': 'Reinforcement-learning-with-tensorflow',
#   'User Name': 'MorvanZhou',
#   'stars': '7.4k',
#   'Repository URL': 'https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow'},
#  {'Sr No': 150,
#   'Repository Name': 'machine-learning-yearning-cn',
#   'User Name': 'deeplearning-ai',
#   'stars': '7.2k',
#   'Repository URL': 'https://github.com/deeplearning-ai/machine-learning-yearning-cn'},
#  {'Sr No': 151,
#   'Repository Name': 'vaex',
#   'User Name': 'vaexio',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/vaexio/vaex'},
#  {'Sr No': 152,
#   'Repository Name': 'onnxruntime',
#   'User Name': 'microsoft',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/microsoft/onnxruntime'},
#  {'Sr No': 153,
#   'Repository Name': 'amazon-sagemaker-examples',
#   'User Name': 'aws',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/aws/amazon-sagemaker-examples'},
#  {'Sr No': 154,
#   'Repository Name': 'ImageAI',
#   'User Name': 'OlafenwaMoses',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/OlafenwaMoses/ImageAI'},
#  {'Sr No': 155,
#   'Repository Name': 'python-small-examples',
#   'User Name': 'jackzhenguo',
#   'stars': '7.1k',
#   'Repository URL': 'https://github.com/jackzhenguo/python-small-examples'},
#  {'Sr No': 156,
#   'Repository Name': 'DeepSpeed',
#   'User Name': 'microsoft',
#   'stars': '7k',
#   'Repository URL': 'https://github.com/microsoft/DeepSpeed'},
#  {'Sr No': 157,
#   'Repository Name': 'trax',
#   'User Name': 'google',
#   'stars': '7k',
#   'Repository URL': 'https://github.com/google/trax'},
#  {'Sr No': 158,
#   'Repository Name': 'Open3D',
#   'User Name': 'isl-org',
#   'stars': '7k',
#   'Repository URL': 'https://github.com/isl-org/Open3D'},
#  {'Sr No': 159,
#   'Repository Name': 'leeml-notes',
#   'User Name': 'datawhalechina',
#   'stars': '6.9k',
#   'Repository URL': 'https://github.com/datawhalechina/leeml-notes'},
#  {'Sr No': 160,
#   'Repository Name': 'generative-models',
#   'User Name': 'wiseodd',
#   'stars': '6.9k',
#   'Repository URL': 'https://github.com/wiseodd/generative-models'},
#  {'Sr No': 161,
#   'Repository Name': 'facets',
#   'User Name': 'PAIR-code',
#   'stars': '6.9k',
#   'Repository URL': 'https://github.com/PAIR-code/facets'},
#  {'Sr No': 162,
#   'Repository Name': 'ML-YouTube-Courses',
#   'User Name': 'dair-ai',
#   'stars': '6.9k',
#   'Repository URL': 'https://github.com/dair-ai/ML-YouTube-Courses'},
#  {'Sr No': 163,
#   'Repository Name': 'machine-learning-course',
#   'User Name': 'instillai',
#   'stars': '6.9k',
#   'Repository URL': 'https://github.com/instillai/machine-learning-course'},
#  {'Sr No': 164,
#   'Repository Name': 'awesome-artificial-intelligence',
#   'User Name': 'owainlewis',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/owainlewis/awesome-artificial-intelligence'},
#  {'Sr No': 165,
#   'Repository Name': 'machine_learning_examples',
#   'User Name': 'lazyprogrammer',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/lazyprogrammer/machine_learning_examples'},
#  {'Sr No': 166,
#   'Repository Name': 'PyTorch-Tutorial',
#   'User Name': 'MorvanZhou',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/MorvanZhou/PyTorch-Tutorial'},
#  {'Sr No': 167,
#   'Repository Name': 'guess',
#   'User Name': 'guess-js',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/guess-js/guess'},
#  {'Sr No': 168,
#   'Repository Name': 'MNN',
#   'User Name': 'alibaba',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/alibaba/MNN'},
#  {'Sr No': 169,
#   'Repository Name': 'kornia',
#   'User Name': 'kornia',
#   'stars': '6.7k',
#   'Repository URL': 'https://github.com/kornia/kornia'},
#  {'Sr No': 170,
#   'Repository Name': 'lab',
#   'User Name': 'deepmind',
#   'stars': '6.7k',
#   'Repository URL': 'https://github.com/deepmind/lab'},
#  {'Sr No': 171,
#   'Repository Name': 'ml-visuals',
#   'User Name': 'dair-ai',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/dair-ai/ml-visuals'},
#  {'Sr No': 172,
#   'Repository Name': 'catboost',
#   'User Name': 'catboost',
#   'stars': '6.6k',
#   'Repository URL': 'https://github.com/catboost/catboost'},
#  {'Sr No': 173,
#   'Repository Name': 'optuna',
#   'User Name': 'optuna',
#   'stars': '6.6k',
#   'Repository URL': 'https://github.com/optuna/optuna'},
#  {'Sr No': 174,
#   'Repository Name': 'DeepFaceLive',
#   'User Name': 'iperov',
#   'stars': '6.6k',
#   'Repository URL': 'https://github.com/iperov/DeepFaceLive'},
#  {'Sr No': 175,
#   'Repository Name': 'angel',
#   'User Name': 'Angel-ML',
#   'stars': '6.6k',
#   'Repository URL': 'https://github.com/Angel-ML/angel'},
#  {'Sr No': 176,
#   'Repository Name': 'python-machine-learning-book-2nd-edition',
#   'User Name': 'rasbt',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/rasbt/python-machine-learning-book-2nd-edition'},
#  {'Sr No': 177,
#   'Repository Name': 'nmap',
#   'User Name': 'nmap',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/nmap/nmap'},
#  {'Sr No': 178,
#   'Repository Name': 'doccano',
#   'User Name': 'doccano',
#   'stars': '6.4k',
#   'Repository URL': 'https://github.com/doccano/doccano'},
#  {'Sr No': 179,
#   'Repository Name': 'awesome-project-ideas',
#   'User Name': 'NirantK',
#   'stars': '6.4k',
#   'Repository URL': 'https://github.com/NirantK/awesome-project-ideas'},
#  {'Sr No': 180,
#   'Repository Name': 'Machine-Learning',
#   'User Name': 'Jack-Cherish',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/Jack-Cherish/Machine-Learning'},
#  {'Sr No': 181,
#   'Repository Name': 'SerpentAI',
#   'User Name': 'SerpentAI',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/SerpentAI/SerpentAI'},
#  {'Sr No': 182,
#   'Repository Name': 'industry-machine-learning',
#   'User Name': 'firmai',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/firmai/industry-machine-learning'},
#  {'Sr No': 183,
#   'Repository Name': 'featuretools',
#   'User Name': 'alteryx',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/alteryx/featuretools'},
#  {'Sr No': 184,
#   'Repository Name': 'TensorFlow-2.x-Tutorials',
#   'User Name': 'dragen1860',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/dragen1860/TensorFlow-2.x-Tutorials'},
#  {'Sr No': 185,
#   'Repository Name': 'tensorpack',
#   'User Name': 'tensorpack',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/tensorpack/tensorpack'},
#  {'Sr No': 186,
#   'Repository Name': 'stanza',
#   'User Name': 'stanfordnlp',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/stanfordnlp/stanza'},
#  {'Sr No': 187,
#   'Repository Name': 'EasyPR',
#   'User Name': 'liuruoze',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/liuruoze/EasyPR'},
#  {'Sr No': 188,
#   'Repository Name': 'BossSensor',
#   'User Name': 'Hironsan',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/Hironsan/BossSensor'},
#  {'Sr No': 189,
#   'Repository Name': 'cnn-explainer',
#   'User Name': 'poloclub',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/poloclub/cnn-explainer'},
#  {'Sr No': 190,
#   'Repository Name': 'swift',
#   'User Name': 'tensorflow',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/tensorflow/swift'},
#  {'Sr No': 191,
#   'Repository Name': 'anomaly-detection-resources',
#   'User Name': 'yzhao062',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/yzhao062/anomaly-detection-resources'},
#  {'Sr No': 192,
#   'Repository Name': 'tensorflow_cookbook',
#   'User Name': 'nfmcclure',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/nfmcclure/tensorflow_cookbook'},
#  {'Sr No': 193,
#   'Repository Name': 'darkflow',
#   'User Name': 'thtrieu',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/thtrieu/darkflow'},
#  {'Sr No': 194,
#   'Repository Name': 'nlp-recipes',
#   'User Name': 'microsoft',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/microsoft/nlp-recipes'},
#  {'Sr No': 195,
#   'Repository Name': 'imbalanced-learn',
#   'User Name': 'scikit-learn-contrib',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/scikit-learn-contrib/imbalanced-learn'},
#  {'Sr No': 196,
#   'Repository Name': 'data-science-blogs',
#   'User Name': 'rushter',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/rushter/data-science-blogs'},
#  {'Sr No': 197,
#   'Repository Name': 'machine-learning-for-trading',
#   'User Name': 'stefan-jansen',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/stefan-jansen/machine-learning-for-trading'},
#  {'Sr No': 198,
#   'Repository Name': 'h2o-3',
#   'User Name': 'h2oai',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/h2oai/h2o-3'},
#  {'Sr No': 199,
#   'Repository Name': 'Swift-AI',
#   'User Name': 'Swift-AI',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/Swift-AI/Swift-AI'},
#  {'Sr No': 200,
#   'Repository Name': 'gorse',
#   'User Name': 'gorse-io',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/gorse-io/gorse'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No               Repository Name      User Name  stars  \
# 0        1                    tensorflow     tensorflow   166k
# 1        2                  transformers    huggingface  66.4k
# 2        3                       pytorch        pytorch  57.1k
# 3        4                         keras     keras-team  55.6k
# 4        5                  scikit-learn   scikit-learn  50.6k
# ..     ...                           ...            ...    ...
# 195    196            data-science-blogs        rushter   5.9k
# 196    197  machine-learning-for-trading  stefan-jansen   5.9k
# 197    198                         h2o-3          h2oai   5.9k
# 198    199                      Swift-AI       Swift-AI   5.9k
# 199    200                         gorse       gorse-io   5.9k
#
#                                         Repository URL
# 0             https://github.com/tensorflow/tensorflow
# 1          https://github.com/huggingface/transformers
# 2                   https://github.com/pytorch/pytorch
# 3                  https://github.com/keras-team/keras
# 4         https://github.com/scikit-learn/scikit-learn
# ..                                                 ...
# 195      https://github.com/rushter/data-science-blogs
# 196  https://github.com/stefan-jansen/machine-learn...
# 197                     https://github.com/h2oai/h2o-3
# 198               https://github.com/Swift-AI/Swift-AI
# 199                  https://github.com/gorse-io/gorse
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_machine_learning.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
