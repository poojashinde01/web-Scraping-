# %%
import requests

# %%
url=requests.get('https://github.com/topics/postgresql').text

# %%
url
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css" /><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" />\n  \n    <link crossorigin="anonymous" media="all" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" rel="stylesheet" href="https://github.githubassets.com/assets/primer-10084108b209.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" rel="stylesheet" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" rel="stylesheet" href="https://github.githubassets.com/assets/github-f815d05d371a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYw ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(url,'lxml')

# %%
first_rep1=soup.find('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-92c7d381038e.css" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-d4a90c367f0c.css" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubassets.com/assets/dark_dimmed-7196bb0d9aaf.css" integrity="sha512-cZa7DZqvMBwD236uzEunO/G1dvw8/QftyT2UtLWKQFEy0z0eq0R5WPwqVME+3NSZG1YaLJAaIqtU+m0zWf/6SQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_high_contrast" data-href="https://github.githubassets.com/assets/dark_high_contrast-595a0aa89e32.css" integrity="sha512-WVoKqJ4y1nLsdNH4RkRT5qrM9+n9RFe1RHSiTnQkBf5TSZkJEc9GpLpTIS7T15EQaUQBJ8BwmKvwFPVqfpTEIQ==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_colorblind" data-href="https://github.githubassets.com/assets/dark_colorblind-5e900c04c491.css" integrity="sha512-XpAMBMSRZ6RTXgepS8LjKiOeNK3BilRbv8qEiA/M3m+Q4GoqxtHedOI5BAZRikCzfBL4KWYvVzYZSZ8Gp/UnUg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_colorblind" data-href="https://github.githubassets.com/assets/light_colorblind-dc71761d9e0b.css" integrity="sha512-3HF2HZ4LgEIQm77yOzoeR20CX1n2cUQlcywscqF4s+5iplolajiHV7E5ranBwkX65jN9TNciHEVSYebQ+8xxEw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_high_contrast" data-href="https://github.githubassets.com/assets/light_high_contrast-f89f23dd3d24.css" integrity="sha512-+J8j3T0kbK9/sL3zbkCfPtgYcRD4qQfRbT6xnfOrOTjvz4zhr0M7AXPuE642PpaxGhHs1t77cTtieW9hI2K6Gw==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="light_tritanopia" data-href="https://github.githubassets.com/assets/light_tritanopia-010780c79c07.css" integrity="sha512-AQeAx5wHQAXNf0DmkvVlHYwA3f6BkxunWTI0GGaRN57GqD+H9tW8RKIKlopLS0qGaC54seFsPc601GDlqIuuHg==" media="all" rel="stylesheet"/><link crossorigin="anonymous" data-color-theme="dark_tritanopia" data-href="https://github.githubassets.com/assets/dark_tritanopia-faee699a0004.css" integrity="sha512-+u5pmgAE0T03d/yI6Ha0NWwz6Pk0W6S6WEfIt8veDVdK8NTjcMbZmQB9XUCkDlrBoAKkABva8HuGJ+SzEpV1Uw==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/primer-10084108b209.css" integrity="sha512-EAhBCLIJ/pXHG3Y6yQhs9s53SHV80sjJ+yCwlQtfv7LaVkD+VoEuZBZ5betQJFUNj/5qBSfZk5GFtazEDzWLAg==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/global-a0f39d2ee1a4.css" integrity="sha512-oPOdLuGklyabk0ahpehbrOn2jEwWT5fIcgNPsUipsBIWjE4YWjMk8n4NDzJ135hL9jDhlewFHFtR38uZFsV8AA==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-f815d05d371a.css" integrity="sha512-+BXQXTcaoVpw6DQma9O1CCCIQiS9PZgyqRhSulibpIQIk0JhSfE6+hFl7fChAl+DmqKRE2lD3oO60mUTKYDpww==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-d31ea144555c.css" integrity="sha512-0x6hRFVcuRNWhPqCOFtXdE2J8WRLzi92vI37R/cnbEyw1JbgRkOIZv+hoYwk1Z+BnSLOwYorhPLm6jrWoV3c7Q==" media="all" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/explore-91bd47378abc.css" integrity="sha512-kb1HN4q8/AYgCEDRBJjoppyNOFO0ZKNJCPB7KNEEVlR6e4OLAZ4K3B0+0Z7Nns+WyRmXQLhf2Ub12ZQ+wUQn+w==" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-44mCWWd9he+TZlQdLzIEo+cbYo6tgMXkx8954MY/9DknkwxQmYGmKJrGKCgbWmcMYmBgxLX6uOEgcRoDL/5eCA==" src="https://github.githubassets.com/assets/runtime-e3898259677d.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ZXV4TpPmxfyBQ9eFqJaVR/Z8Rrt+f/In8yBbbMmt6pqCRMVcnlTWS7/Xy5aedmiIj1tNZXmsvW3cf/vRas/mvQ==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-74aed8-6575784e93e6.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-km+JVvSjuMukaGXFPj5OuzW1lNCVhWt0dB2EAkW4NpEj6x301u0l22+XLYaKm9+hvluGH0OlM6BE4hoTjxtFoQ==" src="https://github.githubassets.com/assets/environment-926f8956f4a3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-57NPhP0wWFMwvRygugK3iI3z+Sv0WTNy8MGBcwfMPYE7SoHKEoH1B89v+ANBqnW9GGvUYzf4gLT6UrP/VmhY2g==" src="https://github.githubassets.com/assets/vendors-node_modules_selector-observer_dist_index_esm_js-e7b34f84fd30.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Es25N4GyPa8Yfp5wpahoe5b2fyPtkRMyR6mKIXyCJC0ocqQazeWvxhGZhx3StRxOfqDfHDR5SS35u/R3Wux6Cg==" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-12cdb93781b2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-lmiecOIgf+hakg5oKMNM7grVhEDyPoIrT39Px448JJH5PSAaK21PH0Twgyz5O5oi8+dnlLr3Jt8bBCtAcpNdRw==" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-c7e9ed-96689e70e220.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-FhIi1nHjAzm1txsZ2LPPUfqIASARJ44qRQ09VSY4p/NVvWz/1reBy21+3an4fDIi6QhfrHNUI4ldKz3NW5by/Q==" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_time-elements_dist_index_js-161222d671e3.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-DE9GK/TS3Hf/dJfP1GMiyjvsGRnpR4A1eGH64s0Ot7Vy7Tj7/aD1d5EOMWHFWQXlXy/ZSwu5MHInG6RZN31bMA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-52e104-0c4f462bf4d2.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-fcVStVRolV54DldAqKbEzSE1OB6Rd/jIIpSj/dcCRRaSc8EgN68GT9sT/Ya0gtpNTq0aAPzs9OLlhWY7l0s4eA==" src="https://github.githubassets.com/assets/github-elements-7dc552b55468.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-n0EqohMRhyf2gYDkWAvqYJsBzb8qCciNwqGUpwOEjVfSLESviOFqm7IrHsihpfLAm+ZhteYJkQ+PPwqjJTUTrQ==" src="https://github.githubassets.com/assets/element-registry-9f412aa21311.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-ULHDrjH3Nz+5xGQnGJ+51ZBv5qENKe3TikjwAxKli4TyT+8KZ5mnWUJxUdXaFwRVMGRJD+8CjfCVhj7913OiOA==" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-50b1c3ae31f7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-XubU6uMX6y2ka6JR/QVSIS8aAdXBH9Jhm1lLCNFS5Dy3xbDEdS6W4ENFx71XaEAwW3d8xzgiS4cS0J/zsnYm6w==" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_github_catalyst_lib_index_-bd1f73-5ee6d4eae317.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-0r1nf/rfPz54kyePp4f63bcPxkFo7wyaUZJD/SwIVDK3q0WzurAK9ydOm88tzKtPJm8xWI0Vo25NyCfecwxJ9g==" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_github_hotkey_dist_index-9f48bd-d2bd677ffadf.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-b6LnssJjHkph4nI0CxyYnXJ/d7eWTCd6fDCQZkhXUwNTMcB55fwq4nPNUDdsFG3h/KS3VEsMjhkqC8jBcQVazA==" src="https://github.githubassets.com/assets/vendors-node_modules_github_paste-markdown_dist_index_esm_js-node_modules_github_quote-select-f71f15-6fa2e7b2c263.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-aD+lpuc5jHemEy0Cf2KYz46MdwOIlj3+2cZ59XIi+mentNdewI1LzaDqroNLJzONIiL4IeUUZ7hJzhPYV4DQVA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_pjax_ts-683fa5a6e739.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-i6G+/7pwOhMb9q+i08xUSvHWO8fWX9lkXtuIJQGpHGn299Mb74hWyc5ikFQAuqgd2i/cV9c5Jw6O9Z10jDfAwg==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_keyboard-shortcuts-helper_ts-app_assets_modules_github_be-af52ef-8ba1beffba70.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-sGIJsMNVLhivulsWgcWql7t/JEs3gUQQt/9GHRjArviQLj6smy1Cei4X6Bg51OC/rZMDXeTNSL733VSNtdlynA==" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_details_ts-app_assets_modules_github_behaviors_include-fr-019af8-b06209b0c355.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-1CN8HrSEXNbvvtNrIvzOMA1IkGwLyUOaFBl/N2UE91/8EvcqBFxy3M83mJVi/n50Kdq4oIRIeZG5D5oTpFTBDg==" src="https://github.githubassets.com/assets/behaviors-d4237c1eb484.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5nWr6hoxY6oc8ngCIfUbQS8h+5n8/1XZVb9KFgP0ak4NzsfM7ERe6b5639AYjyAbYZGs6I/7hC3eieSbWkHx9w==" src="https://github.githubassets.com/assets/notifications-global-e675abea1a31.js" type="application/javascript"></script>
# <title>postgresql · GitHub Topics · GitHub</title>
# <meta content="F7FB:79B9:4ECE9B:55B74E:62C441C1" data-pjax-transient="true" name="request-id"/><meta content="783e9a23cb467a4ce8b5dbf40637f55fb104a9c9f68721be13eedb2afaf847c0" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJGN0ZCOjc5Qjk6NEVDRTlCOjU1Qjc0RTo2MkM0NDFDMSIsInZpc2l0b3JfaWQiOiI2MjYxNDc1OTc0NTg0NzQ2NDMzIiwicmVnaW9uX2VkZ2UiOiJhcC1zb3V0aC0xIiwicmVnaW9uX3JlbmRlciI6ImFwLXNvdXRoLTEifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="26104946385cfffeace1512b3ae14924c4627f4e67810b2995435b01f25a7375" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/postgresql"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="33c2d34c9fa51786d8436810cca2bb9cee18d919dc2ea9489202d74626840bf8" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fpostgresql&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/postgresql;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/postgresql;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/postgresql;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/postgresql;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/postgresql;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/postgresql;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/postgresql;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/postgresql;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/postgresql;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/postgresql;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/postgresql;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/postgresql;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/postgresql;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/postgresql;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/postgresql;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/postgresql;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/postgresql;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/postgresql;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/postgresql;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/postgresql;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/postgresql;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/postgresql;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/postgresql;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/postgresql;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/postgresql;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/postgresql;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/postgresql;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/postgresql;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/postgresql;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/postgresql;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/postgresql;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/postgresql" aria-label="Site" class="js-site-search-form" data-scope-id="17184" data-scope-type="Topic" data-scoped-search-url="/topics/postgresql" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="nysDOjxN8t7CqaafWFCnzvK2mnNC98Tfh3I4HiUH/xC7yvyXxyn+cbFVXsMSlI9Xb3hWjfuxFcoBcLfVeFptsA=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# ...
#                     integration
# </a>
# <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-563617" hidden="hidden">New idea for the Integrations Contest</tool-tip>
# </div>
# </div>
# </div>
# </div>
# </article>
# <div class="px-3 pb-3">
# <article class="d-flex flex-justify-between mb-2">
# <div class="flex-auto">
# <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto h5 lh-condensed">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1268650111,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d0a34a5b90b4a4e9c8211a4ea8cc7e9a3bcefa1b7cfb0fbf52afab6227f30227" data-turbo="false" data-view-component="true" href="https://github.com/mindsdb/mindsdb/issues/2338">
#                     [New Integration]: Integration for Crime Analytics and Prediction with MindsDB
# </a> </h4>
# </div>
# </article>
# <article class="d-flex flex-justify-between mb-2">
# <div class="flex-auto">
# <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
# <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
# </svg> Open
# </span>
# <h4 class="d-inline flex-auto h5 lh-condensed">
# <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1268499065,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="bf8eb30317d0b9a344df69deabdc6088719aa63fc449e0a2ed02d9a7b51c70a4" data-turbo="false" data-view-component="true" href="https://github.com/mindsdb/mindsdb/issues/2337">
#                     [New Integration]: Integrate Elasticsearch and extend Tracardi inference process :+1: :+1: :+1:
# </a> </h4>
# </div>
# <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
# <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
# </svg>
#                   2
#                 </div>
# </article>
# <div class="mt-3">
# <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":143328315,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="bda2de827aa8ad945f3c90e5ba3146069171e43fd7afbc4a337d4f78a0720d94" data-turbo="false" data-view-component="true" href="/mindsdb/mindsdb/contribute">
#                 Find more good first issues
# </a> </div>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/postgresql" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Michael Stonebraker
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> July 8, 1996
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#         Repository
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to postgres/postgres, location:topic page" href="https://github.com/postgres/postgres">
# <span class="css-truncate css-truncate-target" title="postgres/postgres">
#           postgres/postgres
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="https://www.postgresql.org/">
# <span class="css-truncate css-truncate-target" title="www.postgresql.org">
#           www.postgresql.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/PostgreSQL">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/PostgreSQL">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'discourse'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'discourse'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text
stars
# Out:
# '36k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/discourse/discourse'

# %%
base_url='https://github.com/topics/postgresql'

# %%
base_url
# Out:
# 'https://github.com/topics/postgresql'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
Repository_page
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":3220138,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="049f521217c0288d7d7c412b422a0ac6e9c7e41ae95ae779939c4eab08a3ac42" data-turbo="false" data-view-component="true" href="/discourse">
#              discourse
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="1902bbf2a538e7a1e539968d6d76716b54da24f0b11f1f6af77d5364e6c2e2a6" data-turbo="false" data-view-component="true" href="/discourse/discourse">
#              discourse
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":7569578,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4646ed4871db6a5065c3f42584e87f39c9cde736e0d77fb27ba00010e26f5ae5" data-view-component="true" href="/login?return_to=%2Fdiscourse%2Fdiscourse" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="35966 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="35,966">36k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="57c15247795e8997472c976d5a7a7b68433693e16d277d12d7395d7bfd970b73" data-turbo="false" data-view-component="true" href="/discourse/discourse" id="code-tab-7569578">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="b3c7282b0a2eaa688cd8afa012bca7f0c044d0ebe95493f1acf0ce08bdc08ebc" data-turbo="false" data-view-component="true" href="/discourse/discourse/issues" id="issues-tab-7569578">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":7569578,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8ef07809546ccf3f2c011e790dba5018734ae8949e6caf112beb28f83cb0c75d" data-turbo="false" data-view-component="true" href="/discourse/discourse/pulls" id="pull-requests-tab-7569578">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>A platform for community discussion. Free, open, simple.</div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":40,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ebff047b7437bce70ff33431a19cb4cfe3b52b7e20f0cfe999b2ab074100332f" data-view-component="true" href="/topics/javascript" title="Topic: javascript">
#                javascript
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":45,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d7f5a46389b0af8a9e4e116e4e7f8946e1fcfca64ada0a4f1631d05adf22f8a9" data-view-component="true" href="/topics/ruby" title="Topic: ruby">
#                ruby
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":118,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="9cf0c94c65c1516a42d9eb65a87cac316acfa222a2dfa17ea2ba0f60d2eff2ce" data-view-component="true" href="/topics/rails" title="Topic: rails">
#                rails
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":188,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="068de9e10365a8b00d4cd2808e4bdd3c9cf3c91eb0ac61f57b4cf68363fb77cc" data-view-component="true" href="/topics/ember" title="Topic: ember">
#                ember
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":17184,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="491dafda42dc5c75aefde60b32e9debe78805ad6397f26c5eed62d8f92a3c420" data-view-component="true" href="/topics/postgresql" title="Topic: postgresql">
#                postgresql
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":20883,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="180c6b3d38f07f3d933d93e342601dbe9798391bd8bc99ff2b0aa688c2be7d2f" data-view-component="true" href="/topics/forum" title="Topic: forum">
#                forum
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22248,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ff06889c55ef7ec1d37b3f6d535ac53154db0d84dce296d69d184f515382fa9c" data-view-component="true" href="/topics/discourse" title="Topic: discourse">
#                discourse
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-07-05T13:04:03Z">Jul 5, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #701516"></span>
#  <span itemprop="programmingLanguage">Ruby</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a056ccac950a4c5fea5770cda5fd617afa1656fc6a1c1d0f7208e324d5e572c3" data-turbo="false" data-view-component="true" href="/supabase/supabase" style="max-height:275px">
#  <img alt="supabase" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/214587193/00f59f00-90a6-11eb-8764-f49e3f731458"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":54469796,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="059bc94a2e3a7526f6f7b61cad29ecc2f7da7b0f991fab9859284b7864504dc6" data-turbo="false" data-view-component="true" href="/supabase">
#              supabase
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4996f4e54abd06ab2a65970a1a189cb6c98e05e43241806f06fe8096fe8aaf81" data-turbo="false" data-view-component="true" href="/supabase/supabase">
#              supabase
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @supabase" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"supabase","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="15c08dbb7cebdb21cb59b0fdd319e728c55732c5637282db984bb5dff02069ff" data-view-component="true" href="/sponsors/supabase">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":214587193,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a03e8030caaad473e685e237c9b362043dc8eb699346ac4c54dd6bf239e02584" data-view-component="true" href="/login?return_to=%2Fsupabase%2Fsupabase" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="35041 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="35,041">35k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="301765909bf754b6ae03bf721624f7905445c202ebe6062d65265e38feab6422" data-turbo="false" data-view-component="true" href="/supabase/supabase" id="code-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="5fc5a86802734966d28910ae4d2b7b22775a66c95e1d398efe0add8313341614" data-turbo="false" data-view-component="true" href="/supabase/supabase/issues" id="issues-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="6200fb24e9512052ced80cff54a9538b8e458a76ecb403b95a4dfc2989f928b8" data-turbo="false" data-view-component="true" href="/supabase/supabase/pulls" id="pull-requests-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="16d8009fd418892127a736dadf4b48e3210e9203b7a6003cc72f2055e96284fa" data-turbo="false" data-view-component="true" href="/supabase/supabase/discussions" id="discussions-tab-214587193">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1292019000,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a2784ecf7548a5c3f359bbee3864e80880c1c514cf9232001a7ead0303490346" data-turbo="false" data-view-component="true" href="https://github.com/supabase/supabase/issues/7530">
#                  Navbar links 'Guides' and 'Reference' are both higlighted in green at the same time
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                2
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="ChristianLutzCL" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/30475783?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    ChristianLutzCL
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-07-02T10:01:41Z">Jul 2, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h1>Bug report</h1>
#  <h2>Describe the bug</h2>
#  <p>If you access the documentation via the start page or directly via '<a href="https://supabase.com/docs" rel="nofollow">https://supabase.com/docs</a>', and then go to the "Reference" page, the "Guides" and "Reference" links are highlighted in green.</p>
#  <h2>To Reproduce</h2>
#  <p>Steps to reproduce the behavior, please provide code snippets or a repository:</p>
#  <ol>
#  <li>Go to '<a href="https://supabase.com" rel="nofollow">https://supabase.com</a>'</li>
#  <li>Click on 'Developers'</li>
#  <li>C</li>
#  </ol>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1292019000,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ef4727524c854b8db333cf0e038432f6bdd6b3371931c6b293c97418348c5f0e" href="https://github.com/supabase/supabase/issues/7530">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1611370742,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="fec70d2e0d5d391c1418646e8b822776d72328952768cec6306e1485bad72c41" data-name="bug" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Abug" id="label-ea931a" style="--label-r:215;--label-g:58;--label-b:74;--label-h:353;--label-s:66;--label-l:53;">
#                      bug
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-ea931a" hidden="hidden">Something isn't working</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1611370746,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8b70a93f0a31763fa8b3af4bb26fd17d1606d96f6be8e01e44b65947cd27c11e" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-0ac753" style="--label-r:0;--label-g:134;--label-b:114;--label-h:171;--label-s:100;--label-l:26;">
#                      help wanted
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-0ac753" hidden="hidden">Extra attention is needed</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1611370747,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="97895d89521b1c3abf2821fd0132eb4176d2196a9ffe523d63e454840f8c8a8e" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-0c1023" style="--label-r:112;--label-g:87;--label-b:255;--label-h:248;--label-s:100;--label-l:67;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-0c1023" hidden="hidden">Good for newcomers</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1289885604,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="2e88b599074b7b3e111459787b725c6e3cf70af367ad9e146b0dd13f14e44c6e" data-turbo="false" data-view-component="true" href="https://github.com/supabase/supabase/issues/7508">
#                      Make contents of the table's "Description" field visible in Table Editor
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    5
#                  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1288031075,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="566201cf60d0a1462a0e3186280b0233d82a2d9e124bfd6c9469e444d97ba8f7" data-turbo="false" data-view-component="true" href="https://github.com/supabase/supabase/issues/7480">
#                      Fix outline on Docs callouts
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    2
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":214587193,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="e50b7c7e5a552c2d3d89238596b6b1f961861d420081676be27c3cfe0b68bb55" data-turbo="false" data-view-component="true" href="/supabase/supabase/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>,
#  <article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":10520629,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="527770669531b91043ec8886b8aa0f43882423ab02035aaeb4f6fd9efec97691" data-turbo="false" data-view-component="true" href="/metabase">
#              metabase
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="6a797b881a4f796ee0627f7ba02ca2f2f931477937fe2168efd6bd68c255ad2f" data-turbo="false" data-view-component="true" href="/metabase/metabase">
#              metabase
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":30203935,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8c6ee94a704ddddf41d4c61276285bce35f2770908ce3a8170eb360d597a0e47" data-view-component="true" href="/login?return_to=%2Fmetabase%2Fmetabase" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="29026 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="29,026">29k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="c704af3f578bd9d03933aa60210378f6c54f6ac7e26ea0576f493da5e65d6d13" data-turbo="false" data-view-component="true" href="/metabase/metabase" id="code-tab-30203935">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-default" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="e92e0a5825207d8bdf3c54c289e8871268c6a64196cc77e47eef7e10ea0bec9c" data-turbo="false" data-view-component="true" href="/metabase/metabase/issues" id="issues-tab-30203935">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-light" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":30203935,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="c35b00e29a0ff655fb6e277eb9cbd003f1c15524f0d765932bb40ac6d17e186c" data-turbo="false" data-view-component="true" href="/metabase/metabase/pulls" id="pull-requests-tab-30203935">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <div class="px-3 pt-3">
#  <p class="color-fg-muted mb-0"></p><div>The simplest, fastest way to get business intelligence and analytics  to everyone in your company <g-emoji alias="yum" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f60b.png">😋</g-emoji>
#  </div>
#  </div>
#  <div class="d-flex flex-wrap border-bottom color-border-muted px-3 pt-2 pb-2">
#  <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":22,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="ab756594950fd1651e8e9ba091011e1dc1c26250c423927c8033e22d6e93dc91" data-view-component="true" href="/topics/visualization" title="Topic: visualization">
#                visualization
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":42,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="a15c9305aaca063a9eb078d9e1a65cf55996b3811d87d1f37cd9fb59cedc136a" data-view-component="true" href="/topics/mysql" title="Topic: mysql">
#                mysql
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":241,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="9335c60e5fb58f48e3ec476eae248c7e6836828e926406f5c420bcc8e091eb46" data-view-component="true" href="/topics/slack" title="Topic: slack">
#                slack
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":831,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="4866435a14079bbe7d47b42a663d09879f4ec54840adda073a7856b7005635ec" data-view-component="true" href="/topics/postgres" title="Topic: postgres">
#                postgres
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2131,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="702fdaa7da1e8784cfb31466c2b01242924323b9c255fe47daf0a6840e7cc3c4" data-view-component="true" href="/topics/data" title="Topic: data">
#                data
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":2340,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="1e6556d1d50e278e2eaf459771d8c52441a3038507a1effae5d4f80a59fdd44a" data-view-component="true" href="/topics/clojure" title="Topic: clojure">
#                clojure
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":8897,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="71682c5feb5927e5c92a8a0c6c9d59036e0551f215d287a6733e3396dad4ecdf" data-view-component="true" href="/topics/bi" title="Topic: bi">
#                bi
# ...
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":143328315,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="761c0907cb3cf42e5090e7cb2d5d0a21e83c4161843affd11cd6741393a40e8f" data-turbo="false" data-view-component="true" href="/mindsdb/mindsdb/issues" id="issues-tab-143328315">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":143328315,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="779f8b2376fbaa483eb68911e3ff8734f32f9afe2701ca72fb56e3568b3b314c" data-turbo="false" data-view-component="true" href="/mindsdb/mindsdb/pulls" id="pull-requests-tab-143328315">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":143328315,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="cae9b38df3eea610040f657bcc6fcf3dae6f35f33a6255b59e476bd48719fe27" data-turbo="false" data-view-component="true" href="/mindsdb/mindsdb/discussions" id="discussions-tab-143328315">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1291744190,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="02a7a4bc2a55b2d13a07bbf99d1d50f4a7f3094326940c0b9c362ebf51f6f498" data-turbo="false" data-view-component="true" href="https://github.com/mindsdb/mindsdb/issues/2425">
#                  [New Integration]: Store files in AWS S3 and Google Cloud Storage
#  </a> </h4>
#  </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="EZFRICA" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/35665767?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    EZFRICA
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2022-07-01T19:04:32Z">Jul 1, 2022</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h3>Is there an existing integration?</h3>
#  <ul class="contains-task-list">
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> I have searched the existing integrations.</li>
#  </ul>
#  <h3>Use Case</h3>
#  <p>This will allow to host the software on a serverless and stateless service. This will facilitate scaling because no critical data will be on the disk of the system running the application.</p>
#  <h3>Motivation</h3>
#  <p>Allow users to save resources and money.</p>
#  <h3>Implementation</h3>
#  <p><em>No response</em></p>
#  <h3>Anything e</h3>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":1291744190,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="8e84564125fa38507d4e1e1b2bf558e351ea3e392e0a7b50148898d2692f0d67" href="https://github.com/mindsdb/mindsdb/issues/2425">
#                        Read more
#  </a> </div>
#  </div>
#  </div>
#  <div class="mt-3">
#  <span class="discussion-item-icon border-white-fade ml-0 mr-2">
#  <svg aria-hidden="true" class="octicon octicon-tag" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.5 7.775V2.75a.25.25 0 01.25-.25h5.025a.25.25 0 01.177.073l6.25 6.25a.25.25 0 010 .354l-5.025 5.025a.25.25 0 01-.354 0l-6.25-6.25a.25.25 0 01-.073-.177zm-1.5 0V2.75C1 1.784 1.784 1 2.75 1h5.025c.464 0 .91.184 1.238.513l6.25 6.25a1.75 1.75 0 010 2.474l-5.026 5.026a1.75 1.75 0 01-2.474 0l-6.25-6.25A1.75 1.75 0 011 7.775zM6 5a1 1 0 100 2 1 1 0 000-2z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <div class="lh-condensed">
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1012843360,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="6f94be14709c8c5b04f447ef97eedc6f4538a7e50df58a4f2083f2a6f43f85c6" data-name="enhancement" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Aenhancement" id="label-9c7427" style="--label-r:162;--label-g:238;--label-b:239;--label-h:180;--label-s:70;--label-l:78;">
#                      enhancement
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-9c7427" hidden="hidden">New feature or request</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1012843362,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="b2fb3743e97ef34618fe3c3b24a6c5c71c712df6129b39efe37681546c7892a0" data-name="help wanted" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22help+wanted%22" id="label-df6794" style="--label-r:0;--label-g:134;--label-b:114;--label-h:171;--label-s:100;--label-l:26;">
#                      help wanted
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-df6794" hidden="hidden">Extra attention is needed</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":1012843364,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d3a90b166832456b9f9c2da2aadc40550fb4155e7a7b34a5be025dee2d1d674c" data-name="good first issue" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3A%22good+first+issue%22" id="label-e637b6" style="--label-r:112;--label-g:87;--label-b:255;--label-h:248;--label-s:100;--label-l:67;">
#                      good first issue
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-e637b6" hidden="hidden">Good for newcomers</tool-tip>
#  <a class="IssueLabel hx_IssueLabel" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"CONTRIBUTE_PAGE","click_target":"LABEL_SCOPED_ISSUE_SEARCH","click_visual_representation":"LABEL_TAG","actor_id":null,"record_id":4186236223,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="0fa80eef2741a4f3954a69edc37c392302727a3ae55dfd8c0d9c876e738d5d0d" data-name="integration" data-turbo="false" data-view-component="true" href="/issues?q=is%3Aopen+is%3Aissue+label%3Aintegration" id="label-563617" style="--label-r:216;--label-g:237;--label-b:121;--label-h:70;--label-s:76;--label-l:70;">
#                      integration
#  </a>
#  <tool-tip data-direction="s" data-type="description" data-view-component="true" for="label-563617" hidden="hidden">New idea for the Integrations Contest</tool-tip>
#  </div>
#  </div>
#  </div>
#  </div>
#  </article>
#  <div class="px-3 pb-3">
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1268650111,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="d0a34a5b90b4a4e9c8211a4ea8cc7e9a3bcefa1b7cfb0fbf52afab6227f30227" data-turbo="false" data-view-component="true" href="https://github.com/mindsdb/mindsdb/issues/2338">
#                      [New Integration]: Integration for Crime Analytics and Prediction with MindsDB
#  </a> </h4>
#  </div>
#  </article>
#  <article class="d-flex flex-justify-between mb-2">
#  <div class="flex-auto">
#  <span class="State State--open State--small mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto h5 lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:small;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"LITTLE_GOOD_FIRST_ISSUE","actor_id":null,"record_id":1268499065,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="bf8eb30317d0b9a344df69deabdc6088719aa63fc449e0a2ed02d9a7b51c70a4" data-turbo="false" data-view-component="true" href="https://github.com/mindsdb/mindsdb/issues/2337">
#                      [New Integration]: Integrate Elasticsearch and extend Tracardi inference process :+1: :+1: :+1:
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                    2
#                  </div>
#  </article>
#  <div class="mt-3">
#  <a class="btn btn-outline btn-sm" data-ga-click="Explore, go to repository contribute, location:good first issues; text:more good first issues;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_CONTRIBUTE_PAGE","click_visual_representation":"CLICK_VISUAL_REPRESENTATION_UNKNOWN","actor_id":null,"record_id":143328315,"originating_url":"https://github.com/topics/postgresql","user_id":null}}' data-hydro-click-hmac="bda2de827aa8ad945f3c90e5ba3146069171e43fd7afbc4a337d4f78a0720d94" data-turbo="false" data-view-component="true" href="/mindsdb/mindsdb/contribute">
#                  Find more good first issues
#  </a> </div>
#  </div>
#  </div>
#  </article>]

# %%
base_url='https://github.com/topics/postgresql'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
Repository_1_lst
# Out:
# [{'Repository Name': 'discourse',
#   'User Name': 'discourse',
#   'stars': '36k',
#   'Repository URL': 'https://github.com/topics/postgresqldiscourse/discourse'},
#  {'Repository Name': 'supabase',
#   'User Name': 'supabase',
#   'stars': '35k',
#   'Repository URL': 'https://github.com/topics/postgresqlsupabase/supabase'},
#  {'Repository Name': 'metabase',
#   'User Name': 'metabase',
#   'stars': '29k',
#   'Repository URL': 'https://github.com/topics/postgresqlmetabase/metabase'},
#  {'Repository Name': 'typeorm',
#   'User Name': 'typeorm',
#   'stars': '28.7k',
#   'Repository URL': 'https://github.com/topics/postgresqltypeorm/typeorm'},
#  {'Repository Name': 'nocodb',
#   'User Name': 'nocodb',
#   'stars': '28.6k',
#   'Repository URL': 'https://github.com/topics/postgresqlnocodb/nocodb'},
#  {'Repository Name': 'dbeaver',
#   'User Name': 'dbeaver',
#   'stars': '27.2k',
#   'Repository URL': 'https://github.com/topics/postgresqldbeaver/dbeaver'},
#  {'Repository Name': 'sequelize',
#   'User Name': 'sequelize',
#   'stars': '26.4k',
#   'Repository URL': 'https://github.com/topics/postgresqlsequelize/sequelize'},
#  {'Repository Name': 'prisma',
#   'User Name': 'prisma',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/topics/postgresqlprisma/prisma'},
#  {'Repository Name': 'redash',
#   'User Name': 'getredash',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/topics/postgresqlgetredash/redash'},
#  {'Repository Name': 'postgrest',
#   'User Name': 'PostgREST',
#   'stars': '18.9k',
#   'Repository URL': 'https://github.com/topics/postgresqlPostgREST/postgrest'},
#  {'Repository Name': 'directus',
#   'User Name': 'directus',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/topics/postgresqldirectus/directus'},
#  {'Repository Name': 'shardingsphere',
#   'User Name': 'apache',
#   'stars': '16.2k',
#   'Repository URL': 'https://github.com/topics/postgresqlapache/shardingsphere'},
#  {'Repository Name': 'knex',
#   'User Name': 'knex',
#   'stars': '16k',
#   'Repository URL': 'https://github.com/topics/postgresqlknex/knex'},
#  {'Repository Name': 'Qix',
#   'User Name': 'ty4z2008',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/topics/postgresqlty4z2008/Qix'},
#  {'Repository Name': 'APIJSON',
#   'User Name': 'Tencent',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/topics/postgresqlTencent/APIJSON'},
#  {'Repository Name': 'cube.js',
#   'User Name': 'cube-js',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/topics/postgresqlcube-js/cube.js'},
#  {'Repository Name': 'timescaledb',
#   'User Name': 'timescale',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/topics/postgresqltimescale/timescaledb'},
#  {'Repository Name': 'mybatis-plus',
#   'User Name': 'baomidou',
#   'stars': '13.1k',
#   'Repository URL': 'https://github.com/topics/postgresqlbaomidou/mybatis-plus'},
#  {'Repository Name': 'NodeBB',
#   'User Name': 'NodeBB',
#   'stars': '12.7k',
#   'Repository URL': 'https://github.com/topics/postgresqlNodeBB/NodeBB'},
#  {'Repository Name': 'analytics',
#   'User Name': 'plausible',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/topics/postgresqlplausible/analytics'},
#  {'Repository Name': 'postgraphile',
#   'User Name': 'graphile',
#   'stars': '11.4k',
#   'Repository URL': 'https://github.com/topics/postgresqlgraphile/postgraphile'},
#  {'Repository Name': 'beekeeper-studio',
#   'User Name': 'beekeeper-studio',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/topics/postgresqlbeekeeper-studio/beekeeper-studio'},
#  {'Repository Name': 'node-postgres',
#   'User Name': 'brianc',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/topics/postgresqlbrianc/node-postgres'},
#  {'Repository Name': 'pgcli',
#   'User Name': 'dbcli',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/topics/postgresqldbcli/pgcli'},
#  {'Repository Name': 'full-stack-fastapi-postgresql',
#   'User Name': 'tiangolo',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/topics/postgresqltiangolo/full-stack-fastapi-postgresql'},
#  {'Repository Name': 'dogehouse',
#   'User Name': 'benawad',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/topics/postgresqlbenawad/dogehouse'},
#  {'Repository Name': 'questdb',
#   'User Name': 'questdb',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/topics/postgresqlquestdb/questdb'},
#  {'Repository Name': 'dbal',
#   'User Name': 'doctrine',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/topics/postgresqldoctrine/dbal'},
#  {'Repository Name': 'diesel',
#   'User Name': 'diesel-rs',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/topics/postgresqldiesel-rs/diesel'},
#  {'Repository Name': 'mindsdb',
#   'User Name': 'mindsdb',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/topics/postgresqlmindsdb/mindsdb'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                   Repository Name         User Name  stars  \
# 0                       discourse         discourse    36k
# 1                        supabase          supabase    35k
# 2                        metabase          metabase    29k
# 3                         typeorm           typeorm  28.7k
# 4                          nocodb            nocodb  28.6k
# 5                         dbeaver           dbeaver  27.2k
# 6                       sequelize         sequelize  26.4k
# 7                          prisma            prisma    24k
# 8                          redash         getredash  21.3k
# 9                       postgrest         PostgREST  18.9k
# 10                       directus          directus  16.7k
# 11                 shardingsphere            apache  16.2k
# 12                           knex              knex    16k
# 13                            Qix          ty4z2008  13.9k
# 14                        APIJSON           Tencent  13.5k
# 15                        cube.js           cube-js  13.3k
# 16                    timescaledb         timescale  13.3k
# 17                   mybatis-plus          baomidou  13.1k
# 18                         NodeBB            NodeBB  12.7k
# 19                      analytics         plausible  11.7k
# 20                   postgraphile          graphile  11.4k
# 21               beekeeper-studio  beekeeper-studio  10.6k
# 22                  node-postgres            brianc  10.5k
# 23                          pgcli             dbcli  10.5k
# 24  full-stack-fastapi-postgresql          tiangolo   9.3k
# 25                      dogehouse           benawad   9.2k
# 26                        questdb           questdb   8.8k
# 27                           dbal          doctrine   8.7k
# 28                         diesel         diesel-rs   8.7k
# 29                        mindsdb           mindsdb   8.3k
#
#                                        Repository URL
# 0   https://github.com/topics/postgresqldiscourse/...
# 1   https://github.com/topics/postgresqlsupabase/s...
# 2   https://github.com/topics/postgresqlmetabase/m...
# 3   https://github.com/topics/postgresqltypeorm/ty...
# 4   https://github.com/topics/postgresqlnocodb/nocodb
# 5   https://github.com/topics/postgresqldbeaver/db...
# 6   https://github.com/topics/postgresqlsequelize/...
# 7   https://github.com/topics/postgresqlprisma/prisma
# 8   https://github.com/topics/postgresqlgetredash/...
# 9   https://github.com/topics/postgresqlPostgREST/...
# 10  https://github.com/topics/postgresqldirectus/d...
# 11  https://github.com/topics/postgresqlapache/sha...
# 12      https://github.com/topics/postgresqlknex/knex
# 13   https://github.com/topics/postgresqlty4z2008/Qix
# 14  https://github.com/topics/postgresqlTencent/AP...
# 15  https://github.com/topics/postgresqlcube-js/cu...
# 16  https://github.com/topics/postgresqltimescale/...
# 17  https://github.com/topics/postgresqlbaomidou/m...
# 18  https://github.com/topics/postgresqlNodeBB/NodeBB
# 19  https://github.com/topics/postgresqlplausible/...
# 20  https://github.com/topics/postgresqlgraphile/p...
# 21  https://github.com/topics/postgresqlbeekeeper-...
# 22  https://github.com/topics/postgresqlbrianc/nod...
# 23    https://github.com/topics/postgresqldbcli/pgcli
# 24  https://github.com/topics/postgresqltiangolo/f...
# 25  https://github.com/topics/postgresqlbenawad/do...
# 26  https://github.com/topics/postgresqlquestdb/qu...
# 27  https://github.com/topics/postgresqldoctrine/dbal
# 28  https://github.com/topics/postgresqldiesel-rs/...
# 29  https://github.com/topics/postgresqlmindsdb/mi...

# %%
df.to_excel('postgresSqla.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/postgresql?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/postgresql?page=1',
#  'https://github.com/topics/postgresql?page=2',
#  'https://github.com/topics/postgresql?page=3',
#  'https://github.com/topics/postgresql?page=4',
#  'https://github.com/topics/postgresql?page=5',
#  'https://github.com/topics/postgresql?page=6',
#  'https://github.com/topics/postgresql?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/postgresql?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'discourse',
#   'User Name': 'discourse',
#   'stars': '36k',
#   'Repository URL': 'https://github.com/discourse/discourse'},
#  {'Sr No': 2,
#   'Repository Name': 'supabase',
#   'User Name': 'supabase',
#   'stars': '35k',
#   'Repository URL': 'https://github.com/supabase/supabase'},
#  {'Sr No': 3,
#   'Repository Name': 'metabase',
#   'User Name': 'metabase',
#   'stars': '29k',
#   'Repository URL': 'https://github.com/metabase/metabase'},
#  {'Sr No': 4,
#   'Repository Name': 'typeorm',
#   'User Name': 'typeorm',
#   'stars': '28.7k',
#   'Repository URL': 'https://github.com/typeorm/typeorm'},
#  {'Sr No': 5,
#   'Repository Name': 'nocodb',
#   'User Name': 'nocodb',
#   'stars': '28.6k',
#   'Repository URL': 'https://github.com/nocodb/nocodb'},
#  {'Sr No': 6,
#   'Repository Name': 'dbeaver',
#   'User Name': 'dbeaver',
#   'stars': '27.2k',
#   'Repository URL': 'https://github.com/dbeaver/dbeaver'},
#  {'Sr No': 7,
#   'Repository Name': 'sequelize',
#   'User Name': 'sequelize',
#   'stars': '26.4k',
#   'Repository URL': 'https://github.com/sequelize/sequelize'},
#  {'Sr No': 8,
#   'Repository Name': 'prisma',
#   'User Name': 'prisma',
#   'stars': '24k',
#   'Repository URL': 'https://github.com/prisma/prisma'},
#  {'Sr No': 9,
#   'Repository Name': 'redash',
#   'User Name': 'getredash',
#   'stars': '21.3k',
#   'Repository URL': 'https://github.com/getredash/redash'},
#  {'Sr No': 10,
#   'Repository Name': 'postgrest',
#   'User Name': 'PostgREST',
#   'stars': '18.9k',
#   'Repository URL': 'https://github.com/PostgREST/postgrest'},
#  {'Sr No': 11,
#   'Repository Name': 'directus',
#   'User Name': 'directus',
#   'stars': '16.7k',
#   'Repository URL': 'https://github.com/directus/directus'},
#  {'Sr No': 12,
#   'Repository Name': 'shardingsphere',
#   'User Name': 'apache',
#   'stars': '16.2k',
#   'Repository URL': 'https://github.com/apache/shardingsphere'},
#  {'Sr No': 13,
#   'Repository Name': 'knex',
#   'User Name': 'knex',
#   'stars': '16k',
#   'Repository URL': 'https://github.com/knex/knex'},
#  {'Sr No': 14,
#   'Repository Name': 'Qix',
#   'User Name': 'ty4z2008',
#   'stars': '13.9k',
#   'Repository URL': 'https://github.com/ty4z2008/Qix'},
#  {'Sr No': 15,
#   'Repository Name': 'APIJSON',
#   'User Name': 'Tencent',
#   'stars': '13.5k',
#   'Repository URL': 'https://github.com/Tencent/APIJSON'},
#  {'Sr No': 16,
#   'Repository Name': 'cube.js',
#   'User Name': 'cube-js',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/cube-js/cube.js'},
#  {'Sr No': 17,
#   'Repository Name': 'timescaledb',
#   'User Name': 'timescale',
#   'stars': '13.3k',
#   'Repository URL': 'https://github.com/timescale/timescaledb'},
#  {'Sr No': 18,
#   'Repository Name': 'mybatis-plus',
#   'User Name': 'baomidou',
#   'stars': '13.1k',
#   'Repository URL': 'https://github.com/baomidou/mybatis-plus'},
#  {'Sr No': 19,
#   'Repository Name': 'NodeBB',
#   'User Name': 'NodeBB',
#   'stars': '12.7k',
#   'Repository URL': 'https://github.com/NodeBB/NodeBB'},
#  {'Sr No': 20,
#   'Repository Name': 'analytics',
#   'User Name': 'plausible',
#   'stars': '11.7k',
#   'Repository URL': 'https://github.com/plausible/analytics'},
#  {'Sr No': 21,
#   'Repository Name': 'postgraphile',
#   'User Name': 'graphile',
#   'stars': '11.4k',
#   'Repository URL': 'https://github.com/graphile/postgraphile'},
#  {'Sr No': 22,
#   'Repository Name': 'beekeeper-studio',
#   'User Name': 'beekeeper-studio',
#   'stars': '10.6k',
#   'Repository URL': 'https://github.com/beekeeper-studio/beekeeper-studio'},
#  {'Sr No': 23,
#   'Repository Name': 'node-postgres',
#   'User Name': 'brianc',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/brianc/node-postgres'},
#  {'Sr No': 24,
#   'Repository Name': 'pgcli',
#   'User Name': 'dbcli',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/dbcli/pgcli'},
#  {'Sr No': 25,
#   'Repository Name': 'full-stack-fastapi-postgresql',
#   'User Name': 'tiangolo',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/tiangolo/full-stack-fastapi-postgresql'},
#  {'Sr No': 26,
#   'Repository Name': 'dogehouse',
#   'User Name': 'benawad',
#   'stars': '9.2k',
#   'Repository URL': 'https://github.com/benawad/dogehouse'},
#  {'Sr No': 27,
#   'Repository Name': 'questdb',
#   'User Name': 'questdb',
#   'stars': '8.8k',
#   'Repository URL': 'https://github.com/questdb/questdb'},
#  {'Sr No': 28,
#   'Repository Name': 'dbal',
#   'User Name': 'doctrine',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/doctrine/dbal'},
#  {'Sr No': 29,
#   'Repository Name': 'diesel',
#   'User Name': 'diesel-rs',
#   'stars': '8.7k',
#   'Repository URL': 'https://github.com/diesel-rs/diesel'},
#  {'Sr No': 30,
#   'Repository Name': 'mindsdb',
#   'User Name': 'mindsdb',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/mindsdb/mindsdb'},
#  {'Sr No': 31,
#   'Repository Name': 'awesome-postgres',
#   'User Name': 'dhamaniasad',
#   'stars': '7.9k',
#   'Repository URL': 'https://github.com/dhamaniasad/awesome-postgres'},
#  {'Sr No': 32,
#   'Repository Name': 'pgweb',
#   'User Name': 'sosedoff',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/sosedoff/pgweb'},
#  {'Sr No': 33,
#   'Repository Name': 'usql',
#   'User Name': 'xo',
#   'stars': '7.3k',
#   'Repository URL': 'https://github.com/xo/usql'},
#  {'Sr No': 34,
#   'Repository Name': 'azuredatastudio',
#   'User Name': 'microsoft',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/microsoft/azuredatastudio'},
#  {'Sr No': 35,
#   'Repository Name': 'citus',
#   'User Name': 'citusdata',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/citusdata/citus'},
#  {'Sr No': 36,
#   'Repository Name': 'blog',
#   'User Name': 'digoal',
#   'stars': '6.7k',
#   'Repository URL': 'https://github.com/digoal/blog'},
#  {'Sr No': 37,
#   'Repository Name': 'flyway',
#   'User Name': 'flyway',
#   'stars': '6.6k',
#   'Repository URL': 'https://github.com/flyway/flyway'},
#  {'Sr No': 38,
#   'Repository Name': 'xorm',
#   'User Name': 'go-xorm',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/go-xorm/xorm'},
#  {'Sr No': 39,
#   'Repository Name': 'sqlx',
#   'User Name': 'launchbadge',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/launchbadge/sqlx'},
#  {'Sr No': 40,
#   'Repository Name': 'bookshelf',
#   'User Name': 'bookshelf',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/bookshelf/bookshelf'},
#  {'Sr No': 41,
#   'Repository Name': 'NewsBlur',
#   'User Name': 'samuelclay',
#   'stars': '6k',
#   'Repository URL': 'https://github.com/samuelclay/NewsBlur'},
#  {'Sr No': 42,
#   'Repository Name': 'sqlc',
#   'User Name': 'kyleconroy',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/kyleconroy/sqlc'},
#  {'Sr No': 43,
#   'Repository Name': 'dev-setup',
#   'User Name': 'donnemartin',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/donnemartin/dev-setup'},
#  {'Sr No': 44,
#   'Repository Name': 'asyncpg',
#   'User Name': 'MagicStack',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/MagicStack/asyncpg'},
#  {'Sr No': 45,
#   'Repository Name': 'adminer',
#   'User Name': 'vrana',
#   'stars': '5.3k',
#   'Repository URL': 'https://github.com/vrana/adminer'},
#  {'Sr No': 46,
#   'Repository Name': 'gpdb',
#   'User Name': 'greenplum-db',
#   'stars': '5.3k',
#   'Repository URL': 'https://github.com/greenplum-db/gpdb'},
#  {'Sr No': 47,
#   'Repository Name': 'pg',
#   'User Name': 'go-pg',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/go-pg/pg'},
#  {'Sr No': 48,
#   'Repository Name': 'realtime',
#   'User Name': 'supabase',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/supabase/realtime'},
#  {'Sr No': 49,
#   'Repository Name': 'sqlboiler',
#   'User Name': 'volatiletech',
#   'stars': '5k',
#   'Repository URL': 'https://github.com/volatiletech/sqlboiler'},
#  {'Sr No': 50,
#   'Repository Name': 'jOOQ',
#   'User Name': 'jOOQ',
#   'stars': '5k',
#   'Repository URL': 'https://github.com/jOOQ/jOOQ'},
#  {'Sr No': 51,
#   'Repository Name': 'openreplay',
#   'User Name': 'openreplay',
#   'stars': '5k',
#   'Repository URL': 'https://github.com/openreplay/openreplay'},
#  {'Sr No': 52,
#   'Repository Name': 'falcon',
#   'User Name': 'plotly',
#   'stars': '4.9k',
#   'Repository URL': 'https://github.com/plotly/falcon'},
#  {'Sr No': 53,
#   'Repository Name': 'patroni',
#   'User Name': 'zalando',
#   'stars': '4.8k',
#   'Repository URL': 'https://github.com/zalando/patroni'},
#  {'Sr No': 54,
#   'Repository Name': 'mikro-orm',
#   'User Name': 'mikro-orm',
#   'stars': '4.7k',
#   'Repository URL': 'https://github.com/mikro-orm/mikro-orm'},
#  {'Sr No': 55,
#   'Repository Name': 'backup',
#   'User Name': 'backup',
#   'stars': '4.7k',
#   'Repository URL': 'https://github.com/backup/backup'},
#  {'Sr No': 56,
#   'Repository Name': 'sysbench',
#   'User Name': 'akopytov',
#   'stars': '4.6k',
#   'Repository URL': 'https://github.com/akopytov/sysbench'},
#  {'Sr No': 57,
#   'Repository Name': 'FerretDB',
#   'User Name': 'FerretDB',
#   'stars': '4.5k',
#   'Repository URL': 'https://github.com/FerretDB/FerretDB'},
#  {'Sr No': 58,
#   'Repository Name': 'react-firebase-starter',
#   'User Name': 'kriasoft',
#   'stars': '4.4k',
#   'Repository URL': 'https://github.com/kriasoft/react-firebase-starter'},
#  {'Sr No': 59,
#   'Repository Name': 'materialize',
#   'User Name': 'MaterializeInc',
#   'stars': '4.2k',
#   'Repository URL': 'https://github.com/MaterializeInc/materialize'},
#  {'Sr No': 60,
#   'Repository Name': 'bolt',
#   'User Name': 'bolt',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/bolt/bolt'},
#  {'Sr No': 61,
#   'Repository Name': 'postgres',
#   'User Name': 'porsager',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/porsager/postgres'},
#  {'Sr No': 62,
#   'Repository Name': 'SqlSugar',
#   'User Name': 'donet5',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/donet5/SqlSugar'},
#  {'Sr No': 63,
#   'Repository Name': 'zombodb',
#   'User Name': 'zombodb',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/zombodb/zombodb'},
#  {'Sr No': 64,
#   'Repository Name': 'pgloader',
#   'User Name': 'dimitri',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/dimitri/pgloader'},
#  {'Sr No': 65,
#   'Repository Name': 'coolify',
#   'User Name': 'coollabsio',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/coollabsio/coolify'},
#  {'Sr No': 66,
#   'Repository Name': 'franchise',
#   'User Name': 'HVF',
#   'stars': '3.9k',
#   'Repository URL': 'https://github.com/HVF/franchise'},
#  {'Sr No': 67,
#   'Repository Name': 'devilbox',
#   'User Name': 'cytopia',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/cytopia/devilbox'},
#  {'Sr No': 68,
#   'Repository Name': 'v2',
#   'User Name': 'miniflux',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/miniflux/v2'},
#  {'Sr No': 69,
#   'Repository Name': 'JSqlParser',
#   'User Name': 'JSQLParser',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/JSQLParser/JSqlParser'},
#  {'Sr No': 70,
#   'Repository Name': 'stolon',
#   'User Name': 'sorintlab',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/sorintlab/stolon'},
#  {'Sr No': 71,
#   'Repository Name': 'relay-starter-kit',
#   'User Name': 'kriasoft',
#   'stars': '3.6k',
#   'Repository URL': 'https://github.com/kriasoft/relay-starter-kit'},
#  {'Sr No': 72,
#   'Repository Name': 'neon',
#   'User Name': 'neondatabase',
#   'stars': '3.5k',
#   'Repository URL': 'https://github.com/neondatabase/neon'},
#  {'Sr No': 73,
#   'Repository Name': 'ihp',
#   'User Name': 'digitallyinduced',
#   'stars': '3.4k',
#   'Repository URL': 'https://github.com/digitallyinduced/ihp'},
#  {'Sr No': 74,
#   'Repository Name': 'wal-e',
#   'User Name': 'wal-e',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/wal-e/wal-e'},
#  {'Sr No': 75,
#   'Repository Name': 'FreeSql',
#   'User Name': 'dotnetcore',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/dotnetcore/FreeSql'},
#  {'Sr No': 76,
#   'Repository Name': 'dolibarr',
#   'User Name': 'Dolibarr',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/Dolibarr/dolibarr'},
#  {'Sr No': 77,
#   'Repository Name': 'HeidiSQL',
#   'User Name': 'HeidiSQL',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/HeidiSQL/HeidiSQL'},
#  {'Sr No': 78,
#   'Repository Name': 'prest',
#   'User Name': 'prest',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/prest/prest'},
#  {'Sr No': 79,
#   'Repository Name': 'pg-promise',
#   'User Name': 'vitaly-t',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/vitaly-t/pg-promise'},
#  {'Sr No': 80,
#   'Repository Name': 'octosql',
#   'User Name': 'cube2222',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/cube2222/octosql'},
#  {'Sr No': 81,
#   'Repository Name': 'xo',
#   'User Name': 'xo',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/xo/xo'},
#  {'Sr No': 82,
#   'Repository Name': 'db',
#   'User Name': 'upper',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/upper/db'},
#  {'Sr No': 83,
#   'Repository Name': 'slonik',
#   'User Name': 'gajus',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/gajus/slonik'},
#  {'Sr No': 84,
#   'Repository Name': 'node-orm2',
#   'User Name': 'dresende',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/dresende/node-orm2'},
#  {'Sr No': 85,
#   'Repository Name': 'encore',
#   'User Name': 'encoredev',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/encoredev/encore'},
#  {'Sr No': 86,
#   'Repository Name': 'bytebase',
#   'User Name': 'bytebase',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/bytebase/bytebase'},
#  {'Sr No': 87,
#   'Repository Name': 'php-crud-api',
#   'User Name': 'mevdschee',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/mevdschee/php-crud-api'},
#  {'Sr No': 88,
#   'Repository Name': 'tortoise-orm',
#   'User Name': 'tortoise',
#   'stars': '2.9k',
#   'Repository URL': 'https://github.com/tortoise/tortoise-orm'},
#  {'Sr No': 89,
#   'Repository Name': 'pony',
#   'User Name': 'ponyorm',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/ponyorm/pony'},
#  {'Sr No': 90,
#   'Repository Name': 'postgres-operator',
#   'User Name': 'CrunchyData',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/CrunchyData/postgres-operator'},
#  {'Sr No': 91,
#   'Repository Name': 'sequelize-docs-Zh-CN',
#   'User Name': 'demopark',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/demopark/sequelize-docs-Zh-CN'},
#  {'Sr No': 92,
#   'Repository Name': 'formspree',
#   'User Name': 'formspree',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/formspree/formspree'},
#  {'Sr No': 93,
#   'Repository Name': 'goose',
#   'User Name': 'pressly',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/pressly/goose'},
#  {'Sr No': 94,
#   'Repository Name': 'TablePlus',
#   'User Name': 'TablePlus',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/TablePlus/TablePlus'},
#  {'Sr No': 95,
#   'Repository Name': 'pgbadger',
#   'User Name': 'darold',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/darold/pgbadger'},
#  {'Sr No': 96,
#   'Repository Name': 'dbmate',
#   'User Name': 'amacneil',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/amacneil/dbmate'},
#  {'Sr No': 97,
#   'Repository Name': 'EFCore.BulkExtensions',
#   'User Name': 'borisdj',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/borisdj/EFCore.BulkExtensions'},
#  {'Sr No': 98,
#   'Repository Name': 'psycopg2',
#   'User Name': 'psycopg',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/psycopg/psycopg2'},
#  {'Sr No': 99,
#   'Repository Name': 'postgres-operator',
#   'User Name': 'zalando',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/zalando/postgres-operator'},
#  {'Sr No': 100,
#   'Repository Name': 'notadd',
#   'User Name': 'notadd',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/notadd/notadd'},
#  {'Sr No': 101,
#   'Repository Name': 'npgsql',
#   'User Name': 'npgsql',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/npgsql/npgsql'},
#  {'Sr No': 102,
#   'Repository Name': 'migra',
#   'User Name': 'djrobstep',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/djrobstep/migra'},
#  {'Sr No': 103,
#   'Repository Name': 'massive-js',
#   'User Name': 'dmfay',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/dmfay/massive-js'},
#  {'Sr No': 104,
#   'Repository Name': 'scala-exercises',
#   'User Name': 'scala-exercises',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/scala-exercises/scala-exercises'},
#  {'Sr No': 105,
#   'Repository Name': 'pipelinedb',
#   'User Name': 'pipelinedb',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/pipelinedb/pipelinedb'},
#  {'Sr No': 106,
#   'Repository Name': 'pgmodeler',
#   'User Name': 'pgmodeler',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/pgmodeler/pgmodeler'},
#  {'Sr No': 107,
#   'Repository Name': 'changelog.com',
#   'User Name': 'thechangelog',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/thechangelog/changelog.com'},
#  {'Sr No': 108,
#   'Repository Name': 'sqitch',
#   'User Name': 'sqitchers',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/sqitchers/sqitch'},
#  {'Sr No': 109,
#   'Repository Name': 'linq2db',
#   'User Name': 'linq2db',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/linq2db/linq2db'},
#  {'Sr No': 110,
#   'Repository Name': 'PolarDB-for-PostgreSQL',
#   'User Name': 'ApsaraDB',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/ApsaraDB/PolarDB-for-PostgreSQL'},
#  {'Sr No': 111,
#   'Repository Name': 'pgsync',
#   'User Name': 'ankane',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/ankane/pgsync'},
#  {'Sr No': 112,
#   'Repository Name': 'datastation',
#   'User Name': 'multiprocessio',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/multiprocessio/datastation'},
#  {'Sr No': 113,
#   'Repository Name': 'postgresqltuner',
#   'User Name': 'jfcoz',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/jfcoz/postgresqltuner'},
#  {'Sr No': 114,
#   'Repository Name': 'querybuilder',
#   'User Name': 'sqlkata',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/sqlkata/querybuilder'},
#  {'Sr No': 115,
#   'Repository Name': 'graphjin',
#   'User Name': 'dosco',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/dosco/graphjin'},
#  {'Sr No': 116,
#   'Repository Name': 'tsung',
#   'User Name': 'processone',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/processone/tsung'},
#  {'Sr No': 117,
#   'Repository Name': 'wal-g',
#   'User Name': 'wal-g',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/wal-g/wal-g'},
#  {'Sr No': 118,
#   'Repository Name': 'sqlcheck',
#   'User Name': 'jarulraj',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/jarulraj/sqlcheck'},
#  {'Sr No': 119,
#   'Repository Name': 'coolstore-microservices',
#   'User Name': 'vietnam-devs',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/vietnam-devs/coolstore-microservices'},
#  {'Sr No': 120,
#   'Repository Name': 'algernon',
#   'User Name': 'xyproto',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/xyproto/algernon'},
#  {'Sr No': 121,
#   'Repository Name': 'webapp.rs',
#   'User Name': 'saschagrunert',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/saschagrunert/webapp.rs'},
#  {'Sr No': 122,
#   'Repository Name': 'sqler',
#   'User Name': 'alash3al',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/alash3al/sqler'},
#  {'Sr No': 123,
#   'Repository Name': 'Gopherus',
#   'User Name': 'tarunkant',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/tarunkant/Gopherus'},
#  {'Sr No': 124,
#   'Repository Name': 'pg_graphql',
#   'User Name': 'supabase',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/supabase/pg_graphql'},
#  {'Sr No': 125,
#   'Repository Name': 'mara-pipelines',
#   'User Name': 'mara',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/mara/mara-pipelines'},
#  {'Sr No': 126,
#   'Repository Name': 'ibis',
#   'User Name': 'ibis-project',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/ibis-project/ibis'},
#  {'Sr No': 127,
#   'Repository Name': 'sqorn',
#   'User Name': 'sqorn',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/sqorn/sqorn'},
#  {'Sr No': 128,
#   'Repository Name': 'fastapi-realworld-example-app',
#   'User Name': 'nsidnev',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/nsidnev/fastapi-realworld-example-app'},
#  {'Sr No': 129,
#   'Repository Name': 'pspg',
#   'User Name': 'okbob',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/okbob/pspg'},
#  {'Sr No': 130,
#   'Repository Name': 'steampipe',
#   'User Name': 'turbot',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/turbot/steampipe'},
#  {'Sr No': 131,
#   'Repository Name': 'denodb',
#   'User Name': 'eveningkid',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/eveningkid/denodb'},
#  {'Sr No': 132,
#   'Repository Name': 'cstore_fdw',
#   'User Name': 'citusdata',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/citusdata/cstore_fdw'},
#  {'Sr No': 133,
#   'Repository Name': 'pgbouncer',
#   'User Name': 'pgbouncer',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/pgbouncer/pgbouncer'},
#  {'Sr No': 134,
#   'Repository Name': 'pg_cron',
#   'User Name': 'citusdata',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/citusdata/pg_cron'},
#  {'Sr No': 135,
#   'Repository Name': 'Replibyte',
#   'User Name': 'Qovery',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/Qovery/Replibyte'},
#  {'Sr No': 136,
#   'Repository Name': 'backup-manager',
#   'User Name': 'backup-manager',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/backup-manager/backup-manager'},
#  {'Sr No': 137,
#   'Repository Name': 'goqu',
#   'User Name': 'doug-martin',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/doug-martin/goqu'},
#  {'Sr No': 138,
#   'Repository Name': 'dbgate',
#   'User Name': 'dbgate',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/dbgate/dbgate'},
#  {'Sr No': 139,
#   'Repository Name': 'ServiceStack.OrmLite',
#   'User Name': 'ServiceStack',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/ServiceStack/ServiceStack.OrmLite'},
#  {'Sr No': 140,
#   'Repository Name': 'pev2',
#   'User Name': 'dalibo',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/dalibo/pev2'},
#  {'Sr No': 141,
#   'Repository Name': 'pgx',
#   'User Name': 'tcdi',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/tcdi/pgx'},
#  {'Sr No': 142,
#   'Repository Name': 'pg_activity',
#   'User Name': 'dalibo',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/dalibo/pg_activity'},
#  {'Sr No': 143,
#   'Repository Name': 'plv8',
#   'User Name': 'plv8',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/plv8/plv8'},
#  {'Sr No': 144,
#   'Repository Name': 'pg_flame',
#   'User Name': 'mgartner',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/mgartner/pg_flame'},
#  {'Sr No': 145,
#   'Repository Name': 'logica',
#   'User Name': 'EvgSkv',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/EvgSkv/logica'},
#  {'Sr No': 146,
#   'Repository Name': 'starter',
#   'User Name': 'graphile',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/graphile/starter'},
#  {'Sr No': 147,
#   'Repository Name': 'postgresml',
#   'User Name': 'postgresml',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/postgresml/postgresml'},
#  {'Sr No': 148,
#   'Repository Name': 'pgtune',
#   'User Name': 'le0pard',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/le0pard/pgtune'},
#  {'Sr No': 149,
#   'Repository Name': 'tbls',
#   'User Name': 'k1LoW',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/k1LoW/tbls'},
#  {'Sr No': 150,
#   'Repository Name': 'pgcenter',
#   'User Name': 'lesovsky',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/lesovsky/pgcenter'},
#  {'Sr No': 151,
#   'Repository Name': 'ElectroCRUD',
#   'User Name': 'garrylachman',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/garrylachman/ElectroCRUD'},
#  {'Sr No': 152,
#   'Repository Name': 'Chloe',
#   'User Name': 'shuxinqin',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/shuxinqin/Chloe'},
#  {'Sr No': 153,
#   'Repository Name': 'barman',
#   'User Name': 'EnterpriseDB',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/EnterpriseDB/barman'},
#  {'Sr No': 154,
#   'Repository Name': 'pg_partman',
#   'User Name': 'pgpartman',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/pgpartman/pg_partman'},
#  {'Sr No': 155,
#   'Repository Name': 'reshape',
#   'User Name': 'fabianlindfors',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/fabianlindfors/reshape'},
#  {'Sr No': 156,
#   'Repository Name': 'repmgr',
#   'User Name': 'EnterpriseDB',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/EnterpriseDB/repmgr'},
#  {'Sr No': 157,
#   'Repository Name': 'pgwatch2',
#   'User Name': 'cybertec-postgresql',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/cybertec-postgresql/pgwatch2'},
#  {'Sr No': 158,
#   'Repository Name': 'postbird',
#   'User Name': 'Paxa',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/Paxa/postbird'},
#  {'Sr No': 159,
#   'Repository Name': 'database-lab-engine',
#   'User Name': 'postgres-ai',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/postgres-ai/database-lab-engine'},
#  {'Sr No': 160,
#   'Repository Name': 'aiopg',
#   'User Name': 'aio-libs',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/aio-libs/aiopg'},
#  {'Sr No': 161,
#   'Repository Name': 'logidze',
#   'User Name': 'palkan',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/palkan/logidze'},
#  {'Sr No': 162,
#   'Repository Name': 'sqldef',
#   'User Name': 'k0kubun',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/k0kubun/sqldef'},
#  {'Sr No': 163,
#   'Repository Name': 'motor-admin',
#   'User Name': 'motor-admin',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/motor-admin/motor-admin'},
#  {'Sr No': 164,
#   'Repository Name': 'prisma-client-go',
#   'User Name': 'prisma',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/prisma/prisma-client-go'},
#  {'Sr No': 165,
#   'Repository Name': 'transporter',
#   'User Name': 'compose',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/compose/transporter'},
#  {'Sr No': 166,
#   'Repository Name': 'bank',
#   'User Name': 'pietrzakadrian',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/pietrzakadrian/bank'},
#  {'Sr No': 167,
#   'Repository Name': 'pgbackrest',
#   'User Name': 'pgbackrest',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/pgbackrest/pgbackrest'},
#  {'Sr No': 168,
#   'Repository Name': 'docs4dev',
#   'User Name': 'docs4dev',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/docs4dev/docs4dev'},
#  {'Sr No': 169,
#   'Repository Name': 'pop',
#   'User Name': 'gobuffalo',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/gobuffalo/pop'},
#  {'Sr No': 170,
#   'Repository Name': 'fapro',
#   'User Name': 'fofapro',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/fofapro/fapro'},
#  {'Sr No': 171,
#   'Repository Name': 'scalikejdbc',
#   'User Name': 'scalikejdbc',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/scalikejdbc/scalikejdbc'},
#  {'Sr No': 172,
#   'Repository Name': 'trdsql',
#   'User Name': 'noborus',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/noborus/trdsql'},
#  {'Sr No': 173,
#   'Repository Name': 'agensgraph',
#   'User Name': 'bitnine-oss',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/bitnine-oss/agensgraph'},
#  {'Sr No': 174,
#   'Repository Name': 'bun',
#   'User Name': 'uptrace',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/uptrace/bun'},
#  {'Sr No': 175,
#   'Repository Name': 'postgis',
#   'User Name': 'postgis',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/postgis/postgis'},
#  {'Sr No': 176,
#   'Repository Name': 'data-diff',
#   'User Name': 'datafold',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/datafold/data-diff'},
#  {'Sr No': 177,
#   'Repository Name': 'fullstack-apollo-express-postgresql-boilerplate',
#   'User Name': 'the-road-to-graphql',
#   'stars': '1.2k',
#   'Repository URL': 'https://github.com/the-road-to-graphql/fullstack-apollo-express-postgresql-boilerplate'},
#  {'Sr No': 178,
#   'Repository Name': 'metasfresh',
#   'User Name': 'metasfresh',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/metasfresh/metasfresh'},
#  {'Sr No': 179,
#   'Repository Name': 'pghoard',
#   'User Name': 'aiven',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/aiven/pghoard'},
#  {'Sr No': 180,
#   'Repository Name': 'docker-tutorial',
#   'User Name': 'twtrubiks',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/twtrubiks/docker-tutorial'},
#  {'Sr No': 181,
#   'Repository Name': 'soci',
#   'User Name': 'SOCI',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/SOCI/soci'},
#  {'Sr No': 182,
#   'Repository Name': 'pgjdbc',
#   'User Name': 'pgjdbc',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/pgjdbc/pgjdbc'},
#  {'Sr No': 183,
#   'Repository Name': 'orioledb',
#   'User Name': 'orioledb',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/orioledb/orioledb'},
#  {'Sr No': 184,
#   'Repository Name': 'kysely',
#   'User Name': 'koskimas',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/koskimas/kysely'},
#  {'Sr No': 185,
#   'Repository Name': 'promscale',
#   'User Name': 'timescale',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/timescale/promscale'},
#  {'Sr No': 186,
#   'Repository Name': 'efcore.pg',
#   'User Name': 'npgsql',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/npgsql/efcore.pg'},
#  {'Sr No': 187,
#   'Repository Name': 'treefrog-framework',
#   'User Name': 'treefrogframework',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/treefrogframework/treefrog-framework'},
#  {'Sr No': 188,
#   'Repository Name': 'node-pg-migrate',
#   'User Name': 'salsita',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/salsita/node-pg-migrate'},
#  {'Sr No': 189,
#   'Repository Name': 'PostDock',
#   'User Name': 'paunin',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/paunin/PostDock'},
#  {'Sr No': 190,
#   'Repository Name': 'netkiller.github.io',
#   'User Name': 'netkiller',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/netkiller/netkiller.github.io'},
#  {'Sr No': 191,
#   'Repository Name': 'worker',
#   'User Name': 'graphile',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/graphile/worker'},
#  {'Sr No': 192,
#   'Repository Name': 'aquameta',
#   'User Name': 'aquametalabs',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/aquametalabs/aquameta'},
#  {'Sr No': 193,
#   'Repository Name': 'lithium',
#   'User Name': 'matt-42',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/matt-42/lithium'},
#  {'Sr No': 194,
#   'Repository Name': 'readyset',
#   'User Name': 'readysettech',
#   'stars': '1.1k',
#   'Repository URL': 'https://github.com/readysettech/readyset'},
#  {'Sr No': 195,
#   'Repository Name': 'kubegres',
#   'User Name': 'reactive-tech',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/reactive-tech/kubegres'},
#  {'Sr No': 196,
#   'Repository Name': 'docker-postgis',
#   'User Name': 'postgis',
#   'stars': '998',
#   'Repository URL': 'https://github.com/postgis/docker-postgis'},
#  {'Sr No': 197,
#   'Repository Name': 'Pizzly',
#   'User Name': 'Bearer',
#   'stars': '1k',
#   'Repository URL': 'https://github.com/Bearer/Pizzly'},
#  {'Sr No': 198,
#   'Repository Name': 'spilo',
#   'User Name': 'zalando',
#   'stars': '987',
#   'Repository URL': 'https://github.com/zalando/spilo'},
#  {'Sr No': 199,
#   'Repository Name': 'cocalc',
#   'User Name': 'sagemathinc',
#   'stars': '984',
#   'Repository URL': 'https://github.com/sagemathinc/cocalc'},
#  {'Sr No': 200,
#   'Repository Name': 'baserow',
#   'User Name': 'bram2w',
#   'stars': '979',
#   'Repository URL': 'https://github.com/bram2w/baserow'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No Repository Name    User Name  stars  \
# 0        1       discourse    discourse    36k
# 1        2        supabase     supabase    35k
# 2        3        metabase     metabase    29k
# 3        4         typeorm      typeorm  28.7k
# 4        5          nocodb       nocodb  28.6k
# ..     ...             ...          ...    ...
# 195    196  docker-postgis      postgis    998
# 196    197          Pizzly       Bearer     1k
# 197    198           spilo      zalando    987
# 198    199          cocalc  sagemathinc    984
# 199    200         baserow       bram2w    979
#
#                                 Repository URL
# 0       https://github.com/discourse/discourse
# 1         https://github.com/supabase/supabase
# 2         https://github.com/metabase/metabase
# 3           https://github.com/typeorm/typeorm
# 4             https://github.com/nocodb/nocodb
# ..                                         ...
# 195  https://github.com/postgis/docker-postgis
# 196           https://github.com/Bearer/Pizzly
# 197           https://github.com/zalando/spilo
# 198      https://github.com/sagemathinc/cocalc
# 199          https://github.com/bram2w/baserow
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_postgresSql.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
