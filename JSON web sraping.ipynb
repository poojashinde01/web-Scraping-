wicmVnaW9uX2VkZ2UiOiJhcC1zb3V0aC0xIiwicmVnaW9uX3JlbmRlciI6ImFwLXNvdXRoLTEifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="fb4812cb51a56e7d050cea71762a520a6b819b251f183f44e94161084d76ac1e" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="/topics/json"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="" name="user-login"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 83 million people use GitHub to discover, fork, and contribute to over 200 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="github.com" name="hostname"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="IMAGE_METRIC_TRACKING,GEOJSON_AZURE_MAPS" name="enabled-features"/>
# <meta content="2ef47f50a573d66fb21b10ec2d2ed4db8fbc03150446b37fec05fbec43512169" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="c224a14b7e42ef2e4c2b35c8dc3aa0c62077f8537be144b2a9c717f20b88c598" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="ca68c383111ae2bdf3846f2bb959b1ccc632871efa80f03714afc00024c4a733" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="12f34aa3adab8dba14618dc8ef7b1b39e025bf64156956251603245aff687188" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="no-preview" data-pjax-transient="" name="turbo-cache-control"/>
# <meta content="logged-out env-production page-responsive" name="turbo-body-classes"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-J6lR4iW7FvBnTJHgra5DhPqvM1qWXmgI8QRAMSZMaqbscHR4w3EfHJJ1FRDFVBm8bShmPNzvwF/17QHJnNhB6g==" src="https://github.githubassets.com/assets/sessions-27a951e225bb.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-lg d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="6130a162b5f3168ebf137856f1a5abe0b3c3edf23c53de809a30f93f9085f586" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2Ftopics%2Fjson&amp;source=header">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/topics/json;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/topics/json;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/topics/json;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/topics/json;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/topics/json;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/topics/json;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/topics/json;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/topics/json;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/topics/json;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/topics/json;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/json;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/topics/json;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/topics/json;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/topics/json;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/topics/json;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/topics/json;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/topics/json;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/topics/json;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/topics/json;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/topics/json;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/topics/json;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/topics/json;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/topics/json;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/topics/json;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/topics/json;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/topics/json;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/topics/json;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/topics/json;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/topics/json;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/topics/json;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/topics/json;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/topics/json" aria-label="Site" class="js-site-search-form" data-scope-id="2111" data-scope-type="Topic" data-scoped-search-url="/topics/json" data-turbo="false" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-expanded="false" aria-haspopup="listbox" aria-label="Search" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search" data-test-selector="nav-search-input" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" role="combobox" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="i6p1DmVMo3KqnAeFsdGi5UKy8SeSTxxFLZN5PGsiJykR2Bs7bprtv3ltVa6sWnjaWQorpGXbXjc9kelYvIfSBA=="/>
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <svg aria-hidden="true" class="mr-1 header-search-key-slash" height="20" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M3.5.5h12c1.7 0 3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z" fill="none" opacity=".4" stroke="#979A9C"></path><path d="M11.8 6L8 15.1h-.9L10.8 6h1z" fill="#979A9C"></path></svg>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="color-fg-muted">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-owner-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="owner_scoped_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="global_search" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Project" class="octicon octicon-project js-jump-to-octicon-project d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-label="Search" class="octicon octicon-search js-jump-to-octicon-search d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in this topic" class="js-jump-to-badge-search-text-default d-none">
#         In this topic
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-2 flex-shrink-0 color-bg-subtle px-1 color-fg-muted ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </label>
# </form> </div>
# </div>
# </div>
# ...
#               jwt-token
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":85256,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="0e3fa2ea82a40dce77e354deb720f8d760d97e11904f8f5bdebd39d60301118a" data-view-component="true" href="/topics/jwt-bearer-tokens" title="Topic: jwt-bearer-tokens">
#               jwt-bearer-tokens
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":118283,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="58232027dfd0bf6dab46350ef360a8f740766c775aa83856320eadc3965a1ad3" data-view-component="true" href="/topics/jwt-authentication" title="Topic: jwt-authentication">
#               jwt-authentication
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":126618,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="cfaf1d1e179ecf251e7b480d94657804686e1ad5d52c0424b313a5c01ffd757f" data-view-component="true" href="/topics/jwt-server" title="Topic: jwt-server">
#               jwt-server
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":151567,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="7d023ffae2a45f44754cc4ca45a81276ad8e5ed648409e0d3fa71bc56b546e61" data-view-component="true" href="/topics/jwt-auth" title="Topic: jwt-auth">
#               jwt-auth
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":338885,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="2b6f89d387833f26b69999214ca38b98ef770e543cceee3946820ea044a1d8ed" data-view-component="true" href="/topics/java-jwt" title="Topic: java-jwt">
#               java-jwt
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":353849,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="c854a999e3ca002d39cdc65ebc9b8815939e918f3e8f296521b08fcb9430320f" data-view-component="true" href="/topics/jwt-middleware" title="Topic: jwt-middleware">
#               jwt-middleware
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":370842,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="60b6e4b73bb2f01dadec87acf3d441ae01fc69ab982f48d57e2c9e751d6e84cd" data-view-component="true" href="/topics/jjwt" title="Topic: jjwt">
#               jjwt
# </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":416075,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="daa66fadee0435500300abb37bd334cbf1ca212fc8d19576848ee6d937ec7e2e" data-view-component="true" href="/topics/jwtauth" title="Topic: jwtauth">
#               jwtauth
# </a> </div>
# <div class="p-3">
# <ul class="d-flex f6 list-style-none color-fg-muted">
# <li class="mr-4">
#               Updated
#               <relative-time class="no-wrap" datetime="2022-06-18T00:15:09Z">Jun 18, 2022</relative-time>
# </li>
# <li class="mr-4">
# <span class="f6 my-1 ml-0">
# <span class="repo-language-color" style="background-color: #b07219"></span>
# <span itemprop="programmingLanguage">Java</span>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </article>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="https://github.com/topics/json" class="ajax-pagination-form js-ajax-pagination" data-turbo="false" method="get">
# <input name="page" type="hidden" value="2"/>
# <button class="ajax-pagination-btn btn btn-outline color-border-default f6 mt-0 width-full" data-disable-with="Loading more…" type="submit">
#       Load more…
#     </button>
# </form>
# </div>
# <div class="col-md-4 col-lg-3">
# <p class="mb-1">
# <span class="color-fg-muted">Created by</span> Douglas Crockford
#     </p>
# <p class="mb-1">
# <span class="color-fg-muted">Released</span> 2005
#     </p>
# <dl class="my-4">
# <dt class="d-none">
#       Website
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to external url, location:topic page" href="http://www.json.org/">
# <span class="css-truncate css-truncate-target" title="www.json.org">
#           www.json.org
#         </span>
# </a>
# </dd>
# <dt class="d-none">
#       Wikipedia
#     </dt>
# <dd class="mb-1">
# <svg aria-hidden="true" class="octicon octicon-link color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path>
# </svg>
# <a data-ga-click="Explore, go to Wikipedia entry, location:topic page" href="https://en.wikipedia.org/wiki/JSON">
# <span class="css-truncate css-truncate-target" title="en.wikipedia.org/wiki/JSON">
#           Wikipedia
#         </span>
# </a>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="footer width-full container-lg p-responsive">
# <h2 class="sr-only">Footer</h2>
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <div class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <div class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </div>
# </div>
# <nav aria-label="footer" class="col-12 col-lg-8">
# <h3 class="sr-only" id="sr-footer-heading">Footer navigation</h3>
# <ul aria-labelledby="sr-footer-heading" class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </nav>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
Repository_name=first_rep1.find('a',class_='text-bold wb-break-word').text
Repository_name=Repository_name.strip()

# %%
Repository_name
# Out:
# 'fastapi'

# %%
User_Name=first_rep1.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
User_Name=User_Name.split("/")
User_Name=User_Name[0]
User_Name=User_Name.strip()

# %%
User_Name
# Out:
# 'tiangolo'

# %%
stars=first_rep1.find('span',class_='Counter js-social-count').text
stars
# Out:
# '46.9k'

# %%
url_link=first_rep1.find('a',class_='text-bold wb-break-word')['href']

# %%
url_link
# Out:
# '/tiangolo/fastapi'

# %%
base_url='https://github.com/topics/json'

# %%
base_url
# Out:
# 'https://github.com/topics/json'

# %%
Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')

# %%
Repository_page
# Out:
# [<article class="border rounded color-shadow-small color-bg-subtle my-4">
#  <a class="overflow-hidden flex-items-center rounded-top-2 color-border-muted border-bottom d-flex position-relative" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_IMAGE","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="1813f2e4b0dfa13cdf22961060df78ad9f423d7bb869707e54ed49a394cceaf4" data-turbo="false" data-view-component="true" href="/tiangolo/fastapi" style="max-height:275px">
#  <img alt="fastapi" class="d-block width-full" loading="lazy" src="https://repository-images.githubusercontent.com/160919119/29516980-f308-11e9-9096-0836920fdae3"/>
#  </a>
#  <div class="px-3">
#  <div class="d-flex flex-justify-between my-3">
#  <div class="d-flex flex-auto">
#  <span style="margin-top:2px">
#  <svg aria-hidden="true" class="octicon octicon-repo color-fg-muted mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path>
#  </svg>
#  </span>
#  <h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":1326112,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="5c99bbaaf8a7d7a1dd88bd4f7a1de0b481770509bd6a75896ffca40a1c9cfc17" data-turbo="false" data-view-component="true" href="/tiangolo">
#              tiangolo
#  </a>          /
#            <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="b18d088fb7b50966f53529a7b779be1755059ec0c47ac6ac9564d4e87dd078d9" data-turbo="false" data-view-component="true" href="/tiangolo/fastapi">
#              fastapi
#  </a> </h3>
#  </div>
#  <div class="d-flex flex-items-center ml-3">
#  <a aria-label="Sponsor @tiangolo" class="btn btn-sm mr-2" data-hydro-click='{"event_type":"sponsors.button_click","payload":{"button":"TOPIC_PAGE_SPONSOR","sponsorable_login":"tiangolo","originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="f74b1e926598e68e8f63a6773062184746f7d858037ac68e9ac8071fddf796e1" data-view-component="true" href="/sponsors/tiangolo">
#  <svg aria-hidden="true" class="octicon octicon-heart icon-sponsor mr-1 v-align-middle color-fg-sponsors anim-pulse-in" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.25 2.5c-1.336 0-2.75 1.164-2.75 3 0 2.15 1.58 4.144 3.365 5.682A20.565 20.565 0 008 13.393a20.561 20.561 0 003.135-2.211C12.92 9.644 14.5 7.65 14.5 5.5c0-1.836-1.414-3-2.75-3-1.373 0-2.609.986-3.029 2.456a.75.75 0 01-1.442 0C6.859 3.486 5.623 2.5 4.25 2.5zM8 14.25l-.345.666-.002-.001-.006-.003-.018-.01a7.643 7.643 0 01-.31-.17 22.075 22.075 0 01-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.08 22.08 0 01-3.744 2.584l-.018.01-.006.003h-.002L8 14.25zm0 0l.345.666a.752.752 0 01-.69 0L8 14.25z" fill-rule="evenodd"></path>
#  </svg>
#  <span class="v-align-middle">Sponsor</span>
#  </a>
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item color-bg-default" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":160919119,"auth_type":"LOG_IN","originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="85ec36454d431ac4a0b30d83a87bce8336c90089193fc1a7a16faef3a52bd385" data-view-component="true" href="/login?return_to=%2Ftiangolo%2Ffastapi" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 .25a.75.75 0 01.673.418l1.882 3.815 4.21.612a.75.75 0 01.416 1.279l-3.046 2.97.719 4.192a.75.75 0 01-1.088.791L8 12.347l-3.766 1.98a.75.75 0 01-1.088-.79l.72-4.194L.818 6.374a.75.75 0 01.416-1.28l4.21-.611L7.327.668A.75.75 0 018 .25zm0 2.445L6.615 5.5a.75.75 0 01-.564.41l-3.097.45 2.24 2.184a.75.75 0 01.216.664l-.528 3.084 2.769-1.456a.75.75 0 01.698 0l2.77 1.456-.53-3.084a.75.75 0 01.216-.664l2.24-2.183-3.096-.45a.75.75 0 01-.564-.41L8 2.694v.001z" fill-rule="evenodd"></path>
#  </svg><span class="d-inline" data-view-component="true">
#            Star
#  </span> <span aria-label="46877 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="46,877">46.9k</span>
#  </a> <button aria-label="You must be signed in to add this repository to a list" class="btn-sm btn BtnGroup-item px-2" data-view-component="true" disabled="disabled" type="button"> <svg aria-hidden="true" class="octicon octicon-triangle-down" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.427 7.427l3.396 3.396a.25.25 0 00.354 0l3.396-3.396A.25.25 0 0011.396 7H4.604a.25.25 0 00-.177.427z"></path>
#  </svg>
#  </button></div>
#  </div>
#  </div>
#  </div>
#  <nav aria-label="Repository menu" class="tabnav px-3 mb-0" data-view-component="true">
#  <ul class="tabnav-tabs" data-view-component="true">
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"CODE_TAB","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="b8baa9c558d3bb92f05abc83d82f687a4b0a1434e4d50918d00dd04d0e65269d" data-turbo="false" data-view-component="true" href="/tiangolo/fastapi" id="code-tab-160919119">
#  <svg aria-hidden="true" class="octicon octicon-code color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M4.72 3.22a.75.75 0 011.06 1.06L2.06 8l3.72 3.72a.75.75 0 11-1.06 1.06L.47 8.53a.75.75 0 010-1.06l4.25-4.25zm6.56 0a.75.75 0 10-1.06 1.06L13.94 8l-3.72 3.72a.75.75 0 101.06 1.06l4.25-4.25a.75.75 0 000-1.06l-4.25-4.25z" fill-rule="evenodd"></path>
#  </svg> Code
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a aria-current="true" class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository issues, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_ISSUES","click_visual_representation":"ISSUES_TAB","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="7adb2e91b7586952d202f1d47f2c808e0b2e1d8f43ac5f7ae5013a85a46830bf" data-turbo="false" data-view-component="true" href="/tiangolo/fastapi/issues" id="issues-tab-160919119">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened color-gray-dark" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path></svg> Issues
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository pulls, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_PULL_REQUESTS","click_visual_representation":"PULL_REQUESTS_TAB","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="79e87a79c07caa826b88c1a4d339d0af3f84fcddb26b2da37cb1e6902660fea4" data-turbo="false" data-view-component="true" href="/tiangolo/fastapi/pulls" id="pull-requests-tab-160919119">
#  <svg aria-hidden="true" class="octicon octicon-git-pull-request color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M7.177 3.073L9.573.677A.25.25 0 0110 .854v4.792a.25.25 0 01-.427.177L7.177 3.427a.25.25 0 010-.354zM3.75 2.5a.75.75 0 100 1.5.75.75 0 000-1.5zm-2.25.75a2.25 2.25 0 113 2.122v5.256a2.251 2.251 0 11-1.5 0V5.372A2.25 2.25 0 011.5 3.25zM11 2.5h-1V4h1a1 1 0 011 1v5.628a2.251 2.251 0 101.5 0V5A2.5 2.5 0 0011 2.5zm1 10.25a.75.75 0 111.5 0 .75.75 0 01-1.5 0zM3.75 12a.75.75 0 100 1.5.75.75 0 000-1.5z" fill-rule="evenodd"></path>
#  </svg> Pull requests
#
#
#  </a></li>
#  <li class="d-inline-flex" data-view-component="true">
#  <a class="tabnav-tab f6 px-2 py-1" data-ga-click="Explore, go to repository discussions, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY_DISCUSSIONS","click_visual_representation":"DISCUSSIONS_TAB","actor_id":null,"record_id":160919119,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="5fc9999d0c1327f4544a3b772932ada5e66e844f1ae9b7999e66e8d0206245d6" data-turbo="false" data-view-component="true" href="/tiangolo/fastapi/discussions" id="discussions-tab-160919119">
#  <svg aria-hidden="true" class="octicon octicon-comment-discussion color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M1.5 2.75a.25.25 0 01.25-.25h8.5a.25.25 0 01.25.25v5.5a.25.25 0 01-.25.25h-3.5a.75.75 0 00-.53.22L3.5 11.44V9.25a.75.75 0 00-.75-.75h-1a.25.25 0 01-.25-.25v-5.5zM1.75 1A1.75 1.75 0 000 2.75v5.5C0 9.216.784 10 1.75 10H2v1.543a1.457 1.457 0 002.487 1.03L7.061 10h3.189A1.75 1.75 0 0012 8.25v-5.5A1.75 1.75 0 0010.25 1h-8.5zM14.5 4.75a.25.25 0 00-.25-.25h-.5a.75.75 0 110-1.5h.5c.966 0 1.75.784 1.75 1.75v5.5A1.75 1.75 0 0114.25 12H14v1.543a1.457 1.457 0 01-2.487 1.03L9.22 12.28a.75.75 0 111.06-1.06l2.22 2.22v-2.19a.75.75 0 01.75-.75h1a.25.25 0 00.25-.25v-5.5z" fill-rule="evenodd"></path>
#  </svg> Discussions
#
#
#  </a></li>
#  </ul>
#  </nav>
#  <div class="color-bg-default rounded-bottom-2">
#  <article class="p-3">
#  <div class="d-flex flex-justify-between mb-3">
#  <div class="flex-auto">
#  <span class="State State--open State--small v-align-bottom mr-1" data-view-component="true" title="Status: open">
#  <svg aria-hidden="true" class="octicon octicon-issue-opened" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M8 9.5a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path><path d="M8 0a8 8 0 100 16A8 8 0 008 0zM1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0z" fill-rule="evenodd"></path>
#  </svg> Open
#  </span>
#  <h4 class="d-inline flex-auto f3 text-normal lh-condensed">
#  <a class="color-fg-default" data-ga-click="Explore, go to issue, location:good first issues;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"BIG_GOOD_FIRST_ISSUE","actor_id":null,"record_id":638020293,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="af4e6890190cf01e3c60d6d8891529ed616a7ee9e5b283e6c0d0a0b2c5f6645e" data-turbo="false" data-view-component="true" href="https://github.com/tiangolo/fastapi/issues/1561">
#                  Update docs with parameters that default to None to use Optional
#  </a> </h4>
#  </div>
#  <div class="f6 color-fg-muted text-right no-wrap mt-1 ml-3">
#  <svg aria-hidden="true" class="octicon octicon-comment color-fg-muted mr-1" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#  <path d="M2.75 2.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h2a.75.75 0 01.75.75v2.19l2.72-2.72a.75.75 0 01.53-.22h4.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25H2.75zM1 2.75C1 1.784 1.784 1 2.75 1h10.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0113.25 12H9.06l-2.573 2.573A1.457 1.457 0 014 13.543V12H2.75A1.75 1.75 0 011 10.25v-7.5z" fill-rule="evenodd"></path>
#  </svg>
#                11
#              </div>
#  </div>
#  <div class="d-flex">
#  <div class="mr-3">
#  <img alt="tiangolo" class="avatar avatar-user avatar-small" height="32" src="https://avatars.githubusercontent.com/u/1326112?v=4" width="32"/>
#  </div>
#  <div class="flex-auto" style="width: 80%;">
#  <div class="Box Box--condensed position-relative timeline-comment--caret">
#  <div class="Box-header f6 color-fg-muted">
#  <strong class="color-fg-default text-bold">
#                    tiangolo
#                  </strong>
#
#                    commented
#
#                  <relative-time class="no-wrap" datetime="2020-06-12T21:51:13Z">Jun 12, 2020</relative-time>
#  </div>
#  <div class="Box-body comment-body markdown-body position-relative overflow-hidden pt-3" style="max-height:200px">
#  <h3>First check</h3>
#  <ul class="contains-task-list">
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> I added a very descriptive title to this issue.</li>
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> I used the GitHub search to find a similar issue and didn't find it.</li>
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> I searched the FastAPI documentation, with the integrated search.</li>
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> I already searched in Google "How to X in FastAPI" and didn't find any information.</li>
#  <li class="task-list-item"><input checked="" class="task-list-item-checkbox" disabled="" id="" type="checkbox"/> I already read and followed all the tutorial in the docs and didn't find an answ</li>
#  </ul>
#  <div class="position-absolute right-0 left-0 bottom-0 text-center" style="background: linear-gradient(to top, var(--color-canvas-default), var(--color-canvas-default-transparent));">
#  <a class="btn btn-outline btn-sm mx-auto my-3" data-ga-click="Explore, go to issue, location:good first issues;text:read more;size:large;" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"ISSUE","click_visual_representation":"READ_MORE","actor_id":null,"record_id":638020293,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac
"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="7d023ffae2a45f44754cc4ca45a81276ad8e5ed648409e0d3fa71bc56b546e61" data-view-component="true" href="/topics/jwt-auth" title="Topic: jwt-auth">
#                jwt-auth
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":338885,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="2b6f89d387833f26b69999214ca38b98ef770e543cceee3946820ea044a1d8ed" data-view-component="true" href="/topics/java-jwt" title="Topic: java-jwt">
#                java-jwt
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":353849,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="c854a999e3ca002d39cdc65ebc9b8815939e918f3e8f296521b08fcb9430320f" data-view-component="true" href="/topics/jwt-middleware" title="Topic: jwt-middleware">
#                jwt-middleware
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":370842,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="60b6e4b73bb2f01dadec87acf3d441ae01fc69ab982f48d57e2c9e751d6e84cd" data-view-component="true" href="/topics/jjwt" title="Topic: jjwt">
#                jjwt
#  </a> <a class="topic-tag topic-tag-link f6 mb-2" data-ga-click="Explore, go to topic, location:explore feed repository" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"TOPIC","click_visual_representation":"TOPIC_TAG","actor_id":null,"record_id":416075,"originating_url":"https://github.com/topics/json","user_id":null}}' data-hydro-click-hmac="daa66fadee0435500300abb37bd334cbf1ca212fc8d19576848ee6d937ec7e2e" data-view-component="true" href="/topics/jwtauth" title="Topic: jwtauth">
#                jwtauth
#  </a> </div>
#  <div class="p-3">
#  <ul class="d-flex f6 list-style-none color-fg-muted">
#  <li class="mr-4">
#                Updated
#                <relative-time class="no-wrap" datetime="2022-06-18T00:15:09Z">Jun 18, 2022</relative-time>
#  </li>
#  <li class="mr-4">
#  <span class="f6 my-1 ml-0">
#  <span class="repo-language-color" style="background-color: #b07219"></span>
#  <span itemprop="programmingLanguage">Java</span>
#  </span>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
base_url='https://github.com/topics/json'
page_1_dict={}
Repository_1_lst=[]
for item in Repository_page:
    
    Repository_name=item.find('a',class_='text-bold wb-break-word').text
    Repository_name=Repository_name.strip()
    
    User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
    User_Name=User_Name.strip().splitlines()[0].strip()
    User_Name=User_Name.strip()
    
    stars=item.find('span',class_='Counter js-social-count').text
    stars=stars.strip()
    
    URL=(base_url+User_Name+"/"+Repository_name)
    URL=URL.strip()
    Repository_1_dict={
        'Repository Name': Repository_name,
        'User Name': User_Name ,
        'stars': stars,
        'Repository URL':URL,
    }
    Repository_1_lst.append(Repository_1_dict)

# %%
 Repository_1_lst
# Out:
# [{'Repository Name': 'fastapi',
#   'User Name': 'tiangolo',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/topics/jsontiangolo/fastapi'},
#  {'Repository Name': 'prettier',
#   'User Name': 'prettier',
#   'stars': '43.3k',
#   'Repository URL': 'https://github.com/topics/jsonprettier/prettier'},
#  {'Repository Name': 'chinese-poetry',
#   'User Name': 'chinese-poetry',
#   'stars': '36.6k',
#   'Repository URL': 'https://github.com/topics/jsonchinese-poetry/chinese-poetry'},
#  {'Repository Name': 'json',
#   'User Name': 'nlohmann',
#   'stars': '30.8k',
#   'Repository URL': 'https://github.com/topics/jsonnlohmann/json'},
#  {'Repository Name': 'sheetjs',
#   'User Name': 'SheetJS',
#   'stars': '30.6k',
#   'Repository URL': 'https://github.com/topics/jsonSheetJS/sheetjs'},
#  {'Repository Name': 'fastjson',
#   'User Name': 'alibaba',
#   'stars': '24.8k',
#   'Repository URL': 'https://github.com/topics/jsonalibaba/fastjson'},
#  {'Repository Name': 'hutool',
#   'User Name': 'dromara',
#   'stars': '23.2k',
#   'Repository URL': 'https://github.com/topics/jsondromara/hutool'},
#  {'Repository Name': 'httpie',
#   'User Name': 'httpie',
#   'stars': '22.3k',
#   'Repository URL': 'https://github.com/topics/jsonhttpie/httpie'},
#  {'Repository Name': 'SwiftyJSON',
#   'User Name': 'SwiftyJSON',
#   'stars': '21.4k',
#   'Repository URL': 'https://github.com/topics/jsonSwiftyJSON/SwiftyJSON'},
#  {'Repository Name': 'normalizr',
#   'User Name': 'paularmstrong',
#   'stars': '20.9k',
#   'Repository URL': 'https://github.com/topics/jsonpaularmstrong/normalizr'},
#  {'Repository Name': 'editor.js',
#   'User Name': 'codex-team',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/topics/jsoncodex-team/editor.js'},
#  {'Repository Name': 'cli',
#   'User Name': 'urfave',
#   'stars': '18.6k',
#   'Repository URL': 'https://github.com/topics/jsonurfave/cli'},
#  {'Repository Name': 'lowdb',
#   'User Name': 'typicode',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/topics/jsontypicode/lowdb'},
#  {'Repository Name': 'simdjson',
#   'User Name': 'simdjson',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/topics/jsonsimdjson/simdjson'},
#  {'Repository Name': 'fx',
#   'User Name': 'antonmedv',
#   'stars': '14.9k',
#   'Repository URL': 'https://github.com/topics/jsonantonmedv/fx'},
#  {'Repository Name': 'Administrative-divisions-of-China',
#   'User Name': 'modood',
#   'stars': '13.2k',
#   'Repository URL': 'https://github.com/topics/jsonmodood/Administrative-divisions-of-China'},
#  {'Repository Name': 'react-jsonschema-form',
#   'User Name': 'rjsf-team',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/topics/jsonrjsf-team/react-jsonschema-form'},
#  {'Repository Name': 'Mantle',
#   'User Name': 'Mantle',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/topics/jsonMantle/Mantle'},
#  {'Repository Name': 'amis',
#   'User Name': 'baidu',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/topics/jsonbaidu/amis'},
#  {'Repository Name': 'go',
#   'User Name': 'json-iterator',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/topics/jsonjson-iterator/go'},
#  {'Repository Name': 'httpbin',
#   'User Name': 'postmanlabs',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/topics/jsonpostmanlabs/httpbin'},
#  {'Repository Name': 'gjson',
#   'User Name': 'tidwall',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/topics/jsontidwall/gjson'},
#  {'Repository Name': 'pino',
#   'User Name': 'pinojs',
#   'stars': '9.6k',
#   'Repository URL': 'https://github.com/topics/jsonpinojs/pino'},
#  {'Repository Name': 'chinese-xinhua',
#   'User Name': 'pwxcoo',
#   'stars': '9.5k',
#   'Repository URL': 'https://github.com/topics/jsonpwxcoo/chinese-xinhua'},
#  {'Repository Name': 'Newtonsoft.Json',
#   'User Name': 'JamesNK',
#   'stars': '9.4k',
#   'Repository URL': 'https://github.com/topics/jsonJamesNK/Newtonsoft.Json'},
#  {'Repository Name': 'full-stack-fastapi-postgresql',
#   'User Name': 'tiangolo',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/topics/jsontiangolo/full-stack-fastapi-postgresql'},
#  {'Repository Name': 'http-prompt',
#   'User Name': 'httpie',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/topics/jsonhttpie/http-prompt'},
#  {'Repository Name': 'css.gg',
#   'User Name': 'astrit',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/topics/jsonastrit/css.gg'},
#  {'Repository Name': 'MJExtension',
#   'User Name': 'CoderMJLee',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/topics/jsonCoderMJLee/MJExtension'},
#  {'Repository Name': 'jjwt',
#   'User Name': 'jwtk',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/topics/jsonjwtk/jjwt'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(Repository_1_lst)

# %%
df
# Out:
#                       Repository Name       User Name  stars  \
# 0                             fastapi        tiangolo  46.9k
# 1                            prettier        prettier  43.3k
# 2                      chinese-poetry  chinese-poetry  36.6k
# 3                                json        nlohmann  30.8k
# 4                             sheetjs         SheetJS  30.6k
# 5                            fastjson         alibaba  24.8k
# 6                              hutool         dromara  23.2k
# 7                              httpie          httpie  22.3k
# 8                          SwiftyJSON      SwiftyJSON  21.4k
# 9                           normalizr   paularmstrong  20.9k
# 10                          editor.js      codex-team  19.4k
# 11                                cli          urfave  18.6k
# 12                              lowdb        typicode  17.9k
# 13                           simdjson        simdjson  15.8k
# 14                                 fx       antonmedv  14.9k
# 15  Administrative-divisions-of-China          modood  13.2k
# 16              react-jsonschema-form       rjsf-team  11.6k
# 17                             Mantle          Mantle  11.3k
# 18                               amis           baidu  11.3k
# 19                                 go   json-iterator    11k
# 20                            httpbin     postmanlabs    11k
# 21                              gjson         tidwall  10.5k
# 22                               pino          pinojs   9.6k
# 23                     chinese-xinhua          pwxcoo   9.5k
# 24                    Newtonsoft.Json         JamesNK   9.4k
# 25      full-stack-fastapi-postgresql        tiangolo   9.3k
# 26                        http-prompt          httpie   8.5k
# 27                             css.gg          astrit   8.5k
# 28                        MJExtension      CoderMJLee   8.5k
# 29                               jjwt            jwtk   8.4k
#
#                                        Repository URL
# 0      https://github.com/topics/jsontiangolo/fastapi
# 1     https://github.com/topics/jsonprettier/prettier
# 2   https://github.com/topics/jsonchinese-poetry/c...
# 3         https://github.com/topics/jsonnlohmann/json
# 4       https://github.com/topics/jsonSheetJS/sheetjs
# 5      https://github.com/topics/jsonalibaba/fastjson
# 6        https://github.com/topics/jsondromara/hutool
# 7         https://github.com/topics/jsonhttpie/httpie
# 8   https://github.com/topics/jsonSwiftyJSON/Swift...
# 9   https://github.com/topics/jsonpaularmstrong/no...
# 10  https://github.com/topics/jsoncodex-team/edito...
# 11           https://github.com/topics/jsonurfave/cli
# 12       https://github.com/topics/jsontypicode/lowdb
# 13    https://github.com/topics/jsonsimdjson/simdjson
# 14         https://github.com/topics/jsonantonmedv/fx
# 15  https://github.com/topics/jsonmodood/Administr...
# 16  https://github.com/topics/jsonrjsf-team/react-...
# 17        https://github.com/topics/jsonMantle/Mantle
# 18           https://github.com/topics/jsonbaidu/amis
# 19     https://github.com/topics/jsonjson-iterator/go
# 20  https://github.com/topics/jsonpostmanlabs/httpbin
# 21        https://github.com/topics/jsontidwall/gjson
# 22          https://github.com/topics/jsonpinojs/pino
# 23  https://github.com/topics/jsonpwxcoo/chinese-x...
# 24  https://github.com/topics/jsonJamesNK/Newtonso...
# 25  https://github.com/topics/jsontiangolo/full-st...
# 26   https://github.com/topics/jsonhttpie/http-prompt
# 27        https://github.com/topics/jsonastrit/css.gg
# 28  https://github.com/topics/jsonCoderMJLee/MJExt...
# 29            https://github.com/topics/jsonjwtk/jjwt

# %%
df.to_excel('json.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'

# %%
all_page_url='https://github.com/topics/json?page='
final_url=[]
for num in range(1,8):
    final_url.append(all_page_url+str(num))

# %%
final_url
# Out:
# ['https://github.com/topics/json?page=1',
#  'https://github.com/topics/json?page=2',
#  'https://github.com/topics/json?page=3',
#  'https://github.com/topics/json?page=4',
#  'https://github.com/topics/json?page=5',
#  'https://github.com/topics/json?page=6',
#  'https://github.com/topics/json?page=7']

# %%
Repository_name=item.find('a',class_='text-bold wb-break-word').text
User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
stars=item.find('span',class_='Counter js-social-count').text
url_link=item.find('a',class_='text-bold wb-break-word')['href'] 
Repository_url=base_url+url_link

# %%
import requests
from bs4 import BeautifulSoup
base_url='https://github.com/'
all_page_url='https://github.com/topics/json?page='
Repository_dict_1={}
All_Repository_lst=[]
SrNo=1
for item in final_url:
    source=requests.get(item).text
    soup = BeautifulSoup(source,'lxml')
    Repository_page=soup.find_all('article',class_='border rounded color-shadow-small color-bg-subtle my-4')
    for item in Repository_page:
        if(SrNo>200):
            continue
        else:
            Repository_name=item.find('a',class_='text-bold wb-break-word').text
            Repository_name=Repository_name.strip()

            User_Name=item.find('h3',class_='f3 color-fg-muted text-normal lh-condensed').text
            User_Name=User_Name.strip().splitlines()[0].strip()
            User_Name=User_Name.strip()
    
            stars=item.find('span',class_='Counter js-social-count').text
            stars=stars.strip()
    
            URL=(base_url+User_Name+"/"+Repository_name)
            URL=URL.strip()
        
            Repository_dict_1={
                'Sr No':SrNo,
                'Repository Name': Repository_name,
                'User Name': User_Name ,
                'stars': stars,
                'Repository URL':URL,
            }
       
            All_Repository_lst.append(Repository_dict_1)
            SrNo+=1

# %%
All_Repository_lst
# Out:
# [{'Sr No': 1,
#   'Repository Name': 'fastapi',
#   'User Name': 'tiangolo',
#   'stars': '46.9k',
#   'Repository URL': 'https://github.com/tiangolo/fastapi'},
#  {'Sr No': 2,
#   'Repository Name': 'prettier',
#   'User Name': 'prettier',
#   'stars': '43.3k',
#   'Repository URL': 'https://github.com/prettier/prettier'},
#  {'Sr No': 3,
#   'Repository Name': 'chinese-poetry',
#   'User Name': 'chinese-poetry',
#   'stars': '36.6k',
#   'Repository URL': 'https://github.com/chinese-poetry/chinese-poetry'},
#  {'Sr No': 4,
#   'Repository Name': 'json',
#   'User Name': 'nlohmann',
#   'stars': '30.8k',
#   'Repository URL': 'https://github.com/nlohmann/json'},
#  {'Sr No': 5,
#   'Repository Name': 'sheetjs',
#   'User Name': 'SheetJS',
#   'stars': '30.6k',
#   'Repository URL': 'https://github.com/SheetJS/sheetjs'},
#  {'Sr No': 6,
#   'Repository Name': 'fastjson',
#   'User Name': 'alibaba',
#   'stars': '24.8k',
#   'Repository URL': 'https://github.com/alibaba/fastjson'},
#  {'Sr No': 7,
#   'Repository Name': 'hutool',
#   'User Name': 'dromara',
#   'stars': '23.2k',
#   'Repository URL': 'https://github.com/dromara/hutool'},
#  {'Sr No': 8,
#   'Repository Name': 'httpie',
#   'User Name': 'httpie',
#   'stars': '22.3k',
#   'Repository URL': 'https://github.com/httpie/httpie'},
#  {'Sr No': 9,
#   'Repository Name': 'SwiftyJSON',
#   'User Name': 'SwiftyJSON',
#   'stars': '21.4k',
#   'Repository URL': 'https://github.com/SwiftyJSON/SwiftyJSON'},
#  {'Sr No': 10,
#   'Repository Name': 'normalizr',
#   'User Name': 'paularmstrong',
#   'stars': '20.9k',
#   'Repository URL': 'https://github.com/paularmstrong/normalizr'},
#  {'Sr No': 11,
#   'Repository Name': 'editor.js',
#   'User Name': 'codex-team',
#   'stars': '19.4k',
#   'Repository URL': 'https://github.com/codex-team/editor.js'},
#  {'Sr No': 12,
#   'Repository Name': 'cli',
#   'User Name': 'urfave',
#   'stars': '18.6k',
#   'Repository URL': 'https://github.com/urfave/cli'},
#  {'Sr No': 13,
#   'Repository Name': 'lowdb',
#   'User Name': 'typicode',
#   'stars': '17.9k',
#   'Repository URL': 'https://github.com/typicode/lowdb'},
#  {'Sr No': 14,
#   'Repository Name': 'simdjson',
#   'User Name': 'simdjson',
#   'stars': '15.8k',
#   'Repository URL': 'https://github.com/simdjson/simdjson'},
#  {'Sr No': 15,
#   'Repository Name': 'fx',
#   'User Name': 'antonmedv',
#   'stars': '14.9k',
#   'Repository URL': 'https://github.com/antonmedv/fx'},
#  {'Sr No': 16,
#   'Repository Name': 'Administrative-divisions-of-China',
#   'User Name': 'modood',
#   'stars': '13.2k',
#   'Repository URL': 'https://github.com/modood/Administrative-divisions-of-China'},
#  {'Sr No': 17,
#   'Repository Name': 'react-jsonschema-form',
#   'User Name': 'rjsf-team',
#   'stars': '11.6k',
#   'Repository URL': 'https://github.com/rjsf-team/react-jsonschema-form'},
#  {'Sr No': 18,
#   'Repository Name': 'Mantle',
#   'User Name': 'Mantle',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/Mantle/Mantle'},
#  {'Sr No': 19,
#   'Repository Name': 'amis',
#   'User Name': 'baidu',
#   'stars': '11.3k',
#   'Repository URL': 'https://github.com/baidu/amis'},
#  {'Sr No': 20,
#   'Repository Name': 'go',
#   'User Name': 'json-iterator',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/json-iterator/go'},
#  {'Sr No': 21,
#   'Repository Name': 'httpbin',
#   'User Name': 'postmanlabs',
#   'stars': '11k',
#   'Repository URL': 'https://github.com/postmanlabs/httpbin'},
#  {'Sr No': 22,
#   'Repository Name': 'gjson',
#   'User Name': 'tidwall',
#   'stars': '10.5k',
#   'Repository URL': 'https://github.com/tidwall/gjson'},
#  {'Sr No': 23,
#   'Repository Name': 'pino',
#   'User Name': 'pinojs',
#   'stars': '9.6k',
#   'Repository URL': 'https://github.com/pinojs/pino'},
#  {'Sr No': 24,
#   'Repository Name': 'chinese-xinhua',
#   'User Name': 'pwxcoo',
#   'stars': '9.5k',
#   'Repository URL': 'https://github.com/pwxcoo/chinese-xinhua'},
#  {'Sr No': 25,
#   'Repository Name': 'Newtonsoft.Json',
#   'User Name': 'JamesNK',
#   'stars': '9.4k',
#   'Repository URL': 'https://github.com/JamesNK/Newtonsoft.Json'},
#  {'Sr No': 26,
#   'Repository Name': 'full-stack-fastapi-postgresql',
#   'User Name': 'tiangolo',
#   'stars': '9.3k',
#   'Repository URL': 'https://github.com/tiangolo/full-stack-fastapi-postgresql'},
#  {'Sr No': 27,
#   'Repository Name': 'http-prompt',
#   'User Name': 'httpie',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/httpie/http-prompt'},
#  {'Sr No': 28,
#   'Repository Name': 'css.gg',
#   'User Name': 'astrit',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/astrit/css.gg'},
#  {'Sr No': 29,
#   'Repository Name': 'MJExtension',
#   'User Name': 'CoderMJLee',
#   'stars': '8.5k',
#   'Repository URL': 'https://github.com/CoderMJLee/MJExtension'},
#  {'Sr No': 30,
#   'Repository Name': 'jjwt',
#   'User Name': 'jwtk',
#   'stars': '8.4k',
#   'Repository URL': 'https://github.com/jwtk/jjwt'},
#  {'Sr No': 31,
#   'Repository Name': 'quicktype',
#   'User Name': 'quicktype',
#   'stars': '8.3k',
#   'Repository URL': 'https://github.com/quicktype/quicktype'},
#  {'Sr No': 32,
#   'Repository Name': 'ky',
#   'User Name': 'sindresorhus',
#   'stars': '7.8k',
#   'Repository URL': 'https://github.com/sindresorhus/ky'},
#  {'Sr No': 33,
#   'Repository Name': 'sqlmodel',
#   'User Name': 'tiangolo',
#   'stars': '7.6k',
#   'Repository URL': 'https://github.com/tiangolo/sqlmodel'},
#  {'Sr No': 34,
#   'Repository Name': 'opa',
#   'User Name': 'open-policy-agent',
#   'stars': '6.8k',
#   'Repository URL': 'https://github.com/open-policy-agent/opa'},
#  {'Sr No': 35,
#   'Repository Name': 'zerolog',
#   'User Name': 'rs',
#   'stars': '6.5k',
#   'Repository URL': 'https://github.com/rs/zerolog'},
#  {'Sr No': 36,
#   'Repository Name': 'structured-text-tools',
#   'User Name': 'dbohdan',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/dbohdan/structured-text-tools'},
#  {'Sr No': 37,
#   'Repository Name': 'bilibili-API-collect',
#   'User Name': 'SocialSisterYi',
#   'stars': '6.4k',
#   'Repository URL': 'https://github.com/SocialSisterYi/bilibili-API-collect'},
#  {'Sr No': 38,
#   'Repository Name': 'jid',
#   'User Name': 'simeji',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/simeji/jid'},
#  {'Sr No': 39,
#   'Repository Name': 'datasette',
#   'User Name': 'simonw',
#   'stars': '6.3k',
#   'Repository URL': 'https://github.com/simonw/datasette'},
#  {'Sr No': 40,
#   'Repository Name': 'poco',
#   'User Name': 'pocoproject',
#   'stars': '6.2k',
#   'Repository URL': 'https://github.com/pocoproject/poco'},
#  {'Sr No': 41,
#   'Repository Name': 'refit',
#   'User Name': 'reactiveui',
#   'stars': '6.1k',
#   'Repository URL': 'https://github.com/reactiveui/refit'},
#  {'Sr No': 42,
#   'Repository Name': 'yq',
#   'User Name': 'mikefarah',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/mikefarah/yq'},
#  {'Sr No': 43,
#   'Repository Name': 'rest-assured',
#   'User Name': 'rest-assured',
#   'stars': '5.9k',
#   'Repository URL': 'https://github.com/rest-assured/rest-assured'},
#  {'Sr No': 44,
#   'Repository Name': 'boltons',
#   'User Name': 'mahmoud',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/mahmoud/boltons'},
#  {'Sr No': 45,
#   'Repository Name': 'jsonschema2pojo',
#   'User Name': 'joelittlejohn',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/joelittlejohn/jsonschema2pojo'},
#  {'Sr No': 46,
#   'Repository Name': 'neutralinojs',
#   'User Name': 'neutralinojs',
#   'stars': '5.8k',
#   'Repository URL': 'https://github.com/neutralinojs/neutralinojs'},
#  {'Sr No': 47,
#   'Repository Name': 'ArduinoJson',
#   'User Name': 'bblanchon',
#   'stars': '5.7k',
#   'Repository URL': 'https://github.com/bblanchon/ArduinoJson'},
#  {'Sr No': 48,
#   'Repository Name': 'visidata',
#   'User Name': 'saulpw',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/saulpw/visidata'},
#  {'Sr No': 49,
#   'Repository Name': 'jsonnet',
#   'User Name': 'google',
#   'stars': '5.6k',
#   'Repository URL': 'https://github.com/google/jsonnet'},
#  {'Sr No': 50,
#   'Repository Name': 'miller',
#   'User Name': 'johnkerl',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/johnkerl/miller'},
#  {'Sr No': 51,
#   'Repository Name': 'countries',
#   'User Name': 'mledoze',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/mledoze/countries'},
#  {'Sr No': 52,
#   'Repository Name': 'ponzu',
#   'User Name': 'ponzu-cms',
#   'stars': '5.5k',
#   'Repository URL': 'https://github.com/ponzu-cms/ponzu'},
#  {'Sr No': 53,
#   'Repository Name': 'active_model_serializers',
#   'User Name': 'rails-api',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/rails-api/active_model_serializers'},
#  {'Sr No': 54,
#   'Repository Name': 'tinydb',
#   'User Name': 'msiemens',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/msiemens/tinydb'},
#  {'Sr No': 55,
#   'Repository Name': 'json5',
#   'User Name': 'json5',
#   'stars': '5.2k',
#   'Repository URL': 'https://github.com/json5/json5'},
#  {'Sr No': 56,
#   'Repository Name': 'form',
#   'User Name': 'jquery-form',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/jquery-form/form'},
#  {'Sr No': 57,
#   'Repository Name': 'body-parser',
#   'User Name': 'expressjs',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/expressjs/body-parser'},
#  {'Sr No': 58,
#   'Repository Name': 'ServiceStack',
#   'User Name': 'ServiceStack',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/ServiceStack/ServiceStack'},
#  {'Sr No': 59,
#   'Repository Name': 'wiremock',
#   'User Name': 'wiremock',
#   'stars': '5.1k',
#   'Repository URL': 'https://github.com/wiremock/wiremock'},
#  {'Sr No': 60,
#   'Repository Name': 'jsonvisio.com',
#   'User Name': 'AykutSarac',
#   'stars': '4.7k',
#   'Repository URL': 'https://github.com/AykutSarac/jsonvisio.com'},
#  {'Sr No': 61,
#   'Repository Name': 'tabulator',
#   'User Name': 'olifolkerd',
#   'stars': '4.7k',
#   'Repository URL': 'https://github.com/olifolkerd/tabulator'},
#  {'Sr No': 62,
#   'Repository Name': 'jsonparser',
#   'User Name': 'buger',
#   'stars': '4.6k',
#   'Repository URL': 'https://github.com/buger/jsonparser'},
#  {'Sr No': 63,
#   'Repository Name': 'polr',
#   'User Name': 'cydrobolt',
#   'stars': '4.4k',
#   'Repository URL': 'https://github.com/cydrobolt/polr'},
#  {'Sr No': 64,
#   'Repository Name': 'resume-cli',
#   'User Name': 'jsonresume',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/jsonresume/resume-cli'},
#  {'Sr No': 65,
#   'Repository Name': 'browser-compat-data',
#   'User Name': 'mdn',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/mdn/browser-compat-data'},
#  {'Sr No': 66,
#   'Repository Name': 'hcl',
#   'User Name': 'hashicorp',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/hashicorp/hcl'},
#  {'Sr No': 67,
#   'Repository Name': 'jsondiffpatch',
#   'User Name': 'benjamine',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/benjamine/jsondiffpatch'},
#  {'Sr No': 68,
#   'Repository Name': 'FeHelper',
#   'User Name': 'zxlie',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/zxlie/FeHelper'},
#  {'Sr No': 69,
#   'Repository Name': 'fq',
#   'User Name': 'wader',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/wader/fq'},
#  {'Sr No': 70,
#   'Repository Name': 'tbox',
#   'User Name': 'tboox',
#   'stars': '4.1k',
#   'Repository URL': 'https://github.com/tboox/tbox'},
#  {'Sr No': 71,
#   'Repository Name': 'lsp-mode',
#   'User Name': 'emacs-lsp',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/emacs-lsp/lsp-mode'},
#  {'Sr No': 72,
#   'Repository Name': 'gravity',
#   'User Name': 'marcobambini',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/marcobambini/gravity'},
#  {'Sr No': 73,
#   'Repository Name': 'HandyJSON',
#   'User Name': 'alibaba',
#   'stars': '4k',
#   'Repository URL': 'https://github.com/alibaba/HandyJSON'},
#  {'Sr No': 74,
#   'Repository Name': 'kotlinx.serialization',
#   'User Name': 'Kotlin',
#   'stars': '3.9k',
#   'Repository URL': 'https://github.com/Kotlin/kotlinx.serialization'},
#  {'Sr No': 75,
#   'Repository Name': 'bigchaindb',
#   'User Name': 'bigchaindb',
#   'stars': '3.9k',
#   'Repository URL': 'https://github.com/bigchaindb/bigchaindb'},
#  {'Sr No': 76,
#   'Repository Name': 'jc',
#   'User Name': 'kellyjonbrazil',
#   'stars': '3.9k',
#   'Repository URL': 'https://github.com/kellyjonbrazil/jc'},
#  {'Sr No': 77,
#   'Repository Name': 'jsonhero-web',
#   'User Name': 'jsonhero-io',
#   'stars': '3.9k',
#   'Repository URL': 'https://github.com/jsonhero-io/jsonhero-web'},
#  {'Sr No': 78,
#   'Repository Name': 'SBJson',
#   'User Name': 'SBJson',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/SBJson/SBJson'},
#  {'Sr No': 79,
#   'Repository Name': 'easyjson',
#   'User Name': 'mailru',
#   'stars': '3.8k',
#   'Repository URL': 'https://github.com/mailru/easyjson'},
#  {'Sr No': 80,
#   'Repository Name': 'ultrajson',
#   'User Name': 'ultrajson',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/ultrajson/ultrajson'},
#  {'Sr No': 81,
#   'Repository Name': 'jsonschema',
#   'User Name': 'python-jsonschema',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/python-jsonschema/jsonschema'},
#  {'Sr No': 82,
#   'Repository Name': 'TSWeChat',
#   'User Name': 'hilen',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/hilen/TSWeChat'},
#  {'Sr No': 83,
#   'Repository Name': 'alpha_vantage',
#   'User Name': 'RomelTorres',
#   'stars': '3.7k',
#   'Repository URL': 'https://github.com/RomelTorres/alpha_vantage'},
#  {'Sr No': 84,
#   'Repository Name': 'mimesis',
#   'User Name': 'lk-geimfari',
#   'stars': '3.6k',
#   'Repository URL': 'https://github.com/lk-geimfari/mimesis'},
#  {'Sr No': 85,
#   'Repository Name': 'json-to-go',
#   'User Name': 'mholt',
#   'stars': '3.6k',
#   'Repository URL': 'https://github.com/mholt/json-to-go'},
#  {'Sr No': 86,
#   'Repository Name': 'orjson',
#   'User Name': 'ijl',
#   'stars': '3.5k',
#   'Repository URL': 'https://github.com/ijl/orjson'},
#  {'Sr No': 87,
#   'Repository Name': 'tmuxp',
#   'User Name': 'tmux-python',
#   'stars': '3.4k',
#   'Repository URL': 'https://github.com/tmux-python/tmuxp'},
#  {'Sr No': 88,
#   'Repository Name': 'dasel',
#   'User Name': 'TomWright',
#   'stars': '3.4k',
#   'Repository URL': 'https://github.com/TomWright/dasel'},
#  {'Sr No': 89,
#   'Repository Name': 'countries-states-cities-database',
#   'User Name': 'dr5hn',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/dr5hn/countries-states-cities-database'},
#  {'Sr No': 90,
#   'Repository Name': 'toapi',
#   'User Name': 'gaojiuli',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/gaojiuli/toapi'},
#  {'Sr No': 91,
#   'Repository Name': 'react-docgen',
#   'User Name': 'reactjs',
#   'stars': '3.3k',
#   'Repository URL': 'https://github.com/reactjs/react-docgen'},
#  {'Sr No': 92,
#   'Repository Name': 'survey-library',
#   'User Name': 'surveyjs',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/surveyjs/survey-library'},
#  {'Sr No': 93,
#   'Repository Name': 'RedisJSON',
#   'User Name': 'RedisJSON',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/RedisJSON/RedisJSON'},
#  {'Sr No': 94,
#   'Repository Name': 'json-editor',
#   'User Name': 'json-editor',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/json-editor/json-editor'},
#  {'Sr No': 95,
#   'Repository Name': 'gorequest',
#   'User Name': 'parnurzeal',
#   'stars': '3.2k',
#   'Repository URL': 'https://github.com/parnurzeal/gorequest'},
#  {'Sr No': 96,
#   'Repository Name': 'octosql',
#   'User Name': 'cube2222',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/cube2222/octosql'},
#  {'Sr No': 97,
#   'Repository Name': 'json',
#   'User Name': 'serde-rs',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/serde-rs/json'},
#  {'Sr No': 98,
#   'Repository Name': 'jackson-databind',
#   'User Name': 'FasterXML',
#   'stars': '3.1k',
#   'Repository URL': 'https://github.com/FasterXML/jackson-databind'},
#  {'Sr No': 99,
#   'Repository Name': 'minify',
#   'User Name': 'tdewolff',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/tdewolff/minify'},
#  {'Sr No': 100,
#   'Repository Name': 'php-curl-class',
#   'User Name': 'php-curl-class',
#   'stars': '3k',
#   'Repository URL': 'https://github.com/php-curl-class/php-curl-class'},
#  {'Sr No': 101,
#   'Repository Name': 'fast-json-stringify',
#   'User Name': 'fastify',
#   'stars': '2.9k',
#   'Repository URL': 'https://github.com/fastify/fast-json-stringify'},
#  {'Sr No': 102,
#   'Repository Name': 'jless',
#   'User Name': 'PaulJuliusMartinez',
#   'stars': '2.9k',
#   'Repository URL': 'https://github.com/PaulJuliusMartinez/jless'},
#  {'Sr No': 103,
#   'Repository Name': 'oj',
#   'User Name': 'ohler55',
#   'stars': '2.9k',
#   'Repository URL': 'https://github.com/ohler55/oj'},
#  {'Sr No': 104,
#   'Repository Name': 'json-viewer',
#   'User Name': 'tulios',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/tulios/json-viewer'},
#  {'Sr No': 105,
#   'Repository Name': 'gabs',
#   'User Name': 'Jeffail',
#   'stars': '2.8k',
#   'Repository URL': 'https://github.com/Jeffail/gabs'},
#  {'Sr No': 106,
#   'Repository Name': 'cocoyaxi',
#   'User Name': 'idealvin',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/idealvin/cocoyaxi'},
#  {'Sr No': 107,
#   'Repository Name': 'core',
#   'User Name': 'elm',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/elm/core'},
#  {'Sr No': 108,
#   'Repository Name': 'flask-restplus',
#   'User Name': 'noirbizarre',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/noirbizarre/flask-restplus'},
#  {'Sr No': 109,
#   'Repository Name': 'jansson',
#   'User Name': 'akheron',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/akheron/jansson'},
#  {'Sr No': 110,
#   'Repository Name': 'xLog',
#   'User Name': 'elvishew',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/elvishew/xLog'},
#  {'Sr No': 111,
#   'Repository Name': 'json-schema-spec',
#   'User Name': 'json-schema-org',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/json-schema-org/json-schema-spec'},
#  {'Sr No': 112,
#   'Repository Name': 'react-json-view',
#   'User Name': 'mac-s-g',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/mac-s-g/react-json-view'},
#  {'Sr No': 113,
#   'Repository Name': 'awesome-json-datasets',
#   'User Name': 'jdorfman',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/jdorfman/awesome-json-datasets'},
#  {'Sr No': 114,
#   'Repository Name': 'Sync',
#   'User Name': '3lvis',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/3lvis/Sync'},
#  {'Sr No': 115,
#   'Repository Name': 'scalatra',
#   'User Name': 'scalatra',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/scalatra/scalatra'},
#  {'Sr No': 116,
#   'Repository Name': 'webdis',
#   'User Name': 'nicolasff',
#   'stars': '2.6k',
#   'Repository URL': 'https://github.com/nicolasff/webdis'},
#  {'Sr No': 117,
#   'Repository Name': 'serialize-javascript',
#   'User Name': 'yahoo',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/yahoo/serialize-javascript'},
#  {'Sr No': 118,
#   'Repository Name': 'jsonform',
#   'User Name': 'jsonform',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/jsonform/jsonform'},
#  {'Sr No': 119,
#   'Repository Name': 'jsonbox',
#   'User Name': 'vasanthv',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/vasanthv/jsonbox'},
#  {'Sr No': 120,
#   'Repository Name': 'json-c',
#   'User Name': 'json-c',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/json-c/json-c'},
#  {'Sr No': 121,
#   'Repository Name': 'data_location',
#   'User Name': 'mumuy',
#   'stars': '2.5k',
#   'Repository URL': 'https://github.com/mumuy/data_location'},
#  {'Sr No': 122,
#   'Repository Name': 'django-import-export',
#   'User Name': 'django-import-export',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/django-import-export/django-import-export'},
#  {'Sr No': 123,
#   'Repository Name': 'dsq',
#   'User Name': 'multiprocessio',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/multiprocessio/dsq'},
#  {'Sr No': 124,
#   'Repository Name': 'hjson',
#   'User Name': 'hjson',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/hjson/hjson'},
#  {'Sr No': 125,
#   'Repository Name': 'wretch',
#   'User Name': 'elbywan',
#   'stars': '2.4k',
#   'Repository URL': 'https://github.com/elbywan/wretch'},
#  {'Sr No': 126,
#   'Repository Name': 'mojo',
#   'User Name': 'mojolicious',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/mojolicious/mojo'},
#  {'Sr No': 127,
#   'Repository Name': 'Osiris',
#   'User Name': 'danielkrupinski',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/danielkrupinski/Osiris'},
#  {'Sr No': 128,
#   'Repository Name': 'circe',
#   'User Name': 'circe',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/circe/circe'},
#  {'Sr No': 129,
#   'Repository Name': 'neo',
#   'User Name': 'neomjs',
#   'stars': '2.3k',
#   'Repository URL': 'https://github.com/neomjs/neo'},
#  {'Sr No': 130,
#   'Repository Name': 'sql-generator',
#   'User Name': 'liyupi',
#   'stars': '2.7k',
#   'Repository URL': 'https://github.com/liyupi/sql-generator'},
#  {'Sr No': 131,
#   'Repository Name': 'know-your-http-well',
#   'User Name': 'for-GET',
#   'stars': '2.2k',
#   'Repository URL': 'https://github.com/for-GET/know-your-http-well'},
#  {'Sr No': 132,
#   'Repository Name': 'serializer',
#   'User Name': 'symfony',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/symfony/serializer'},
#  {'Sr No': 133,
#   'Repository Name': 'yyjson',
#   'User Name': 'ibireme',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/ibireme/yyjson'},
#  {'Sr No': 134,
#   'Repository Name': 'logstash-logback-encoder',
#   'User Name': 'logfellow',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/logfellow/logstash-logback-encoder'},
#  {'Sr No': 135,
#   'Repository Name': 'rq',
#   'User Name': 'dflemstr',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/dflemstr/rq'},
#  {'Sr No': 136,
#   'Repository Name': 'awesome-resume-for-chinese',
#   'User Name': 'dyweb',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/dyweb/awesome-resume-for-chinese'},
#  {'Sr No': 137,
#   'Repository Name': 'jackson-core',
#   'User Name': 'FasterXML',
#   'stars': '2.1k',
#   'Repository URL': 'https://github.com/FasterXML/jackson-core'},
#  {'Sr No': 138,
#   'Repository Name': 'stash',
#   'User Name': 'stashapp',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/stashapp/stash'},
#  {'Sr No': 139,
#   'Repository Name': 'gojay',
#   'User Name': 'francoispqt',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/francoispqt/gojay'},
#  {'Sr No': 140,
#   'Repository Name': 'nano',
#   'User Name': 'lonng',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/lonng/nano'},
#  {'Sr No': 141,
#   'Repository Name': 'Unbox',
#   'User Name': 'JohnSundell',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/JohnSundell/Unbox'},
#  {'Sr No': 142,
#   'Repository Name': 'generatedata',
#   'User Name': 'benkeen',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/benkeen/generatedata'},
#  {'Sr No': 143,
#   'Repository Name': 'node-convict',
#   'User Name': 'mozilla',
#   'stars': '2k',
#   'Repository URL': 'https://github.com/mozilla/node-convict'},
#  {'Sr No': 144,
#   'Repository Name': 'httpexpect',
#   'User Name': 'gavv',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/gavv/httpexpect'},
#  {'Sr No': 145,
#   'Repository Name': 'poison',
#   'User Name': 'devinus',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/devinus/poison'},
#  {'Sr No': 146,
#   'Repository Name': 'yq',
#   'User Name': 'kislyuk',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/kislyuk/yq'},
#  {'Sr No': 147,
#   'Repository Name': 'gojsonq',
#   'User Name': 'thedevsaddam',
#   'stars': '1.9k',
#   'Repository URL': 'https://github.com/thedevsaddam/gojsonq'},
#  {'Sr No': 148,
#   'Repository Name': 'JSON-Splora',
#   'User Name': 'wellsjo',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/wellsjo/JSON-Splora'},
#  {'Sr No': 149,
#   'Repository Name': 'jwt',
#   'User Name': 'jwt-dotnet',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/jwt-dotnet/jwt'},
#  {'Sr No': 150,
#   'Repository Name': 'uvicorn-gunicorn-fastapi-docker',
#   'User Name': 'tiangolo',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/tiangolo/uvicorn-gunicorn-fastapi-docker'},
#  {'Sr No': 151,
#   'Repository Name': 'fastjson2',
#   'User Name': 'alibaba',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/alibaba/fastjson2'},
#  {'Sr No': 152,
#   'Repository Name': 'funiture',
#   'User Name': 'kanwangzjm',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/kanwangzjm/funiture'},
#  {'Sr No': 153,
#   'Repository Name': 'protostuff',
#   'User Name': 'protostuff',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/protostuff/protostuff'},
#  {'Sr No': 154,
#   'Repository Name': 'schema-registry',
#   'User Name': 'confluentinc',
#   'stars': '1.8k',
#   'Repository URL': 'https://github.com/confluentinc/schema-registry'},
#  {'Sr No': 155,
#   'Repository Name': 'klaxon',
#   'User Name': 'cbeust',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/cbeust/klaxon'},
#  {'Sr No': 156,
#   'Repository Name': 'tesla',
#   'User Name': 'elixir-tesla',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/elixir-tesla/tesla'},
#  {'Sr No': 157,
#   'Repository Name': 'WebApiClient',
#   'User Name': 'dotnetcore',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/dotnetcore/WebApiClient'},
#  {'Sr No': 158,
#   'Repository Name': 'unqlite',
#   'User Name': 'symisc',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/symisc/unqlite'},
#  {'Sr No': 159,
#   'Repository Name': 'json-rules-engine',
#   'User Name': 'CacheControl',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/CacheControl/json-rules-engine'},
#  {'Sr No': 160,
#   'Repository Name': 'killedbygoogle',
#   'User Name': 'codyogden',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/codyogden/killedbygoogle'},
#  {'Sr No': 161,
#   'Repository Name': 'sjson',
#   'User Name': 'tidwall',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/tidwall/sjson'},
#  {'Sr No': 162,
#   'Repository Name': 'tanka',
#   'User Name': 'grafana',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/grafana/tanka'},
#  {'Sr No': 163,
#   'Repository Name': 'quicktype-xcode',
#   'User Name': 'quicktype',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/quicktype/quicktype-xcode'},
#  {'Sr No': 164,
#   'Repository Name': 'ISO-3166-Countries-with-Regional-Codes',
#   'User Name': 'lukes',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/lukes/ISO-3166-Countries-with-Regional-Codes'},
#  {'Sr No': 165,
#   'Repository Name': 'Gloss',
#   'User Name': 'hkellaway',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/hkellaway/Gloss'},
#  {'Sr No': 166,
#   'Repository Name': 'radon',
#   'User Name': 'radondb',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/radondb/radon'},
#  {'Sr No': 167,
#   'Repository Name': 'hibernate-types',
#   'User Name': 'vladmihalcea',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/vladmihalcea/hibernate-types'},
#  {'Sr No': 168,
#   'Repository Name': 'render',
#   'User Name': 'unrolled',
#   'stars': '1.7k',
#   'Repository URL': 'https://github.com/unrolled/render'},
#  {'Sr No': 169,
#   'Repository Name': 'facil.io',
#   'User Name': 'boazsegev',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/boazsegev/facil.io'},
#  {'Sr No': 170,
#   'Repository Name': 'go-json',
#   'User Name': 'goccy',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/goccy/go-json'},
#  {'Sr No': 171,
#   'Repository Name': 'widelands',
#   'User Name': 'widelands',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/widelands/widelands'},
#  {'Sr No': 172,
#   'Repository Name': 'fastjson',
#   'User Name': 'valyala',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/valyala/fastjson'},
#  {'Sr No': 173,
#   'Repository Name': 'flask-restx',
#   'User Name': 'python-restx',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/python-restx/flask-restx'},
#  {'Sr No': 174,
#   'Repository Name': 'finch',
#   'User Name': 'finagle',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/finagle/finch'},
#  {'Sr No': 175,
#   'Repository Name': 'mockit',
#   'User Name': 'boyney123',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/boyney123/mockit'},
#  {'Sr No': 176,
#   'Repository Name': 'fast-xml-parser',
#   'User Name': 'NaturalIntelligence',
#   'stars': '1.6k',
#   'Repository URL': 'https://github.com/NaturalIntelligence/fast-xml-parser'},
#  {'Sr No': 177,
#   'Repository Name': 'tabtoy',
#   'User Name': 'davyxu',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/davyxu/tabtoy'},
#  {'Sr No': 178,
#   'Repository Name': 'just-dashboard',
#   'User Name': 'kantord',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/kantord/just-dashboard'},
#  {'Sr No': 179,
#   'Repository Name': 'spectral',
#   'User Name': 'stoplightio',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/stoplightio/spectral'},
#  {'Sr No': 180,
#   'Repository Name': 'utils',
#   'User Name': 'nette',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/nette/utils'},
#  {'Sr No': 181,
#   'Repository Name': 'simplejson',
#   'User Name': 'simplejson',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/simplejson/simplejson'},
#  {'Sr No': 182,
#   'Repository Name': 'fast-serialization',
#   'User Name': 'RuedigerMoeller',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/RuedigerMoeller/fast-serialization'},
#  {'Sr No': 183,
#   'Repository Name': 'config-rs',
#   'User Name': 'mehcode',
#   'stars': '1.5k',
#   'Repository URL': 'https://github.com/mehcode/config-rs'},
#  {'Sr No': 184,
#   'Repository Name': 'feedparser',
#   'User Name': 'kurtmckee',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/kurtmckee/feedparser'},
#  {'Sr No': 185,
#   'Repository Name': 'dprint',
#   'User Name': 'dprint',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/dprint/dprint'},
#  {'Sr No': 186,
#   'Repository Name': 'json4s',
#   'User Name': 'json4s',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/json4s/json4s'},
#  {'Sr No': 187,
#   'Repository Name': 'yar',
#   'User Name': 'laruence',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/laruence/yar'},
#  {'Sr No': 188,
#   'Repository Name': 'null',
#   'User Name': 'guregu',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/guregu/null'},
#  {'Sr No': 189,
#   'Repository Name': 'jsonmapper',
#   'User Name': 'cweiske',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/cweiske/jsonmapper'},
#  {'Sr No': 190,
#   'Repository Name': 'gojq',
#   'User Name': 'itchyny',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/itchyny/gojq'},
#  {'Sr No': 191,
#   'Repository Name': 'java',
#   'User Name': 'json-iterator',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/json-iterator/java'},
#  {'Sr No': 192,
#   'Repository Name': 'jam-api',
#   'User Name': 'dinubs',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/dinubs/jam-api'},
#  {'Sr No': 193,
#   'Repository Name': 'summitdb',
#   'User Name': 'tidwall',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/tidwall/summitdb'},
#  {'Sr No': 194,
#   'Repository Name': 'jason',
#   'User Name': 'michalmuskala',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/michalmuskala/jason'},
#  {'Sr No': 195,
#   'Repository Name': 'json_resume',
#   'User Name': 'prat0318',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/prat0318/json_resume'},
#  {'Sr No': 196,
#   'Repository Name': 'excel2json',
#   'User Name': 'neil3d',
#   'stars': '1.4k',
#   'Repository URL': 'https://github.com/neil3d/excel2json'},
#  {'Sr No': 197,
#   'Repository Name': 'electron-json-storage',
#   'User Name': 'electron-userland',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/electron-userland/electron-json-storage'},
#  {'Sr No': 198,
#   'Repository Name': 'catj',
#   'User Name': 'soheilpro',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/soheilpro/catj'},
#  {'Sr No': 199,
#   'Repository Name': 'Spots',
#   'User Name': 'zenangst',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/zenangst/Spots'},
#  {'Sr No': 200,
#   'Repository Name': 'news-please',
#   'User Name': 'fhamborg',
#   'stars': '1.3k',
#   'Repository URL': 'https://github.com/fhamborg/news-please'}]

# %%
import pandas as pd

# %%
df=pd.DataFrame(All_Repository_lst)

# %%
df
# Out:
#      Sr No        Repository Name          User Name  stars  \
# 0        1                fastapi           tiangolo  46.9k
# 1        2               prettier           prettier  43.3k
# 2        3         chinese-poetry     chinese-poetry  36.6k
# 3        4                   json           nlohmann  30.8k
# 4        5                sheetjs            SheetJS  30.6k
# ..     ...                    ...                ...    ...
# 195    196             excel2json             neil3d   1.4k
# 196    197  electron-json-storage  electron-userland   1.3k
# 197    198                   catj          soheilpro   1.3k
# 198    199                  Spots           zenangst   1.3k
# 199    200            news-please           fhamborg   1.3k
#
#                                         Repository URL
# 0                  https://github.com/tiangolo/fastapi
# 1                 https://github.com/prettier/prettier
# 2     https://github.com/chinese-poetry/chinese-poetry
# 3                     https://github.com/nlohmann/json
# 4                   https://github.com/SheetJS/sheetjs
# ..                                                 ...
# 195               https://github.com/neil3d/excel2json
# 196  https://github.com/electron-userland/electron-...
# 197                  https://github.com/soheilpro/catj
# 198                  https://github.com/zenangst/Spots
# 199            https://github.com/fhamborg/news-please
#
# [200 rows x 5 columns]

# %%
df.to_excel('200_json_re.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\SAURABH TUNGAR'
